# %% [markdown]
# <a href="https://colab.research.google.com/github/ipeirotis/dealing_with_data/blob/master/02-WebAPIs/B2-Google_Natural_Language_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interacting with the Google Cloud Natural Language API
#
# Another useful API, especially when dealing with text, is the [Google Cloud Natural Language API](https://cloud.google.com/natural-language), which offers a variety of text analysis functionalities, such as sentiment analysis, entity extraction, keyword extraction, etc.
#
# We will give a couple of examples below, to understand how we can take an unstructured piece of text (either the text alone, or a URL with text), and extract some "semi-structured" representation of its content.
#
#
#
# ## /analyzeSentiment call
#
# We will first start with the `/analyzeSentiment` API call ([documentation](https://cloud.google.com/natural-language/docs/analyzing-sentiment) & also [here](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeSentiment)) which takes as input a piece of text, and returns an analysis across various dimensions.
#
# The call below gets as input a "text" variable, and returns back the sentiment of the text.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
with open('/content/drive/My Drive/api_keys.json') as f:
    api_keys = json.load(f)

# %%
import requests

def analyze_sentiment(text, api_key):
    url = f"https://language.googleapis.com/v1/documents:analyzeSentiment?key={api_key}"

    data = {
        "document": {
            "type": "PLAIN_TEXT",
            "content": text
        },
        "encodingType": "UTF8"
    }

    response = requests.post(url, json=data)

    return response.json()

# %%
# We will analyze the text below using the IBM Watson API

text = '''
I got their Egg & Cheese sandwich on a Whole Wheat Everything Bagel. 
First off, I loved loved loved the texture of the bagel itself. 
It was very chewy yet soft, which is a top feature for a NY style bagel. 
However, I thought there could've been more seasoning on top of 
the bagel as I found the bagel itself to be a bit bland. 

Speaking of bland, I thought the egg and cheese filling were also quite bland. 
This was definitely lacking salt and pepper in the eggs and the cheese didn't
really add too much flavor either, which was really disappointing! 
My mom also had the same complaint with her bagel sandwich 
(she had the egg sandwich on a blueberry bagel) so I definitely wasn't 
the only one.

'''

# %%
data = analyze_sentiment(text, api_keys['google_nlp_api_key'])

# %% [markdown]
# Now, let's try to understand the structure of the answer. First, we check the high-level keys.

# %%
data.keys()
# Out:
# dict_keys(['documentSentiment', 'language', 'sentences'])

# %% [markdown]
# Now, let's check the content of these keys:

# %%
data['documentSentiment']
# Out:
# {'magnitude': 5.1, 'score': -0.1}

# %%
# Let's go deeper into the 'sentence'
data['sentences']
# Out:
# [{'text': {'content': 'I got their Egg & Cheese sandwich on a Whole Wheat Everything Bagel.',
#    'beginOffset': 1},
#   'sentiment': {'magnitude': 0.3, 'score': 0.3}},
#  {'text': {'content': 'First off, I loved loved loved the texture of the bagel itself.',
#    'beginOffset': 71},
#   'sentiment': {'magnitude': 0.9, 'score': 0.9}},
#  {'text': {'content': 'It was very chewy yet soft, which is a top feature for a NY style bagel.',
#    'beginOffset': 136},
#   'sentiment': {'magnitude': 0.9, 'score': 0.9}},
#  {'text': {'content': "However, I thought there could've been more seasoning on top of \nthe bagel as I found the bagel itself to be a bit bland.",
#    'beginOffset': 210},
#   'sentiment': {'magnitude': 0.7, 'score': -0.7}},
#  {'text': {'content': 'Speaking of bland, I thought the egg and cheese filling were also quite bland.',
#    'beginOffset': 334},
#   'sentiment': {'magnitude': 0.8, 'score': -0.8}},
#  {'text': {'content': "This was definitely lacking salt and pepper in the eggs and the cheese didn't\nreally add too much flavor either, which was really disappointing!",
#    'beginOffset': 414},
#   'sentiment': {'magnitude': 0.7, 'score': -0.7}},
#  {'text': {'content': "My mom also had the same complaint with her bagel sandwich \n(she had the egg sandwich on a blueberry bagel) so I definitely wasn't \nthe only one.",
#    'beginOffset': 560},
#   'sentiment': {'magnitude': 0.7, 'score': -0.7}}]

# %%
# And a bit more
print(f"The sentiment in this text is {data['documentSentiment']['score']}")
# Out:
# The sentiment in this text is -0.1

# %% [markdown]
# ### Exercise
#
# Type your own piece of text, and analyze it to extract sentiment. Discuss your findings

# %% [markdown]
# ## Entities call
#
# [Full Documentation of the call](https://cloud.google.com/natural-language/docs/reference/rest/v1/documents/analyzeEntities)
#
# This is a an API call that extracts entities from the text, and also the sentiment for each of these entities.
#
# In terms of natural language processing, we will examine a couple of capabilities of the API. First, you will see that there is the capability of "normalizing" each entity, so that two different ways of saying the same thing get mapped to the same entity. So for example, "President Biden" and "Joe Biden" get mapped to the same Knowledge Graph entity.

# %%
import requests

def extract_entities(url_to_analyze, api_key):
    html_content = requests.get(url_to_analyze).text
    url = f"https://language.googleapis.com/v1/documents:analyzeEntities?key={api_key}"

    data = {
        "document": {
            "type": "HTML",
            "content": html_content
        },
        "encodingType": "UTF8"
    }

    response = requests.post(url, json=data)
    return response.json()

# %%
url_to_analyze = 'https://www.reuters.com/lifestyle/elvis-everything-everywhere-vie-oscar-nods-tuesday-2023-01-24/'

data = extract_entities(url_to_analyze, api_keys['google_nlp_api_key'])

# %%
# Let's see what we get back as top-level attributes
data.keys()
# Out:
# dict_keys(['entities', 'language'])

# %%
# Let' see the entities list
data['entities']
# Out:
# [{'name': 'tab',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.7716946,
#   'mentions': [{'text': {'content': 'tab', 'beginOffset': 131167},
#     'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 135093}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 138259}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 141531}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 144749}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 147935}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 151101}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 154286}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 157797}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 160953}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 171199}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 174574}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 177931}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 181618}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 185007}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 188411}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 192161}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 195327}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 198636}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 201782}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 204954}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 208160}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 211303}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 214489}, 'type': 'COMMON'},
#    {'text': {'content': 'tab', 'beginOffset': 217643}, 'type': 'COMMON'}]},
#  {'name': 'Thomson Reuters',
#   'type': 'ORGANIZATION',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Reuters',
#    'mid': '/m/0ps53'},
#   'salience': 0.014524409,
#   'mentions': [{'text': {'content': 'Reuters', 'beginOffset': 161},
#     'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 18626}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 63415}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 131862}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 132337}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 145168}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 148334}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 151513}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 161542}, 'type': 'PROPER'},
#    {'text': {'content': 'division', 'beginOffset': 161570}, 'type': 'COMMON'},
#    {'text': {'content': 'multimedia news provider', 'beginOffset': 161624},
#     'type': 'COMMON'},
#    {'text': {'content': 'Reuters', 'beginOffset': 161699}, 'type': 'PROPER'},
#    {'text': {'content': 'Thomson Reuters', 'beginOffset': 168066},
#     'type': 'PROPER'},
#    {'text': {'content': 'Reuters', 'beginOffset': 218394}, 'type': 'PROPER'},
#    {'text': {'content': 'REUTERS', 'beginOffset': 77900}, 'type': 'PROPER'},
#    {'text': {'content': 'Reuters News Agency', 'beginOffset': 138763},
#     'type': 'PROPER'}]},
#  {'name': 'Box office hits',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0077313827,
#   'mentions': [{'text': {'content': 'Box office hits', 'beginOffset': 44},
#     'type': 'COMMON'}]},
#  {'name': 'The Banshees of Inisherin',
#   'type': 'OTHER',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/The_Banshees_of_Inisherin',
#    'mid': '/g/11qgfbm_lz'},
#   'salience': 0.0074512972,
#   'mentions': [{'text': {'content': 'The Banshees of Inisherin',
#      'beginOffset': 65007},
#     'type': 'PROPER'},
#    {'text': {'content': 'Banshees', 'beginOffset': 75280}, 'type': 'PROPER'},
#    {'text': {'content': 'Banshees', 'beginOffset': 86009}, 'type': 'PROPER'},
#    {'text': {'content': 'Banshees', 'beginOffset': 86068}, 'type': 'PROPER'},
#    {'text': {'content': 'Banshees', 'beginOffset': 86453}, 'type': 'PROPER'},
#    {'text': {'content': 'Banshees', 'beginOffset': 87071}, 'type': 'PROPER'}]},
#  {'name': 'return',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.0070678266,
#   'mentions': [{'text': {'content': 'return', 'beginOffset': 70558},
#     'type': 'COMMON'},
#    {'text': {'content': 'return', 'beginOffset': 106663}, 'type': 'COMMON'}]},
#  {'name': 'Everything Everywhere',
#   'type': 'WORK_OF_ART',
#   'metadata': {'mid': '/g/11frq9yk7v',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Everything_Everywhere_All_at_Once'},
#   'salience': 0.006849018,
#   'mentions': [{'text': {'content': 'Everything Everywhere',
#      'beginOffset': 66},
#     'type': 'PROPER'},
#    {'text': {'content': 'Everything Everywhere', 'beginOffset': 49720},
#     'type': 'PROPER'},
#    {'text': {'content': 'Everything Everywhere', 'beginOffset': 63908},
#     'type': 'PROPER'},
#    {'text': {'content': 'Everything Everywhere All at Once',
#      'beginOffset': 63460},
#     'type': 'PROPER'},
#    {'text': {'content': 'Everything Everywhere All at Once',
#      'beginOffset': 77766},
#     'type': 'PROPER'},
#    {'text': {'content': 'Everything Everywhere', 'beginOffset': 82439},
#     'type': 'PROPER'},
#    {'text': {'content': 'Everything Everywhere', 'beginOffset': 83635},
#     'type': 'PROPER'}]},
#  {'name': 'academy',
#   'type': 'ORGANIZATION',
#   'metadata': {},
#   'salience': 0.0049005235,
#   'mentions': [{'text': {'content': 'academy', 'beginOffset': 66739},
#     'type': 'COMMON'},
#    {'text': {'content': 'academy', 'beginOffset': 99465}, 'type': 'COMMON'}]},
#  {'name': 'Avatar: The Way of Water',
#   'type': 'WORK_OF_ART',
#   'metadata': {'mid': '/m/0gmbk1g',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water'},
#   'salience': 0.0046095755,
#   'mentions': [{'text': {'content': 'Avatar: The Way of Water',
#      'beginOffset': 64408},
#     'type': 'PROPER'},
#    {'text': {'content': 'spectacle', 'beginOffset': 64468},
#     'type': 'COMMON'}]},
#  {'name': 'Austin Butler',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Austin_Butler',
#    'mid': '/m/03d6k8m'},
#   'salience': 0.004507687,
#   'mentions': [{'text': {'content': 'Austin Butler', 'beginOffset': 75122},
#     'type': 'PROPER'},
#    {'text': {'content': 'Butler', 'beginOffset': 81597}, 'type': 'PROPER'},
#    {'text': {'content': 'Butler', 'beginOffset': 82037}, 'type': 'PROPER'}]},
#  {'name': 'nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0038678749,
#   'mentions': [{'text': {'content': 'nominations', 'beginOffset': 147},
#     'type': 'COMMON'}]},
#  {'name': 'Will Smith',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Will_Smith',
#    'mid': '/m/0147dk'},
#   'salience': 0.0037401277,
#   'mentions': [{'text': {'content': 'Will Smith', 'beginOffset': 73532},
#     'type': 'PROPER'},
#    {'text': {'content': 'Smith', 'beginOffset': 84838}, 'type': 'PROPER'}]},
#  {'name': 'Box office hits',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0036265266,
#   'mentions': [{'text': {'content': 'Box office hits', 'beginOffset': 49698},
#     'type': 'COMMON'}]},
#  {'name': 'TV viewers',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0030869409,
#   'mentions': [{'text': {'content': 'TV viewers', 'beginOffset': 73188},
#     'type': 'COMMON'},
#    {'text': {'content': 'ones', 'beginOffset': 73221}, 'type': 'COMMON'}]},
#  {'name': 'Riseborough',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/02qv816',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Andrea_Riseborough'},
#   'salience': 0.0028814387,
#   'mentions': [{'text': {'content': 'Riseborough', 'beginOffset': 66798},
#     'type': 'PROPER'},
#    {'text': {'content': 'nominee', 'beginOffset': 66790}, 'type': 'COMMON'},
#    {'text': {'content': 'Riseborough', 'beginOffset': 99524},
#     'type': 'PROPER'},
#    {'text': {'content': 'nominee', 'beginOffset': 99516}, 'type': 'COMMON'}]},
#  {'name': 'Avatar',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0027246503,
#   'mentions': [{'text': {'content': 'Avatar', 'beginOffset': 123},
#     'type': 'COMMON'}]},
#  {'name': 'people',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0024320227,
#   'mentions': [{'text': {'content': 'people', 'beginOffset': 83188},
#     'type': 'COMMON'},
#    {'text': {'content': 'people', 'beginOffset': 83598}, 'type': 'COMMON'}]},
#  {'name': 'Elvis',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Elvis_Presley',
#    'mid': '/m/02jq1'},
#   'salience': 0.0023742313,
#   'mentions': [{'text': {'content': 'Elvis', 'beginOffset': 101},
#     'type': 'PROPER'},
#    {'text': {'content': 'Elvis', 'beginOffset': 49755}, 'type': 'PROPER'},
#    {'text': {'content': 'Elvis', 'beginOffset': 64809}, 'type': 'PROPER'},
#    {'text': {'content': 'Elvis Presley', 'beginOffset': 75169},
#     'type': 'PROPER'},
#    {'text': {'content': 'rock legend', 'beginOffset': 75157},
#     'type': 'COMMON'},
#    {'text': {'content': 'Elvis', 'beginOffset': 81659}, 'type': 'PROPER'}]},
#  {'name': 'All Quiet on the Western Front',
#   'type': 'WORK_OF_ART',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/All_Quiet_on_the_Western_Front_(2022_film)',
#    'mid': '/g/11rd5hjfmm'},
#   'salience': 0.0023726863,
#   'mentions': [{'text': {'content': 'All Quiet on the Western Front',
#      'beginOffset': 72223},
#     'type': 'PROPER'},
#    {'text': {'content': 'All Quiet on the Western Front',
#      'beginOffset': 87016},
#     'type': 'PROPER'}]},
#  {'name': 'land',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.0023146784,
#   'mentions': [{'text': {'content': 'land', 'beginOffset': 136},
#     'type': 'COMMON'}]},
#  {'name': 'academy',
#   'type': 'ORGANIZATION',
#   'metadata': {},
#   'salience': 0.0022356862,
#   'mentions': [{'text': {'content': 'academy', 'beginOffset': 83159},
#     'type': 'COMMON'}]},
#  {'name': 'screen',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0021136785,
#   'mentions': [{'text': {'content': 'screen', 'beginOffset': 70599},
#     'type': 'COMMON'},
#    {'text': {'content': 'screen', 'beginOffset': 106704}, 'type': 'COMMON'}]},
#  {'name': 'Lisa Marie Presley',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/0qlry',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Lisa_Marie_Presley'},
#   'salience': 0.0020456514,
#   'mentions': [{'text': {'content': 'daughter', 'beginOffset': 81672},
#     'type': 'COMMON'},
#    {'text': {'content': 'Lisa Marie Presley', 'beginOffset': 81681},
#     'type': 'PROPER'}]},
#  {'name': 'fandom',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0019280997,
#   'mentions': [{'text': {'content': 'fandom', 'beginOffset': 70540},
#     'type': 'COMMON'},
#    {'text': {'content': 'fandom', 'beginOffset': 106645}, 'type': 'COMMON'}]},
#  {'name': 'Oscar',
#   'type': 'OTHER',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Academy_Awards',
#    'mid': '/m/0g_w'},
#   'salience': 0.0018289468,
#   'mentions': [{'text': {'content': 'Oscar', 'beginOffset': 141},
#     'type': 'PROPER'},
#    {'text': {'content': 'Oscar', 'beginOffset': 49795}, 'type': 'PROPER'},
#    {'text': {'content': 'Oscar', 'beginOffset': 73980}, 'type': 'PROPER'},
#    {'text': {'content': 'Academy Awards', 'beginOffset': 64371},
#     'type': 'PROPER'},
#    {'text': {'content': 'Academy Awards', 'beginOffset': 73502},
#     'type': 'PROPER'},
#    {'text': {'content': 'Oscar', 'beginOffset': 66784}, 'type': 'PROPER'},
#    {'text': {'content': 'Oscar', 'beginOffset': 99510}, 'type': 'PROPER'},
#    {'text': {'content': 'Oscars', 'beginOffset': 73126}, 'type': 'PROPER'},
#    {'text': {'content': 'Oscars', 'beginOffset': 74084}, 'type': 'PROPER'},
#    {'text': {'content': 'Oscars', 'beginOffset': 84957}, 'type': 'PROPER'}]},
#  {'name': 'nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.001809429,
#   'mentions': [{'text': {'content': 'nominations', 'beginOffset': 49801},
#     'type': 'COMMON'}]},
#  {'name': 'nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0018060046,
#   'mentions': [{'text': {'content': 'nominations', 'beginOffset': 64042},
#     'type': 'COMMON'}]},
#  {'name': 'film academy',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0017144587,
#   'mentions': [{'text': {'content': 'film academy', 'beginOffset': 63595},
#     'type': 'COMMON'}]},
#  {'name': 'people',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0016436267,
#   'mentions': [{'text': {'content': 'people', 'beginOffset': 74828},
#     'type': 'COMMON'}]},
#  {'name': 'films',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0016396554,
#   'mentions': [{'text': {'content': 'films', 'beginOffset': 64327},
#     'type': 'COMMON'}]},
#  {'name': 'Oscars',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0016365732,
#   'mentions': [{'text': {'content': 'Oscars', 'beginOffset': 63568},
#     'type': 'COMMON'}]},
#  {'name': 'news',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0015077309,
#   'mentions': [{'text': {'content': 'news', 'beginOffset': 15399},
#     'type': 'COMMON'}]},
#  {'name': 'Lifestyle',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0014822517,
#   'mentions': [{'text': {'content': 'Lifestyle', 'beginOffset': 48530},
#     'type': 'COMMON'}]},
#  {'name': 'Chris Rock',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/016_mj',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Chris_Rock'},
#   'salience': 0.0013767241,
#   'mentions': [{'text': {'content': 'Chris Rock', 'beginOffset': 73561},
#     'type': 'PROPER'},
#    {'text': {'content': 'presenter', 'beginOffset': 73551}, 'type': 'COMMON'},
#    {'text': {'content': 'Rock', 'beginOffset': 84992}, 'type': 'PROPER'}]},
#  {'name': 'Swamp Thing',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0013715902,
#   'mentions': [{'text': {'content': 'Swamp Thing', 'beginOffset': 70574},
#     'type': 'PROPER'},
#    {'text': {'content': 'article', 'beginOffset': 70782}, 'type': 'COMMON'},
#    {'text': {'content': 'Swamp Thing', 'beginOffset': 106679},
#     'type': 'PROPER'}]},
#  {'name': 'World',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.001368419,
#   'mentions': [{'text': {'content': 'World', 'beginOffset': 27333},
#     'type': 'COMMON'}]},
#  {'name': 'movies',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0013483095,
#   'mentions': [{'text': {'content': 'movies', 'beginOffset': 63519},
#     'type': 'COMMON'}]},
#  {'name': 'movie',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0013467302,
#   'mentions': [{'text': {'content': 'movie', 'beginOffset': 64529},
#     'type': 'COMMON'}]},
#  {'name': 'data',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.001297385,
#   'mentions': [{'text': {'content': 'data', 'beginOffset': 15405},
#     'type': 'COMMON'}]},
#  {'name': 'Business',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0012884872,
#   'mentions': [{'text': {'content': 'Business', 'beginOffset': 28084},
#     'type': 'COMMON'}]},
#  {'name': 'Markets',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0012845112,
#   'mentions': [{'text': {'content': 'Markets', 'beginOffset': 29584},
#     'type': 'COMMON'}]},
#  {'name': 'View',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0012775507,
#   'mentions': [{'text': {'content': 'View', 'beginOffset': 32790},
#     'type': 'COMMON'}]},
#  {'name': 'content',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0012123232,
#   'mentions': [{'text': {'content': 'content', 'beginOffset': 15005},
#     'type': 'COMMON'}]},
#  {'name': 'market professionals',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0012080413,
#   'mentions': [{'text': {'content': 'market professionals',
#      'beginOffset': 15438},
#     'type': 'COMMON'}]},
#  {'name': 'Technology',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0011931045,
#   'mentions': [{'text': {'content': 'Technology', 'beginOffset': 30615},
#     'type': 'COMMON'}]},
#  {'name': 'hits',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.001184364,
#   'mentions': [{'text': {'content': 'hits', 'beginOffset': 63637},
#     'type': 'COMMON'}]},
#  {'name': 'list',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.001184364,
#   'mentions': [{'text': {'content': 'list', 'beginOffset': 63511},
#     'type': 'COMMON'}]},
#  {'name': 'acting nods',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0011836535,
#   'mentions': [{'text': {'content': 'acting nods', 'beginOffset': 64087},
#     'type': 'COMMON'}]},
#  {'name': 'gallery',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0011104591,
#   'mentions': [{'text': {'content': 'gallery', 'beginOffset': 99725},
#     'type': 'COMMON'},
#    {'text': {'content': 'gallery', 'beginOffset': 120387}, 'type': 'COMMON'}]},
#  {'name': 'Breakingviews',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.0010895134,
#   'mentions': [{'text': {'content': 'Breakingviews', 'beginOffset': 30316},
#     'type': 'COMMON'}]},
#  {'name': 'Investigations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0010870728,
#   'mentions': [{'text': {'content': 'Investigations', 'beginOffset': 31376},
#     'type': 'COMMON'}]},
#  {'name': 'land',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.0010816643,
#   'mentions': [{'text': {'content': 'land', 'beginOffset': 49790},
#     'type': 'COMMON'}]},
#  {'name': 'adventure',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0010802634,
#   'mentions': [{'text': {'content': 'adventure', 'beginOffset': 63444},
#     'type': 'COMMON'}]},
#  {'name': 'Michelle Yeoh',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Michelle_Yeoh',
#    'mid': '/m/012ykt'},
#   'salience': 0.0010745716,
#   'mentions': [{'text': {'content': 'Michelle Yeoh', 'beginOffset': 77666},
#     'type': 'PROPER'},
#    {'text': {'content': 'Michelle Yeoh', 'beginOffset': 82472},
#     'type': 'PROPER'},
#    {'text': {'content': 'star', 'beginOffset': 82467}, 'type': 'COMMON'},
#    {'text': {'content': 'Yeoh', 'beginOffset': 83669}, 'type': 'PROPER'}]},
#  {'name': 'Martin McDonagh',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/040rjq',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Martin_McDonagh'},
#   'salience': 0.0010480914,
#   'mentions': [{'text': {'content': 'Martin McDonagh', 'beginOffset': 86477},
#     'type': 'PROPER'},
#    {'text': {'content': 'director', 'beginOffset': 86468}, 'type': 'COMMON'},
#    {'text': {'content': 'nominee', 'beginOffset': 86501}, 'type': 'COMMON'}]},
#  {'name': 'analytics',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00096784584,
#   'mentions': [{'text': {'content': 'analytics', 'beginOffset': 15414},
#     'type': 'COMMON'}]},
#  {'name': 'home',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.0009651925,
#   'mentions': [{'text': {'content': 'home', 'beginOffset': 18634},
#     'type': 'COMMON'}]},
#  {'name': 'Register',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0009522347,
#   'mentions': [{'text': {'content': 'Register', 'beginOffset': 34161},
#     'type': 'COMMON'}]},
#  {'name': 'best picture prize',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00094887044,
#   'mentions': [{'text': {'content': 'best picture prize',
#      'beginOffset': 63661},
#     'type': 'COMMON'}]},
#  {'name': 'science-fiction flick',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00094830105,
#   'mentions': [{'text': {'content': 'science-fiction flick',
#      'beginOffset': 63939},
#     'type': 'COMMON'}]},
#  {'name': 'immigrant',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00094830105,
#   'mentions': [{'text': {'content': 'immigrant', 'beginOffset': 63990},
#     'type': 'COMMON'}]},
#  {'name': 'taxes',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00094830105,
#   'mentions': [{'text': {'content': 'taxes', 'beginOffset': 64025},
#     'type': 'COMMON'}]},
#  {'name': 'hunt',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.00094775844,
#   'mentions': [{'text': {'content': 'hunt', 'beginOffset': 64340},
#     'type': 'COMMON'}]},
#  {'name': 'trophy',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00094775844,
#   'mentions': [{'text': {'content': 'trophy', 'beginOffset': 64357},
#     'type': 'COMMON'}]},
#  {'name': 'sequel',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00094775844,
#   'mentions': [{'text': {'content': 'sequel', 'beginOffset': 64395},
#     'type': 'COMMON'}]},
#  {'name': 'Colin Farrell',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Colin_Farrell',
#    'mid': '/m/01wxyx1'},
#   'salience': 0.0009470002,
#   'mentions': [{'text': {'content': 'Colin Farrell', 'beginOffset': 75188},
#     'type': 'PROPER'}]},
#  {'name': 'picture',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0009433188,
#   'mentions': [{'text': {'content': 'picture', 'beginOffset': 64070},
#     'type': 'COMMON'}]},
#  {'name': 'Avatar',
#   'type': 'WORK_OF_ART',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Avatar_(franchise)',
#    'mid': '/g/11c6cfy20n'},
#   'salience': 0.0009339577,
#   'mentions': [{'text': {'content': 'Avatar', 'beginOffset': 49777},
#     'type': 'COMMON'},
#    {'text': {'content': 'Avatar', 'beginOffset': 85989}, 'type': 'PROPER'}]},
#  {'name': 'Titanic',
#   'type': 'WORK_OF_ART',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Titanic_(1997_film)',
#    'mid': '/m/0dr_4'},
#   'salience': 0.0008523671,
#   'mentions': [{'text': {'content': 'Titanic', 'beginOffset': 74132},
#     'type': 'PROPER'},
#    {'text': {'content': 'megahit', 'beginOffset': 74118}, 'type': 'COMMON'}]},
#  {'name': 'Ana de Armas',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/09g99cj',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Ana_de_Armas'},
#   'salience': 0.0008091975,
#   'mentions': [{'text': {'content': 'Ana de Armas', 'beginOffset': 84527},
#     'type': 'PROPER'},
#    {'text': {'content': 'actress', 'beginOffset': 84519}, 'type': 'COMMON'}]},
#  {'name': 'Jimmy Kimmel',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Jimmy_Kimmel',
#    'mid': '/m/02238b'},
#   'salience': 0.0008027817,
#   'mentions': [{'text': {'content': 'Jimmy Kimmel', 'beginOffset': 72619},
#     'type': 'PROPER'},
#    {'text': {'content': 'comedian', 'beginOffset': 72610}, 'type': 'COMMON'}]},
#  {'name': 'actors',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00077359646,
#   'mentions': [{'text': {'content': 'actors', 'beginOffset': 82821},
#     'type': 'COMMON'}]},
#  {'name': 'Cate Blanchett',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/0154qm',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Cate_Blanchett'},
#   'salience': 0.000738834,
#   'mentions': [{'text': {'content': 'Cate Blanchett', 'beginOffset': 82313},
#     'type': 'PROPER'}]},
#  {'name': 'Hollywood',
#   'type': 'LOCATION',
#   'metadata': {'mid': '/m/0f2wj',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Hollywood,_Los_Angeles'},
#   'salience': 0.00070005143,
#   'mentions': [{'text': {'content': 'Hollywood', 'beginOffset': 63578},
#     'type': 'PROPER'}]},
#  {'name': 'LOS ANGELES',
#   'type': 'LOCATION',
#   'metadata': {'mid': '/m/030qb3t',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Los_Angeles'},
#   'salience': 0.0006384846,
#   'mentions': [{'text': {'content': 'LOS ANGELES', 'beginOffset': 63394},
#     'type': 'PROPER'}]},
#  {'name': 'article',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00063501525,
#   'mentions': [{'text': {'content': 'article', 'beginOffset': 66986},
#     'type': 'COMMON'}]},
#  {'name': 'Ke Huy Quan',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Ke_Huy_Quan',
#    'mid': '/m/01nfsr'},
#   'salience': 0.00062024227,
#   'mentions': [{'text': {'content': 'Ke Huy Quan', 'beginOffset': 83693},
#     'type': 'PROPER'},
#    {'text': {'content': 'child star', 'beginOffset': 83708}, 'type': 'COMMON'},
#    {'text': {'content': 'Quan', 'beginOffset': 84123}, 'type': 'PROPER'}]},
#  {'name': 'Scott Feinberg',
#   'type': 'PERSON',
#   'metadata': {'mid': '/g/11fmd7dznj'},
#   'salience': 0.0005711333,
#   'mentions': [{'text': {'content': 'Scott Feinberg', 'beginOffset': 74010},
#     'type': 'PROPER'},
#    {'text': {'content': 'awards editor', 'beginOffset': 74026},
#     'type': 'COMMON'},
#    {'text': {'content': 'Feinberg', 'beginOffset': 74498}, 'type': 'PROPER'}]},
#  {'name': 'Chinese',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.0005604496,
#   'mentions': [{'text': {'content': 'Chinese', 'beginOffset': 63982},
#     'type': 'PROPER'}]},
#  {'name': 'James Cameron',
#   'type': 'PERSON',
#   'metadata': {'mid': '/m/03_gd',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/James_Cameron'},
#   'salience': 0.00056012877,
#   'mentions': [{'text': {'content': 'James Cameron', 'beginOffset': 64440},
#     'type': 'PROPER'}]},
#  {'name': 'Lifestylecategory',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0005577388,
#   'mentions': [{'text': {'content': 'Lifestyle<span style="border:0;clip:rect(0 0 0 0);clip-path:inset(50%);height:1px;margin:0 -1px -1px 0;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap">category',
#      'beginOffset': 66224},
#     'type': 'COMMON'}]},
#  {'name': 'Lifestylecategory',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0005574696,
#   'mentions': [{'text': {'content': 'Lifestyle<span style="border:0;clip:rect(0 0 0 0);clip-path:inset(50%);height:1px;margin:0 -1px -1px 0;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap">category',
#      'beginOffset': 70038},
#     'type': 'COMMON'}]},
#  {'name': 'Tom Cruise',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Tom_Cruise',
#    'mid': '/m/07r1h'},
#   'salience': 0.0005396473,
#   'mentions': [{'text': {'content': 'Tom Cruise', 'beginOffset': 75321},
#     'type': 'PROPER'},
#    {'text': {'content': 'star', 'beginOffset': 75316}, 'type': 'COMMON'}]},
#  {'name': 'Film',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00053440547,
#   'mentions': [{'text': {'content': 'Film', 'beginOffset': 66734},
#     'type': 'COMMON'}]},
#  {'name': 'Top Gun: Maverick',
#   'type': 'WORK_OF_ART',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Top_Gun:_Maverick',
#    'mid': '/m/0mztk28'},
#   'salience': 0.00052923214,
#   'mentions': [{'text': {'content': 'Top Gun: Maverick', 'beginOffset': 64775},
#     'type': 'PROPER'},
#    {'text': {'content': 'Top Gun', 'beginOffset': 75302}, 'type': 'PROPER'}]},
#  {'name': 'dark comedy',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.000509202,
#   'mentions': [{'text': {'content': 'dark comedy', 'beginOffset': 64989},
#     'type': 'COMMON'}]},
#  {'name': 'gallery',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0005086796,
#   'mentions': [{'text': {'content': 'gallery', 'beginOffset': 66999},
#     'type': 'COMMON'}]},
#  {'name': 'image',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0005084341,
#   'mentions': [{'text': {'content': 'image', 'beginOffset': 70795},
#     'type': 'COMMON'}]},
#  {'name': 'Thomson Reuters Trust Principles',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00050438545,
#   'mentions': [{'text': {'content': 'Standards', 'beginOffset': 95183},
#     'type': 'COMMON'},
#    {'text': {'content': 'Thomson Reuters Trust Principles',
#      'beginOffset': 95427},
#     'type': 'PROPER'}]},
#  {'name': 'Emancipation',
#   'type': 'WORK_OF_ART',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Emancipation_(2022_film)',
#    'mid': '/g/11rs2n1smq'},
#   'salience': 0.00049941376,
#   'mentions': [{'text': {'content': 'Emancipation', 'beginOffset': 84880},
#     'type': 'PROPER'},
#    {'text': {'content': 'slavery drama', 'beginOffset': 84860},
#     'type': 'COMMON'}]},
#  {'name': 'industry',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00047896928,
#   'mentions': [{'text': {'content': 'industry', 'beginOffset': 72529},
#     'type': 'COMMON'}]},
#  {'name': 'TV viewers',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0004785762,
#   'mentions': [{'text': {'content': 'TV viewers', 'beginOffset': 73623},
#     'type': 'COMMON'}]},
#  {'name': 'nomination',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00046743097,
#   'mentions': [{'text': {'content': 'nomination', 'beginOffset': 84551},
#     'type': 'COMMON'}]},
#  {'name': 'nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00046688283,
#   'mentions': [{'text': {'content': 'nominations', 'beginOffset': 85934},
#     'type': 'COMMON'}]},
#  {'name': 'acting nominees',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00046206368,
#   'mentions': [{'text': {'content': 'acting nominees', 'beginOffset': 83577},
#     'type': 'COMMON'}]},
#  {'name': 'nominees',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0004579108,
#   'mentions': [{'text': {'content': 'nominees', 'beginOffset': 74876},
#     'type': 'COMMON'}]},
#  {'name': 'drama',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00044722718,
#   'mentions': [{'text': {'content': 'drama', 'beginOffset': 64953},
#     'type': 'COMMON'}]},
#  {'name': 'list',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00044614545,
#   'mentions': [{'text': {'content': 'list', 'beginOffset': 72287},
#     'type': 'COMMON'}]},
#  {'name': 'actor',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00042942996,
#   'mentions': [{'text': {'content': 'actor', 'beginOffset': 73592},
#     'type': 'COMMON'}]},
#  {'name': 'nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00042338457,
#   'mentions': [{'text': {'content': 'nominations', 'beginOffset': 85026},
#     'type': 'COMMON'}]},
#  {'name': 'nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0004232853,
#   'mentions': [{'text': {'content': 'nominations', 'beginOffset': 85319},
#     'type': 'COMMON'}]},
#  {'name': 'acting nominations',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00042299848,
#   'mentions': [{'text': {'content': 'acting nominations',
#      'beginOffset': 86095},
#     'type': 'COMMON'}]},
#  {'name': 'updates',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00040766987,
#   'mentions': [{'text': {'content': 'Updates', 'beginOffset': 65518},
#     'type': 'COMMON'}]},
#  {'name': 'Winners',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00040672117,
#   'mentions': [{'text': {'content': 'Winners', 'beginOffset': 72514},
#     'type': 'COMMON'}]},
#  {'name': 'ceremony',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.00040672117,
#   'mentions': [{'text': {'content': 'ceremony', 'beginOffset': 72591},
#     'type': 'COMMON'}]},
#  {'name': 'honors',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00040672117,
#   'mentions': [{'text': {'content': 'honors', 'beginOffset': 72553},
#     'type': 'COMMON'}]},
#  {'name': 'network',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00040672117,
#   'mentions': [{'text': {'content': 'network', 'beginOffset': 72892},
#     'type': 'COMMON'}]},
#  {'name': 'ceremony',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.00040638735,
#   'mentions': [{'text': {'content': 'ceremony', 'beginOffset': 73517},
#     'type': 'COMMON'}]},
#  {'name': 'Lisa Richwine',
#   'type': 'PERSON',
#   'metadata': {'mid': '/g/11f04rrkth'},
#   'salience': 0.00038046154,
#   'mentions': [{'text': {'content': 'Lisa Richwine', 'beginOffset': 50102},
#     'type': 'PROPER'},
#    {'text': {'content': 'Lisa Richwine', 'beginOffset': 87305},
#     'type': 'PROPER'}]},
#  {'name': 'DC Comics',
#   'type': 'ORGANIZATION',
#   'metadata': {'mid': '/m/02hvd',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/DC_Comics'},
#   'salience': 0.00037899512,
#   'mentions': [{'text': {'content': 'DC Comics', 'beginOffset': 70530},
#     'type': 'PROPER'},
#    {'text': {'content': 'DC Comics', 'beginOffset': 106635},
#     'type': 'PROPER'}]},
#  {'name': 'Derek Carr',
#   'type': 'PERSON',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/Derek_Carr',
#    'mid': '/m/080kqfc'},
#   'salience': 0.0003744159,
#   'mentions': [{'text': {'content': 'Derek Carr', 'beginOffset': 124219},
#     'type': 'PROPER'},
#    {'text': {'content': 'QB', 'beginOffset': 124216}, 'type': 'COMMON'}]},
#  {'name': 'award',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00037408102,
#   'mentions': [{'text': {'content': 'award', 'beginOffset': 77695},
#     'type': 'COMMON'}]},
#  {'name': 'films',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00035930163,
#   'mentions': [{'text': {'content': 'films', 'beginOffset': 73910},
#     'type': 'COMMON'}]},
#  {'name': 'Comedy Motion Picture',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00035842753,
#   'mentions': [{'text': {'content': 'Comedy Motion Picture',
#      'beginOffset': 77734},
#     'type': 'COMMON'}]},
#  {'name': 'cut',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00035823442,
#   'mentions': [{'text': {'content': 'cut', 'beginOffset': 64884},
#     'type': 'COMMON'}]},
#  {'name': 'blockbusters',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00035823442,
#   'mentions': [{'text': {'content': 'blockbusters', 'beginOffset': 64856},
#     'type': 'COMMON'}]},
#  {'name': 'stories',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0003575279,
#   'mentions': [{'text': {'content': 'stories', 'beginOffset': 71528},
#     'type': 'COMMON'}]},
#  {'name': 'remake',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00035736786,
#   'mentions': [{'text': {'content': 'remake', 'beginOffset': 72207},
#     'type': 'COMMON'}]},
#  {'name': 'awards shows',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.00035706442,
#   'mentions': [{'text': {'content': 'awards shows', 'beginOffset': 73143},
#     'type': 'COMMON'}]},
#  {'name': 'audience',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00035692027,
#   'mentions': [{'text': {'content': 'audience', 'beginOffset': 73655},
#     'type': 'COMMON'}]},
#  {'name': 'image',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00035331649,
#   'mentions': [{'text': {'content': 'image', 'beginOffset': 104729},
#     'type': 'COMMON'},
#    {'text': {'content': 'image', 'beginOffset': 106900}, 'type': 'COMMON'}]},
#  {'name': 'Walt Disney Co',
#   'type': 'ORGANIZATION',
#   'metadata': {'mid': '/m/09b3v',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/The_Walt_Disney_Company'},
#   'salience': 0.00034723186,
#   'mentions': [{'text': {'content': 'Walt Disney Co', 'beginOffset': 72650},
#     'type': 'PROPER'},
#    {'text': {'content': 'Disney', 'beginOffset': 85909}, 'type': 'PROPER'}]},
#  {'name': 'awards',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00034621372,
#   'mentions': [{'text': {'content': 'awards', 'beginOffset': 85042},
#     'type': 'COMMON'}]},
#  {'name': 'art house movies',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00034200138,
#   'mentions': [{'text': {'content': 'art house movies', 'beginOffset': 73947},
#     'type': 'COMMON'}]},
#  {'name': 'movies',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00033343333,
#   'mentions': [{'text': {'content': 'movies', 'beginOffset': 74400},
#     'type': 'COMMON'}]},
#  {'name': 'picture',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00033157173,
#   'mentions': [{'text': {'content': 'picture', 'beginOffset': 85617},
#     'type': 'COMMON'}]},
#  {'name': 'best actress',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00032532983,
#   'mentions': [{'text': {'content': 'best actress', 'beginOffset': 82299},
#     'type': 'COMMON'}]},
#  {'name': 'movies',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00031553485,
#   'mentions': [{'text': {'content': 'movies', 'beginOffset': 85966},
#     'type': 'COMMON'}]},
#  {'name': 'portrayal',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0003028999,
#   'mentions': [{'text': {'content': 'portrayal', 'beginOffset': 82347},
#     'type': 'COMMON'}]},
#  {'name': 'producers',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00030281607,
#   'mentions': [{'text': {'content': 'producers', 'beginOffset': 82829},
#     'type': 'COMMON'}]},
#  {'name': 'actor',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00030257553,
#   'mentions': [{'text': {'content': 'actor', 'beginOffset': 83826},
#     'type': 'COMMON'}]},
#  {'name': 'nods',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00029993325,
#   'mentions': [{'text': {'content': 'nods', 'beginOffset': 74855},
#     'type': 'COMMON'}]},
#  {'name': 'portrayal',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00029983209,
#   'mentions': [{'text': {'content': 'portrayal', 'beginOffset': 75144},
#     'type': 'COMMON'}]},
#  {'name': 'actress',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0002979941,
#   'mentions': [{'text': {'content': 'actress', 'beginOffset': 84420},
#     'type': 'COMMON'}]},
#  {'name': 'article',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00029569192,
#   'mentions': [{'text': {'content': 'article', 'beginOffset': 120374},
#     'type': 'COMMON'}]},
#  {'name': 'article',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00029564305,
#   'mentions': [{'text': {'content': 'article', 'beginOffset': 122271},
#     'type': 'COMMON'}]},
#  {'name': 'article',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00029559483,
#   'mentions': [{'text': {'content': 'article', 'beginOffset': 124434},
#     'type': 'COMMON'}]},
#  {'name': 'Best Actress in a Musical',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00028134105,
#   'mentions': [{'text': {'content': 'Best Actress in a Musical',
#      'beginOffset': 77705},
#     'type': 'PROPER'}]},
#  {'name': 'argument',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00027794487,
#   'mentions': [{'text': {'content': 'argument', 'beginOffset': 171398},
#     'type': 'COMMON'}]},
#  {'name': 'statement',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0002775172,
#   'mentions': [{'text': {'content': 'statement', 'beginOffset': 84138},
#     'type': 'COMMON'}]},
#  {'name': 'drama',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00027718535,
#   'mentions': [{'text': {'content': 'drama', 'beginOffset': 85652},
#     'type': 'COMMON'}]},
#  {'name': 'nods',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00027706125,
#   'mentions': [{'text': {'content': 'nods', 'beginOffset': 86133},
#     'type': 'COMMON'}]},
#  {'name': 'statement',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00027688325,
#   'mentions': [{'text': {'content': 'statement', 'beginOffset': 86520},
#     'type': 'COMMON'}]},
#  {'name': 'age',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00027640682,
#   'mentions': [{'text': {'content': 'age', 'beginOffset': 81742},
#     'type': 'COMMON'}]},
#  {'name': 'Winners',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00027617207,
#   'mentions': [{'text': {'content': 'Winners', 'beginOffset': 82774},
#     'type': 'COMMON'}]},
#  {'name': 'directors',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00027617207,
#   'mentions': [{'text': {'content': 'directors', 'beginOffset': 82840},
#     'type': 'COMMON'}]},
#  {'name': 'color',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00027609736,
#   'mentions': [{'text': {'content': 'color', 'beginOffset': 83198},
#     'type': 'COMMON'}]},
#  {'name': 'women',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00027609736,
#   'mentions': [{'text': {'content': 'women', 'beginOffset': 83178},
#     'type': 'COMMON'}]},
#  {'name': 'color',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00027602425,
#   'mentions': [{'text': {'content': 'color', 'beginOffset': 83608},
#     'type': 'COMMON'}]},
#  {'name': 'honors',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00027383605,
#   'mentions': [{'text': {'content': 'honors', 'beginOffset': 74156},
#     'type': 'COMMON'}]},
#  {'name': 'public',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0002737354,
#   'mentions': [{'text': {'content': 'public', 'beginOffset': 74440},
#     'type': 'COMMON'}]},
#  {'name': 'public',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.0002737354,
#   'mentions': [{'text': {'content': 'public', 'beginOffset': 74428},
#     'type': 'COMMON'}]},
#  {'name': 'The Fabelmans',
#   'type': 'WORK_OF_ART',
#   'metadata': {'mid': '/g/11nxfw3yns',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/The_Fabelmans'},
#   'salience': 0.00027221264,
#   'mentions': [{'text': {'content': 'The Fabelmans', 'beginOffset': 64965},
#     'type': 'PROPER'},
#    {'text': {'content': 'The Fabelmans', 'beginOffset': 82517},
#     'type': 'PROPER'}]},
#  {'name': 'Lifestyle',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00025917756,
#   'mentions': [{'text': {'content': 'Lifestyle', 'beginOffset': 131541},
#     'type': 'COMMON'}]},
#  {'name': 'Newsletters',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0002585479,
#   'mentions': [{'text': {'content': 'Newsletters', 'beginOffset': 158193},
#     'type': 'COMMON'}]},
#  {'name': 'news',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00025845907,
#   'mentions': [{'text': {'content': 'news', 'beginOffset': 161555},
#     'type': 'COMMON'}]},
#  {'name': 'news',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00025843,
#   'mentions': [{'text': {'content': 'news', 'beginOffset': 161764},
#     'type': 'COMMON'}]},
#  {'name': 'turn',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00025303548,
#   'mentions': [{'text': {'content': 'turn', 'beginOffset': 84570},
#     'type': 'COMMON'}]},
#  {'name': 'services',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.000252854,
#   'mentions': [{'text': {'content': 'services', 'beginOffset': 85367},
#     'type': 'COMMON'}]},
#  {'name': 'service',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00025246802,
#   'mentions': [{'text': {'content': 'service', 'beginOffset': 86763},
#     'type': 'COMMON'}]},
#  {'name': 'SportscategoryReport',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00024874439,
#   'mentions': [{'text': {'content': 'Sports<span style="border:0;clip:rect(0 0 0 0);clip-path:inset(50%);height:1px;margin:0 -1px -1px 0;overflow:hidden;padding:0;position:absolute;width:1px;white-space:nowrap">category</span></a></span><a data-testid="Heading" href="/lifestyle/sports/report-raiders-qb-derek-carr-not-permitted-seek-trade-2023-02-01/" class="text__text__1FZLe text__dark-grey__3Ml43 text__medium__1kbOh text__heading_5_and_half__3YluN heading__base__2T28j heading_5_half media-story-card__heading__eqhp9"><span>Report',
#      'beginOffset': 123708},
#     'type': 'COMMON'}]},
#  {'name': 'Diversity Report',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00024787482,
#   'mentions': [{'text': {'content': 'Diversity Report', 'beginOffset': 151521},
#     'type': 'COMMON'}]},
#  {'name': 'OscarsSoWhite',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00024726902,
#   'mentions': [{'text': {'content': 'OscarsSoWhite', 'beginOffset': 83228},
#     'type': 'PROPER'}]},
#  {'name': 'Screen',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0002454144,
#   'mentions': [{'text': {'content': 'Screen', 'beginOffset': 188590},
#     'type': 'COMMON'}]},
#  {'name': 'total',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00024494957,
#   'mentions': [{'text': {'content': 'total', 'beginOffset': 85949},
#     'type': 'COMMON'}]},
#  {'name': 'Ramonda',
#   'type': 'PERSON',
#   'metadata': {'mid': '/g/11ggb3ndbf'},
#   'salience': 0.0002445843,
#   'mentions': [{'text': {'content': 'Ramonda', 'beginOffset': 84446},
#     'type': 'PROPER'},
#    {'text': {'content': 'Queen', 'beginOffset': 84440}, 'type': 'COMMON'}]},
#  {'name': 'cardiac arrest',
#   'type': 'EVENT',
#   'metadata': {},
#   'salience': 0.0002427565,
#   'mentions': [{'text': {'content': 'cardiac arrest', 'beginOffset': 81724},
#     'type': 'COMMON'}]},
#  {'name': 'reaction',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0002427565,
#   'mentions': [{'text': {'content': 'reaction', 'beginOffset': 81626},
#     'type': 'COMMON'}]},
#  {'name': 'performance',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0002427565,
#   'mentions': [{'text': {'content': 'performance', 'beginOffset': 81642},
#     'type': 'COMMON'}]},
#  {'name': 'others',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00024261748,
#   'mentions': [{'text': {'content': 'others', 'beginOffset': 82544},
#     'type': 'COMMON'}]},
#  {'name': 'orchestra conductor',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00024261748,
#   'mentions': [{'text': {'content': 'orchestra conductor',
#      'beginOffset': 82375},
#     'type': 'COMMON'}]},
#  {'name': 'film craftspeople',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00024255035,
#   'mentions': [{'text': {'content': 'film craftspeople', 'beginOffset': 82854},
#     'type': 'COMMON'}]},
#  {'name': 'membership',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0002424847,
#   'mentions': [{'text': {'content': 'membership', 'beginOffset': 83285},
#     'type': 'COMMON'}]},
#  {'name': 'ranks',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0002424847,
#   'mentions': [{'text': {'content': 'ranks', 'beginOffset': 83211},
#     'type': 'COMMON'}]},
#  {'name': 'uproars',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.0002424847,
#   'mentions': [{'text': {'content': 'uproars', 'beginOffset': 83242},
#     'type': 'COMMON'}]},
#  {'name': 'front-runner',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00024235765,
#   'mentions': [{'text': {'content': 'front-runner', 'beginOffset': 83793},
#     'type': 'COMMON'}]},
#  {'name': 'ratings',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00024058978,
#   'mentions': [{'text': {'content': 'ratings', 'beginOffset': 73986},
#     'type': 'COMMON'}]},
#  {'name': 'tunes',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00024041023,
#   'mentions': [{'text': {'content': 'tunes', 'beginOffset': 74466},
#     'type': 'COMMON'}]},
#  {'name': 'Tar',
#   'type': 'OTHER',
#   'metadata': {'mid': '/g/11qh3_pnm9',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Tár'},
#   'salience': 0.0002404086,
#   'mentions': [{'text': {'content': 'Tar', 'beginOffset': 72124},
#     'type': 'PROPER'},
#    {'text': {'content': 'Tar', 'beginOffset': 82404}, 'type': 'PROPER'}]},
#  {'name': 'success',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00024032443,
#   'mentions': [{'text': {'content': 'success', 'beginOffset': 74547},
#     'type': 'COMMON'}]},
#  {'name': 'anything',
#   'type': 'OTHER',
#   'metadata': {},
#   'salience': 0.00024032443,
#   'mentions': [{'text': {'content': 'anything', 'beginOffset': 74566},
#     'type': 'COMMON'}]},
#  {'name': 'farmer',
#   'type': 'PERSON',
#   'metadata': {},
#   'salience': 0.00024016004,
#   'mentions': [{'text': {'content': 'farmer', 'beginOffset': 75227},
#     'type': 'COMMON'}]},
#  {'name': 'field',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.00024008118,
#   'mentions': [{'text': {'content': 'field', 'beginOffset': 75357},
#     'type': 'COMMON'}]},
#  {'name': 'image',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.00023680442,
#   'mentions': [{'text': {'content': 'image', 'beginOffset': 122284},
#     'type': 'COMMON'}]},
#  {'name': 'image',
#   'type': 'WORK_OF_ART',
#   'metadata': {},
#   'salience': 0.0002367658,
#   'mentions': [{'text': {'content': 'image', 'beginOffset': 124447},
#     'type': 'COMMON'}]},
#  {'name': 'World',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.00023665295,
#   'mentions': [{'text': {'content': 'World', 'beginOffset': 126128},
#     'type': 'COMMON'}]},
#  {'name': 'world',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.00023571673,
#   'mentions': [{'text': {'content': 'world', 'beginOffset': 161606},
#     'type': 'COMMON'}]},
#  {'name': 'world',
#   'type': 'LOCATION',
#   'metadata': {},
#   'salience': 0.00023569021,
#   'mentions': [{'text': {'content': 'world', 'beginOffset': 161813},
#     'type': 'COMMON'}]},
#  {'name': 'The Hollywood Reporter',
#   'type': 'ORGANIZATION',
#   'metadata': {'wikipedia_url': 'https://en.wikipedia.org/wiki/The_Hollywood_Reporter',
#    'mid': '/m/03cg25'},
#   'salience': 0.00023108836,
#   'mentions': [{'text': {'content': 'The Hollywood Reporter',
#      'beginOffset': 74043},
#     'type': 'PROPER'},
#    {'text': {'content': 'Hollywood Reporter', 'beginOffset': 82053},
#     'type': 'PROPER'}]},
#  {'name': 'Business',
# ...
#  {'name': 'VfL Wolfsburg 2-1',
#   'type': 'ORGANIZATION',
#   'metadata': {'mid': '/m/049f05',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/VfL_Wolfsburg'},
#   'salience': 3.6964797e-05,
#   'mentions': [{'text': {'content': 'Wolfsburg', 'beginOffset': 112148},
#     'type': 'PROPER'},
#    {'text': {'content': 'VfL Wolfsburg 2-1', 'beginOffset': 113015},
#     'type': 'PROPER'}]},
#  {'name': 'SoccerNewcastle',
#   'type': 'ORGANIZATION',
#   'metadata': {},
#   'salience': 2.41703e-05,
#   'mentions': [{'text': {'content': 'Soccer</span></span><a data-testid="Heading" href="/lifestyle/sports/newcastle-see-off-southampton-reach-league-cup-final-2023-01-31/" class="text__text__1FZLe text__dark-grey__3Ml43 text__medium__1kbOh text__heading_5_and_half__3YluN heading__base__2T28j heading_5_half media-story-card__heading__eqhp9"><span>Newcastle',
#      'beginOffset': 119831},
#     'type': 'PROPER'}]},
#  {'name': '2023. REUTERS',
#   'type': 'PHONE_NUMBER',
#   'metadata': {'number': '3738837',
#    'national_prefix': '1',
#    'area_code': '202'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023. REUTERS', 'beginOffset': 77894},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 24, 20236:09 PM UTC',
#   'type': 'DATE',
#   'metadata': {'day': '24', 'year': '2023', 'month': '1'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 24, 20236:09 PM UTC',
#      'beginOffset': 49358},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'Jan 24',
#   'type': 'DATE',
#   'metadata': {'day': '24', 'month': '1'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'Jan 24', 'beginOffset': 63407},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'March 12',
#   'type': 'DATE',
#   'metadata': {'month': '3', 'day': '12'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'March 12', 'beginOffset': 72582},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 10, 2023',
#   'type': 'DATE',
#   'metadata': {'month': '1', 'year': '2023', 'day': '10'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 10, 2023', 'beginOffset': 77882},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2015',
#   'type': 'DATE',
#   'metadata': {'year': '2015'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2015', 'beginOffset': 83253},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2016',
#   'type': 'DATE',
#   'metadata': {'year': '2016'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2016', 'beginOffset': 83262},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'month': '1', 'day': '31', 'year': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 99970},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'month': '1', 'day': '31', 'year': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 102777},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'day': '31', 'year': '2023', 'month': '1'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 104972},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'month': '1', 'year': '2023', 'day': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 107143},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'year': '2023', 'month': '1', 'day': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 112733},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'month': '1', 'day': '31', 'year': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 116846},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'year': '2023', 'month': '1', 'day': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 120632},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'DATE',
#   'metadata': {'year': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 122090},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'January 31, 2023',
#   'type': 'DATE',
#   'metadata': {'month': '1', 'year': '2023', 'day': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'January 31, 2023', 'beginOffset': 122527},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'DATE',
#   'metadata': {'year': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 218389},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '1',
#   'type': 'NUMBER',
#   'metadata': {'value': '1'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '1', 'beginOffset': 112128},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '12',
#   'type': 'NUMBER',
#   'metadata': {'value': '12'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '12', 'beginOffset': 124690},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 122535},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '80',
#   'type': 'NUMBER',
#   'metadata': {'value': '80'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '80', 'beginOffset': 76370},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2',
#   'type': 'NUMBER',
#   'metadata': {'value': '2'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2', 'beginOffset': 113029},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 102785},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 116854},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '15',
#   'type': 'NUMBER',
#   'metadata': {'value': '15'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '15', 'beginOffset': 124693},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 122539},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '1/5',
#   'type': 'NUMBER',
#   'metadata': {'value': '0.200000'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '1/5', 'beginOffset': 77648},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 112745},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '4',
#   'type': 'NUMBER',
#   'metadata': {'value': '4'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '4', 'beginOffset': 49301},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '11',
#   'type': 'NUMBER',
#   'metadata': {'value': '11'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '11', 'beginOffset': 64039},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 99982},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'nine',
#   'type': 'NUMBER',
#   'metadata': {'value': '9'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'nine', 'beginOffset': 86120},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'nine',
#   'type': 'NUMBER',
#   'metadata': {'value': '9'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'nine', 'beginOffset': 87091},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '15',
#   'type': 'NUMBER',
#   'metadata': {'value': '15'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '15', 'beginOffset': 217905},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '10',
#   'type': 'NUMBER',
#   'metadata': {'value': '10'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '10', 'beginOffset': 84968},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 122090},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '1984',
#   'type': 'NUMBER',
#   'metadata': {'value': '1984'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '1984', 'beginOffset': 83722},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '24',
#   'type': 'NUMBER',
#   'metadata': {'value': '24'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '24', 'beginOffset': 49366},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '12',
#   'type': 'NUMBER',
#   'metadata': {'value': '12'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '12', 'beginOffset': 72588},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'two',
#   'type': 'NUMBER',
#   'metadata': {'value': '2'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'two', 'beginOffset': 64822},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2015',
#   'type': 'NUMBER',
#   'metadata': {'value': '2015'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2015', 'beginOffset': 83253},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 218389},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '25',
#   'type': 'NUMBER',
#   'metadata': {'value': '25'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '25', 'beginOffset': 74102},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '1',
#   'type': 'NUMBER',
#   'metadata': {'value': '1'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '1', 'beginOffset': 113031},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 77894},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '10,000',
#   'type': 'NUMBER',
#   'metadata': {'value': '10000'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '10,000', 'beginOffset': 82814},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '10',
#   'type': 'NUMBER',
#   'metadata': {'value': '10'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '10', 'beginOffset': 72276},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 99978},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '20',
#   'type': 'NUMBER',
#   'metadata': {'value': '20'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '20', 'beginOffset': 74825},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 120640},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'four',
#   'type': 'NUMBER',
#   'metadata': {'value': '4'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'four', 'beginOffset': 64082},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '10',
#   'type': 'NUMBER',
#   'metadata': {'value': '10'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '10', 'beginOffset': 77890},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '1',
#   'type': 'NUMBER',
#   'metadata': {'value': '1'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '1', 'beginOffset': 79133},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 102789},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 104980},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'Sixteen',
#   'type': 'NUMBER',
#   'metadata': {'value': '16'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'Sixteen', 'beginOffset': 74810},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'four',
#   'type': 'NUMBER',
#   'metadata': {'value': '4'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'four', 'beginOffset': 86090},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 112741},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '22',
#   'type': 'NUMBER',
#   'metadata': {'value': '22'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '22', 'beginOffset': 85958},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '31',
#   'type': 'NUMBER',
#   'metadata': {'value': '31'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '31', 'beginOffset': 107151},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2',
#   'type': 'NUMBER',
#   'metadata': {'value': '2'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2', 'beginOffset': 79529},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '3',
#   'type': 'NUMBER',
#   'metadata': {'value': '3'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '3', 'beginOffset': 79925},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 116858},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '15.4 million',
#   'type': 'NUMBER',
#   'metadata': {'value': '15400000.000000'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '15.4 million', 'beginOffset': 73610},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2',
#   'type': 'NUMBER',
#   'metadata': {'value': '2'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2', 'beginOffset': 71521},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '24',
#   'type': 'NUMBER',
#   'metadata': {'value': '24'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '24', 'beginOffset': 63411},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 104984},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2016',
#   'type': 'NUMBER',
#   'metadata': {'value': '2016'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2016', 'beginOffset': 83262},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'eight',
#   'type': 'NUMBER',
#   'metadata': {'value': '8'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'eight', 'beginOffset': 112178},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 120644},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '09',
#   'type': 'NUMBER',
#   'metadata': {'value': '9'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '09', 'beginOffset': 49420},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '54',
#   'type': 'NUMBER',
#   'metadata': {'value': '54'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '54', 'beginOffset': 81746},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '5',
#   'type': 'NUMBER',
#   'metadata': {'value': '5'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '5', 'beginOffset': 80717},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '20',
#   'type': 'NUMBER',
#   'metadata': {'value': '20'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '20', 'beginOffset': 83574},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '80',
#   'type': 'NUMBER',
#   'metadata': {'value': '80'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '80', 'beginOffset': 77814},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '4',
#   'type': 'NUMBER',
#   'metadata': {'value': '4'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '4', 'beginOffset': 80321},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2023',
#   'type': 'NUMBER',
#   'metadata': {'value': '2023'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2023', 'beginOffset': 107155},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': 'seven',
#   'type': 'NUMBER',
#   'metadata': {'value': '7'},
#   'salience': 0,
#   'mentions': [{'text': {'content': 'seven', 'beginOffset': 83561},
#     'type': 'TYPE_UNKNOWN'}]},
#  {'name': '2',
#   'type': 'NUMBER',
#   'metadata': {'value': '2'},
#   'salience': 0,
#   'mentions': [{'text': {'content': '2', 'beginOffset': 112126},
#     'type': 'TYPE_UNKNOWN'}]}]

# %%
# This function takes as input the result
# from the IBM Watson API and returns a list
# of entities that are relevant (above threshold)
# to the article
def getEntities(data, threshold):
    result = []
    for entity in data["entities"]:
        relevance = float(entity['salience'])
        if relevance > threshold:
            result.append(entity['name'])
    return result

getEntities(data, 0.002)
# Out:
# ['tab',
#  'Thomson Reuters',
#  'Box office hits',
#  'The Banshees of Inisherin',
#  'return',
#  'Everything Everywhere',
#  'academy',
#  'Avatar: The Way of Water',
#  'Austin Butler',
#  'nominations',
#  'Will Smith',
#  'Box office hits',
#  'TV viewers',
#  'Riseborough',
#  'Avatar',
#  'people',
#  'Elvis',
#  'All Quiet on the Western Front',
#  'land',
#  'academy',
#  'screen',
#  'Lisa Marie Presley']

# %% [markdown]
# ### Exercise 2
# Now let's try to use the classify content tool to the content type of a website. You can find the documentation [here](https://cloud.google.com/natural-language/docs/categories) and [here](https://cloud.google.com/natural-language/docs/reference/rest/v1/ClassificationCategory).

# %%
# ADD YOUR CODE HERE
