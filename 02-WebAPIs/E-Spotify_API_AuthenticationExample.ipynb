# %% [markdown]
# <a href="https://colab.research.google.com/github/ipeirotis/dealing_with_data/blob/master/02-WebAPIs/E-Spotify_API_AuthenticationExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %% [markdown]
# We are going to use the "Client Credentials Flow" from https://developer.spotify.com/web-api/authorization-guide/#client_credentials_flow

# %%
# We first create an app on https://developer.spotify.com
# and we get the client ID and client secret
# NOTE/PANOS: I have disabled my client_secret.
# Please register and get your own credentials if you want to run the code
client_id = 'f50bb3a5dd0946fdb02c6c6459d69aea'
client_secret = '3e72b403842a4713afef76c5aefddbe0'

# %%
# We use the "Client Credentials Flow" from https://developer.spotify.com/web-api/authorization-guide/#client_credentials_flow
# We will submit the client id and client secret, to get back our "access token"
body_params = {'grant_type' : 'client_credentials'}
url = 'https://accounts.spotify.com/api/token'
auth_data = requests.post(url, data=body_params, auth=(client_id, client_secret)).json()
auth_data
# Out:
# {'access_token': 'BQCbUleYuobY2UKq2MKw7x4aRb1NWhHX4YhI-ndQqKhRbBpqEhFprzj0ySdSq0eSu2pjMSLXOIOf720SVdV4Ys2szpK0YW4g6qerXb1yUjxPdZKYJwk',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
# We will be using now the access_token to authenticate our app with Spotify
#
# We test this API call https://developer.spotify.com/web-api/search-item/
url = 'https://api.spotify.com/v1/search'
auth_header = {'Authorization': 'Bearer ' + auth_data['access_token']}
parameters = {
    "q"     : "Taylor Swift",
    "type"  : "artist",
    "limit" : 50
}
response = requests.get(url, headers=auth_header, params=parameters).json()
response
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Taylor+Swift&type=artist&offset=0&limit=50',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'followers': {'href': None, 'total': 113134236},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebe672b5f553298dcdccb0e676',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174e672b5f553298dcdccb0e676',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178e672b5f553298dcdccb0e676',
#       'width': 160}],
#     'name': 'Taylor Swift',
#     'popularity': 100,
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DwbGCdaD8YLRiVUEiV70Q'},
#     'followers': {'href': None, 'total': 3466},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0DwbGCdaD8YLRiVUEiV70Q',
#     'id': '0DwbGCdaD8YLRiVUEiV70Q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738160a48bb1693050f496b11e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028160a48bb1693050f496b11e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518160a48bb1693050f496b11e',
#       'width': 64}],
#     'name': 'Taylor Swift Piano Covers',
#     'popularity': 29,
#     'type': 'artist',
#     'uri': 'spotify:artist:0DwbGCdaD8YLRiVUEiV70Q'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#     'followers': {'href': None, 'total': 36795065},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#     'id': '1McMsnEElThX1knmY4oliG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebe03a98785f3658f0b6461ec4',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174e03a98785f3658f0b6461ec4',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178e03a98785f3658f0b6461ec4',
#       'width': 160}],
#     'name': 'Olivia Rodrigo',
#     'popularity': 87,
#     'type': 'artist',
#     'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3OGj4jFXF7Cw4ORWS7T3ra'},
#     'followers': {'href': None, 'total': 427},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3OGj4jFXF7Cw4ORWS7T3ra',
#     'id': '3OGj4jFXF7Cw4ORWS7T3ra',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bbd79a349857d5e5ec3f88d0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bbd79a349857d5e5ec3f88d0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bbd79a349857d5e5ec3f88d0',
#       'width': 64}],
#     'name': 'Taylor Swift Facts',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:3OGj4jFXF7Cw4ORWS7T3ra'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#     'followers': {'href': None, 'total': 33352242},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#     'id': '6jJ0s89eD6GaHleKKya26X',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebc16e9a79a6262f2c72232942',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174c16e9a79a6262f2c72232942',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178c16e9a79a6262f2c72232942',
#       'width': 160}],
#     'name': 'Katy Perry',
#     'popularity': 83,
#     'type': 'artist',
#     'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Yzz6SisIkcvuhKSdJ02en'},
#     'followers': {'href': None, 'total': 110},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5Yzz6SisIkcvuhKSdJ02en',
#     'id': '5Yzz6SisIkcvuhKSdJ02en',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273623c43e08dff5dce47beb004',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02623c43e08dff5dce47beb004',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851623c43e08dff5dce47beb004',
#       'width': 64}],
#     'name': 'Taylor Swifter',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5Yzz6SisIkcvuhKSdJ02en'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#     'followers': {'href': None, 'total': 24115342},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#     'id': '5YGY8feqx7naU7z4HrwZM6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebb4ba86c361191d48cbeb4b32',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174b4ba86c361191d48cbeb4b32',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178b4ba86c361191d48cbeb4b32',
#       'width': 160}],
#     'name': 'Miley Cyrus',
#     'popularity': 82,
#     'type': 'artist',
#     'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bgoHMYkNqVC9PTOrQECts'},
#     'followers': {'href': None, 'total': 384},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1bgoHMYkNqVC9PTOrQECts',
#     'id': '1bgoHMYkNqVC9PTOrQECts',
#     'images': [],
#     'name': 'Ed Sheeran Taylor Swift',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:1bgoHMYkNqVC9PTOrQECts'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#     'followers': {'href': None, 'total': 5442096},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#     'id': '45dkTj5sMRSjrmBSBeiHym',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb846308bf9bf7d3183958b3a6',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174846308bf9bf7d3183958b3a6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178846308bf9bf7d3183958b3a6',
#       'width': 160}],
#     'name': 'Tate McRae',
#     'popularity': 82,
#     'type': 'artist',
#     'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7oW3aIseIypoEqcOqvzUfS'},
#     'followers': {'href': None, 'total': 90},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7oW3aIseIypoEqcOqvzUfS',
#     'id': '7oW3aIseIypoEqcOqvzUfS',
#     'images': [],
#     'name': 'taylorr swiftt',
#     'popularity': 6,
#     'type': 'artist',
#     'uri': 'spotify:artist:7oW3aIseIypoEqcOqvzUfS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Vvvx45Apu6dQqwuZQxtgW'},
#     'followers': {'href': None, 'total': 1207162},
#     'genres': ["children's music"],
#     'href': 'https://api.spotify.com/v1/artists/1Vvvx45Apu6dQqwuZQxtgW',
#     'id': '1Vvvx45Apu6dQqwuZQxtgW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb72c72bfa75f2d33c9fb441f9',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517472c72bfa75f2d33c9fb441f9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17872c72bfa75f2d33c9fb441f9',
#       'width': 160}],
#     'name': 'Kidz Bop Kids',
#     'popularity': 65,
#     'type': 'artist',
#     'uri': 'spotify:artist:1Vvvx45Apu6dQqwuZQxtgW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/14waR9FpjuHkqhd3DlMAYu'},
#     'followers': {'href': None, 'total': 61},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/14waR9FpjuHkqhd3DlMAYu',
#     'id': '14waR9FpjuHkqhd3DlMAYu',
#     'images': [],
#     'name': 'Taylor Swiftsz',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:14waR9FpjuHkqhd3DlMAYu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6s22t5Y3prQHyaHWUN1R1C'},
#     'followers': {'href': None, 'total': 3344919},
#     'genres': ['pov: indie'],
#     'href': 'https://api.spotify.com/v1/artists/6s22t5Y3prQHyaHWUN1R1C',
#     'id': '6s22t5Y3prQHyaHWUN1R1C',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebe65fa0329c232ac6f5040f80',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174e65fa0329c232ac6f5040f80',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178e65fa0329c232ac6f5040f80',
#       'width': 160}],
#     'name': 'AJR',
#     'popularity': 72,
#     'type': 'artist',
#     'uri': 'spotify:artist:6s22t5Y3prQHyaHWUN1R1C'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5D4eBBCFWPid24YVLH7206'},
#     'followers': {'href': None, 'total': 49},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5D4eBBCFWPid24YVLH7206',
#     'id': '5D4eBBCFWPid24YVLH7206',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b8f456b4e50c43b271d81704',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b8f456b4e50c43b271d81704',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b8f456b4e50c43b271d81704',
#       'width': 64}],
#     'name': 'Taylor Swiftoo',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5D4eBBCFWPid24YVLH7206'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#     'followers': {'href': None, 'total': 55874806},
#     'genres': ['british soul', 'pop', 'pop soul', 'uk pop'],
#     'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#     'id': '4dpARuHxo51G3z768sgnrY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb68f6e5892075d7f22615bd17',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517468f6e5892075d7f22615bd17',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17868f6e5892075d7f22615bd17',
#       'width': 160}],
#     'name': 'Adele',
#     'popularity': 82,
#     'type': 'artist',
#     'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vZoN5cnYOycsJ5KsFkjo5'},
#     'followers': {'href': None, 'total': 154},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3vZoN5cnYOycsJ5KsFkjo5',
#     'id': '3vZoN5cnYOycsJ5KsFkjo5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273785702c6f41f1fa6d6c3d2b1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02785702c6f41f1fa6d6c3d2b1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851785702c6f41f1fa6d6c3d2b1',
#       'width': 64}],
#     'name': 'Taylor Swift - Evermore - Piano Covers',
#     'popularity': 5,
#     'type': 'artist',
#     'uri': 'spotify:artist:3vZoN5cnYOycsJ5KsFkjo5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LqNN22kT3074XbTVUrhzX'},
#     'followers': {'href': None, 'total': 7900156},
#     'genres': ['dance pop', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/6LqNN22kT3074XbTVUrhzX',
#     'id': '6LqNN22kT3074XbTVUrhzX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb93edab94acfe329cfcd339ec',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517493edab94acfe329cfcd339ec',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17893edab94acfe329cfcd339ec',
#       'width': 160}],
#     'name': 'Kesha',
#     'popularity': 77,
#     'type': 'artist',
#     'uri': 'spotify:artist:6LqNN22kT3074XbTVUrhzX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/75xajtqlPSZfqpy29CcGT9'},
#     'followers': {'href': None, 'total': 157},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/75xajtqlPSZfqpy29CcGT9',
#     'id': '75xajtqlPSZfqpy29CcGT9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737e3a27b3ac512860386631c0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027e3a27b3ac512860386631c0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517e3a27b3ac512860386631c0',
#       'width': 64}],
#     'name': 'The Taylor Swift Piano Cover Band',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:75xajtqlPSZfqpy29CcGT9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/163tK9Wjr9P9DmM0AVK7lm'},
#     'followers': {'href': None, 'total': 9968230},
#     'genres': ['art pop', 'metropopolis', 'nz pop', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/163tK9Wjr9P9DmM0AVK7lm',
#     'id': '163tK9Wjr9P9DmM0AVK7lm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebc4902f080d3620b3e6da80c3',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174c4902f080d3620b3e6da80c3',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178c4902f080d3620b3e6da80c3',
#       'width': 160}],
#     'name': 'Lorde',
#     'popularity': 73,
#     'type': 'artist',
#     'uri': 'spotify:artist:163tK9Wjr9P9DmM0AVK7lm'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1pZI3RPswAgKWRNDFP9ReN'},
#     'followers': {'href': None, 'total': 54},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1pZI3RPswAgKWRNDFP9ReN',
#     'id': '1pZI3RPswAgKWRNDFP9ReN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf2cd5ae696486ff79391f43',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf2cd5ae696486ff79391f43',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf2cd5ae696486ff79391f43',
#       'width': 64}],
#     'name': 'Taylor Swift Piano Instrumentals',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1pZI3RPswAgKWRNDFP9ReN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#     'followers': {'href': None, 'total': 4455278},
#     'genres': ['modern indie pop', 'pov: indie', 'singer-songwriter pop'],
#     'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#     'id': '164Uj4eKjl6zTBKfJLFKKK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebce33386a81a202e149934ec1',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174ce33386a81a202e149934ec1',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178ce33386a81a202e149934ec1',
#       'width': 160}],
#     'name': 'JVKE',
#     'popularity': 74,
#     'type': 'artist',
#     'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/56oDRnqbIiwx4mymNEv7dS'},
#     'followers': {'href': None, 'total': 5715478},
#     'genres': ['escape room', 'minnesota hip hop', 'pop', 'trap queen'],
#     'href': 'https://api.spotify.com/v1/artists/56oDRnqbIiwx4mymNEv7dS',
#     'id': '56oDRnqbIiwx4mymNEv7dS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb0d66b3670294bf801847dae2',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051740d66b3670294bf801847dae2',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1780d66b3670294bf801847dae2',
#       'width': 160}],
#     'name': 'Lizzo',
#     'popularity': 69,
#     'type': 'artist',
#     'uri': 'spotify:artist:56oDRnqbIiwx4mymNEv7dS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JZ7CnR6gTvEMKX4g70Amv'},
#     'followers': {'href': None, 'total': 6202410},
#     'genres': ['pop'],
#     'href': 'https://api.spotify.com/v1/artists/5JZ7CnR6gTvEMKX4g70Amv',
#     'id': '5JZ7CnR6gTvEMKX4g70Amv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebb173d69f77530d77a991984f',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174b173d69f77530d77a991984f',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178b173d69f77530d77a991984f',
#       'width': 160}],
#     'name': 'Lauv',
#     'popularity': 74,
#     'type': 'artist',
#     'uri': 'spotify:artist:5JZ7CnR6gTvEMKX4g70Amv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Dd3NScHWwnW6obMFbl1BH'},
#     'followers': {'href': None, 'total': 1625098},
#     'genres': ['alt z', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/6Dd3NScHWwnW6obMFbl1BH',
#     'id': '6Dd3NScHWwnW6obMFbl1BH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebec8fc3ab9894dc3f5afef6f6',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174ec8fc3ab9894dc3f5afef6f6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178ec8fc3ab9894dc3f5afef6f6',
#       'width': 160}],
#     'name': 'Daya',
#     'popularity': 71,
#     'type': 'artist',
#     'uri': 'spotify:artist:6Dd3NScHWwnW6obMFbl1BH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1A0WloDoRE88uUwo3wensY'},
#     'followers': {'href': None, 'total': 191422},
#     'genres': ['singer-songwriter pop'],
#     'href': 'https://api.spotify.com/v1/artists/1A0WloDoRE88uUwo3wensY',
#     'id': '1A0WloDoRE88uUwo3wensY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb84806a06ae1de0777ef1e1be',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517484806a06ae1de0777ef1e1be',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17884806a06ae1de0777ef1e1be',
#       'width': 160}],
#     'name': 'Taylor Acorn',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:1A0WloDoRE88uUwo3wensY'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ca3AFdIIgaP4ZIW8J6zXu'},
#     'followers': {'href': None, 'total': 213977},
#     'genres': ["australian children's music"],
#     'href': 'https://api.spotify.com/v1/artists/6ca3AFdIIgaP4ZIW8J6zXu',
#     'id': '6ca3AFdIIgaP4ZIW8J6zXu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb9ca66f0901a76a7ac29c04e9',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051749ca66f0901a76a7ac29c04e9',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1789ca66f0901a76a7ac29c04e9',
#       'width': 160}],
#     'name': 'Bluey',
#     'popularity': 64,
#     'type': 'artist',
#     'uri': 'spotify:artist:6ca3AFdIIgaP4ZIW8J6zXu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/64TYMfqkpGQsUEuF5xqS2R'},
#     'followers': {'href': None, 'total': 52486},
#     'genres': ['cartoon', "children's music"],
#     'href': 'https://api.spotify.com/v1/artists/64TYMfqkpGQsUEuF5xqS2R',
#     'id': '64TYMfqkpGQsUEuF5xqS2R',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb666a1746919918e63fafb413',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174666a1746919918e63fafb413',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178666a1746919918e63fafb413',
#       'width': 160}],
#     'name': 'Elmo',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:64TYMfqkpGQsUEuF5xqS2R'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IqjJsWlAPR2IafHTtnjPQ'},
#     'followers': {'href': None, 'total': 47825},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0IqjJsWlAPR2IafHTtnjPQ',
#     'id': '0IqjJsWlAPR2IafHTtnjPQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb4084723d3a5d604d446f5041',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051744084723d3a5d604d446f5041',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1784084723d3a5d604d446f5041',
#       'width': 160}],
#     'name': 'Minnz Piano',
#     'popularity': 56,
#     'type': 'artist',
#     'uri': 'spotify:artist:0IqjJsWlAPR2IafHTtnjPQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ui2kfOqGujY81UcPrb5KE'},
#     'followers': {'href': None, 'total': 1323278},
#     'genres': ['indietronica', 'metropopolis'],
#     'href': 'https://api.spotify.com/v1/artists/4Ui2kfOqGujY81UcPrb5KE',
#     'id': '4Ui2kfOqGujY81UcPrb5KE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eba688abfbbed1037befa47232',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174a688abfbbed1037befa47232',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178a688abfbbed1037befa47232',
#       'width': 160}],
#     'name': 'HAIM',
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:4Ui2kfOqGujY81UcPrb5KE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2L7RaHwfVU6ge64IJF8GO5'},
#     'followers': {'href': None, 'total': 138403},
#     'genres': ['movie tunes'],
#     'href': 'https://api.spotify.com/v1/artists/2L7RaHwfVU6ge64IJF8GO5',
#     'id': '2L7RaHwfVU6ge64IJF8GO5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb89569545e37b9419767946fe',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517489569545e37b9419767946fe',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17889569545e37b9419767946fe',
#       'width': 160}],
#     'name': 'ZOMBIES – Cast',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:2L7RaHwfVU6ge64IJF8GO5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1VbWMsap5Ex2erHPlmndr0'},
#     'followers': {'href': None, 'total': 302316},
#     'genres': ['broadway'],
#     'href': 'https://api.spotify.com/v1/artists/1VbWMsap5Ex2erHPlmndr0',
#     'id': '1VbWMsap5Ex2erHPlmndr0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb6ce6a9993a3b2f5ae6984778',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051746ce6a9993a3b2f5ae6984778',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1786ce6a9993a3b2f5ae6984778',
#       'width': 160}],
#     'name': 'SIX',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:1VbWMsap5Ex2erHPlmndr0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/58nB2Z6IiDdTUTwHYw56xI'},
#     'followers': {'href': None, 'total': 193936},
#     'genres': ['redneck'],
#     'href': 'https://api.spotify.com/v1/artists/58nB2Z6IiDdTUTwHYw56xI',
#     'id': '58nB2Z6IiDdTUTwHYw56xI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eba0fc6e8727e4183e95e344f7',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174a0fc6e8727e4183e95e344f7',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178a0fc6e8727e4183e95e344f7',
#       'width': 160}],
#     'name': 'Taylor Ray Holbrook',
#     'popularity': 51,
#     'type': 'artist',
#     'uri': 'spotify:artist:58nB2Z6IiDdTUTwHYw56xI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/480xKab3lUPhBBnCzlzqIu'},
#     'followers': {'href': None, 'total': 193248},
#     'genres': ['bow pop', 'pop violin'],
#     'href': 'https://api.spotify.com/v1/artists/480xKab3lUPhBBnCzlzqIu',
#     'id': '480xKab3lUPhBBnCzlzqIu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebcefd7abc8e4cfd9680005cab',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174cefd7abc8e4cfd9680005cab',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178cefd7abc8e4cfd9680005cab',
#       'width': 160}],
#     'name': 'Taylor Davis',
#     'popularity': 47,
#     'type': 'artist',
#     'uri': 'spotify:artist:480xKab3lUPhBBnCzlzqIu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hz3IW691fbgGqLk4yvlNN'},
#     'followers': {'href': None, 'total': 139564},
#     'genres': ['social media pop'],
#     'href': 'https://api.spotify.com/v1/artists/5Hz3IW691fbgGqLk4yvlNN',
#     'id': '5Hz3IW691fbgGqLk4yvlNN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb771800ed354173c1f7fadd6b',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174771800ed354173c1f7fadd6b',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178771800ed354173c1f7fadd6b',
#       'width': 160}],
#     'name': 'Tayler Holder',
#     'popularity': 42,
#     'type': 'artist',
#     'uri': 'spotify:artist:5Hz3IW691fbgGqLk4yvlNN'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1f0vGTFXE64SLuypBV8zB0'},
#     'followers': {'href': None, 'total': 14391},
#     'genres': ['broadway', 'show tunes'],
#     'href': 'https://api.spotify.com/v1/artists/1f0vGTFXE64SLuypBV8zB0',
#     'id': '1f0vGTFXE64SLuypBV8zB0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb1a15c0765808044ffc633803',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051741a15c0765808044ffc633803',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1781a15c0765808044ffc633803',
#       'width': 160}],
#     'name': 'Taylor Louderman',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:1f0vGTFXE64SLuypBV8zB0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/32lVGr0fSRGT6okLKHiP68'},
#     'followers': {'href': None, 'total': 465854},
#     'genres': ['freestyle',
#      'hi-nrg',
#      'new romantic',
#      'new wave pop',
#      'soft rock',
#      'synthpop'],
#     'href': 'https://api.spotify.com/v1/artists/32lVGr0fSRGT6okLKHiP68',
#     'id': '32lVGr0fSRGT6okLKHiP68',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebd6944ca0fcb7fc4d2aecad46',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174d6944ca0fcb7fc4d2aecad46',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178d6944ca0fcb7fc4d2aecad46',
#       'width': 160}],
#     'name': 'Taylor Dayne',
#     'popularity': 55,
#     'type': 'artist',
#     'uri': 'spotify:artist:32lVGr0fSRGT6okLKHiP68'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Iq6waFNaQnjLjEjp2l3nc'},
#     'followers': {'href': None, 'total': 540909},
#     'genres': ['movie tunes'],
#     'href': 'https://api.spotify.com/v1/artists/3Iq6waFNaQnjLjEjp2l3nc',
#     'id': '3Iq6waFNaQnjLjEjp2l3nc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb5fafe669290dd825da1b118e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051745fafe669290dd825da1b118e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1785fafe669290dd825da1b118e',
#       'width': 160}],
#     'name': 'Jojo Siwa (Kids)',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Iq6waFNaQnjLjEjp2l3nc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Mbytr4DD854L4vp4J1LEj'},
#     'followers': {'href': None, 'total': 4407},
#     'genres': ['show tunes'],
#     'href': 'https://api.spotify.com/v1/artists/6Mbytr4DD854L4vp4J1LEj',
#     'id': '6Mbytr4DD854L4vp4J1LEj',
#     'images': [],
#     'name': 'Elle McLemore',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:6Mbytr4DD854L4vp4J1LEj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jcl46xRBm9LKIwrKGQPE6'},
#     'followers': {'href': None, 'total': 207654},
#     'genres': ['movie tunes', 'nyc pop'],
#     'href': 'https://api.spotify.com/v1/artists/0jcl46xRBm9LKIwrKGQPE6',
#     'id': '0jcl46xRBm9LKIwrKGQPE6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb9f75349ecac0b1e94563af6e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051749f75349ecac0b1e94563af6e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1789f75349ecac0b1e94563af6e',
#       'width': 160}],
#     'name': 'Meg Donnelly',
#     'popularity': 55,
#     'type': 'artist',
#     'uri': 'spotify:artist:0jcl46xRBm9LKIwrKGQPE6'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zTbBugfNc95zo8ClFDhIn'},
#     'followers': {'href': None, 'total': 99239},
#     'genres': ['movie tunes'],
#     'href': 'https://api.spotify.com/v1/artists/6zTbBugfNc95zo8ClFDhIn',
#     'id': '6zTbBugfNc95zo8ClFDhIn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebb2acbcc89d74da7e4f300650',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174b2acbcc89d74da7e4f300650',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178b2acbcc89d74da7e4f300650',
#       'width': 160}],
#     'name': 'Troy',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:6zTbBugfNc95zo8ClFDhIn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nkr1fevjIVmgx5biwAWVo'},
#     'followers': {'href': None, 'total': 13785},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7nkr1fevjIVmgx5biwAWVo',
#     'id': '7nkr1fevjIVmgx5biwAWVo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb8e5a8ed4bb07804dc8ebe8b0',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051748e5a8ed4bb07804dc8ebe8b0',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1788e5a8ed4bb07804dc8ebe8b0',
#       'width': 160}],
#     'name': 'Taylour Paige',
#     'popularity': 47,
#     'type': 'artist',
#     'uri': 'spotify:artist:7nkr1fevjIVmgx5biwAWVo'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3HsVtnnjOUToyJThxaoBfx'},
#     'followers': {'href': None, 'total': 314140},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3HsVtnnjOUToyJThxaoBfx',
#     'id': '3HsVtnnjOUToyJThxaoBfx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb46ffe763f21bc8b1a6745c9c',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517446ffe763f21bc8b1a6745c9c',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17846ffe763f21bc8b1a6745c9c',
#       'width': 160}],
#     'name': 'Halle',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:3HsVtnnjOUToyJThxaoBfx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/30ejUciK31BCg0IVCbt1dW'},
#     'followers': {'href': None, 'total': 17084},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/30ejUciK31BCg0IVCbt1dW',
#     'id': '30ejUciK31BCg0IVCbt1dW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb39ab87fa7e1dd658ec5dd081',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517439ab87fa7e1dd658ec5dd081',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17839ab87fa7e1dd658ec5dd081',
#       'width': 160}],
#     'name': 'Mike Taylor',
#     'popularity': 52,
#     'type': 'artist',
#     'uri': 'spotify:artist:30ejUciK31BCg0IVCbt1dW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7cxXeGqb1uIhoiSXQ6kejX'},
#     'followers': {'href': None, 'total': 13539},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7cxXeGqb1uIhoiSXQ6kejX',
#     'id': '7cxXeGqb1uIhoiSXQ6kejX',
#     'images': [],
#     'name': 'The Lorax Singers',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:7cxXeGqb1uIhoiSXQ6kejX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0iv7RfSxMSAvCzCVnxys6g'},
#     'followers': {'href': None, 'total': 262875},
#     'genres': ['meme'],
#     'href': 'https://api.spotify.com/v1/artists/0iv7RfSxMSAvCzCVnxys6g',
#     'id': '0iv7RfSxMSAvCzCVnxys6g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb2ddecde6dafacf68bd59b0f3',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051742ddecde6dafacf68bd59b0f3',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1782ddecde6dafacf68bd59b0f3',
#       'width': 160}],
#     'name': 'Tiko',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:0iv7RfSxMSAvCzCVnxys6g'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3CVk2LzA3zH6FBAXuPbnhc'},
#     'followers': {'href': None, 'total': 35937},
#     'genres': ['christian indie'],
#     'href': 'https://api.spotify.com/v1/artists/3CVk2LzA3zH6FBAXuPbnhc',
#     'id': '3CVk2LzA3zH6FBAXuPbnhc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebed79936eeb4325a3212d9db3',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174ed79936eeb4325a3212d9db3',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178ed79936eeb4325a3212d9db3',
#       'width': 160}],
#     'name': 'Taylor Armstrong',
#     'popularity': 42,
#     'type': 'artist',
#     'uri': 'spotify:artist:3CVk2LzA3zH6FBAXuPbnhc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5f1cs8LexmMYbhNEIOsDLT'},
#     'followers': {'href': None, 'total': 27828},
#     'genres': ['south carolina indie'],
#     'href': 'https://api.spotify.com/v1/artists/5f1cs8LexmMYbhNEIOsDLT',
#     'id': '5f1cs8LexmMYbhNEIOsDLT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebd98037c4ea387ebbb6f8b7a5',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174d98037c4ea387ebbb6f8b7a5',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178d98037c4ea387ebbb6f8b7a5',
#       'width': 160}],
#     'name': 'Taylor McCall',
#     'popularity': 40,
#     'type': 'artist',
#     'uri': 'spotify:artist:5f1cs8LexmMYbhNEIOsDLT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/68CRxZTAqk19AznItZInip'},
#     'followers': {'href': None, 'total': 37731},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/68CRxZTAqk19AznItZInip',
#     'id': '68CRxZTAqk19AznItZInip',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb7debf8864ec8725e7b191d49',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051747debf8864ec8725e7b191d49',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1787debf8864ec8725e7b191d49',
#       'width': 160}],
#     'name': 'Swifty Blue',
#     'popularity': 44,
#     'type': 'artist',
#     'uri': 'spotify:artist:68CRxZTAqk19AznItZInip'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fxg10eJ6YmvUdM2PPB4Zk'},
#     'followers': {'href': None, 'total': 59432},
#     'genres': ['alt z'],
#     'href': 'https://api.spotify.com/v1/artists/3Fxg10eJ6YmvUdM2PPB4Zk',
#     'id': '3Fxg10eJ6YmvUdM2PPB4Zk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb62d8eb6c871c46e88b4d5eec',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517462d8eb6c871c46e88b4d5eec',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17862d8eb6c871c46e88b4d5eec',
#       'width': 160}],
#     'name': 'Taylor Bickett',
#     'popularity': 42,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Fxg10eJ6YmvUdM2PPB4Zk'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aU66AnY6CxGppINw6QGq1'},
#     'followers': {'href': None, 'total': 28356},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7aU66AnY6CxGppINw6QGq1',
#     'id': '7aU66AnY6CxGppINw6QGq1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb3f3acc7ab586aa4fa19d5396',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051743f3acc7ab586aa4fa19d5396',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1783f3acc7ab586aa4fa19d5396',
#       'width': 160}],
#     'name': 'Kylee Russell',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:7aU66AnY6CxGppINw6QGq1'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Taylor+Swift&type=artist&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 810}}

# %%
response.keys()
# Out:
# dict_keys(['artists'])

# %%
response['artists'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
response['artists']['next']
# Out:
# 'https://api.spotify.com/v1/search?query=Taylor+Swift&type=artist&offset=50&limit=50'

# %%
response['artists']['total']
# Out:
# 810

# %%
response['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#   'followers': {'href': None, 'total': 113134236},
#   'genres': ['pop'],
#   'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#   'id': '06HL4z0CvFAxyc27GXpf02',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe672b5f553298dcdccb0e676',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e672b5f553298dcdccb0e676',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e672b5f553298dcdccb0e676',
#     'width': 160}],
#   'name': 'Taylor Swift',
#   'popularity': 100,
#   'type': 'artist',
#   'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DwbGCdaD8YLRiVUEiV70Q'},
#   'followers': {'href': None, 'total': 3466},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/0DwbGCdaD8YLRiVUEiV70Q',
#   'id': '0DwbGCdaD8YLRiVUEiV70Q',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738160a48bb1693050f496b11e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028160a48bb1693050f496b11e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518160a48bb1693050f496b11e',
#     'width': 64}],
#   'name': 'Taylor Swift Piano Covers',
#   'popularity': 29,
#   'type': 'artist',
#   'uri': 'spotify:artist:0DwbGCdaD8YLRiVUEiV70Q'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#   'followers': {'href': None, 'total': 36795065},
#   'genres': ['pop'],
#   'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#   'id': '1McMsnEElThX1knmY4oliG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe03a98785f3658f0b6461ec4',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e03a98785f3658f0b6461ec4',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e03a98785f3658f0b6461ec4',
#     'width': 160}],
#   'name': 'Olivia Rodrigo',
#   'popularity': 87,
#   'type': 'artist',
#   'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3OGj4jFXF7Cw4ORWS7T3ra'},
#   'followers': {'href': None, 'total': 427},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/3OGj4jFXF7Cw4ORWS7T3ra',
#   'id': '3OGj4jFXF7Cw4ORWS7T3ra',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bbd79a349857d5e5ec3f88d0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bbd79a349857d5e5ec3f88d0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bbd79a349857d5e5ec3f88d0',
#     'width': 64}],
#   'name': 'Taylor Swift Facts',
#   'popularity': 2,
#   'type': 'artist',
#   'uri': 'spotify:artist:3OGj4jFXF7Cw4ORWS7T3ra'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#   'followers': {'href': None, 'total': 33352242},
#   'genres': ['pop'],
#   'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#   'id': '6jJ0s89eD6GaHleKKya26X',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc16e9a79a6262f2c72232942',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c16e9a79a6262f2c72232942',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c16e9a79a6262f2c72232942',
#     'width': 160}],
#   'name': 'Katy Perry',
#   'popularity': 83,
#   'type': 'artist',
#   'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Yzz6SisIkcvuhKSdJ02en'},
#   'followers': {'href': None, 'total': 110},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/5Yzz6SisIkcvuhKSdJ02en',
#   'id': '5Yzz6SisIkcvuhKSdJ02en',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273623c43e08dff5dce47beb004',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02623c43e08dff5dce47beb004',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851623c43e08dff5dce47beb004',
#     'width': 64}],
#   'name': 'Taylor Swifter',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:5Yzz6SisIkcvuhKSdJ02en'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#   'followers': {'href': None, 'total': 24115342},
#   'genres': ['pop'],
#   'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#   'id': '5YGY8feqx7naU7z4HrwZM6',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb4ba86c361191d48cbeb4b32',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b4ba86c361191d48cbeb4b32',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b4ba86c361191d48cbeb4b32',
#     'width': 160}],
#   'name': 'Miley Cyrus',
#   'popularity': 82,
#   'type': 'artist',
#   'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1bgoHMYkNqVC9PTOrQECts'},
#   'followers': {'href': None, 'total': 384},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/1bgoHMYkNqVC9PTOrQECts',
#   'id': '1bgoHMYkNqVC9PTOrQECts',
#   'images': [],
#   'name': 'Ed Sheeran Taylor Swift',
#   'popularity': 1,
#   'type': 'artist',
#   'uri': 'spotify:artist:1bgoHMYkNqVC9PTOrQECts'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#   'followers': {'href': None, 'total': 5442096},
#   'genres': ['pop'],
#   'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#   'id': '45dkTj5sMRSjrmBSBeiHym',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb846308bf9bf7d3183958b3a6',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174846308bf9bf7d3183958b3a6',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178846308bf9bf7d3183958b3a6',
#     'width': 160}],
#   'name': 'Tate McRae',
#   'popularity': 82,
#   'type': 'artist',
#   'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7oW3aIseIypoEqcOqvzUfS'},
#   'followers': {'href': None, 'total': 90},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7oW3aIseIypoEqcOqvzUfS',
#   'id': '7oW3aIseIypoEqcOqvzUfS',
#   'images': [],
#   'name': 'taylorr swiftt',
#   'popularity': 6,
#   'type': 'artist',
#   'uri': 'spotify:artist:7oW3aIseIypoEqcOqvzUfS'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Vvvx45Apu6dQqwuZQxtgW'},
#   'followers': {'href': None, 'total': 1207162},
#   'genres': ["children's music"],
#   'href': 'https://api.spotify.com/v1/artists/1Vvvx45Apu6dQqwuZQxtgW',
#   'id': '1Vvvx45Apu6dQqwuZQxtgW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb72c72bfa75f2d33c9fb441f9',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517472c72bfa75f2d33c9fb441f9',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17872c72bfa75f2d33c9fb441f9',
#     'width': 160}],
#   'name': 'Kidz Bop Kids',
#   'popularity': 65,
#   'type': 'artist',
#   'uri': 'spotify:artist:1Vvvx45Apu6dQqwuZQxtgW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/14waR9FpjuHkqhd3DlMAYu'},
#   'followers': {'href': None, 'total': 61},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/14waR9FpjuHkqhd3DlMAYu',
#   'id': '14waR9FpjuHkqhd3DlMAYu',
#   'images': [],
#   'name': 'Taylor Swiftsz',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:14waR9FpjuHkqhd3DlMAYu'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6s22t5Y3prQHyaHWUN1R1C'},
#   'followers': {'href': None, 'total': 3344919},
#   'genres': ['pov: indie'],
#   'href': 'https://api.spotify.com/v1/artists/6s22t5Y3prQHyaHWUN1R1C',
#   'id': '6s22t5Y3prQHyaHWUN1R1C',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebe65fa0329c232ac6f5040f80',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174e65fa0329c232ac6f5040f80',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178e65fa0329c232ac6f5040f80',
#     'width': 160}],
#   'name': 'AJR',
#   'popularity': 72,
#   'type': 'artist',
#   'uri': 'spotify:artist:6s22t5Y3prQHyaHWUN1R1C'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5D4eBBCFWPid24YVLH7206'},
#   'followers': {'href': None, 'total': 49},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/5D4eBBCFWPid24YVLH7206',
#   'id': '5D4eBBCFWPid24YVLH7206',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b8f456b4e50c43b271d81704',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b8f456b4e50c43b271d81704',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b8f456b4e50c43b271d81704',
#     'width': 64}],
#   'name': 'Taylor Swiftoo',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:5D4eBBCFWPid24YVLH7206'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#   'followers': {'href': None, 'total': 55874806},
#   'genres': ['british soul', 'pop', 'pop soul', 'uk pop'],
#   'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#   'id': '4dpARuHxo51G3z768sgnrY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb68f6e5892075d7f22615bd17',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517468f6e5892075d7f22615bd17',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17868f6e5892075d7f22615bd17',
#     'width': 160}],
#   'name': 'Adele',
#   'popularity': 82,
#   'type': 'artist',
#   'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vZoN5cnYOycsJ5KsFkjo5'},
#   'followers': {'href': None, 'total': 154},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/3vZoN5cnYOycsJ5KsFkjo5',
#   'id': '3vZoN5cnYOycsJ5KsFkjo5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273785702c6f41f1fa6d6c3d2b1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02785702c6f41f1fa6d6c3d2b1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851785702c6f41f1fa6d6c3d2b1',
#     'width': 64}],
#   'name': 'Taylor Swift - Evermore - Piano Covers',
#   'popularity': 5,
#   'type': 'artist',
#   'uri': 'spotify:artist:3vZoN5cnYOycsJ5KsFkjo5'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LqNN22kT3074XbTVUrhzX'},
#   'followers': {'href': None, 'total': 7900156},
#   'genres': ['dance pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/6LqNN22kT3074XbTVUrhzX',
#   'id': '6LqNN22kT3074XbTVUrhzX',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb93edab94acfe329cfcd339ec',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517493edab94acfe329cfcd339ec',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17893edab94acfe329cfcd339ec',
#     'width': 160}],
#   'name': 'Kesha',
#   'popularity': 77,
#   'type': 'artist',
#   'uri': 'spotify:artist:6LqNN22kT3074XbTVUrhzX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/75xajtqlPSZfqpy29CcGT9'},
#   'followers': {'href': None, 'total': 157},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/75xajtqlPSZfqpy29CcGT9',
#   'id': '75xajtqlPSZfqpy29CcGT9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737e3a27b3ac512860386631c0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027e3a27b3ac512860386631c0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517e3a27b3ac512860386631c0',
#     'width': 64}],
#   'name': 'The Taylor Swift Piano Cover Band',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:75xajtqlPSZfqpy29CcGT9'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/163tK9Wjr9P9DmM0AVK7lm'},
#   'followers': {'href': None, 'total': 9968230},
#   'genres': ['art pop', 'metropopolis', 'nz pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/163tK9Wjr9P9DmM0AVK7lm',
#   'id': '163tK9Wjr9P9DmM0AVK7lm',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebc4902f080d3620b3e6da80c3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174c4902f080d3620b3e6da80c3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178c4902f080d3620b3e6da80c3',
#     'width': 160}],
#   'name': 'Lorde',
#   'popularity': 73,
#   'type': 'artist',
#   'uri': 'spotify:artist:163tK9Wjr9P9DmM0AVK7lm'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1pZI3RPswAgKWRNDFP9ReN'},
#   'followers': {'href': None, 'total': 54},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/1pZI3RPswAgKWRNDFP9ReN',
#   'id': '1pZI3RPswAgKWRNDFP9ReN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bf2cd5ae696486ff79391f43',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bf2cd5ae696486ff79391f43',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bf2cd5ae696486ff79391f43',
#     'width': 64}],
#   'name': 'Taylor Swift Piano Instrumentals',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:1pZI3RPswAgKWRNDFP9ReN'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK'},
#   'followers': {'href': None, 'total': 4455278},
#   'genres': ['modern indie pop', 'pov: indie', 'singer-songwriter pop'],
#   'href': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK',
#   'id': '164Uj4eKjl6zTBKfJLFKKK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebce33386a81a202e149934ec1',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174ce33386a81a202e149934ec1',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178ce33386a81a202e149934ec1',
#     'width': 160}],
#   'name': 'JVKE',
#   'popularity': 74,
#   'type': 'artist',
#   'uri': 'spotify:artist:164Uj4eKjl6zTBKfJLFKKK'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/56oDRnqbIiwx4mymNEv7dS'},
#   'followers': {'href': None, 'total': 5715478},
#   'genres': ['escape room', 'minnesota hip hop', 'pop', 'trap queen'],
#   'href': 'https://api.spotify.com/v1/artists/56oDRnqbIiwx4mymNEv7dS',
#   'id': '56oDRnqbIiwx4mymNEv7dS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb0d66b3670294bf801847dae2',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051740d66b3670294bf801847dae2',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1780d66b3670294bf801847dae2',
#     'width': 160}],
#   'name': 'Lizzo',
#   'popularity': 69,
#   'type': 'artist',
#   'uri': 'spotify:artist:56oDRnqbIiwx4mymNEv7dS'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JZ7CnR6gTvEMKX4g70Amv'},
#   'followers': {'href': None, 'total': 6202410},
#   'genres': ['pop'],
#   'href': 'https://api.spotify.com/v1/artists/5JZ7CnR6gTvEMKX4g70Amv',
#   'id': '5JZ7CnR6gTvEMKX4g70Amv',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb173d69f77530d77a991984f',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b173d69f77530d77a991984f',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b173d69f77530d77a991984f',
#     'width': 160}],
#   'name': 'Lauv',
#   'popularity': 74,
#   'type': 'artist',
#   'uri': 'spotify:artist:5JZ7CnR6gTvEMKX4g70Amv'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Dd3NScHWwnW6obMFbl1BH'},
#   'followers': {'href': None, 'total': 1625098},
#   'genres': ['alt z', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/6Dd3NScHWwnW6obMFbl1BH',
#   'id': '6Dd3NScHWwnW6obMFbl1BH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebec8fc3ab9894dc3f5afef6f6',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174ec8fc3ab9894dc3f5afef6f6',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178ec8fc3ab9894dc3f5afef6f6',
#     'width': 160}],
#   'name': 'Daya',
#   'popularity': 71,
#   'type': 'artist',
#   'uri': 'spotify:artist:6Dd3NScHWwnW6obMFbl1BH'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1A0WloDoRE88uUwo3wensY'},
#   'followers': {'href': None, 'total': 191422},
#   'genres': ['singer-songwriter pop'],
#   'href': 'https://api.spotify.com/v1/artists/1A0WloDoRE88uUwo3wensY',
#   'id': '1A0WloDoRE88uUwo3wensY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb84806a06ae1de0777ef1e1be',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517484806a06ae1de0777ef1e1be',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17884806a06ae1de0777ef1e1be',
#     'width': 160}],
#   'name': 'Taylor Acorn',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:1A0WloDoRE88uUwo3wensY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ca3AFdIIgaP4ZIW8J6zXu'},
#   'followers': {'href': None, 'total': 213977},
#   'genres': ["australian children's music"],
#   'href': 'https://api.spotify.com/v1/artists/6ca3AFdIIgaP4ZIW8J6zXu',
#   'id': '6ca3AFdIIgaP4ZIW8J6zXu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb9ca66f0901a76a7ac29c04e9',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051749ca66f0901a76a7ac29c04e9',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1789ca66f0901a76a7ac29c04e9',
#     'width': 160}],
#   'name': 'Bluey',
#   'popularity': 64,
#   'type': 'artist',
#   'uri': 'spotify:artist:6ca3AFdIIgaP4ZIW8J6zXu'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/64TYMfqkpGQsUEuF5xqS2R'},
#   'followers': {'href': None, 'total': 52486},
#   'genres': ['cartoon', "children's music"],
#   'href': 'https://api.spotify.com/v1/artists/64TYMfqkpGQsUEuF5xqS2R',
#   'id': '64TYMfqkpGQsUEuF5xqS2R',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb666a1746919918e63fafb413',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174666a1746919918e63fafb413',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178666a1746919918e63fafb413',
#     'width': 160}],
#   'name': 'Elmo',
#   'popularity': 57,
#   'type': 'artist',
#   'uri': 'spotify:artist:64TYMfqkpGQsUEuF5xqS2R'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IqjJsWlAPR2IafHTtnjPQ'},
#   'followers': {'href': None, 'total': 47825},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/0IqjJsWlAPR2IafHTtnjPQ',
#   'id': '0IqjJsWlAPR2IafHTtnjPQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb4084723d3a5d604d446f5041',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051744084723d3a5d604d446f5041',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1784084723d3a5d604d446f5041',
#     'width': 160}],
#   'name': 'Minnz Piano',
#   'popularity': 56,
#   'type': 'artist',
#   'uri': 'spotify:artist:0IqjJsWlAPR2IafHTtnjPQ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ui2kfOqGujY81UcPrb5KE'},
#   'followers': {'href': None, 'total': 1323278},
#   'genres': ['indietronica', 'metropopolis'],
#   'href': 'https://api.spotify.com/v1/artists/4Ui2kfOqGujY81UcPrb5KE',
#   'id': '4Ui2kfOqGujY81UcPrb5KE',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba688abfbbed1037befa47232',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a688abfbbed1037befa47232',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a688abfbbed1037befa47232',
#     'width': 160}],
#   'name': 'HAIM',
#   'popularity': 62,
#   'type': 'artist',
#   'uri': 'spotify:artist:4Ui2kfOqGujY81UcPrb5KE'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2L7RaHwfVU6ge64IJF8GO5'},
#   'followers': {'href': None, 'total': 138403},
#   'genres': ['movie tunes'],
#   'href': 'https://api.spotify.com/v1/artists/2L7RaHwfVU6ge64IJF8GO5',
#   'id': '2L7RaHwfVU6ge64IJF8GO5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb89569545e37b9419767946fe',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517489569545e37b9419767946fe',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17889569545e37b9419767946fe',
#     'width': 160}],
#   'name': 'ZOMBIES – Cast',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:2L7RaHwfVU6ge64IJF8GO5'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1VbWMsap5Ex2erHPlmndr0'},
#   'followers': {'href': None, 'total': 302316},
#   'genres': ['broadway'],
#   'href': 'https://api.spotify.com/v1/artists/1VbWMsap5Ex2erHPlmndr0',
#   'id': '1VbWMsap5Ex2erHPlmndr0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb6ce6a9993a3b2f5ae6984778',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051746ce6a9993a3b2f5ae6984778',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1786ce6a9993a3b2f5ae6984778',
#     'width': 160}],
#   'name': 'SIX',
#   'popularity': 60,
#   'type': 'artist',
#   'uri': 'spotify:artist:1VbWMsap5Ex2erHPlmndr0'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/58nB2Z6IiDdTUTwHYw56xI'},
#   'followers': {'href': None, 'total': 193936},
#   'genres': ['redneck'],
#   'href': 'https://api.spotify.com/v1/artists/58nB2Z6IiDdTUTwHYw56xI',
#   'id': '58nB2Z6IiDdTUTwHYw56xI',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eba0fc6e8727e4183e95e344f7',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174a0fc6e8727e4183e95e344f7',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178a0fc6e8727e4183e95e344f7',
#     'width': 160}],
#   'name': 'Taylor Ray Holbrook',
#   'popularity': 51,
#   'type': 'artist',
#   'uri': 'spotify:artist:58nB2Z6IiDdTUTwHYw56xI'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/480xKab3lUPhBBnCzlzqIu'},
#   'followers': {'href': None, 'total': 193248},
#   'genres': ['bow pop', 'pop violin'],
#   'href': 'https://api.spotify.com/v1/artists/480xKab3lUPhBBnCzlzqIu',
#   'id': '480xKab3lUPhBBnCzlzqIu',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebcefd7abc8e4cfd9680005cab',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174cefd7abc8e4cfd9680005cab',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178cefd7abc8e4cfd9680005cab',
#     'width': 160}],
#   'name': 'Taylor Davis',
#   'popularity': 47,
#   'type': 'artist',
#   'uri': 'spotify:artist:480xKab3lUPhBBnCzlzqIu'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hz3IW691fbgGqLk4yvlNN'},
#   'followers': {'href': None, 'total': 139564},
#   'genres': ['social media pop'],
#   'href': 'https://api.spotify.com/v1/artists/5Hz3IW691fbgGqLk4yvlNN',
#   'id': '5Hz3IW691fbgGqLk4yvlNN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb771800ed354173c1f7fadd6b',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174771800ed354173c1f7fadd6b',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178771800ed354173c1f7fadd6b',
#     'width': 160}],
#   'name': 'Tayler Holder',
#   'popularity': 42,
#   'type': 'artist',
#   'uri': 'spotify:artist:5Hz3IW691fbgGqLk4yvlNN'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1f0vGTFXE64SLuypBV8zB0'},
#   'followers': {'href': None, 'total': 14391},
#   'genres': ['broadway', 'show tunes'],
#   'href': 'https://api.spotify.com/v1/artists/1f0vGTFXE64SLuypBV8zB0',
#   'id': '1f0vGTFXE64SLuypBV8zB0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb1a15c0765808044ffc633803',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051741a15c0765808044ffc633803',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1781a15c0765808044ffc633803',
#     'width': 160}],
#   'name': 'Taylor Louderman',
#   'popularity': 50,
#   'type': 'artist',
#   'uri': 'spotify:artist:1f0vGTFXE64SLuypBV8zB0'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/32lVGr0fSRGT6okLKHiP68'},
#   'followers': {'href': None, 'total': 465854},
#   'genres': ['freestyle',
#    'hi-nrg',
#    'new romantic',
#    'new wave pop',
#    'soft rock',
#    'synthpop'],
#   'href': 'https://api.spotify.com/v1/artists/32lVGr0fSRGT6okLKHiP68',
#   'id': '32lVGr0fSRGT6okLKHiP68',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd6944ca0fcb7fc4d2aecad46',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d6944ca0fcb7fc4d2aecad46',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d6944ca0fcb7fc4d2aecad46',
#     'width': 160}],
#   'name': 'Taylor Dayne',
#   'popularity': 55,
#   'type': 'artist',
#   'uri': 'spotify:artist:32lVGr0fSRGT6okLKHiP68'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Iq6waFNaQnjLjEjp2l3nc'},
#   'followers': {'href': None, 'total': 540909},
#   'genres': ['movie tunes'],
#   'href': 'https://api.spotify.com/v1/artists/3Iq6waFNaQnjLjEjp2l3nc',
#   'id': '3Iq6waFNaQnjLjEjp2l3nc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb5fafe669290dd825da1b118e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051745fafe669290dd825da1b118e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1785fafe669290dd825da1b118e',
#     'width': 160}],
#   'name': 'Jojo Siwa (Kids)',
#   'popularity': 48,
#   'type': 'artist',
#   'uri': 'spotify:artist:3Iq6waFNaQnjLjEjp2l3nc'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Mbytr4DD854L4vp4J1LEj'},
#   'followers': {'href': None, 'total': 4407},
#   'genres': ['show tunes'],
#   'href': 'https://api.spotify.com/v1/artists/6Mbytr4DD854L4vp4J1LEj',
#   'id': '6Mbytr4DD854L4vp4J1LEj',
#   'images': [],
#   'name': 'Elle McLemore',
#   'popularity': 54,
#   'type': 'artist',
#   'uri': 'spotify:artist:6Mbytr4DD854L4vp4J1LEj'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jcl46xRBm9LKIwrKGQPE6'},
#   'followers': {'href': None, 'total': 207654},
#   'genres': ['movie tunes', 'nyc pop'],
#   'href': 'https://api.spotify.com/v1/artists/0jcl46xRBm9LKIwrKGQPE6',
#   'id': '0jcl46xRBm9LKIwrKGQPE6',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb9f75349ecac0b1e94563af6e',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051749f75349ecac0b1e94563af6e',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1789f75349ecac0b1e94563af6e',
#     'width': 160}],
#   'name': 'Meg Donnelly',
#   'popularity': 55,
#   'type': 'artist',
#   'uri': 'spotify:artist:0jcl46xRBm9LKIwrKGQPE6'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zTbBugfNc95zo8ClFDhIn'},
#   'followers': {'href': None, 'total': 99239},
#   'genres': ['movie tunes'],
#   'href': 'https://api.spotify.com/v1/artists/6zTbBugfNc95zo8ClFDhIn',
#   'id': '6zTbBugfNc95zo8ClFDhIn',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebb2acbcc89d74da7e4f300650',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174b2acbcc89d74da7e4f300650',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178b2acbcc89d74da7e4f300650',
#     'width': 160}],
#   'name': 'Troy',
#   'popularity': 58,
#   'type': 'artist',
#   'uri': 'spotify:artist:6zTbBugfNc95zo8ClFDhIn'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nkr1fevjIVmgx5biwAWVo'},
#   'followers': {'href': None, 'total': 13785},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7nkr1fevjIVmgx5biwAWVo',
#   'id': '7nkr1fevjIVmgx5biwAWVo',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb8e5a8ed4bb07804dc8ebe8b0',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051748e5a8ed4bb07804dc8ebe8b0',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1788e5a8ed4bb07804dc8ebe8b0',
#     'width': 160}],
#   'name': 'Taylour Paige',
#   'popularity': 47,
#   'type': 'artist',
#   'uri': 'spotify:artist:7nkr1fevjIVmgx5biwAWVo'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3HsVtnnjOUToyJThxaoBfx'},
#   'followers': {'href': None, 'total': 314140},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/3HsVtnnjOUToyJThxaoBfx',
#   'id': '3HsVtnnjOUToyJThxaoBfx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb46ffe763f21bc8b1a6745c9c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517446ffe763f21bc8b1a6745c9c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17846ffe763f21bc8b1a6745c9c',
#     'width': 160}],
#   'name': 'Halle',
#   'popularity': 53,
#   'type': 'artist',
#   'uri': 'spotify:artist:3HsVtnnjOUToyJThxaoBfx'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/30ejUciK31BCg0IVCbt1dW'},
#   'followers': {'href': None, 'total': 17084},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/30ejUciK31BCg0IVCbt1dW',
#   'id': '30ejUciK31BCg0IVCbt1dW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb39ab87fa7e1dd658ec5dd081',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517439ab87fa7e1dd658ec5dd081',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17839ab87fa7e1dd658ec5dd081',
#     'width': 160}],
#   'name': 'Mike Taylor',
#   'popularity': 52,
#   'type': 'artist',
#   'uri': 'spotify:artist:30ejUciK31BCg0IVCbt1dW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7cxXeGqb1uIhoiSXQ6kejX'},
#   'followers': {'href': None, 'total': 13539},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7cxXeGqb1uIhoiSXQ6kejX',
#   'id': '7cxXeGqb1uIhoiSXQ6kejX',
#   'images': [],
#   'name': 'The Lorax Singers',
#   'popularity': 49,
#   'type': 'artist',
#   'uri': 'spotify:artist:7cxXeGqb1uIhoiSXQ6kejX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0iv7RfSxMSAvCzCVnxys6g'},
#   'followers': {'href': None, 'total': 262875},
#   'genres': ['meme'],
#   'href': 'https://api.spotify.com/v1/artists/0iv7RfSxMSAvCzCVnxys6g',
#   'id': '0iv7RfSxMSAvCzCVnxys6g',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb2ddecde6dafacf68bd59b0f3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051742ddecde6dafacf68bd59b0f3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1782ddecde6dafacf68bd59b0f3',
#     'width': 160}],
#   'name': 'Tiko',
#   'popularity': 48,
#   'type': 'artist',
#   'uri': 'spotify:artist:0iv7RfSxMSAvCzCVnxys6g'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3CVk2LzA3zH6FBAXuPbnhc'},
#   'followers': {'href': None, 'total': 35937},
#   'genres': ['christian indie'],
#   'href': 'https://api.spotify.com/v1/artists/3CVk2LzA3zH6FBAXuPbnhc',
#   'id': '3CVk2LzA3zH6FBAXuPbnhc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebed79936eeb4325a3212d9db3',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174ed79936eeb4325a3212d9db3',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178ed79936eeb4325a3212d9db3',
#     'width': 160}],
#   'name': 'Taylor Armstrong',
#   'popularity': 42,
#   'type': 'artist',
#   'uri': 'spotify:artist:3CVk2LzA3zH6FBAXuPbnhc'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5f1cs8LexmMYbhNEIOsDLT'},
#   'followers': {'href': None, 'total': 27828},
#   'genres': ['south carolina indie'],
#   'href': 'https://api.spotify.com/v1/artists/5f1cs8LexmMYbhNEIOsDLT',
#   'id': '5f1cs8LexmMYbhNEIOsDLT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebd98037c4ea387ebbb6f8b7a5',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174d98037c4ea387ebbb6f8b7a5',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178d98037c4ea387ebbb6f8b7a5',
#     'width': 160}],
#   'name': 'Taylor McCall',
#   'popularity': 40,
#   'type': 'artist',
#   'uri': 'spotify:artist:5f1cs8LexmMYbhNEIOsDLT'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/68CRxZTAqk19AznItZInip'},
#   'followers': {'href': None, 'total': 37731},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/68CRxZTAqk19AznItZInip',
#   'id': '68CRxZTAqk19AznItZInip',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb7debf8864ec8725e7b191d49',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051747debf8864ec8725e7b191d49',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1787debf8864ec8725e7b191d49',
#     'width': 160}],
#   'name': 'Swifty Blue',
#   'popularity': 44,
#   'type': 'artist',
#   'uri': 'spotify:artist:68CRxZTAqk19AznItZInip'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fxg10eJ6YmvUdM2PPB4Zk'},
#   'followers': {'href': None, 'total': 59432},
#   'genres': ['alt z'],
#   'href': 'https://api.spotify.com/v1/artists/3Fxg10eJ6YmvUdM2PPB4Zk',
#   'id': '3Fxg10eJ6YmvUdM2PPB4Zk',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb62d8eb6c871c46e88b4d5eec',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517462d8eb6c871c46e88b4d5eec',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17862d8eb6c871c46e88b4d5eec',
#     'width': 160}],
#   'name': 'Taylor Bickett',
#   'popularity': 42,
#   'type': 'artist',
#   'uri': 'spotify:artist:3Fxg10eJ6YmvUdM2PPB4Zk'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aU66AnY6CxGppINw6QGq1'},
#   'followers': {'href': None, 'total': 28356},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7aU66AnY6CxGppINw6QGq1',
#   'id': '7aU66AnY6CxGppINw6QGq1',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb3f3acc7ab586aa4fa19d5396',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051743f3acc7ab586aa4fa19d5396',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1783f3acc7ab586aa4fa19d5396',
#     'width': 160}],
#   'name': 'Kylee Russell',
#   'popularity': 49,
#   'type': 'artist',
#   'uri': 'spotify:artist:7aU66AnY6CxGppINw6QGq1'}]

# %%
# Let's take a look at the first returned result
first_returned_artist = response['artists']['items'][0]

# %%
first_returned_artist.keys()
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
first_returned_artist['id']
# Out:
# '06HL4z0CvFAxyc27GXpf02'

# %%
first_returned_artist['name']
# Out:
# 'Taylor Swift'

# %%
first_returned_artist['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}

# %%
first_returned_artist['followers']
# Out:
# {'href': None, 'total': 113134236}

# %%
first_returned_artist['popularity']
# Out:
# 100

# %%
# Now, let's create a dataframe to see all the returned data
import pandas as pd

df = pd.DataFrame(response['artists']['items'])
df
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/0...
# 1   {'spotify': 'https://open.spotify.com/artist/0...
# 2   {'spotify': 'https://open.spotify.com/artist/1...
# 3   {'spotify': 'https://open.spotify.com/artist/3...
# 4   {'spotify': 'https://open.spotify.com/artist/6...
# 5   {'spotify': 'https://open.spotify.com/artist/5...
# 6   {'spotify': 'https://open.spotify.com/artist/5...
# 7   {'spotify': 'https://open.spotify.com/artist/1...
# 8   {'spotify': 'https://open.spotify.com/artist/4...
# 9   {'spotify': 'https://open.spotify.com/artist/7...
# 10  {'spotify': 'https://open.spotify.com/artist/1...
# 11  {'spotify': 'https://open.spotify.com/artist/1...
# 12  {'spotify': 'https://open.spotify.com/artist/6...
# 13  {'spotify': 'https://open.spotify.com/artist/5...
# 14  {'spotify': 'https://open.spotify.com/artist/4...
# 15  {'spotify': 'https://open.spotify.com/artist/3...
# 16  {'spotify': 'https://open.spotify.com/artist/6...
# 17  {'spotify': 'https://open.spotify.com/artist/7...
# 18  {'spotify': 'https://open.spotify.com/artist/1...
# 19  {'spotify': 'https://open.spotify.com/artist/1...
# 20  {'spotify': 'https://open.spotify.com/artist/1...
# 21  {'spotify': 'https://open.spotify.com/artist/5...
# 22  {'spotify': 'https://open.spotify.com/artist/5...
# 23  {'spotify': 'https://open.spotify.com/artist/6...
# 24  {'spotify': 'https://open.spotify.com/artist/1...
# 25  {'spotify': 'https://open.spotify.com/artist/6...
# 26  {'spotify': 'https://open.spotify.com/artist/6...
# 27  {'spotify': 'https://open.spotify.com/artist/0...
# 28  {'spotify': 'https://open.spotify.com/artist/4...
# 29  {'spotify': 'https://open.spotify.com/artist/2...
# 30  {'spotify': 'https://open.spotify.com/artist/1...
# 31  {'spotify': 'https://open.spotify.com/artist/5...
# 32  {'spotify': 'https://open.spotify.com/artist/4...
# 33  {'spotify': 'https://open.spotify.com/artist/5...
# 34  {'spotify': 'https://open.spotify.com/artist/1...
# 35  {'spotify': 'https://open.spotify.com/artist/3...
# 36  {'spotify': 'https://open.spotify.com/artist/3...
# 37  {'spotify': 'https://open.spotify.com/artist/6...
# 38  {'spotify': 'https://open.spotify.com/artist/0...
# 39  {'spotify': 'https://open.spotify.com/artist/6...
# 40  {'spotify': 'https://open.spotify.com/artist/7...
# 41  {'spotify': 'https://open.spotify.com/artist/3...
# 42  {'spotify': 'https://open.spotify.com/artist/3...
# 43  {'spotify': 'https://open.spotify.com/artist/7...
# 44  {'spotify': 'https://open.spotify.com/artist/0...
# 45  {'spotify': 'https://open.spotify.com/artist/3...
# 46  {'spotify': 'https://open.spotify.com/artist/5...
# 47  {'spotify': 'https://open.spotify.com/artist/6...
# 48  {'spotify': 'https://open.spotify.com/artist/3...
# 49  {'spotify': 'https://open.spotify.com/artist/7...
#
#                              followers  \
# 0   {'href': None, 'total': 113134236}
# 1        {'href': None, 'total': 3466}
# 2    {'href': None, 'total': 36795065}
# 3         {'href': None, 'total': 427}
# 4    {'href': None, 'total': 33352242}
# 5         {'href': None, 'total': 110}
# 6    {'href': None, 'total': 24115342}
# 7         {'href': None, 'total': 384}
# 8     {'href': None, 'total': 5442096}
# 9          {'href': None, 'total': 90}
# 10    {'href': None, 'total': 1207162}
# 11         {'href': None, 'total': 61}
# 12    {'href': None, 'total': 3344919}
# 13         {'href': None, 'total': 49}
# 14   {'href': None, 'total': 55874806}
# 15        {'href': None, 'total': 154}
# 16    {'href': None, 'total': 7900156}
# 17        {'href': None, 'total': 157}
# 18    {'href': None, 'total': 9968230}
# 19         {'href': None, 'total': 54}
# 20    {'href': None, 'total': 4455278}
# 21    {'href': None, 'total': 5715478}
# 22    {'href': None, 'total': 6202410}
# 23    {'href': None, 'total': 1625098}
# 24     {'href': None, 'total': 191422}
# 25     {'href': None, 'total': 213977}
# 26      {'href': None, 'total': 52486}
# 27      {'href': None, 'total': 47825}
# 28    {'href': None, 'total': 1323278}
# 29     {'href': None, 'total': 138403}
# 30     {'href': None, 'total': 302316}
# 31     {'href': None, 'total': 193936}
# 32     {'href': None, 'total': 193248}
# 33     {'href': None, 'total': 139564}
# 34      {'href': None, 'total': 14391}
# 35     {'href': None, 'total': 465854}
# 36     {'href': None, 'total': 540909}
# 37       {'href': None, 'total': 4407}
# 38     {'href': None, 'total': 207654}
# 39      {'href': None, 'total': 99239}
# 40      {'href': None, 'total': 13785}
# 41     {'href': None, 'total': 314140}
# 42      {'href': None, 'total': 17084}
# 43      {'href': None, 'total': 13539}
# 44     {'href': None, 'total': 262875}
# 45      {'href': None, 'total': 35937}
# 46      {'href': None, 'total': 27828}
# 47      {'href': None, 'total': 37731}
# 48      {'href': None, 'total': 59432}
# 49      {'href': None, 'total': 28356}
#
#                                                genres  \
# 0                                               [pop]
# 1                                                  []
# 2                                               [pop]
# 3                                                  []
# 4                                               [pop]
# 5                                                  []
# 6                                               [pop]
# 7                                                  []
# 8                                               [pop]
# 9                                                  []
# 10                                 [children's music]
# 11                                                 []
# 12                                       [pov: indie]
# 13                                                 []
# 14              [british soul, pop, pop soul, uk pop]
# 15                                                 []
# 16                                   [dance pop, pop]
# 17                                                 []
# 18               [art pop, metropopolis, nz pop, pop]
# 19                                                 []
# 20  [modern indie pop, pov: indie, singer-songwrit...
# 21  [escape room, minnesota hip hop, pop, trap queen]
# 22                                              [pop]
# 23                                       [alt z, pop]
# 24                            [singer-songwriter pop]
# 25                      [australian children's music]
# 26                        [cartoon, children's music]
# 27                                                 []
# 28                       [indietronica, metropopolis]
# 29                                      [movie tunes]
# 30                                         [broadway]
# 31                                          [redneck]
# 32                              [bow pop, pop violin]
# 33                                 [social media pop]
# 34                             [broadway, show tunes]
# 35  [freestyle, hi-nrg, new romantic, new wave pop...
# 36                                      [movie tunes]
# 37                                       [show tunes]
# 38                             [movie tunes, nyc pop]
# 39                                      [movie tunes]
# 40                                                 []
# 41                                                 []
# 42                                                 []
# 43                                                 []
# 44                                             [meme]
# 45                                  [christian indie]
# 46                             [south carolina indie]
# 47                                                 []
# 48                                            [alt z]
# 49                                                 []
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 1   https://api.spotify.com/v1/artists/0DwbGCdaD8Y...  0DwbGCdaD8YLRiVUEiV70Q
# 2   https://api.spotify.com/v1/artists/1McMsnEElTh...  1McMsnEElThX1knmY4oliG
# 3   https://api.spotify.com/v1/artists/3OGj4jFXF7C...  3OGj4jFXF7Cw4ORWS7T3ra
# 4   https://api.spotify.com/v1/artists/6jJ0s89eD6G...  6jJ0s89eD6GaHleKKya26X
# 5   https://api.spotify.com/v1/artists/5Yzz6SisIkc...  5Yzz6SisIkcvuhKSdJ02en
# 6   https://api.spotify.com/v1/artists/5YGY8feqx7n...  5YGY8feqx7naU7z4HrwZM6
# 7   https://api.spotify.com/v1/artists/1bgoHMYkNqV...  1bgoHMYkNqVC9PTOrQECts
# 8   https://api.spotify.com/v1/artists/45dkTj5sMRS...  45dkTj5sMRSjrmBSBeiHym
# 9   https://api.spotify.com/v1/artists/7oW3aIseIyp...  7oW3aIseIypoEqcOqvzUfS
# 10  https://api.spotify.com/v1/artists/1Vvvx45Apu6...  1Vvvx45Apu6dQqwuZQxtgW
# 11  https://api.spotify.com/v1/artists/14waR9FpjuH...  14waR9FpjuHkqhd3DlMAYu
# 12  https://api.spotify.com/v1/artists/6s22t5Y3prQ...  6s22t5Y3prQHyaHWUN1R1C
# 13  https://api.spotify.com/v1/artists/5D4eBBCFWPi...  5D4eBBCFWPid24YVLH7206
# 14  https://api.spotify.com/v1/artists/4dpARuHxo51...  4dpARuHxo51G3z768sgnrY
# 15  https://api.spotify.com/v1/artists/3vZoN5cnYOy...  3vZoN5cnYOycsJ5KsFkjo5
# 16  https://api.spotify.com/v1/artists/6LqNN22kT30...  6LqNN22kT3074XbTVUrhzX
# 17  https://api.spotify.com/v1/artists/75xajtqlPSZ...  75xajtqlPSZfqpy29CcGT9
# 18  https://api.spotify.com/v1/artists/163tK9Wjr9P...  163tK9Wjr9P9DmM0AVK7lm
# 19  https://api.spotify.com/v1/artists/1pZI3RPswAg...  1pZI3RPswAgKWRNDFP9ReN
# 20  https://api.spotify.com/v1/artists/164Uj4eKjl6...  164Uj4eKjl6zTBKfJLFKKK
# 21  https://api.spotify.com/v1/artists/56oDRnqbIiw...  56oDRnqbIiwx4mymNEv7dS
# 22  https://api.spotify.com/v1/artists/5JZ7CnR6gTv...  5JZ7CnR6gTvEMKX4g70Amv
# 23  https://api.spotify.com/v1/artists/6Dd3NScHWwn...  6Dd3NScHWwnW6obMFbl1BH
# 24  https://api.spotify.com/v1/artists/1A0WloDoRE8...  1A0WloDoRE88uUwo3wensY
# 25  https://api.spotify.com/v1/artists/6ca3AFdIIga...  6ca3AFdIIgaP4ZIW8J6zXu
# 26  https://api.spotify.com/v1/artists/64TYMfqkpGQ...  64TYMfqkpGQsUEuF5xqS2R
# 27  https://api.spotify.com/v1/artists/0IqjJsWlAPR...  0IqjJsWlAPR2IafHTtnjPQ
# 28  https://api.spotify.com/v1/artists/4Ui2kfOqGuj...  4Ui2kfOqGujY81UcPrb5KE
# 29  https://api.spotify.com/v1/artists/2L7RaHwfVU6...  2L7RaHwfVU6ge64IJF8GO5
# 30  https://api.spotify.com/v1/artists/1VbWMsap5Ex...  1VbWMsap5Ex2erHPlmndr0
# 31  https://api.spotify.com/v1/artists/58nB2Z6IiDd...  58nB2Z6IiDdTUTwHYw56xI
# 32  https://api.spotify.com/v1/artists/480xKab3lUP...  480xKab3lUPhBBnCzlzqIu
# 33  https://api.spotify.com/v1/artists/5Hz3IW691fb...  5Hz3IW691fbgGqLk4yvlNN
# 34  https://api.spotify.com/v1/artists/1f0vGTFXE64...  1f0vGTFXE64SLuypBV8zB0
# 35  https://api.spotify.com/v1/artists/32lVGr0fSRG...  32lVGr0fSRGT6okLKHiP68
# 36  https://api.spotify.com/v1/artists/3Iq6waFNaQn...  3Iq6waFNaQnjLjEjp2l3nc
# 37  https://api.spotify.com/v1/artists/6Mbytr4DD85...  6Mbytr4DD854L4vp4J1LEj
# 38  https://api.spotify.com/v1/artists/0jcl46xRBm9...  0jcl46xRBm9LKIwrKGQPE6
# 39  https://api.spotify.com/v1/artists/6zTbBugfNc9...  6zTbBugfNc95zo8ClFDhIn
# 40  https://api.spotify.com/v1/artists/7nkr1fevjIV...  7nkr1fevjIVmgx5biwAWVo
# 41  https://api.spotify.com/v1/artists/3HsVtnnjOUT...  3HsVtnnjOUToyJThxaoBfx
# 42  https://api.spotify.com/v1/artists/30ejUciK31B...  30ejUciK31BCg0IVCbt1dW
# 43  https://api.spotify.com/v1/artists/7cxXeGqb1uI...  7cxXeGqb1uIhoiSXQ6kejX
# 44  https://api.spotify.com/v1/artists/0iv7RfSxMSA...  0iv7RfSxMSAvCzCVnxys6g
# 45  https://api.spotify.com/v1/artists/3CVk2LzA3zH...  3CVk2LzA3zH6FBAXuPbnhc
# 46  https://api.spotify.com/v1/artists/5f1cs8LexmM...  5f1cs8LexmMYbhNEIOsDLT
# 47  https://api.spotify.com/v1/artists/68CRxZTAqk1...  68CRxZTAqk19AznItZInip
# 48  https://api.spotify.com/v1/artists/3Fxg10eJ6Ym...  3Fxg10eJ6YmvUdM2PPB4Zk
# 49  https://api.spotify.com/v1/artists/7aU66AnY6Cx...  7aU66AnY6CxGppINw6QGq1
#
#                                                images  \
# 0   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7                                                  []
# 8   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9                                                  []
# 10  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11                                                 []
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 16  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 20  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 21  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 22  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 23  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 24  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 25  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 26  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 27  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 28  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 29  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 31  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 32  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 33  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 34  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 35  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 36  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 37                                                 []
# 38  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 39  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 40  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 41  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 42  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 43                                                 []
# 44  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 45  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 46  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 47  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 48  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 49  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                       name  popularity    type  \
# 0                             Taylor Swift         100  artist
# 1                Taylor Swift Piano Covers          29  artist
# 2                           Olivia Rodrigo          87  artist
# 3                       Taylor Swift Facts           2  artist
# 4                               Katy Perry          83  artist
# 5                           Taylor Swifter           0  artist
# 6                              Miley Cyrus          82  artist
# 7                  Ed Sheeran Taylor Swift           1  artist
# 8                               Tate McRae          82  artist
# 9                           taylorr swiftt           6  artist
# 10                           Kidz Bop Kids          65  artist
# 11                          Taylor Swiftsz           0  artist
# 12                                     AJR          72  artist
# 13                          Taylor Swiftoo           0  artist
# 14                                   Adele          82  artist
# 15  Taylor Swift - Evermore - Piano Covers           5  artist
# 16                                   Kesha          77  artist
# 17       The Taylor Swift Piano Cover Band           0  artist
# 18                                   Lorde          73  artist
# 19        Taylor Swift Piano Instrumentals           0  artist
# 20                                    JVKE          74  artist
# 21                                   Lizzo          69  artist
# 22                                    Lauv          74  artist
# 23                                    Daya          71  artist
# 24                            Taylor Acorn          54  artist
# 25                                   Bluey          64  artist
# 26                                    Elmo          57  artist
# 27                             Minnz Piano          56  artist
# 28                                    HAIM          62  artist
# 29                          ZOMBIES – Cast          60  artist
# 30                                     SIX          60  artist
# 31                     Taylor Ray Holbrook          51  artist
# 32                            Taylor Davis          47  artist
# 33                           Tayler Holder          42  artist
# 34                        Taylor Louderman          50  artist
# 35                            Taylor Dayne          55  artist
# 36                        Jojo Siwa (Kids)          48  artist
# 37                           Elle McLemore          54  artist
# 38                            Meg Donnelly          55  artist
# 39                                    Troy          58  artist
# 40                           Taylour Paige          47  artist
# 41                                   Halle          53  artist
# 42                             Mike Taylor          52  artist
# 43                       The Lorax Singers          49  artist
# 44                                    Tiko          48  artist
# 45                        Taylor Armstrong          42  artist
# 46                           Taylor McCall          40  artist
# 47                             Swifty Blue          44  artist
# 48                          Taylor Bickett          42  artist
# 49                           Kylee Russell          49  artist
#
#                                       uri
# 0   spotify:artist:06HL4z0CvFAxyc27GXpf02
# 1   spotify:artist:0DwbGCdaD8YLRiVUEiV70Q
# 2   spotify:artist:1McMsnEElThX1knmY4oliG
# 3   spotify:artist:3OGj4jFXF7Cw4ORWS7T3ra
# 4   spotify:artist:6jJ0s89eD6GaHleKKya26X
# 5   spotify:artist:5Yzz6SisIkcvuhKSdJ02en
# 6   spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 7   spotify:artist:1bgoHMYkNqVC9PTOrQECts
# 8   spotify:artist:45dkTj5sMRSjrmBSBeiHym
# 9   spotify:artist:7oW3aIseIypoEqcOqvzUfS
# 10  spotify:artist:1Vvvx45Apu6dQqwuZQxtgW
# 11  spotify:artist:14waR9FpjuHkqhd3DlMAYu
# 12  spotify:artist:6s22t5Y3prQHyaHWUN1R1C
# 13  spotify:artist:5D4eBBCFWPid24YVLH7206
# 14  spotify:artist:4dpARuHxo51G3z768sgnrY
# 15  spotify:artist:3vZoN5cnYOycsJ5KsFkjo5
# 16  spotify:artist:6LqNN22kT3074XbTVUrhzX
# 17  spotify:artist:75xajtqlPSZfqpy29CcGT9
# 18  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 19  spotify:artist:1pZI3RPswAgKWRNDFP9ReN
# 20  spotify:artist:164Uj4eKjl6zTBKfJLFKKK
# 21  spotify:artist:56oDRnqbIiwx4mymNEv7dS
# 22  spotify:artist:5JZ7CnR6gTvEMKX4g70Amv
# 23  spotify:artist:6Dd3NScHWwnW6obMFbl1BH
# 24  spotify:artist:1A0WloDoRE88uUwo3wensY
# 25  spotify:artist:6ca3AFdIIgaP4ZIW8J6zXu
# 26  spotify:artist:64TYMfqkpGQsUEuF5xqS2R
# 27  spotify:artist:0IqjJsWlAPR2IafHTtnjPQ
# 28  spotify:artist:4Ui2kfOqGujY81UcPrb5KE
# 29  spotify:artist:2L7RaHwfVU6ge64IJF8GO5
# 30  spotify:artist:1VbWMsap5Ex2erHPlmndr0
# 31  spotify:artist:58nB2Z6IiDdTUTwHYw56xI
# 32  spotify:artist:480xKab3lUPhBBnCzlzqIu
# 33  spotify:artist:5Hz3IW691fbgGqLk4yvlNN
# 34  spotify:artist:1f0vGTFXE64SLuypBV8zB0
# 35  spotify:artist:32lVGr0fSRGT6okLKHiP68
# 36  spotify:artist:3Iq6waFNaQnjLjEjp2l3nc
# 37  spotify:artist:6Mbytr4DD854L4vp4J1LEj
# 38  spotify:artist:0jcl46xRBm9LKIwrKGQPE6
# 39  spotify:artist:6zTbBugfNc95zo8ClFDhIn
# 40  spotify:artist:7nkr1fevjIVmgx5biwAWVo
# 41  spotify:artist:3HsVtnnjOUToyJThxaoBfx
# 42  spotify:artist:30ejUciK31BCg0IVCbt1dW
# 43  spotify:artist:7cxXeGqb1uIhoiSXQ6kejX
# 44  spotify:artist:0iv7RfSxMSAvCzCVnxys6g
# 45  spotify:artist:3CVk2LzA3zH6FBAXuPbnhc
# 46  spotify:artist:5f1cs8LexmMYbhNEIOsDLT
# 47  spotify:artist:68CRxZTAqk19AznItZInip
# 48  spotify:artist:3Fxg10eJ6YmvUdM2PPB4Zk
# 49  spotify:artist:7aU66AnY6CxGppINw6QGq1

# %%
# And we will use json_normalize to flatten the elements that are dictionaries
# We will still have elements that contain lists
from pandas import json_normalize

df_normalized = json_normalize(response['artists']['items'])
df_normalized.dtypes
# Out:
# genres                   object
# href                     object
# id                       object
# images                   object
# name                     object
# popularity                int64
# type                     object
# uri                      object
# external_urls.spotify    object
# followers.href           object
# followers.total           int64
# dtype: object

# %%
df_normalized
# Out:
#                                                genres  \
# 0                                               [pop]
# 1                                                  []
# 2                                               [pop]
# 3                                                  []
# 4                                               [pop]
# 5                                                  []
# 6                                               [pop]
# 7                                                  []
# 8                                               [pop]
# 9                                                  []
# 10                                 [children's music]
# 11                                                 []
# 12                                       [pov: indie]
# 13                                                 []
# 14              [british soul, pop, pop soul, uk pop]
# 15                                                 []
# 16                                   [dance pop, pop]
# 17                                                 []
# 18               [art pop, metropopolis, nz pop, pop]
# 19                                                 []
# 20  [modern indie pop, pov: indie, singer-songwrit...
# 21  [escape room, minnesota hip hop, pop, trap queen]
# 22                                              [pop]
# 23                                       [alt z, pop]
# 24                            [singer-songwriter pop]
# 25                      [australian children's music]
# 26                        [cartoon, children's music]
# 27                                                 []
# 28                       [indietronica, metropopolis]
# 29                                      [movie tunes]
# 30                                         [broadway]
# 31                                          [redneck]
# 32                              [bow pop, pop violin]
# 33                                 [social media pop]
# 34                             [broadway, show tunes]
# 35  [freestyle, hi-nrg, new romantic, new wave pop...
# 36                                      [movie tunes]
# 37                                       [show tunes]
# 38                             [movie tunes, nyc pop]
# 39                                      [movie tunes]
# 40                                                 []
# 41                                                 []
# 42                                                 []
# 43                                                 []
# 44                                             [meme]
# 45                                  [christian indie]
# 46                             [south carolina indie]
# 47                                                 []
# 48                                            [alt z]
# 49                                                 []
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 1   https://api.spotify.com/v1/artists/0DwbGCdaD8Y...  0DwbGCdaD8YLRiVUEiV70Q
# 2   https://api.spotify.com/v1/artists/1McMsnEElTh...  1McMsnEElThX1knmY4oliG
# 3   https://api.spotify.com/v1/artists/3OGj4jFXF7C...  3OGj4jFXF7Cw4ORWS7T3ra
# 4   https://api.spotify.com/v1/artists/6jJ0s89eD6G...  6jJ0s89eD6GaHleKKya26X
# 5   https://api.spotify.com/v1/artists/5Yzz6SisIkc...  5Yzz6SisIkcvuhKSdJ02en
# 6   https://api.spotify.com/v1/artists/5YGY8feqx7n...  5YGY8feqx7naU7z4HrwZM6
# 7   https://api.spotify.com/v1/artists/1bgoHMYkNqV...  1bgoHMYkNqVC9PTOrQECts
# 8   https://api.spotify.com/v1/artists/45dkTj5sMRS...  45dkTj5sMRSjrmBSBeiHym
# 9   https://api.spotify.com/v1/artists/7oW3aIseIyp...  7oW3aIseIypoEqcOqvzUfS
# 10  https://api.spotify.com/v1/artists/1Vvvx45Apu6...  1Vvvx45Apu6dQqwuZQxtgW
# 11  https://api.spotify.com/v1/artists/14waR9FpjuH...  14waR9FpjuHkqhd3DlMAYu
# 12  https://api.spotify.com/v1/artists/6s22t5Y3prQ...  6s22t5Y3prQHyaHWUN1R1C
# 13  https://api.spotify.com/v1/artists/5D4eBBCFWPi...  5D4eBBCFWPid24YVLH7206
# 14  https://api.spotify.com/v1/artists/4dpARuHxo51...  4dpARuHxo51G3z768sgnrY
# 15  https://api.spotify.com/v1/artists/3vZoN5cnYOy...  3vZoN5cnYOycsJ5KsFkjo5
# 16  https://api.spotify.com/v1/artists/6LqNN22kT30...  6LqNN22kT3074XbTVUrhzX
# 17  https://api.spotify.com/v1/artists/75xajtqlPSZ...  75xajtqlPSZfqpy29CcGT9
# 18  https://api.spotify.com/v1/artists/163tK9Wjr9P...  163tK9Wjr9P9DmM0AVK7lm
# 19  https://api.spotify.com/v1/artists/1pZI3RPswAg...  1pZI3RPswAgKWRNDFP9ReN
# 20  https://api.spotify.com/v1/artists/164Uj4eKjl6...  164Uj4eKjl6zTBKfJLFKKK
# 21  https://api.spotify.com/v1/artists/56oDRnqbIiw...  56oDRnqbIiwx4mymNEv7dS
# 22  https://api.spotify.com/v1/artists/5JZ7CnR6gTv...  5JZ7CnR6gTvEMKX4g70Amv
# 23  https://api.spotify.com/v1/artists/6Dd3NScHWwn...  6Dd3NScHWwnW6obMFbl1BH
# 24  https://api.spotify.com/v1/artists/1A0WloDoRE8...  1A0WloDoRE88uUwo3wensY
# 25  https://api.spotify.com/v1/artists/6ca3AFdIIga...  6ca3AFdIIgaP4ZIW8J6zXu
# 26  https://api.spotify.com/v1/artists/64TYMfqkpGQ...  64TYMfqkpGQsUEuF5xqS2R
# 27  https://api.spotify.com/v1/artists/0IqjJsWlAPR...  0IqjJsWlAPR2IafHTtnjPQ
# 28  https://api.spotify.com/v1/artists/4Ui2kfOqGuj...  4Ui2kfOqGujY81UcPrb5KE
# 29  https://api.spotify.com/v1/artists/2L7RaHwfVU6...  2L7RaHwfVU6ge64IJF8GO5
# 30  https://api.spotify.com/v1/artists/1VbWMsap5Ex...  1VbWMsap5Ex2erHPlmndr0
# 31  https://api.spotify.com/v1/artists/58nB2Z6IiDd...  58nB2Z6IiDdTUTwHYw56xI
# 32  https://api.spotify.com/v1/artists/480xKab3lUP...  480xKab3lUPhBBnCzlzqIu
# 33  https://api.spotify.com/v1/artists/5Hz3IW691fb...  5Hz3IW691fbgGqLk4yvlNN
# 34  https://api.spotify.com/v1/artists/1f0vGTFXE64...  1f0vGTFXE64SLuypBV8zB0
# 35  https://api.spotify.com/v1/artists/32lVGr0fSRG...  32lVGr0fSRGT6okLKHiP68
# 36  https://api.spotify.com/v1/artists/3Iq6waFNaQn...  3Iq6waFNaQnjLjEjp2l3nc
# 37  https://api.spotify.com/v1/artists/6Mbytr4DD85...  6Mbytr4DD854L4vp4J1LEj
# 38  https://api.spotify.com/v1/artists/0jcl46xRBm9...  0jcl46xRBm9LKIwrKGQPE6
# 39  https://api.spotify.com/v1/artists/6zTbBugfNc9...  6zTbBugfNc95zo8ClFDhIn
# 40  https://api.spotify.com/v1/artists/7nkr1fevjIV...  7nkr1fevjIVmgx5biwAWVo
# 41  https://api.spotify.com/v1/artists/3HsVtnnjOUT...  3HsVtnnjOUToyJThxaoBfx
# 42  https://api.spotify.com/v1/artists/30ejUciK31B...  30ejUciK31BCg0IVCbt1dW
# 43  https://api.spotify.com/v1/artists/7cxXeGqb1uI...  7cxXeGqb1uIhoiSXQ6kejX
# 44  https://api.spotify.com/v1/artists/0iv7RfSxMSA...  0iv7RfSxMSAvCzCVnxys6g
# 45  https://api.spotify.com/v1/artists/3CVk2LzA3zH...  3CVk2LzA3zH6FBAXuPbnhc
# 46  https://api.spotify.com/v1/artists/5f1cs8LexmM...  5f1cs8LexmMYbhNEIOsDLT
# 47  https://api.spotify.com/v1/artists/68CRxZTAqk1...  68CRxZTAqk19AznItZInip
# 48  https://api.spotify.com/v1/artists/3Fxg10eJ6Ym...  3Fxg10eJ6YmvUdM2PPB4Zk
# 49  https://api.spotify.com/v1/artists/7aU66AnY6Cx...  7aU66AnY6CxGppINw6QGq1
#
#                                                images  \
# 0   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7                                                  []
# 8   [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9                                                  []
# 10  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11                                                 []
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 16  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 20  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 21  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 22  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 23  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 24  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 25  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 26  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 27  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 28  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 29  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 31  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 32  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 33  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 34  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 35  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 36  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 37                                                 []
# 38  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 39  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 40  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 41  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 42  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 43                                                 []
# 44  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 45  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 46  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 47  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 48  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 49  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                       name  popularity    type  \
# 0                             Taylor Swift         100  artist
# 1                Taylor Swift Piano Covers          29  artist
# 2                           Olivia Rodrigo          87  artist
# 3                       Taylor Swift Facts           2  artist
# 4                               Katy Perry          83  artist
# 5                           Taylor Swifter           0  artist
# 6                              Miley Cyrus          82  artist
# 7                  Ed Sheeran Taylor Swift           1  artist
# 8                               Tate McRae          82  artist
# 9                           taylorr swiftt           6  artist
# 10                           Kidz Bop Kids          65  artist
# 11                          Taylor Swiftsz           0  artist
# 12                                     AJR          72  artist
# 13                          Taylor Swiftoo           0  artist
# 14                                   Adele          82  artist
# 15  Taylor Swift - Evermore - Piano Covers           5  artist
# 16                                   Kesha          77  artist
# 17       The Taylor Swift Piano Cover Band           0  artist
# 18                                   Lorde          73  artist
# 19        Taylor Swift Piano Instrumentals           0  artist
# 20                                    JVKE          74  artist
# 21                                   Lizzo          69  artist
# 22                                    Lauv          74  artist
# 23                                    Daya          71  artist
# 24                            Taylor Acorn          54  artist
# 25                                   Bluey          64  artist
# 26                                    Elmo          57  artist
# 27                             Minnz Piano          56  artist
# 28                                    HAIM          62  artist
# 29                          ZOMBIES – Cast          60  artist
# 30                                     SIX          60  artist
# 31                     Taylor Ray Holbrook          51  artist
# 32                            Taylor Davis          47  artist
# 33                           Tayler Holder          42  artist
# 34                        Taylor Louderman          50  artist
# 35                            Taylor Dayne          55  artist
# 36                        Jojo Siwa (Kids)          48  artist
# 37                           Elle McLemore          54  artist
# 38                            Meg Donnelly          55  artist
# 39                                    Troy          58  artist
# 40                           Taylour Paige          47  artist
# 41                                   Halle          53  artist
# 42                             Mike Taylor          52  artist
# 43                       The Lorax Singers          49  artist
# 44                                    Tiko          48  artist
# 45                        Taylor Armstrong          42  artist
# 46                           Taylor McCall          40  artist
# 47                             Swifty Blue          44  artist
# 48                          Taylor Bickett          42  artist
# 49                           Kylee Russell          49  artist
#
#                                       uri  \
# 0   spotify:artist:06HL4z0CvFAxyc27GXpf02
# 1   spotify:artist:0DwbGCdaD8YLRiVUEiV70Q
# 2   spotify:artist:1McMsnEElThX1knmY4oliG
# 3   spotify:artist:3OGj4jFXF7Cw4ORWS7T3ra
# 4   spotify:artist:6jJ0s89eD6GaHleKKya26X
# 5   spotify:artist:5Yzz6SisIkcvuhKSdJ02en
# 6   spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 7   spotify:artist:1bgoHMYkNqVC9PTOrQECts
# 8   spotify:artist:45dkTj5sMRSjrmBSBeiHym
# 9   spotify:artist:7oW3aIseIypoEqcOqvzUfS
# 10  spotify:artist:1Vvvx45Apu6dQqwuZQxtgW
# 11  spotify:artist:14waR9FpjuHkqhd3DlMAYu
# 12  spotify:artist:6s22t5Y3prQHyaHWUN1R1C
# 13  spotify:artist:5D4eBBCFWPid24YVLH7206
# 14  spotify:artist:4dpARuHxo51G3z768sgnrY
# 15  spotify:artist:3vZoN5cnYOycsJ5KsFkjo5
# 16  spotify:artist:6LqNN22kT3074XbTVUrhzX
# 17  spotify:artist:75xajtqlPSZfqpy29CcGT9
# 18  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 19  spotify:artist:1pZI3RPswAgKWRNDFP9ReN
# 20  spotify:artist:164Uj4eKjl6zTBKfJLFKKK
# 21  spotify:artist:56oDRnqbIiwx4mymNEv7dS
# 22  spotify:artist:5JZ7CnR6gTvEMKX4g70Amv
# 23  spotify:artist:6Dd3NScHWwnW6obMFbl1BH
# 24  spotify:artist:1A0WloDoRE88uUwo3wensY
# 25  spotify:artist:6ca3AFdIIgaP4ZIW8J6zXu
# 26  spotify:artist:64TYMfqkpGQsUEuF5xqS2R
# 27  spotify:artist:0IqjJsWlAPR2IafHTtnjPQ
# 28  spotify:artist:4Ui2kfOqGujY81UcPrb5KE
# 29  spotify:artist:2L7RaHwfVU6ge64IJF8GO5
# 30  spotify:artist:1VbWMsap5Ex2erHPlmndr0
# 31  spotify:artist:58nB2Z6IiDdTUTwHYw56xI
# 32  spotify:artist:480xKab3lUPhBBnCzlzqIu
# 33  spotify:artist:5Hz3IW691fbgGqLk4yvlNN
# 34  spotify:artist:1f0vGTFXE64SLuypBV8zB0
# 35  spotify:artist:32lVGr0fSRGT6okLKHiP68
# 36  spotify:artist:3Iq6waFNaQnjLjEjp2l3nc
# 37  spotify:artist:6Mbytr4DD854L4vp4J1LEj
# 38  spotify:artist:0jcl46xRBm9LKIwrKGQPE6
# 39  spotify:artist:6zTbBugfNc95zo8ClFDhIn
# 40  spotify:artist:7nkr1fevjIVmgx5biwAWVo
# 41  spotify:artist:3HsVtnnjOUToyJThxaoBfx
# 42  spotify:artist:30ejUciK31BCg0IVCbt1dW
# 43  spotify:artist:7cxXeGqb1uIhoiSXQ6kejX
# 44  spotify:artist:0iv7RfSxMSAvCzCVnxys6g
# 45  spotify:artist:3CVk2LzA3zH6FBAXuPbnhc
# 46  spotify:artist:5f1cs8LexmMYbhNEIOsDLT
# 47  spotify:artist:68CRxZTAqk19AznItZInip
# 48  spotify:artist:3Fxg10eJ6YmvUdM2PPB4Zk
# 49  spotify:artist:7aU66AnY6CxGppINw6QGq1
#
#                                 external_urls.spotify followers.href  \
# 0   https://open.spotify.com/artist/06HL4z0CvFAxyc...           None
# 1   https://open.spotify.com/artist/0DwbGCdaD8YLRi...           None
# 2   https://open.spotify.com/artist/1McMsnEElThX1k...           None
# 3   https://open.spotify.com/artist/3OGj4jFXF7Cw4O...           None
# 4   https://open.spotify.com/artist/6jJ0s89eD6GaHl...           None
# 5   https://open.spotify.com/artist/5Yzz6SisIkcvuh...           None
# 6   https://open.spotify.com/artist/5YGY8feqx7naU7...           None
# 7   https://open.spotify.com/artist/1bgoHMYkNqVC9P...           None
# 8   https://open.spotify.com/artist/45dkTj5sMRSjrm...           None
# 9   https://open.spotify.com/artist/7oW3aIseIypoEq...           None
# 10  https://open.spotify.com/artist/1Vvvx45Apu6dQq...           None
# 11  https://open.spotify.com/artist/14waR9FpjuHkqh...           None
# 12  https://open.spotify.com/artist/6s22t5Y3prQHya...           None
# 13  https://open.spotify.com/artist/5D4eBBCFWPid24...           None
# 14  https://open.spotify.com/artist/4dpARuHxo51G3z...           None
# 15  https://open.spotify.com/artist/3vZoN5cnYOycsJ...           None
# 16  https://open.spotify.com/artist/6LqNN22kT3074X...           None
# 17  https://open.spotify.com/artist/75xajtqlPSZfqp...           None
# 18  https://open.spotify.com/artist/163tK9Wjr9P9Dm...           None
# 19  https://open.spotify.com/artist/1pZI3RPswAgKWR...           None
# 20  https://open.spotify.com/artist/164Uj4eKjl6zTB...           None
# 21  https://open.spotify.com/artist/56oDRnqbIiwx4m...           None
# 22  https://open.spotify.com/artist/5JZ7CnR6gTvEMK...           None
# 23  https://open.spotify.com/artist/6Dd3NScHWwnW6o...           None
# 24  https://open.spotify.com/artist/1A0WloDoRE88uU...           None
# 25  https://open.spotify.com/artist/6ca3AFdIIgaP4Z...           None
# 26  https://open.spotify.com/artist/64TYMfqkpGQsUE...           None
# 27  https://open.spotify.com/artist/0IqjJsWlAPR2Ia...           None
# 28  https://open.spotify.com/artist/4Ui2kfOqGujY81...           None
# 29  https://open.spotify.com/artist/2L7RaHwfVU6ge6...           None
# 30  https://open.spotify.com/artist/1VbWMsap5Ex2er...           None
# 31  https://open.spotify.com/artist/58nB2Z6IiDdTUT...           None
# 32  https://open.spotify.com/artist/480xKab3lUPhBB...           None
# 33  https://open.spotify.com/artist/5Hz3IW691fbgGq...           None
# 34  https://open.spotify.com/artist/1f0vGTFXE64SLu...           None
# 35  https://open.spotify.com/artist/32lVGr0fSRGT6o...           None
# 36  https://open.spotify.com/artist/3Iq6waFNaQnjLj...           None
# 37  https://open.spotify.com/artist/6Mbytr4DD854L4...           None
# 38  https://open.spotify.com/artist/0jcl46xRBm9LKI...           None
# 39  https://open.spotify.com/artist/6zTbBugfNc95zo...           None
# 40  https://open.spotify.com/artist/7nkr1fevjIVmgx...           None
# 41  https://open.spotify.com/artist/3HsVtnnjOUToyJ...           None
# 42  https://open.spotify.com/artist/30ejUciK31BCg0...           None
# 43  https://open.spotify.com/artist/7cxXeGqb1uIhoi...           None
# 44  https://open.spotify.com/artist/0iv7RfSxMSAvCz...           None
# 45  https://open.spotify.com/artist/3CVk2LzA3zH6FB...           None
# 46  https://open.spotify.com/artist/5f1cs8LexmMYbh...           None
# 47  https://open.spotify.com/artist/68CRxZTAqk19Az...           None
# 48  https://open.spotify.com/artist/3Fxg10eJ6YmvUd...           None
# 49  https://open.spotify.com/artist/7aU66AnY6CxGpp...           None
#
#     followers.total
# 0         113134236
# 1              3466
# 2          36795065
# 3               427
# 4          33352242
# 5               110
# 6          24115342
# 7               384
# 8           5442096
# 9                90
# 10          1207162
# 11               61
# 12          3344919
# 13               49
# 14         55874806
# 15              154
# 16          7900156
# 17              157
# 18          9968230
# 19               54
# 20          4455278
# 21          5715478
# 22          6202410
# 23          1625098
# 24           191422
# 25           213977
# 26            52486
# 27            47825
# 28          1323278
# 29           138403
# 30           302316
# 31           193936
# 32           193248
# 33           139564
# 34            14391
# 35           465854
# 36           540909
# 37             4407
# 38           207654
# 39            99239
# 40            13785
# 41           314140
# 42            17084
# 43            13539
# 44           262875
# 45            35937
# 46            27828
# 47            37731
# 48            59432
# 49            28356
