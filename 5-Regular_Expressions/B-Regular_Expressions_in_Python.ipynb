# %% [markdown]
# Regular Expressions
# -------------------
#
# This document will present basic regular expression syntax and cover common use cases for regular expressions: pattern matching, filtering, data extraction, and string replacement.
#
# We will present examples using python’s standard [re regular expression library](http://docs.python.org/library/re.html).
#
# You may also want to look at this [*excellent* tutorial from Google](https://developers.google.com/edu/python/regular-expressions).

# %% [markdown]
# ### Basic Patterns
#
# * a, X, 9, < -- ordinary characters just match themselves exactly. The meta-characters which do not match themselves because they have special meanings are: . ^ \$ * + ? { [ ] \ | ( ) (details below)
# * . (a period) -- matches any single character except newline '\n'
# * \w -- (lowercase w) matches a "word" character: a letter or digit or underbar [a-zA-Z0-9_]. Note that although "word" is the mnemonic for this, it only matches a single word char, not a whole word. \W (upper case W) matches any non-word character.
# * \b -- boundary between word and non-word
# * \s -- (lowercase s) matches a single whitespace character -- space, newline, return, tab, form [ \n\r\t\f]. \S (upper case S) matches any non-whitespace character.
# * \t, \n, \r -- tab, newline, return
# * \d -- decimal digit [0-9] (some older regex utilities do not support but \d, but they all support \w and \s)
# * ^ = start, $ = end -- match the start or end of the string
# * \ -- inhibit the "specialness" of a character. So, for example, use \. to match a period or \\ to match a slash. If you are unsure if a character has special meaning, such as '@', you can put a slash in front of it, \@, to make sure it is treated just as a character.

# %% [markdown]
# ### Searching strings using regexes

# %%
# first import the library
import re

# %%
# Regular expressions are compiled into pattern objects
regex = re.compile(r'D.*Data')
text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu"
match = regex.search(text)
print match.group()
# Out:
# Dealing with Data

# %%
regex = re.compile(r'\d{3}\D*\d{3}\D*\d{4}')
match = regex.search(text)
print match.group()
# Out:
# 212-998-0803

# %%
# We will now try to match an email address. What is wrong in our regex?
regex = re.compile(r'[a-z]*@([a-z])+(.[a-z]+)+')
#regex = re.compile(r'[a-z0-9._]+@([a-z])+(\.[a-z]+)+')
text = "adam.branden_burger034@stern.nyu.edu"
match = regex.search(text)
print match.group()
# Out:
# @stern.nyu.edu

# %%
# We are looking for binary numbers
regex = re.compile(r'[10]+')
text = "asddf1101110100011abd"
match = regex.search(text)
print match.group()
# Out:
# 1101110100011

# %%
# We look for money figures, either integers, or with 1 or 2 decimal
# digits
regex = re.compile(r'^\$?(\d*(\.\d\d?)?|\d+)')
text = '$1200.23 is the price today'
match = regex.search(text)
print match.group()
# Out:
# $1200.23

# %%
# This code is going to generate an error
regex = re.compile(r'Ra*nd.*m R[egex]')
text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu"
match = regex.search(text)
print match.group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-59f22400b3f6> in <module>()
#       3 text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu"
#       4 match = regex.search(text)
# ----> 5 print match.group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %% [markdown]
# When the regular expression does not find anything, then the search function returns `None`, which can cause an error in the code above:

# %%
str = 'an example word:cat!!'
match = re.search(r'word:\w\w\w', str)
# If-statement after search() tests if it succeeded
if match:                      
    print 'found', match.group() ## 'found word:cat'
else:
    print 'did not find'
# Out:
# found word:cat

# %% [markdown]
# Therefore, we need to check that the returned object is not None, before trying to access a method of the object. The `None` value within the context of an `if` conditional gets translated to `False`; hence, we can modify the code above as follows:

# %%
# Regular expressions are compiled into pattern objects
regex = re.compile(r'Ra*nd.*m R[egex]')
text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu"
match = regex.search(text)
if match:
    print match.group()
else:
    print "not found"

# %% [markdown]
# ### Flags for regexes: Case-sentitivity and multiline searches

# %% [markdown]
# Regular expressions are typically case-sensitive.

# %%
# Regular expressions are compiled into pattern objects
# Regular expressions are case-sensitive
regex = re.compile(r'I.*IS')
text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu"
match = regex.search(text)
if match:
    print match.group()
else:
    print "not found"

# %% [markdown]
# But we can specify that they are case-insensitive, using the flag re.IGNORECASE

# %%
# Unless we specify that they are case-insensitive, using the flag re.IGNORECASE
regex = re.compile('I.*IS',re.IGNORECASE)
text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu"
match = regex.search(text)
if match:
    print match.group()
else:
    print "not found"

# %% [markdown]
#  For a full list of available flags, please see the [re documentation](http://docs.python.org/library/re.html).

# %% [markdown]
# ### Multiple matches in a string

# %% [markdown]
# The search command goes through the string to find the longest expression that matches the regex
# and once it finds the first match, it stops. For example, we will not get the second phone number

# %%
# The search command goes through the string to find the longest expression that matches the regex
# and once it finds the first match, it stops. For example, we will not get the second phone number
regex = re.compile('[0-9]{3}-[0-9]{3}-[0-9]{4}')
text = '''
Panos Ipeirotis, Dealing with Data, 
212-998-0803, panos@nyu.edu, 646-555-5555
'''
match = regex.search(text)
if match:
    print match.group()
else:
    print "not found"
# Out:
# 212-998-0803

# %% [markdown]
# If we want to find multiple matches within the string, then we use the `finditer` command that returns a collection of `MatchObject` items. (For comparison, `search` returns just the first `MatchObject` item.)

# %%
# The finditer command goes through the string to find the all the expressions that matches the regex
regex = re.compile(r'[0-9]{3}-[0-9]{3}-[0-9]{4}')
text = "Panos Ipeirotis, Dealing with Data, 212-998-0803, panos@nyu.edu, 646-555-5555"
matches = regex.finditer(text)
for m in matches:
    print "Starts at:", m.start(), 
    "Ends at:", m.end(),
    "Content:", m.group()
# Out:
# Starts at: 36 Ends at: 48 Content: 212-998-0803
# Starts at: 65 Ends at: 77 Content: 646-555-5555

# %% [markdown]
# ### Extracting Data -- where regex start to get really cool
#
# In addition to simple matching and filtering, many regular expressions implementations, including python’s re, provide a powerful mechanism for extracting meaningful data from raw text. Through capturing, those strings that satisfy a particular regular expression are extracted from the text being matched, and returned to the program processing the raw data. The portion of regular expressions that should be captured is surrounded by parentheses, `"( )"`. Then, provided the regular expression containing the capturing statement is satisfied, the result of the regular expression will contain a group of text matching patterns. This group method gets the results of the portions of the input text matched by the capturing statements in the regular expression. The matches are indexed from one-- to get the portion of the text matched by first capturing statement, you could query `result.group(1)`, the second parentheses will have its match stored in `result.group(2)`, etc. The value stored at `result.group(0)`, is the entire portion of the input string matched by the regular expression, not just the portion satisfying the capturing parentheses.
#
# As example of data extraction using capturing regular expressions, say we’re scanning some raw text for phone numbers that we wish to retain for later processing. We might try something like:

# %%
raw_text = r"""
512-234-5234
foo
bar
124-512-5555
biz
125-555-5785
679-397-5255
2126660921
212-998-0902
888-888-2222
801-555-1211
802 555 1212
803.555.1213
(804) 555-1214
1-805-555-1215
1(806)555-1216
807-555-1217-1234
808-555-1218x1234
809-555-1219 ext. 1234
work 1-(810) 555.1220 #1234
"""

# Notice now that each part of the phone is included in parentheses
# allowing us to grab individual part of the phone number
regex = re.compile(r'([2-9]\d{2})\D*(\d{3})\D*(\d{4})')
matches = regex.finditer(raw_text)

phones = set()
for m in matches:
    phone = "(" + m.group(1) + ")" + m.group(2) + "-" + m.group(3) + " Ext:" + m.group(4)
    # print phone
    phones.add(phone)

phones
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-21-7869592b0fc3> in <module>()
#      29 phones = set()
#      30 for m in matches:
# ---> 31     phone = "(" + m.group(1) + ")" + m.group(2) + "-" + m.group(3) + " Ext:" + m.group(4)
#      32     # print phone
#      33     phones.add(phone)
#
# TypeError: cannot concatenate 'str' and 'NoneType' objects

# %% [markdown]
# (See also http://www.diveintopython.net/regular_expressions/phone_numbers.html if you want to see further examples.)
#
# The examples will look like gobbledygook at first.  But after you go through some actual cases, and especially after you struggle to write a few for a real data science task, you will realize that you're not in Kansas any longer.  Now get ready for a horse of a different color...

# %% [markdown]
# ### String Replacement
#
# In addition to matching and extraction, regular expressions can be used to change data--especially unstructured text--in very powerful ways.  In particular, regex allow you to find specific patterns and then replace them with specified strings.
#
# As a data scientist, this is useful when trying to get data formated correctly as input to a specific system, such as when doing data cleanup.
#
# In python’s re library, the function used for replacement is `sub()` (think "substitute").
#
# The pattern for invoking `sub()` is
#
# `re.sub(regex, replacement, text)`
#
# This will return a version of text where all instances of the regex have been substituted with replacement.
#
# Imagine we want to conceal all phone numbers in a document. We could use the following call to `sub()`:

# %%
raw_text = """512-234-5234
foo
bar
124-512-5555
biz
125-555-5785
679-397-5255
2126660921
212-998-0902
888-888-2222
801-555-1211
802 555 1212
803.555.1213
(804) 555-1214
1-805-555-1215
1(806)555-1216
807-555-1217-1234
808-555-1218x1234
809-555-1219 ext. 1234
work 1-(810) 555.1220 #1234
"""

regex = re.compile('([0-9]{3})\W*([0-9]{3})\W*([0-9]{4})')

newstring = re.sub(regex, "XXX-XXX-XXXX", raw_text)

print newstring

# %% [markdown]
# When performing substitution, matches found using the capturing mechanism are available to the replacement using `\1`, `\2`, and so on, as shortcuts to `group(1)`, `group(2)`, etc.
#
# In order to use this back-referencing capability, we need to tell the `sub()` mechanism to treat the replacement string as a regular expression. For instance, if we want to make sure all phone numbers are normalized and all area codes are surrounded by parentheses, we can use:

# %%
print re.sub(regex, r"(\1)-\2-\3", raw_text)

# %% [markdown]
# ### Exercise

# %% [markdown]
# Find all the emails in a webpage.
#
# Since we have not covered yet the networking abilities of Python (coming next), just use curl to fetch the HTML source of the page. Remember that you can either store the outcome of curl into a file and then read the file into Python, or (preferable) directly get the output of curl into a Python variable.
#
# Then you will need to write the right regex and write the code that finds emails in the retrieved html.

# %%
#your code here
import requests
# fetch html
urls = [
    'http://www.stern.nyu.edu/faculty/search_name_form/',
    'http://www.nyu.edu/footer/contact-us.html'
]

emails = set()
for url in urls:
    response = requests.get(url)
    html = response.text
    # build the regular expression for emails
    regex = re.compile(r'([a-z.]+)@\w+(\.\w+)+')
    # find all parts of the text that match the regular expression above
    matches = regex.finditer(html)
    # go through all the matches and add them to a set of found emails
    for m in matches:
        emails.add( m.group() )

f = open("/home/ubuntu/data/emails.txt", "w")
for email in emails:
    f.write(email + "\n")
f.close()

# %%
<a href="http://www.nasdaq.com/symbol/tfsc">
						            TFSC</a>
# Out:
# ['http://finance.yahoo.com/q/hp?s=GOOG+Historical+Prices',
#  'http://finance.yahoo.com/q/hp?s=AAPL+Historical+Prices',
#  'http://finance.yahoo.com/q/hp?s=FB+Historical+Prices']

# %%
tickers = set()

alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
for i in range(len(alphabet)):
    letter = alphabet[i]
    # Create the URL for the selected letter
    url = "http://www.nasdaq.com/screening/companies-by-name.aspx?letter=" + letter
    print "Fetching "+url
    response = requests.get(url)
    html = response.text
    # build the regular expression for finding the tickers
    # in the html we have urls of the form 
    # http://www.nasdaq.com/symbol/TICKER
    # so we will find such URLs and extract just the ticker
    regex = re.compile(r'http://www.nasdaq.com/symbol/(\w+)')
    # find all parts of the text that match the regular expression above
    matches = regex.finditer(html)
    # go through all the matches and add them to a set of found emails
    for m in matches:
        ticker = m.group(1)
        tickers.add(ticker.upper())
    print "So far we have " + len(tickers) + " tickers"
    
tickers
# Out:
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=A
# 50
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=B
# 88
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=C
# 137
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=D
# 185
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=E
# 231
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=F
# 275
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=G
# 311
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=H
# 357
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=I
# 407
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=J
# 449
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=K
# 495
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=L
# 542
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=M
# 587
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=N
# 635
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=O
# 681
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=P
# 723
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=Q
# 768
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=R
# 812
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=S
# 858
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=T
# 903
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=U
# 944
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=V
# 991
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=W
# 1037
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=X
# 1065
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=Y
# 1083
# Fetching http://www.nasdaq.com/screening/companies-by-name.aspx?letter=Z
# 1114
# {u'RYN',
#  u'AGM',
#  u'RTN',
#  u'JBHT',
#  u'LSTR',
#  u'CPN',
#  u'UBCP',
#  u'LSBK',
#  u'EOI',
#  u'SAGE',
#  u'CPE',
#  u'EOS',
#  u'ZF',
#  u'IDXX',
#  u'QRVO',
#  u'MGNX',
#  u'EOT',
#  u'FALC',
#  u'CAFD',
#  u'NRCIA',
#  u'BCPC',
#  u'ABAX',
#  u'NRCIB',
#  u'XIN',
#  u'HEES',
#  u'ROIA',
#  u'KYN',
#  u'OIIM',
#  u'SPP',
#  u'QLGC',
#  u'RLGT',
#  u'TEGP',
#  u'TINY',
#  u'GROW',
#  u'VTHR',
#  u'LMRK',
#  u'ZTS',
#  u'NGLS',
#  u'TAL',
#  u'ZUMZ',
#  u'SCX',
#  u'WRE',
#  u'WRB',
#  u'RDCM',
#  u'VAL',
#  u'UFI',
#  u'LHO',
#  u'KTEC',
#  u'TAYD',
#  u'PRGNL',
#  u'WRI',
#  u'P',
#  u'GLPG',
#  u'OSBCP',
#  u'RDWR',
#  u'VAR',
#  u'FII',
#  u'GK',
#  u'JNS',
#  u'AHC',
#  u'PACW',
#  u'ICCC',
#  u'AXAS',
#  u'HNR',
#  u'ZIXI',
#  u'EBMT',
#  u'ZPIN',
#  u'PACD',
#  u'PACE',
#  u'MAC',
#  u'MAB',
#  u'RICK',
#  u'LAZ',
#  u'JKS',
#  u'FFG',
#  u'YUM',
#  u'ODFL',
#  u'XYL',
#  u'LAQ',
#  u'WILC',
#  u'USEG',
#  u'MMV',
#  u'EGBN',
#  u'EVM',
#  u'EVN',
#  u'TSI',
#  u'WBMD',
#  u'QTM',
#  u'SID',
#  u'VTWV',
#  u'ZFC',
#  u'GUT',
#  u'ICUI',
#  u'GALTU',
#  u'GAIA',
#  u'EVV',
#  u'OXY',
#  u'ECCA',
#  u'KBH',
#  u'FEIC',
#  u'PGRE',
#  u'VLO',
#  u'TANH',
#  u'VONV',
#  u'VIGI',
#  u'PAM',
#  u'FLWS',
#  u'ZNWAA',
#  u'IPWR',
#  u'TTM',
#  u'KBR',
#  u'VLP',
#  u'VONE',
#  u'NWLI',
#  u'NFG',
#  u'GRMN',
#  u'MHLD',
#  u'BLX',
#  u'JSYNU',
#  u'KCAP',
#  u'MAGS',
#  u'K',
#  u'PFIN',
#  u'FFIV',
#  u'ZB',
#  u'PACEU',
#  u'GRF',
#  u'BLL',
#  u'GLMD',
#  u'IMAX',
#  u'SB',
#  u'GARS',
#  u'NAKD',
#  u'IPXL',
#  u'WAGE',
#  u'RPTP',
#  u'RADA',
#  u'AVHI',
#  u'PRGN',
#  u'LPSB',
#  u'EACQW',
#  u'MH',
#  u'EACQU',
#  u'WFBI',
#  u'QHC',
#  u'NDAQ',
#  u'CBT',
#  u'HLG',
#  u'NOV',
#  u'LZB',
#  u'MX',
#  u'OLLI',
#  u'CTU',
#  u'CTV',
#  u'CTW',
#  u'CTQ',
#  u'RFTA',
#  u'CTX',
#  u'MSFG',
#  u'CTZ',
#  u'BANFP',
#  u'FB',
#  u'RAVN',
#  u'LBAI',
#  u'KYE',
#  u'YHOO',
#  u'RAVE',
#  u'VYMI',
#  u'FN',
#  u'ORIG',
#  u'GGT',
#  u'FCS',
#  u'QRHC',
#  u'XXII',
#  u'NNDM',
#  u'LFL',
#  u'NGHC',
#  u'IBO',
#  u'GGZ',
#  u'RDUS',
#  u'HYH',
#  u'FCB',
#  u'NATH',
#  u'XTNT',
#  u'DGAS',
#  u'FCH',
#  u'TASR',
#  u'GGN',
#  u'FICO',
#  u'FCO',
#  u'LTS',
#  u'JEQ',
#  u'ABEOW',
#  u'TAOM',
#  u'LJPC',
#  u'ATEN',
#  u'YIN',
#  u'IBIO',
#  u'TRGP',
#  u'FMN',
#  u'JEC',
#  u'ILMN',
#  u'WSO',
#  u'KNDI',
#  u'MVG',
#  u'AUY',
#  u'PZG',
#  u'SBR',
#  u'LOR',
#  u'FGEN',
#  u'RCMT',
#  u'ZBRA',
#  u'NTP',
#  u'YCB',
#  u'ECCZ',
#  u'MMP',
#  u'MMM',
#  u'VTWO',
#  u'SN',
#  u'ORI',
#  u'SC',
#  u'MMD',
#  u'SBH',
#  u'LCA',
#  u'QNST',
#  u'MGYR',
#  u'QUIK',
#  u'YUMA',
#  u'IBN',
#  u'DECK',
#  u'FARM',
#  u'FARO',
#  u'YRCW',
#  u'VCIT',
#  u'RP',
#  u'YY',
#  u'XHR',
#  u'CAI',
#  u'WUBA',
#  u'BAC',
#  u'CAL',
#  u'CAB',
#  u'CAA',
#  u'HMPR',
#  u'DATA',
#  u'DPM',
#  u'CAE',
#  u'LE',
#  u'LB',
#  u'NHC',
#  u'ONB',
#  u'NHI',
#  u'SBRAP',
#  u'LH',
#  u'PTSI',
#  u'UN',
#  u'HBIO',
#  u'JSML',
#  u'HIG',
#  u'VNRAP',
#  u'JSMD',
#  u'ABB',
#  u'CACQ',
#  u'ABE',
#  u'TFSCU',
#  u'KEYS',
#  u'ZNGA',
#  u'ABM',
#  u'Q',
#  u'JAGX',
#  u'BANF',
#  u'ABT',
#  u'LAYN',
#  u'BANC',
#  u'NBHC',
#  u'ABY',
#  u'VALE',
#  u'CACI',
#  u'WCN',
#  u'CALX',
#  u'TFSC',
#  u'XENE',
#  u'TAIT',
#  u'OLBK',
#  u'XEL',
#  u'HRMN',
#  u'CALL',
#  u'HRMNU',
#  u'LSBG',
#  u'HRMNW',
#  u'OGE',
#  u'CALA',
#  u'CDZI',
#  u'XNPT',
#  u'CALD',
#  u'KEN',
#  u'KALU',
#  u'EGY',
#  u'VFL',
#  u'RAND',
#  u'MIC',
#  u'EGP',
#  u'VFC',
#  u'HDNG',
#  u'RDNT',
#  u'TISI',
#  u'FNB',
#  u'WCIC',
#  u'ZAYO',
#  u'DKL',
#  u'VMBS',
#  u'MIW',
#  u'RELY',
#  u'WTS',
#  u'IMPV',
#  u'SAN',
#  u'SAL',
#  u'GLPI',
#  u'TLRD',
#  u'FGP',
#  u'XRS',
#  u'RAS',
#  u'RXDX',
#  u'RL',
#  u'SAR',
#  u'SAQ',
#  u'BOSC',
#  u'XTLB',
#  u'IDT',
#  u'RAX',
#  u'UNAM',
#  u'QGEN',
#  u'JSYNR',
#  u'QLTI',
#  u'JAX',
#  u'OHAI',
#  u'CHI',
#  u'LQ',
#  u'HRS',
#  u'HLIT',
#  u'DAKP',
#  u'OCLSW',
#  u'DAKT',
#  u'JSYNW',
#  u'MAYS',
#  u'CHW',
#  u'KPTI',
#  u'CHY',
#  u'XUE',
#  u'PACB',
#  u'HRB',
#  u'HAFC',
#  u'MIII',
#  u'ZAIS',
#  u'BWINA',
#  u'NPK',
#  u'BWINB',
#  u'KAI',
#  u'QUMU',
#  u'LAKE',
#  u'NSPH',
#  u'KAR',
#  u'PRXL',
#  u'KAP',
#  u'LNDC',
#  u'OFLX',
#  u'WRES',
#  u'KMPR',
#  u'KSU',
#  u'YUME',
#  u'NGG',
#  u'OCN',
#  u'ZION',
#  u'RILY',
#  u'NSEC',
#  u'QLIK',
#  u'ISNS',
#  u'NGS',
#  u'ABEO',
#  u'FUL',
#  u'WFT',
#  u'GGACW',
#  u'GGACU',
#  u'BMA',
#  u'HMY',
#  u'QIWI',
#  u'JOF',
#  u'BMI',
#  u'SBRA',
#  u'SGMO',
#  u'UCTT',
#  u'CEV',
#  u'YZC',
#  u'WSTG',
#  u'PKG',
#  u'RLOG',
#  u'ZN',
#  u'UGP',
#  u'DLA',
#  u'DTLK',
#  u'IMN',
#  u'RFT',
#  u'GCH',
#  u'UGI',
#  u'NRP',
#  u'SLCA',
#  u'WYIG',
#  u'JACK',
#  u'W',
#  u'GCV',
#  u'LANC',
#  u'DLX',
#  u'CSQ',
#  u'COOL',
#  u'SALM',
#  u'FBRC',
#  u'MGA',
#  u'OCFC',
#  u'YELP',
#  u'CZR',
#  u'OIS',
#  u'OVLY',
#  u'SASR',
#  u'XOXO',
#  u'SSP',
#  u'SSL',
#  u'BTG',
#  u'SSN',
#  u'VTIP',
#  u'MGU',
#  u'LARK',
#  u'YPF',
#  u'BTN',
#  u'WB',
#  u'MFNC',
#  u'TLMR',
#  u'RRD',
#  u'HGH',
#  u'UREE',
#  u'OSBC',
#  u'TCPI',
#  u'TFSCR',
#  u'GPIC',
#  u'MCBC',
#  u'TFSCW',
#  u'VGSH',
#  u'TSM',
#  u'BKJ',
#  u'ISL',
#  u'DMD',
#  u'JBL',
#  u'CVGW',
#  u'VXUS',
#  u'QUNR',
#  u'ECC',
#  u'QTS',
#  u'FCSC',
#  u'IKGH',
#  u'CTAA',
#  u'AAN',
#  u'LBIX',
#  u'FMSA',
#  u'XCOM',
#  u'BFS',
#  u'DGX',
#  u'IRG',
#  u'VNDA',
#  u'JASNW',
#  u'RSYS',
#  u'NGHCO',
#  u'BBN',
#  u'ETFC',
#  u'UNT',
#  u'HASI',
#  u'XL',
#  u'BBH',
#  u'IMH',
#  u'QCRH',
#  u'BBD',
#  u'IMO',
#  u'CSTE',
#  u'TECD',
#  u'UNB',
#  u'FRP',
#  u'NGHCZ',
#  u'JCAP',
#  u'FRT',
#  u'TLN',
#  u'NGHCP',
#  u'KB',
#  u'KEM',
#  u'VMM',
#  u'IKNX',
#  u'VMI',
#  u'FCTY',
#  u'VCSH',
#  u'KED',
#  u'ZEN',
#  u'RYAM',
#  u'EACQ',
#  u'KS',
#  u'MNGA',
#  u'HNRG',
#  u'KW',
#  u'NHLD',
#  u'KEY',
#  u'ITW',
#  u'NW',
#  u'EGLE',
#  u'XGTI',
#  u'UNP',
#  u'VGIT',
#  u'DK',
#  u'AAC',
#  u'DF',
#  u'DD',
#  u'DE',
#  u'DWSN',
#  u'MGLN',
#  u'RARE',
#  u'VNQI',
#  u'BBDO',
#  u'WBC',
#  u'ABIL',
#  u'WBA',
#  u'KRNY',
#  u'RDIB',
#  u'NKSH',
#  u'DQ',
#  u'SANW',
#  u'OHRP',
#  u'GYB',
#  u'ETV',
#  u'UCP',
#  u'TEAR',
#  u'WAFDW',
#  u'CAMP',
#  u'NBRV',
#  u'BKMU',
#  u'TGB',
#  u'SAND',
#  u'RACE',
#  u'GALTW',
#  u'XGTIW',
#  u'SANM',
#  u'CALM',
#  u'VCF',
#  u'WNC',
#  u'BEAV',
#  u'M',
#  u'CWT',
#  u'OME',
#  u'SJT',
#  u'MMYT',
#  u'TGT',
#  u'ICAD',
#  u'XCRA',
#  u'DHR',
#  u'MCN',
#  u'LGI',
#  u'JPM',
#  u'MCI',
#  u'SNY',
#  u'USPH',
#  u'DHRM',
#  u'MCZ',
#  u'LCNB',
#  u'JIVE',
#  u'RPT',
#  u'GFA',
#  u'IMMU',
#  u'OPOF',
#  u'TLF',
#  u'XPO',
#  u'WPC',
#  u'PAR',
#  u'WD',
#  u'BGE',
#  u'XNCR',
#  u'SRCE',
#  u'BGH',
#  u'WM',
#  u'ZAGG',
#  u'OAS',
#  u'IIVI',
#  u'BGS',
#  u'EXP',
#  u'QUAD',
#  u'JD',
#  u'PAI',
#  u'ZYNE',
#  u'ULBI',
#  u'KATE',
#  u'TCPC',
#  u'WYIGU',
#  u'HSC',
#  u'WYIGW',
#  u'Z',
#  u'FATE',
#  u'TCO',
#  u'QPAC',
#  u'OMAM',
#  u'LKFN',
#  u'CDNS',
#  u'CFNB',
#  u'EGIF',
#  u'VNR',
#  u'JMBA',
#  u'DCT',
#  u'ICON',
#  u'DLPH',
#  u'SBFG',
#  u'WEC',
#  u'WEB',
#  u'HAL',
#  u'OFG',
#  u'EV',
#  u'FCAU',
#  u'BNDX',
#  u'IAG',
#  u'IAF',
#  u'SGNT',
#  u'HAE',
#  u'IAC',
#  u'GLOG',
#  u'BNK',
#  u'OFS',
#  u'VALX',
#  u'NAII',
#  u'TMHC',
#  u'GLOP',
#  u'HAR',
#  u'HAS',
#  u'IESC',
#  u'OVBC',
#  u'FCAM',
#  u'UBSH',
#  u'QURE',
#  u'ZLTQ',
#  u'KODK',
#  u'OII',
#  u'IHS',
#  u'KIQ',
#  u'TACOW',
#  u'PANW',
#  u'PHF',
#  u'KMPH',
#  u'KEG',
#  u'PHX',
#  u'ZFGN',
#  u'KMPA',
#  u'IEC',
#  u'MCUR',
#  u'UMBF',
#  u'CFGE',
#  u'HQCL',
#  u'SKT',
#  u'JOBS',
#  u'MHO',
#  u'EML',
#  u'GBL',
#  u'EMN',
#  u'EMI',
#  u'VNTV',
#  u'VRNS',
#  u'CRC',
#  u'FDS',
#  u'CTY',
#  u'PMBC',
#  u'FDX',
#  u'NAUH',
#  u'OIBR',
#  u'CRM',
#  u'BSBR',
#  u'MFD',
#  u'LDF',
#  u'DCTH',
#  u'SABR',
#  u'ABMD',
#  u'UMPQ',
#  u'CCMP',
#  u'TCP',
#  u'IMNP',
#  u'LDR',
#  u'DRIO',
#  u'TCB',
#  u'WAFD',
#  u'HWKN',
#  u'MGIC',
#  u'STBA',
#  u'FBSS',
#  u'VNRBP',
#  u'XRM',
#  u'JASN',
#  u'EGRX',
#  u'ZG',
#  u'FIZZ',
#  u'LMRKP',
#  u'ROYT',
#  u'IBKC',
#  u'WGBS',
#  u'DDR',
#  u'BBVA',
#  u'EFT',
#  u'KAMN',
#  u'JAKK',
#  u'FOE',
#  u'KTCC',
#  u'QCOM',
#  u'XRX',
#  u'TATT',
#  u'MSCA',
#  u'HCAP',
#  u'HALL',
#  u'EFF',
#  u'DDD',
#  u'PAAS',
#  u'ANF',
#  u'OSHC',
#  u'WTW',
#  u'KBSF',
#  u'FLAG',
#  u'HVT',
#  u'MPET',
#  u'PAAC',
#  u'KFRC',
#  u'QADA',
#  u'FRSH',
#  u'HCAPL',
#  u'WMT',
#  u'LCI',
#  u'ABCD',
#  u'KMF',
#  u'RLOC',
#  u'BCH',
#  u'ETW',
#  u'OCLS',
#  u'WDFC',
#  u'HNH',
#  u'ETX',
#  u'GRA',
#  u'DVA',
#  u'PER',
#  u'DAVE',
#  u'FSS',
#  u'LPI',
#  u'COG',
#  u'UNIS',
#  u'TMH',
#  u'BCV',
#  u'ETN',
#  u'UMH',
#  u'BCR',
#  u'WBS',
#  u'ZIOP',
#  u'QPACU',
#  u'QPACW',
#  u'MJCO',
#  u'TTWO',
#  u'PZZA',
#  u'PPBI',
#  u'ZBK',
#  u'OLN',
#  u'DDF',
#  u'QEP',
#  u'OMEX',
#  u'HALO',
#  u'VNRCP',
#  u'JKHY',
#  u'HNSN',
#  u'JGW',
#  u'SFE',
#  u'ZGNX',
#  u'GALT',
#  u'IEX',
#  u'CH',
#  u'OCLR',
#  u'IMGN',
#  u'CB',
#  u'CA',
#  u'MHNA',
#  u'ULTA',
#  u'MHNC',
#  u'MHNB',
#  u'GALE',
#  u'ICLR',
#  u'YOD',
#  u'ZSAN',
#  u'WTI',
#  u'KRC',
#  u'BLDP',
#  u'WAT',
#  u'IBKCP',
#  u'OPTT',
#  u'VGLT',
#  u'ZTR',
#  u'CHRW',
#  u'UFPT',
#  u'SAP',
#  u'SAIA',
#  u'KMT',
#  u'NNVC',
#  u'PCRX',
#  u'UTEK',
#  u'MTSI',
#  u'FFKT',
#  u'CLI',
#  u'ZOES',
#  u'VCLT',
#  u'IMUC',
#  u'GNT',
#  u'EIV',
#  u'PRSS',
#  u'BXS',
#  u'EVBS',
#  u'VDSI',
#  u'AIR',
#  u'EIA',
#  u'WASH',
#  u'OCRX',
#  u'ZHNE',
#  u'JHX',
#  u'EIM',
#  u'CVC',
#  u'DIS',
#  u'QADB',
#  u'FAX',
#  u'SAEX',
#  u'NSM',
#  u'KERX',
#  u'ULTR',
#  u'NSA',
#  u'PPH',
#  u'FHCO',
#  u'QTWO',
#  u'TTOO',
#  u'MBTF',
#  u'NGVC',
#  u'SOV',
#  u'DELT',
#  u'GAB',
#  u'RGSE',
#  u'JCP',
#  u'LVS',
#  u'GWW',
#  u'IDSY',
#  u'RMAX',
#  u'IT',
#  u'PAACW',
#  u'MIIIU',
#  u'NHTC',
#  u'VR',
#  u'MTN',
#  u'OCUL',
#  u'TACO',
#  u'MTB',
#  u'ROIAK',
#  u'ELNK',
#  u'PAACU',
#  u'TARO',
#  u'IF',
#  u'SDT',
#  u'DELTW',
#  u'PWR',
#  u'NANO',
#  u'SDR',
#  u'QUOT',
#  u'RNWK',
#  u'LAMR',
#  u'RJF',
#  u'RJD',
#  u'TNGO',
#  u'HBHCL',
#  u'UNF',
#  u'WNFM',
#  u'XTLY',
#  u'BHI',
#  u'USCR',
#  u'HBI',
#  u'GST',
#  u'HBK',
#  u'LADR',
#  u'OAK',
#  u'DRI',
#  u'CLMS',
#  u'WDR',
#  u'BW',
#  u'SHLM',
#  u'PARR',
#  u'CLMT',
#  u'YRD',
#  u'CCD',
#  u'OFED',
#  u'KWN',
#  u'GSM',
#  u'OCIP',
#  u'CCC',
#  u'PIH',
#  u'JASO',
#  u'DBVT',
#  u'OHI',
#  u'IROQ',
#  u'SBFGP',
#  u'UIS',
#  u'KWR',
#  u'TAHO',
#  u'WEBK',
#  u'MHLDO',
#  u'MESG',
#  u'RPD',
#  u'EGHT',
#  u'DSKY',
#  u'SAFM',
#  u'QSII',
#  u'PAACR',
#  u'JTPY',
#  u'OASM',
#  u'LTRX',
#  u'PEIX',
#  u'JJSF',
#  u'WMK',
#  u'YDKN',
#  u'HCOM',
#  u'UNXL',
#  u'SAFT',
#  u'SRPT',
#  u'UBS',
#  u'SMM',
#  u'FNHC',
#  u'TWOU',
#  u'NTRA',
#  u'DEX',
#  u'JCOM',
#  u'KANG',
#  u'HK',
#  u'DEL',
#  u'VWOB',
#  u'DEA',
#  u'FSTR',
#  u'HA',
#  u'XPLR',
#  u'XBIT',
#  u'HE',
#  u'PTN',
#  u'DTEA',
#  u'DHI',
#  u'DFRG',
#  u'IDRA',
#  u'JMP',
#  u'VALU',
#  u'ACIA',
#  u'LLL',
#  u'INVE',
#  u'ZIONZ',
#  u'UBIC',
#  u'NSTG',
#  u'LRCX',
#  u'DAIO',
#  u'WVE',
#  u'JAZZ',
#  u'CFFI',
#  u'O',
#  u'XOMA',
#  u'TRX',
#  u'QTNT',
#  u'TNDM',
#  u'LDRH',
#  u'VONG',
#  u'EGAS',
#  u'PCBK',
#  u'JSYN',
#  u'KCG',
#  u'MAIN',
#  u'ABBV',
#  u'HTM',
#  u'LRN',
#  u'MPV',
#  u'UL',
#  u'VNET',
#  u'HTS',
#  u'MDC',
#  u'UFAB',
#  u'XBKS',
#  u'QLYS',
#  u'UA',
#  u'FENX',
#  u'FMNB',
#  u'ESTE',
#  u'VRX',
#  u'CABO',
#  u'GPS',
#  u'ZEUS',
#  u'IMDZ',
#  u'UBNT',
#  u'KTWO',
#  u'GNRX',
#  u'IDI',
#  u'JBLU',
#  u'ZBH',
#  u'TEDU',
#  ...}

# %%
len(tickers)
# Out:
# 1114

# %% [markdown]
# #### Solution for Exercise

# %%
# Email regex
regex = re.compile(r'[a-z0-9]+@([a-z0-9]+\.)+[a-z]+')

# We can create either a list or a set, but let's avoid duplicates
emails = set()

# We iterate through the lines of the html code
for line in html:
    # Find matches
    matches = regex.finditer(line)
    # Go through matches
    for m in matches:
        print m.group()
        emails.add(m.group())

print len(emails)

# %%
# and let's make it very compact using list comprehensions
html = !curl -s 'http://www.stern.nyu.edu/faculty/search_name_form'
regex = re.compile(r'[a-z0-9]+@([a-z0-9]+\.)+[a-z]+')
emails = set([m.group() for line in html for m in regex.finditer(line) ])
emails
