# %%
# We will use http://amueller.github.io/word_cloud/index.html

# !sudo -H pip3 install -U wordcloud
# Out:
# Requirement already up-to-date: wordcloud in /usr/local/lib/python3.5/dist-packages
# Requirement already up-to-date: matplotlib in /usr/local/lib/python3.5/dist-packages (from wordcloud)
# Requirement already up-to-date: numpy>=1.6.1 in /usr/local/lib/python3.5/dist-packages (from wordcloud)
# Requirement already up-to-date: pillow in /usr/local/lib/python3.5/dist-packages (from wordcloud)
# Requirement already up-to-date: six>=1.10 in /usr/lib/python3/dist-packages (from matplotlib->wordcloud)
# Requirement already up-to-date: pyparsing!=2.0.0,!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /usr/local/lib/python3.5/dist-packages (from matplotlib->wordcloud)
# Requirement already up-to-date: python-dateutil in /usr/local/lib/python3.5/dist-packages (from matplotlib->wordcloud)
# Requirement already up-to-date: pytz in /usr/local/lib/python3.5/dist-packages (from matplotlib->wordcloud)
# Requirement already up-to-date: cycler>=0.10 in /usr/local/lib/python3.5/dist-packages (from matplotlib->wordcloud)
# Requirement already up-to-date: olefile in /usr/local/lib/python3.5/dist-packages (from pillow->wordcloud)

# %%
from nltk.book import *

# Create a string with the text
# We will use the Inaugural Presidential Addresses for this example
text = " ".join(text4.tokens)

# %%
# Basic example of creating a word cloud
from wordcloud import WordCloud

wordcloud = WordCloud().generate(text)

# %%
# Let's show it, using the "imshow" command of matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Let's remove stopwords
# We will use the stopwords from the NLTK, 
# augmented by the list of stopwords from the wordcloud module

from nltk.corpus import stopwords
from wordcloud import STOPWORDS

sw = stopwords.words('english')
sw.extend(STOPWORDS)

# We can add more words in the list
sw.append("will")
sw.append("said")

# %%
# Recreate the wordcloud, this time removing stopwords.
# We pass the corresponding parameter to the call

wordcloud = WordCloud(stopwords=sw).generate(text)

plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# A more complex example in terms of options. 
# For the full list of options, see 
# http://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html#wordcloud.WordCloud for options
wordcloud = WordCloud(background_color="white",
                      width = 900,
                      height = 600,
                      max_words=100, 
                      stopwords=sw, 
                      margin=10,
                      random_state=1,
                      max_font_size=60,
                      ranks_only=False).generate(text)

# %%
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# And this one uses a recoloring function to change the colors

import random

def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(30, 60)


wordcloud.recolor(color_func=grey_color_func, random_state=3)

plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
