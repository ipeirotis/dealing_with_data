# %%
import requests

# %% [markdown]
# We are going to use the "Client Credentials Flow" from https://developer.spotify.com/web-api/authorization-guide/#client_credentials_flow

# %%
# We first create an app on https://developer.spotify.com
# and we get the client ID and client secret
# NOTE/PANOS: I have disabled my client_secret. 
# Please register and get your own credentials if you want to run the code
client_id = 'f50bb3a5dd0946fdb02c6c6459d69aea'
client_secret = '270762791192492db9b6e55cc553a1aa'

# %%
# We use the "Client Credentials Flow" from https://developer.spotify.com/web-api/authorization-guide/#client_credentials_flow
# We will submit the client id and client secret, to get back our "access token"
body_params = {'grant_type' : 'client_credentials'}
url = 'https://accounts.spotify.com/api/token'
auth_data = requests.post(url, data=body_params, auth=(client_id, client_secret)).json()
auth_data
# Out:
# {'access_token': 'BQBP2HH9ldCm59g-92oa6Zx0nkwUY_2mJv-cc3f3MTygN8nx48IAaxpknPplI8FWefZmero3x5DeLvDCl4s',
#  'expires_in': 3600,
#  'scope': '',
#  'token_type': 'Bearer'}

# %%
# We will be using now the access_token to authenticate our app with Spotify
#
# We test this API call https://developer.spotify.com/web-api/search-item/
url = 'https://api.spotify.com/v1/search'
auth_header = {'Authorization': 'Bearer ' + auth_data['access_token']}
parameters = {
    "q"     : "November Rain",
    "type"  : "track",
    "limit" : 50
}
response = requests.get(url, headers=auth_header, params=parameters).json()
response
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=November+Rain&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#        'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#        'id': '3qm84nBOXUEQ2vnTfUTTFC',
#        'name': "Guns N' Roses",
#        'type': 'artist',
#        'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0CxPbTRARqKUYighiEY9Sz'},
#      'href': 'https://api.spotify.com/v1/albums/0CxPbTRARqKUYighiEY9Sz',
#      'id': '0CxPbTRARqKUYighiEY9Sz',
#      'images': [{'height': 637,
#        'url': 'https://i.scdn.co/image/fa10c6d51c37a2306b3a610241d32d46101fc9c6',
#        'width': 640},
#       {'height': 299,
#        'url': 'https://i.scdn.co/image/7843f5e2910381a94e5d796d6e11ce800fd13fee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/c1e722ccf8858db0930bf3606979e444cf414856',
#        'width': 64}],
#      'name': 'Use Your Illusion I',
#      'release_date': '1991-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:0CxPbTRARqKUYighiEY9Sz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#       'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#       'id': '3qm84nBOXUEQ2vnTfUTTFC',
#       'name': "Guns N' Roses",
#       'type': 'artist',
#       'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 537506,
#     'explicit': False,
#     'external_ids': {'isrc': 'USGF19141510'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3YRCqOhFifThpSRFJ1VWFM'},
#     'href': 'https://api.spotify.com/v1/tracks/3YRCqOhFifThpSRFJ1VWFM',
#     'id': '3YRCqOhFifThpSRFJ1VWFM',
#     'name': 'November Rain',
#     'popularity': 70,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3YRCqOhFifThpSRFJ1VWFM'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#        'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#        'id': '3qm84nBOXUEQ2vnTfUTTFC',
#        'name': "Guns N' Roses",
#        'type': 'artist',
#        'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4a92B7gXZWKJopxs6gWgqb'},
#      'href': 'https://api.spotify.com/v1/albums/4a92B7gXZWKJopxs6gWgqb',
#      'id': '4a92B7gXZWKJopxs6gWgqb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/4ac28b48e3082694ff99e56d5f918e19f44adbb1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8730631bb5ada7d5046118e1ebb582290fdf5ead',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/9df140f123b4a70d94128c3d62b92ebcd1265691',
#        'width': 64}],
#      'name': 'Greatest Hits',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:4a92B7gXZWKJopxs6gWgqb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#       'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#       'id': '3qm84nBOXUEQ2vnTfUTTFC',
#       'name': "Guns N' Roses",
#       'type': 'artist',
#       'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 536960,
#     'explicit': False,
#     'external_ids': {'isrc': 'USGF19141510'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/11C3oTzP4WJ2UlU3TzHtCK'},
#     'href': 'https://api.spotify.com/v1/tracks/11C3oTzP4WJ2UlU3TzHtCK',
#     'id': '11C3oTzP4WJ2UlU3TzHtCK',
#     'name': 'November Rain',
#     'popularity': 51,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:11C3oTzP4WJ2UlU3TzHtCK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3w6zswp5THsSKYLICUbDTZ'},
#        'href': 'https://api.spotify.com/v1/artists/3w6zswp5THsSKYLICUbDTZ',
#        'id': '3w6zswp5THsSKYLICUbDTZ',
#        'name': 'Gabrielle Aplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:3w6zswp5THsSKYLICUbDTZ'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'DE',
#       'DO',
#       'EC',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IS',
#       'LI',
#       'MC',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PY',
#       'SG',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kyjDxYcff3MeWKtw0fnLW'},
#      'href': 'https://api.spotify.com/v1/albums/7kyjDxYcff3MeWKtw0fnLW',
#      'id': '7kyjDxYcff3MeWKtw0fnLW',
#      'images': [{'height': 585,
#        'url': 'https://i.scdn.co/image/abce476a1a2189295bd198432955c6bb570ebfa9',
#        'width': 640},
#       {'height': 274,
#        'url': 'https://i.scdn.co/image/548ef62e954ed5e216ac75d2a55d33fb0ab170d5',
#        'width': 300},
#       {'height': 58,
#        'url': 'https://i.scdn.co/image/b85f75f7891212bc2d4833644da48b6dec951d1c',
#        'width': 63}],
#      'name': 'English Rain',
#      'release_date': '2013-05-13',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:7kyjDxYcff3MeWKtw0fnLW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3w6zswp5THsSKYLICUbDTZ'},
#       'href': 'https://api.spotify.com/v1/artists/3w6zswp5THsSKYLICUbDTZ',
#       'id': '3w6zswp5THsSKYLICUbDTZ',
#       'name': 'Gabrielle Aplin',
#       'type': 'artist',
#       'uri': 'spotify:artist:3w6zswp5THsSKYLICUbDTZ'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'DE',
#      'DO',
#      'EC',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IS',
#      'LI',
#      'MC',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PY',
#      'SG',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 245560,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1202442'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1dMOkSlIgQEgIKFTz4LqL6'},
#     'href': 'https://api.spotify.com/v1/tracks/1dMOkSlIgQEgIKFTz4LqL6',
#     'id': '1dMOkSlIgQEgIKFTz4LqL6',
#     'name': 'November',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c1a62f079732f476b5250a3d25cb6a7a506f75c7?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:1dMOkSlIgQEgIKFTz4LqL6'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#        'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#        'id': '3qm84nBOXUEQ2vnTfUTTFC',
#        'name': "Guns N' Roses",
#        'type': 'artist',
#        'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ZwjaVcnVo2TwhK8N8WWVs'},
#      'href': 'https://api.spotify.com/v1/albums/3ZwjaVcnVo2TwhK8N8WWVs',
#      'id': '3ZwjaVcnVo2TwhK8N8WWVs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ee52ae3d67fe2c1b7530bb97cdddc51fa698932f',
#        'width': 630},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/cbf3feba5df61146e034fcdeb2b38d746241ec8b',
#        'width': 296},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/be89b2e7c51e9a3cba87673a9be025cf3881b8c7',
#        'width': 63}],
#      'name': "Live Era '87-'93",
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:3ZwjaVcnVo2TwhK8N8WWVs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#       'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#       'id': '3qm84nBOXUEQ2vnTfUTTFC',
#       'name': "Guns N' Roses",
#       'type': 'artist',
#       'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 749773,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR19915125'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EQDIFyn4VPMl4OWBc0EV2'},
#     'href': 'https://api.spotify.com/v1/tracks/4EQDIFyn4VPMl4OWBc0EV2',
#     'id': '4EQDIFyn4VPMl4OWBc0EV2',
#     'name': 'November Rain - Live In Japan / 1992',
#     'popularity': 42,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:4EQDIFyn4VPMl4OWBc0EV2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33k6kPYIS5TgseAc70LZjy'},
#        'href': 'https://api.spotify.com/v1/artists/33k6kPYIS5TgseAc70LZjy',
#        'id': '33k6kPYIS5TgseAc70LZjy',
#        'name': 'David Garrett',
#        'type': 'artist',
#        'uri': 'spotify:artist:33k6kPYIS5TgseAc70LZjy'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3PNKgHOAHp8oWnAEB7gCXx'},
#      'href': 'https://api.spotify.com/v1/albums/3PNKgHOAHp8oWnAEB7gCXx',
#      'id': '3PNKgHOAHp8oWnAEB7gCXx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/e41c535d9ddaded3077bc3c35892288de8b89383',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c8ba1785c52d1a408c3ef38012e25f494f66e2de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/fd37d6bab1f0b4b63de2a2e2a1a53e3af93b1557',
#        'width': 64}],
#      'name': 'Rock Symphonies',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:3PNKgHOAHp8oWnAEB7gCXx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33k6kPYIS5TgseAc70LZjy'},
#       'href': 'https://api.spotify.com/v1/artists/33k6kPYIS5TgseAc70LZjy',
#       'id': '33k6kPYIS5TgseAc70LZjy',
#       'name': 'David Garrett',
#       'type': 'artist',
#       'uri': 'spotify:artist:33k6kPYIS5TgseAc70LZjy'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 238773,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBBA1042840'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1XfYyru6HemV6aexQPdF8n'},
#     'href': 'https://api.spotify.com/v1/tracks/1XfYyru6HemV6aexQPdF8n',
#     'id': '1XfYyru6HemV6aexQPdF8n',
#     'name': 'November Rain',
#     'popularity': 33,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1XfYyru6HemV6aexQPdF8n'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#        'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#        'id': '3ccVtqcqedranb7y8eywJ5',
#        'name': 'Blanco White',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3wErgKbRnazBrl24VaPIRT'},
#      'href': 'https://api.spotify.com/v1/albums/3wErgKbRnazBrl24VaPIRT',
#      'id': '3wErgKbRnazBrl24VaPIRT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1041425390d2332be02395a1446354b65a5f8933',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7ac1c7d02b6e124f6f1c7ae26fbe5680904b9eca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6fd22cf9000ecdc1222844c459672901ee5fea73',
#        'width': 64}],
#      'name': 'November Rain',
#      'release_date': '2015-11-23',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:3wErgKbRnazBrl24VaPIRT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#       'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#       'id': '3ccVtqcqedranb7y8eywJ5',
#       'name': 'Blanco White',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 246132,
#     'explicit': False,
#     'external_ids': {'isrc': 'UK4GH1500015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1BZGq1lAq98mTVdO8HLZaX'},
#     'href': 'https://api.spotify.com/v1/tracks/1BZGq1lAq98mTVdO8HLZaX',
#     'id': '1BZGq1lAq98mTVdO8HLZaX',
#     'name': 'November Rain',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3349059141465b892064bdc8e25a79996f71a615?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1BZGq1lAq98mTVdO8HLZaX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2tQASTYJPc7QQ9GCVbtXfo'},
#      'href': 'https://api.spotify.com/v1/albums/2tQASTYJPc7QQ9GCVbtXfo',
#      'id': '2tQASTYJPc7QQ9GCVbtXfo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/34066a747764d36809751a0d29482dfe3e41489d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/3c62aede5a0d66c6a44e83f06f1a50dbb5cadccf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a958908bca60c9bd23136cb2de737dac56e9e313',
#        'width': 64}],
#      'name': "Bossa N' Roses",
#      'release_date': '2006-11-14',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:2tQASTYJPc7QQ9GCVbtXfo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0g6rXs7y0Xalc9NSqM3jER'},
#       'href': 'https://api.spotify.com/v1/artists/0g6rXs7y0Xalc9NSqM3jER',
#       'id': '0g6rXs7y0Xalc9NSqM3jER',
#       'name': 'Ghetto Blaster Ltd.',
#       'type': 'artist',
#       'uri': 'spotify:artist:0g6rXs7y0Xalc9NSqM3jER'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 291426,
#     'explicit': False,
#     'external_ids': {'isrc': 'ARF410600521'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2sO2B8YGt8Bi9p3tgmSdlC'},
#     'href': 'https://api.spotify.com/v1/tracks/2sO2B8YGt8Bi9p3tgmSdlC',
#     'id': '2sO2B8YGt8Bi9p3tgmSdlC',
#     'name': 'November Rain - B&H Version',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eeafe7a4a2d88f3d0ef29ea175710c6ad4127366?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2sO2B8YGt8Bi9p3tgmSdlC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#        'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#        'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#        'name': 'Rockabye Baby!',
#        'type': 'artist',
#        'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dEdYpJR27Ggmc0jp0Oflg'},
#      'href': 'https://api.spotify.com/v1/albums/5dEdYpJR27Ggmc0jp0Oflg',
#      'id': '5dEdYpJR27Ggmc0jp0Oflg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/d05eb58b15de67729ca9c27b2f14cdab671d08c0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/dfcb6f58ff0be9a8fa96337cfb1f09884738b2d9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/890332839ab9c76926b5ee87637633179d6edfa0',
#        'width': 64}],
#      'name': "Lullaby Renditions of Guns n' Roses",
#      'release_date': '2009-11-10',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5dEdYpJR27Ggmc0jp0Oflg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#       'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#       'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#       'name': 'Rockabye Baby!',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 286893,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC0982552'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7l7hhlpkcxs4zA5cOBC1jI'},
#     'href': 'https://api.spotify.com/v1/tracks/7l7hhlpkcxs4zA5cOBC1jI',
#     'id': '7l7hhlpkcxs4zA5cOBC1jI',
#     'name': 'November Rain',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bf7ad325883d9dfb133cedb096fbbb8ad6b2fd9d?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7l7hhlpkcxs4zA5cOBC1jI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77A9XsX4SDJlhB23yyUwQt'},
#        'href': 'https://api.spotify.com/v1/artists/77A9XsX4SDJlhB23yyUwQt',
#        'id': '77A9XsX4SDJlhB23yyUwQt',
#        'name': 'Steve ´n´ Seagulls',
#        'type': 'artist',
#        'uri': 'spotify:artist:77A9XsX4SDJlhB23yyUwQt'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5P48aG3Qgn5oe6Xy9jkXdn'},
#      'href': 'https://api.spotify.com/v1/albums/5P48aG3Qgn5oe6Xy9jkXdn',
#      'id': '5P48aG3Qgn5oe6Xy9jkXdn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/f911a77aaa283fd59722db3c52c31dd21013fa68',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/f9fb3217890f2d20a79f6f7d72e259e46868c33a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/d6e1c9463faec2a2b288946c20b1e03f94561e81',
#        'width': 64}],
#      'name': 'Brothers In Farms',
#      'release_date': '2016-09-09',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5P48aG3Qgn5oe6Xy9jkXdn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77A9XsX4SDJlhB23yyUwQt'},
#       'href': 'https://api.spotify.com/v1/artists/77A9XsX4SDJlhB23yyUwQt',
#       'id': '77A9XsX4SDJlhB23yyUwQt',
#       'name': 'Steve ´n´ Seagulls',
#       'type': 'artist',
#       'uri': 'spotify:artist:77A9XsX4SDJlhB23yyUwQt'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 303546,
#     'explicit': False,
#     'external_ids': {'isrc': 'FIUM71600358'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6QF3vavxEItY8ru6DcL9N2'},
#     'href': 'https://api.spotify.com/v1/tracks/6QF3vavxEItY8ru6DcL9N2',
#     'id': '6QF3vavxEItY8ru6DcL9N2',
#     'name': 'November Rain',
#     'popularity': 29,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6QF3vavxEItY8ru6DcL9N2'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#        'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#        'id': '3ccVtqcqedranb7y8eywJ5',
#        'name': 'Blanco White',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5eOg5JJewzpCZjO4u3wm9O'},
#      'href': 'https://api.spotify.com/v1/albums/5eOg5JJewzpCZjO4u3wm9O',
#      'id': '5eOg5JJewzpCZjO4u3wm9O',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1041425390d2332be02395a1446354b65a5f8933',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/7ac1c7d02b6e124f6f1c7ae26fbe5680904b9eca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/6fd22cf9000ecdc1222844c459672901ee5fea73',
#        'width': 64}],
#      'name': 'The Wind Rose EP',
#      'release_date': '2016-02-05',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5eOg5JJewzpCZjO4u3wm9O'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#       'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#       'id': '3ccVtqcqedranb7y8eywJ5',
#       'name': 'Blanco White',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 246132,
#     'explicit': False,
#     'external_ids': {'isrc': 'UK4GH1500015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71EeFAAKi6iekORgxgz2d5'},
#     'href': 'https://api.spotify.com/v1/tracks/71EeFAAKi6iekORgxgz2d5',
#     'id': '71EeFAAKi6iekORgxgz2d5',
#     'name': 'November Rain',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3349059141465b892064bdc8e25a79996f71a615?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:71EeFAAKi6iekORgxgz2d5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5dPAnuLyn7AHGV6XIIcY64'},
#      'href': 'https://api.spotify.com/v1/albums/5dPAnuLyn7AHGV6XIIcY64',
#      'id': '5dPAnuLyn7AHGV6XIIcY64',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9aef9f1188bd6d779f227ebfea3798273fc193aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/6ff8889f96fbefc978e59beab8e0d1a722a1a353',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0556f278ce239569d15267520914a1b651605db1',
#        'width': 64}],
#      'name': 'Vintage Café - Lounge & Jazz Blends',
#      'release_date': '2007-09-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5dPAnuLyn7AHGV6XIIcY64'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#       'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#       'id': '4BoBwZFmzlSepZqWiok2Z9',
#       'name': 'Anakelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 2,
#     'duration_ms': 255320,
#     'explicit': False,
#     'external_ids': {'isrc': 'ARF410600421'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/77CnXU4HGxTP2IMRWyJJAk'},
#     'href': 'https://api.spotify.com/v1/tracks/77CnXU4HGxTP2IMRWyJJAk',
#     'id': '77CnXU4HGxTP2IMRWyJJAk',
#     'name': 'November Rain',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2e721357b5cbe1ccc15b7f7e727c1b84a2687c27?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:77CnXU4HGxTP2IMRWyJJAk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wMmGaXRfdHPhqSEAVQIr6'},
#        'href': 'https://api.spotify.com/v1/artists/0wMmGaXRfdHPhqSEAVQIr6',
#        'id': '0wMmGaXRfdHPhqSEAVQIr6',
#        'name': 'Instrumental',
#        'type': 'artist',
#        'uri': 'spotify:artist:0wMmGaXRfdHPhqSEAVQIr6'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1pxMDMjn9XXi4SyUo2wyVb'},
#      'href': 'https://api.spotify.com/v1/albums/1pxMDMjn9XXi4SyUo2wyVb',
#      'id': '1pxMDMjn9XXi4SyUo2wyVb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/9c96f4689ee789cdf560cb182ccf46e737de1f6c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/5ea0862c55f2f23a2d50dab3acaa37ba39f977b2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/195e84002aee8193f2f8d6c68b115467b6c9f74b',
#        'width': 64}],
#      'name': '50 Classical Study Songs',
#      'release_date': '2016-12-14',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:1pxMDMjn9XXi4SyUo2wyVb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wMmGaXRfdHPhqSEAVQIr6'},
#       'href': 'https://api.spotify.com/v1/artists/0wMmGaXRfdHPhqSEAVQIr6',
#       'id': '0wMmGaXRfdHPhqSEAVQIr6',
#       'name': 'Instrumental',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wMmGaXRfdHPhqSEAVQIr6'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 253164,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS81601442'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3x4u7JB8TO4Y44KTe0N2Uo'},
#     'href': 'https://api.spotify.com/v1/tracks/3x4u7JB8TO4Y44KTe0N2Uo',
#     'id': '3x4u7JB8TO4Y44KTe0N2Uo',
#     'name': 'November Rain',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0bd5593838d5c37611dca0632bc306bc14fb55bd?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 32,
#     'type': 'track',
#     'uri': 'spotify:track:3x4u7JB8TO4Y44KTe0N2Uo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#        'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#        'id': '4BoBwZFmzlSepZqWiok2Z9',
#        'name': 'Anakelly',
#        'type': 'artist',
#        'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6CkestcVpVUxGKkVbK4SG4'},
#      'href': 'https://api.spotify.com/v1/albums/6CkestcVpVUxGKkVbK4SG4',
#      'id': '6CkestcVpVUxGKkVbK4SG4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/80df3433d79081074d07b4cb5e6917e77b74f448',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/aac721a141453e9d8ebb12a68f59f0f9ce599c48',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/72c2d14b2995cdc18bef50e274ed019e1f2117aa',
#        'width': 64}],
#      'name': 'Summer Lounge Beats',
#      'release_date': '2014-04-29',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:6CkestcVpVUxGKkVbK4SG4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#       'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#       'id': '4BoBwZFmzlSepZqWiok2Z9',
#       'name': 'Anakelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 255320,
#     'explicit': False,
#     'external_ids': {'isrc': 'ARF410600421'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5TSqyACHswDUYtvXkEIwqR'},
#     'href': 'https://api.spotify.com/v1/tracks/5TSqyACHswDUYtvXkEIwqR',
#     'id': '5TSqyACHswDUYtvXkEIwqR',
#     'name': 'November Rain',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2e721357b5cbe1ccc15b7f7e727c1b84a2687c27?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5TSqyACHswDUYtvXkEIwqR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#        'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#        'id': '4TMHGUX5WI7OOm53PqSDAT',
#        'name': 'Grateful Dead',
#        'type': 'artist',
#        'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/24rc4HaQfvOOSnq32PkOC1'},
#      'href': 'https://api.spotify.com/v1/albums/24rc4HaQfvOOSnq32PkOC1',
#      'id': '24rc4HaQfvOOSnq32PkOC1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/94baf5577e231cd2c451d2deb4e6a5a2eabf469d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/63ab7b9a6635e4a9658751828630e379b8fec23a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a6cd7577f51c1c58b59d71765e000bb7b973be06',
#        'width': 64}],
#      'name': "Dick's Picks Vol. 34: 11/5/77 (Community War Memorial, Rochester, NY)",
#      'release_date': '2005',
#      'release_date_precision': 'year',
#      'type': 'album',
#      'uri': 'spotify:album:24rc4HaQfvOOSnq32PkOC1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#       'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#       'id': '4TMHGUX5WI7OOm53PqSDAT',
#       'name': 'Grateful Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 505693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH10901610'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7q2HjPftSMAwrZZyys5Zfz'},
#     'href': 'https://api.spotify.com/v1/tracks/7q2HjPftSMAwrZZyys5Zfz',
#     'id': '7q2HjPftSMAwrZZyys5Zfz',
#     'name': 'Looks Like Rain [Live At Community War Memorial, Rochester, NY, November 5, 1977]',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cbfb972cac401b11e6a2b629f811cf3fb52c6bdd?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7q2HjPftSMAwrZZyys5Zfz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nSGBmlgUdqWNExnOX8VtV'},
#        'href': 'https://api.spotify.com/v1/artists/5nSGBmlgUdqWNExnOX8VtV',
#        'id': '5nSGBmlgUdqWNExnOX8VtV',
#        'name': 'Rain Sounds',
#        'type': 'artist',
#        'uri': 'spotify:artist:5nSGBmlgUdqWNExnOX8VtV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NqS7DbPFYwZmniGHCPMpm'},
#        'href': 'https://api.spotify.com/v1/artists/4NqS7DbPFYwZmniGHCPMpm',
#        'id': '4NqS7DbPFYwZmniGHCPMpm',
#        'name': 'Nature Sounds',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NqS7DbPFYwZmniGHCPMpm'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2w5q7SKsUmpdUuyf5HOA2c'},
#        'href': 'https://api.spotify.com/v1/artists/2w5q7SKsUmpdUuyf5HOA2c',
#        'id': '2w5q7SKsUmpdUuyf5HOA2c',
#        'name': 'Nature Sounds Nature Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:2w5q7SKsUmpdUuyf5HOA2c'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5tefhBt5YTFTWR60lQaY20'},
#      'href': 'https://api.spotify.com/v1/albums/5tefhBt5YTFTWR60lQaY20',
#      'id': '5tefhBt5YTFTWR60lQaY20',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/4309d6876ae25fd8df86cde5248b267135973c5c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/fe7ca3c751f417c5dcf9e1cfaef792bef591c4bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/477bba82b66134550296268cb46f41940a32f629',
#        'width': 64}],
#      'name': 'Rain Sounds for Sleep',
#      'release_date': '2016-11-02',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5tefhBt5YTFTWR60lQaY20'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nSGBmlgUdqWNExnOX8VtV'},
#       'href': 'https://api.spotify.com/v1/artists/5nSGBmlgUdqWNExnOX8VtV',
#       'id': '5nSGBmlgUdqWNExnOX8VtV',
#       'name': 'Rain Sounds',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nSGBmlgUdqWNExnOX8VtV'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 127066,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBMJG1613627'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5zffvp3o6umOuOgEuFIg8T'},
#     'href': 'https://api.spotify.com/v1/tracks/5zffvp3o6umOuOgEuFIg8T',
#     'id': '5zffvp3o6umOuOgEuFIg8T',
#     'name': 'November Rain',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c3e3195853e6533eb098d424ac4d91fe9609104f?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5zffvp3o6umOuOgEuFIg8T'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xnfpcM4DC9zeHVuDhYICB'},
#        'href': 'https://api.spotify.com/v1/artists/3xnfpcM4DC9zeHVuDhYICB',
#        'id': '3xnfpcM4DC9zeHVuDhYICB',
#        'name': 'Sandi Thom',
#        'type': 'artist',
#        'uri': 'spotify:artist:3xnfpcM4DC9zeHVuDhYICB'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ugWbv9RDXOu6iKoeKKvFf'},
#      'href': 'https://api.spotify.com/v1/albums/0ugWbv9RDXOu6iKoeKKvFf',
#      'id': '0ugWbv9RDXOu6iKoeKKvFf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/20d95c516e12cf300bb146ec2df76d374dba0f5c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/aacfdedc2c9840435e52a0df7f9469ae391de132',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/b60decfc5ee3fa16f8f8682f1fd0e3106292e3a3',
#        'width': 64}],
#      'name': 'The Covers Collection',
#      'release_date': '2013-11-11',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:0ugWbv9RDXOu6iKoeKKvFf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xnfpcM4DC9zeHVuDhYICB'},
#       'href': 'https://api.spotify.com/v1/artists/3xnfpcM4DC9zeHVuDhYICB',
#       'id': '3xnfpcM4DC9zeHVuDhYICB',
#       'name': 'Sandi Thom',
#       'type': 'artist',
# ...
#      'type': 'album',
#      'uri': 'spotify:album:4QLlTAC9pOzbZo7qQ63dXm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#       'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#       'id': '4TMHGUX5WI7OOm53PqSDAT',
#       'name': 'Grateful Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 452506,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH10900706'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1T6dQI8z0iHcbn1LwmppIE'},
#     'href': 'https://api.spotify.com/v1/tracks/1T6dQI8z0iHcbn1LwmppIE',
#     'id': '1T6dQI8z0iHcbn1LwmppIE',
#     'name': 'Cold Rain & Snow [Live at Richmond Coliseum, Richmond, VA, November 1, 1985]',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/352b5c6751b11df428d1db9d285eaba93ac73250?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1T6dQI8z0iHcbn1LwmppIE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oyZF2G7rCd7ZPxXsnXwBR'},
#        'href': 'https://api.spotify.com/v1/artists/2oyZF2G7rCd7ZPxXsnXwBR',
#        'id': '2oyZF2G7rCd7ZPxXsnXwBR',
#        'name': 'Rain relax',
#        'type': 'artist',
#        'uri': 'spotify:artist:2oyZF2G7rCd7ZPxXsnXwBR'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/61xIwfrVYpdQk9rmWptAN8'},
#      'href': 'https://api.spotify.com/v1/albums/61xIwfrVYpdQk9rmWptAN8',
#      'id': '61xIwfrVYpdQk9rmWptAN8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/a4e2813bcb11479a322c2363ab6d63fc6f392d01',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ad3b0b36cfe638459492f756582654e5e9c755e1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/7c22ec735b6b98060e45e057e7b601d3d471f6fc',
#        'width': 64}],
#      'name': '100 Nature Rain Sounds and Ambient Sounds for Relaxation',
#      'release_date': '2015-05-11',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:61xIwfrVYpdQk9rmWptAN8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oyZF2G7rCd7ZPxXsnXwBR'},
#       'href': 'https://api.spotify.com/v1/artists/2oyZF2G7rCd7ZPxXsnXwBR',
#       'id': '2oyZF2G7rCd7ZPxXsnXwBR',
#       'name': 'Rain relax',
#       'type': 'artist',
#       'uri': 'spotify:artist:2oyZF2G7rCd7ZPxXsnXwBR'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 227395,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB-SMU-20-98894'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ersyoaH6HDtJ77Cow60VS'},
#     'href': 'https://api.spotify.com/v1/tracks/0ersyoaH6HDtJ77Cow60VS',
#     'id': '0ersyoaH6HDtJ77Cow60VS',
#     'name': 'November rain',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3b6e1937364149fe58f29d924c4ccee1d2dc55da?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:0ersyoaH6HDtJ77Cow60VS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mDSQ2wWtSRVgalV0BJX2d'},
#        'href': 'https://api.spotify.com/v1/artists/1mDSQ2wWtSRVgalV0BJX2d',
#        'id': '1mDSQ2wWtSRVgalV0BJX2d',
#        'name': 'Sixx Digit',
#        'type': 'artist',
#        'uri': 'spotify:artist:1mDSQ2wWtSRVgalV0BJX2d'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5MTdosz9Th00BxmDHAReF2'},
#      'href': 'https://api.spotify.com/v1/albums/5MTdosz9Th00BxmDHAReF2',
#      'id': '5MTdosz9Th00BxmDHAReF2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/1ce89e8d3c8ce5320ccbe0e2dbc2b458973ecfaf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/6676c40f97cd6883d2cdcdcfe80c9c5682f0b694',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/0b12e25007bbc67bec3af19deb04dbe4c5fd2a3e',
#        'width': 64}],
#      'name': 'Cold November Rain',
#      'release_date': '2009-07-13',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5MTdosz9Th00BxmDHAReF2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mDSQ2wWtSRVgalV0BJX2d'},
#       'href': 'https://api.spotify.com/v1/artists/1mDSQ2wWtSRVgalV0BJX2d',
#       'id': '1mDSQ2wWtSRVgalV0BJX2d',
#       'name': 'Sixx Digit',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mDSQ2wWtSRVgalV0BJX2d'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 2,
#     'duration_ms': 295546,
#     'explicit': True,
#     'external_ids': {'isrc': 'ushm80944600'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oGxGCkpSGGr8kS8x5wUar'},
#     'href': 'https://api.spotify.com/v1/tracks/4oGxGCkpSGGr8kS8x5wUar',
#     'id': '4oGxGCkpSGGr8kS8x5wUar',
#     'name': 'Cold November Rain',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7c0b7f07e46ec3fb21631029753f6e78834ddba2?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4oGxGCkpSGGr8kS8x5wUar'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3A12QFuD1pphKdNKs2B2mg'},
#        'href': 'https://api.spotify.com/v1/artists/3A12QFuD1pphKdNKs2B2mg',
#        'id': '3A12QFuD1pphKdNKs2B2mg',
#        'name': 'Dirge for November',
#        'type': 'artist',
#        'uri': 'spotify:artist:3A12QFuD1pphKdNKs2B2mg'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jpEWBMsUhRS2rkBS6YAsK'},
#      'href': 'https://api.spotify.com/v1/albums/5jpEWBMsUhRS2rkBS6YAsK',
#      'id': '5jpEWBMsUhRS2rkBS6YAsK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/834d7b3f503ea8eec5cca0afa497e4713cfdc582',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/0499442c9900a3f48d0da7cb77c021fb4da8fa67',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/91d7a07325e823c1df9b06ca5ad2e9c89d7d02d0',
#        'width': 64}],
#      'name': 'November',
#      'release_date': '2017-04-01',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5jpEWBMsUhRS2rkBS6YAsK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3A12QFuD1pphKdNKs2B2mg'},
#       'href': 'https://api.spotify.com/v1/artists/3A12QFuD1pphKdNKs2B2mg',
#       'id': '3A12QFuD1pphKdNKs2B2mg',
#       'name': 'Dirge for November',
#       'type': 'artist',
#       'uri': 'spotify:artist:3A12QFuD1pphKdNKs2B2mg'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 165866,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4DW1794461'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15TJnX8wI4dWmC5fm8ZJ5N'},
#     'href': 'https://api.spotify.com/v1/tracks/15TJnX8wI4dWmC5fm8ZJ5N',
#     'id': '15TJnX8wI4dWmC5fm8ZJ5N',
#     'name': 'Rain',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c683998b4c4e037800b433232abbdb89b8f01bd3?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:15TJnX8wI4dWmC5fm8ZJ5N'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oXAHFsKzKMklJtiBw8peV'},
#        'href': 'https://api.spotify.com/v1/artists/1oXAHFsKzKMklJtiBw8peV',
#        'id': '1oXAHFsKzKMklJtiBw8peV',
#        'name': 'DJ Darq',
#        'type': 'artist',
#        'uri': 'spotify:artist:1oXAHFsKzKMklJtiBw8peV'}],
#      'available_markets': ['AD',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IS',
#       'IT',
#       'JP',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'US',
#       'UY'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5qyTqcVVwA9efacmZEbKbU'},
#      'href': 'https://api.spotify.com/v1/albums/5qyTqcVVwA9efacmZEbKbU',
#      'id': '5qyTqcVVwA9efacmZEbKbU',
#      'images': [{'height': 600,
#        'url': 'https://i.scdn.co/image/e6bcf19a7cf3398740c438d8d9a57a5bf3e90910',
#        'width': 600},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/e47556f98ae495350c8baa01edf8e4a31518925f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/bd7e646d36b1dfbe90d5a5202126493725989ee3',
#        'width': 64}],
#      'name': 'November Rain',
#      'release_date': '2010-03-05',
#      'release_date_precision': 'day',
#      'type': 'album',
#      'uri': 'spotify:album:5qyTqcVVwA9efacmZEbKbU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oXAHFsKzKMklJtiBw8peV'},
#       'href': 'https://api.spotify.com/v1/artists/1oXAHFsKzKMklJtiBw8peV',
#       'id': '1oXAHFsKzKMklJtiBw8peV',
#       'name': 'DJ Darq',
#       'type': 'artist',
#       'uri': 'spotify:artist:1oXAHFsKzKMklJtiBw8peV'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY'],
#     'disc_number': 1,
#     'duration_ms': 488805,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEAR41036113'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4I0riUaf4ADqQyRNh0mWy2'},
#     'href': 'https://api.spotify.com/v1/tracks/4I0riUaf4ADqQyRNh0mWy2',
#     'id': '4I0riUaf4ADqQyRNh0mWy2',
#     'name': 'November Rain - Original Mix',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3b4846a747b7ab27439739901725dd44ee7f6ed6?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4I0riUaf4ADqQyRNh0mWy2'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=November+Rain&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 1224}}

# %%
response.keys()
# Out:
# dict_keys(['tracks'])

# %%
response['tracks'].keys()
# Out:
# dict_keys(['next', 'previous', 'limit', 'offset', 'total', 'href', 'items'])

# %%
response['tracks']['next']
# Out:
# 'https://api.spotify.com/v1/search?query=November+Rain&type=track&offset=50&limit=50'

# %%
response['tracks']['total']
# Out:
# 1224

# %%
response['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#      'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#      'id': '3qm84nBOXUEQ2vnTfUTTFC',
#      'name': "Guns N' Roses",
#      'type': 'artist',
#      'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0CxPbTRARqKUYighiEY9Sz'},
#    'href': 'https://api.spotify.com/v1/albums/0CxPbTRARqKUYighiEY9Sz',
#    'id': '0CxPbTRARqKUYighiEY9Sz',
#    'images': [{'height': 637,
#      'url': 'https://i.scdn.co/image/fa10c6d51c37a2306b3a610241d32d46101fc9c6',
#      'width': 640},
#     {'height': 299,
#      'url': 'https://i.scdn.co/image/7843f5e2910381a94e5d796d6e11ce800fd13fee',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/c1e722ccf8858db0930bf3606979e444cf414856',
#      'width': 64}],
#    'name': 'Use Your Illusion I',
#    'release_date': '1991-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:0CxPbTRARqKUYighiEY9Sz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#     'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#     'id': '3qm84nBOXUEQ2vnTfUTTFC',
#     'name': "Guns N' Roses",
#     'type': 'artist',
#     'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 537506,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19141510'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3YRCqOhFifThpSRFJ1VWFM'},
#   'href': 'https://api.spotify.com/v1/tracks/3YRCqOhFifThpSRFJ1VWFM',
#   'id': '3YRCqOhFifThpSRFJ1VWFM',
#   'name': 'November Rain',
#   'popularity': 70,
#   'preview_url': None,
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:3YRCqOhFifThpSRFJ1VWFM'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#      'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#      'id': '3qm84nBOXUEQ2vnTfUTTFC',
#      'name': "Guns N' Roses",
#      'type': 'artist',
#      'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4a92B7gXZWKJopxs6gWgqb'},
#    'href': 'https://api.spotify.com/v1/albums/4a92B7gXZWKJopxs6gWgqb',
#    'id': '4a92B7gXZWKJopxs6gWgqb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/4ac28b48e3082694ff99e56d5f918e19f44adbb1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/8730631bb5ada7d5046118e1ebb582290fdf5ead',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/9df140f123b4a70d94128c3d62b92ebcd1265691',
#      'width': 64}],
#    'name': 'Greatest Hits',
#    'release_date': '2004-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:4a92B7gXZWKJopxs6gWgqb'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#     'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#     'id': '3qm84nBOXUEQ2vnTfUTTFC',
#     'name': "Guns N' Roses",
#     'type': 'artist',
#     'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 536960,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19141510'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/11C3oTzP4WJ2UlU3TzHtCK'},
#   'href': 'https://api.spotify.com/v1/tracks/11C3oTzP4WJ2UlU3TzHtCK',
#   'id': '11C3oTzP4WJ2UlU3TzHtCK',
#   'name': 'November Rain',
#   'popularity': 51,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:11C3oTzP4WJ2UlU3TzHtCK'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3w6zswp5THsSKYLICUbDTZ'},
#      'href': 'https://api.spotify.com/v1/artists/3w6zswp5THsSKYLICUbDTZ',
#      'id': '3w6zswp5THsSKYLICUbDTZ',
#      'name': 'Gabrielle Aplin',
#      'type': 'artist',
#      'uri': 'spotify:artist:3w6zswp5THsSKYLICUbDTZ'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'DE',
#     'DO',
#     'EC',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IS',
#     'LI',
#     'MC',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PY',
#     'SG',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7kyjDxYcff3MeWKtw0fnLW'},
#    'href': 'https://api.spotify.com/v1/albums/7kyjDxYcff3MeWKtw0fnLW',
#    'id': '7kyjDxYcff3MeWKtw0fnLW',
#    'images': [{'height': 585,
#      'url': 'https://i.scdn.co/image/abce476a1a2189295bd198432955c6bb570ebfa9',
#      'width': 640},
#     {'height': 274,
#      'url': 'https://i.scdn.co/image/548ef62e954ed5e216ac75d2a55d33fb0ab170d5',
#      'width': 300},
#     {'height': 58,
#      'url': 'https://i.scdn.co/image/b85f75f7891212bc2d4833644da48b6dec951d1c',
#      'width': 63}],
#    'name': 'English Rain',
#    'release_date': '2013-05-13',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:7kyjDxYcff3MeWKtw0fnLW'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3w6zswp5THsSKYLICUbDTZ'},
#     'href': 'https://api.spotify.com/v1/artists/3w6zswp5THsSKYLICUbDTZ',
#     'id': '3w6zswp5THsSKYLICUbDTZ',
#     'name': 'Gabrielle Aplin',
#     'type': 'artist',
#     'uri': 'spotify:artist:3w6zswp5THsSKYLICUbDTZ'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'DE',
#    'DO',
#    'EC',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IS',
#    'LI',
#    'MC',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PY',
#    'SG',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 245560,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAYE1202442'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1dMOkSlIgQEgIKFTz4LqL6'},
#   'href': 'https://api.spotify.com/v1/tracks/1dMOkSlIgQEgIKFTz4LqL6',
#   'id': '1dMOkSlIgQEgIKFTz4LqL6',
#   'name': 'November',
#   'popularity': 40,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c1a62f079732f476b5250a3d25cb6a7a506f75c7?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:1dMOkSlIgQEgIKFTz4LqL6'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#      'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#      'id': '3qm84nBOXUEQ2vnTfUTTFC',
#      'name': "Guns N' Roses",
#      'type': 'artist',
#      'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3ZwjaVcnVo2TwhK8N8WWVs'},
#    'href': 'https://api.spotify.com/v1/albums/3ZwjaVcnVo2TwhK8N8WWVs',
#    'id': '3ZwjaVcnVo2TwhK8N8WWVs',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ee52ae3d67fe2c1b7530bb97cdddc51fa698932f',
#      'width': 630},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/cbf3feba5df61146e034fcdeb2b38d746241ec8b',
#      'width': 296},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/be89b2e7c51e9a3cba87673a9be025cf3881b8c7',
#      'width': 63}],
#    'name': "Live Era '87-'93",
#    'release_date': '1999-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3ZwjaVcnVo2TwhK8N8WWVs'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#     'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#     'id': '3qm84nBOXUEQ2vnTfUTTFC',
#     'name': "Guns N' Roses",
#     'type': 'artist',
#     'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 749773,
#   'explicit': False,
#   'external_ids': {'isrc': 'USIR19915125'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4EQDIFyn4VPMl4OWBc0EV2'},
#   'href': 'https://api.spotify.com/v1/tracks/4EQDIFyn4VPMl4OWBc0EV2',
#   'id': '4EQDIFyn4VPMl4OWBc0EV2',
#   'name': 'November Rain - Live In Japan / 1992',
#   'popularity': 42,
#   'preview_url': None,
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:4EQDIFyn4VPMl4OWBc0EV2'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33k6kPYIS5TgseAc70LZjy'},
#      'href': 'https://api.spotify.com/v1/artists/33k6kPYIS5TgseAc70LZjy',
#      'id': '33k6kPYIS5TgseAc70LZjy',
#      'name': 'David Garrett',
#      'type': 'artist',
#      'uri': 'spotify:artist:33k6kPYIS5TgseAc70LZjy'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3PNKgHOAHp8oWnAEB7gCXx'},
#    'href': 'https://api.spotify.com/v1/albums/3PNKgHOAHp8oWnAEB7gCXx',
#    'id': '3PNKgHOAHp8oWnAEB7gCXx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/e41c535d9ddaded3077bc3c35892288de8b89383',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/c8ba1785c52d1a408c3ef38012e25f494f66e2de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/fd37d6bab1f0b4b63de2a2e2a1a53e3af93b1557',
#      'width': 64}],
#    'name': 'Rock Symphonies',
#    'release_date': '2010-01-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3PNKgHOAHp8oWnAEB7gCXx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33k6kPYIS5TgseAc70LZjy'},
#     'href': 'https://api.spotify.com/v1/artists/33k6kPYIS5TgseAc70LZjy',
#     'id': '33k6kPYIS5TgseAc70LZjy',
#     'name': 'David Garrett',
#     'type': 'artist',
#     'uri': 'spotify:artist:33k6kPYIS5TgseAc70LZjy'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 238773,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBBBA1042840'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1XfYyru6HemV6aexQPdF8n'},
#   'href': 'https://api.spotify.com/v1/tracks/1XfYyru6HemV6aexQPdF8n',
#   'id': '1XfYyru6HemV6aexQPdF8n',
#   'name': 'November Rain',
#   'popularity': 33,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1XfYyru6HemV6aexQPdF8n'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#      'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#      'id': '3ccVtqcqedranb7y8eywJ5',
#      'name': 'Blanco White',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wErgKbRnazBrl24VaPIRT'},
#    'href': 'https://api.spotify.com/v1/albums/3wErgKbRnazBrl24VaPIRT',
#    'id': '3wErgKbRnazBrl24VaPIRT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1041425390d2332be02395a1446354b65a5f8933',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/7ac1c7d02b6e124f6f1c7ae26fbe5680904b9eca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/6fd22cf9000ecdc1222844c459672901ee5fea73',
#      'width': 64}],
#    'name': 'November Rain',
#    'release_date': '2015-11-23',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:3wErgKbRnazBrl24VaPIRT'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#     'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#     'id': '3ccVtqcqedranb7y8eywJ5',
#     'name': 'Blanco White',
#     'type': 'artist',
#     'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 246132,
#   'explicit': False,
#   'external_ids': {'isrc': 'UK4GH1500015'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1BZGq1lAq98mTVdO8HLZaX'},
#   'href': 'https://api.spotify.com/v1/tracks/1BZGq1lAq98mTVdO8HLZaX',
#   'id': '1BZGq1lAq98mTVdO8HLZaX',
#   'name': 'November Rain',
#   'popularity': 35,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3349059141465b892064bdc8e25a79996f71a615?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1BZGq1lAq98mTVdO8HLZaX'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2tQASTYJPc7QQ9GCVbtXfo'},
#    'href': 'https://api.spotify.com/v1/albums/2tQASTYJPc7QQ9GCVbtXfo',
#    'id': '2tQASTYJPc7QQ9GCVbtXfo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/34066a747764d36809751a0d29482dfe3e41489d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/3c62aede5a0d66c6a44e83f06f1a50dbb5cadccf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/a958908bca60c9bd23136cb2de737dac56e9e313',
#      'width': 64}],
#    'name': "Bossa N' Roses",
#    'release_date': '2006-11-14',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:2tQASTYJPc7QQ9GCVbtXfo'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0g6rXs7y0Xalc9NSqM3jER'},
#     'href': 'https://api.spotify.com/v1/artists/0g6rXs7y0Xalc9NSqM3jER',
#     'id': '0g6rXs7y0Xalc9NSqM3jER',
#     'name': 'Ghetto Blaster Ltd.',
#     'type': 'artist',
#     'uri': 'spotify:artist:0g6rXs7y0Xalc9NSqM3jER'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 291426,
#   'explicit': False,
#   'external_ids': {'isrc': 'ARF410600521'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2sO2B8YGt8Bi9p3tgmSdlC'},
#   'href': 'https://api.spotify.com/v1/tracks/2sO2B8YGt8Bi9p3tgmSdlC',
#   'id': '2sO2B8YGt8Bi9p3tgmSdlC',
#   'name': 'November Rain - B&H Version',
#   'popularity': 49,
#   'preview_url': 'https://p.scdn.co/mp3-preview/eeafe7a4a2d88f3d0ef29ea175710c6ad4127366?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:2sO2B8YGt8Bi9p3tgmSdlC'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#      'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#      'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#      'name': 'Rockabye Baby!',
#      'type': 'artist',
#      'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5dEdYpJR27Ggmc0jp0Oflg'},
#    'href': 'https://api.spotify.com/v1/albums/5dEdYpJR27Ggmc0jp0Oflg',
#    'id': '5dEdYpJR27Ggmc0jp0Oflg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/d05eb58b15de67729ca9c27b2f14cdab671d08c0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/dfcb6f58ff0be9a8fa96337cfb1f09884738b2d9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/890332839ab9c76926b5ee87637633179d6edfa0',
#      'width': 64}],
#    'name': "Lullaby Renditions of Guns n' Roses",
#    'release_date': '2009-11-10',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5dEdYpJR27Ggmc0jp0Oflg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#     'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#     'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#     'name': 'Rockabye Baby!',
#     'type': 'artist',
#     'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 286893,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEWC0982552'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7l7hhlpkcxs4zA5cOBC1jI'},
#   'href': 'https://api.spotify.com/v1/tracks/7l7hhlpkcxs4zA5cOBC1jI',
#   'id': '7l7hhlpkcxs4zA5cOBC1jI',
#   'name': 'November Rain',
#   'popularity': 30,
#   'preview_url': 'https://p.scdn.co/mp3-preview/bf7ad325883d9dfb133cedb096fbbb8ad6b2fd9d?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:7l7hhlpkcxs4zA5cOBC1jI'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77A9XsX4SDJlhB23yyUwQt'},
#      'href': 'https://api.spotify.com/v1/artists/77A9XsX4SDJlhB23yyUwQt',
#      'id': '77A9XsX4SDJlhB23yyUwQt',
#      'name': 'Steve ´n´ Seagulls',
#      'type': 'artist',
#      'uri': 'spotify:artist:77A9XsX4SDJlhB23yyUwQt'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5P48aG3Qgn5oe6Xy9jkXdn'},
#    'href': 'https://api.spotify.com/v1/albums/5P48aG3Qgn5oe6Xy9jkXdn',
#    'id': '5P48aG3Qgn5oe6Xy9jkXdn',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/f911a77aaa283fd59722db3c52c31dd21013fa68',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/f9fb3217890f2d20a79f6f7d72e259e46868c33a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/d6e1c9463faec2a2b288946c20b1e03f94561e81',
#      'width': 64}],
#    'name': 'Brothers In Farms',
#    'release_date': '2016-09-09',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5P48aG3Qgn5oe6Xy9jkXdn'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77A9XsX4SDJlhB23yyUwQt'},
#     'href': 'https://api.spotify.com/v1/artists/77A9XsX4SDJlhB23yyUwQt',
#     'id': '77A9XsX4SDJlhB23yyUwQt',
#     'name': 'Steve ´n´ Seagulls',
#     'type': 'artist',
#     'uri': 'spotify:artist:77A9XsX4SDJlhB23yyUwQt'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 303546,
#   'explicit': False,
#   'external_ids': {'isrc': 'FIUM71600358'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6QF3vavxEItY8ru6DcL9N2'},
#   'href': 'https://api.spotify.com/v1/tracks/6QF3vavxEItY8ru6DcL9N2',
#   'id': '6QF3vavxEItY8ru6DcL9N2',
#   'name': 'November Rain',
#   'popularity': 29,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:6QF3vavxEItY8ru6DcL9N2'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#      'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#      'id': '3ccVtqcqedranb7y8eywJ5',
#      'name': 'Blanco White',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5eOg5JJewzpCZjO4u3wm9O'},
#    'href': 'https://api.spotify.com/v1/albums/5eOg5JJewzpCZjO4u3wm9O',
#    'id': '5eOg5JJewzpCZjO4u3wm9O',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1041425390d2332be02395a1446354b65a5f8933',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/7ac1c7d02b6e124f6f1c7ae26fbe5680904b9eca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/6fd22cf9000ecdc1222844c459672901ee5fea73',
#      'width': 64}],
#    'name': 'The Wind Rose EP',
#    'release_date': '2016-02-05',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5eOg5JJewzpCZjO4u3wm9O'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ccVtqcqedranb7y8eywJ5'},
#     'href': 'https://api.spotify.com/v1/artists/3ccVtqcqedranb7y8eywJ5',
#     'id': '3ccVtqcqedranb7y8eywJ5',
#     'name': 'Blanco White',
#     'type': 'artist',
#     'uri': 'spotify:artist:3ccVtqcqedranb7y8eywJ5'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 246132,
#   'explicit': False,
#   'external_ids': {'isrc': 'UK4GH1500015'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/71EeFAAKi6iekORgxgz2d5'},
#   'href': 'https://api.spotify.com/v1/tracks/71EeFAAKi6iekORgxgz2d5',
#   'id': '71EeFAAKi6iekORgxgz2d5',
#   'name': 'November Rain',
#   'popularity': 33,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3349059141465b892064bdc8e25a79996f71a615?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:71EeFAAKi6iekORgxgz2d5'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5dPAnuLyn7AHGV6XIIcY64'},
#    'href': 'https://api.spotify.com/v1/albums/5dPAnuLyn7AHGV6XIIcY64',
#    'id': '5dPAnuLyn7AHGV6XIIcY64',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9aef9f1188bd6d779f227ebfea3798273fc193aa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/6ff8889f96fbefc978e59beab8e0d1a722a1a353',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/0556f278ce239569d15267520914a1b651605db1',
#      'width': 64}],
#    'name': 'Vintage Café - Lounge & Jazz Blends',
#    'release_date': '2007-09-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5dPAnuLyn7AHGV6XIIcY64'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#     'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#     'id': '4BoBwZFmzlSepZqWiok2Z9',
#     'name': 'Anakelly',
#     'type': 'artist',
#     'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 2,
#   'duration_ms': 255320,
#   'explicit': False,
#   'external_ids': {'isrc': 'ARF410600421'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/77CnXU4HGxTP2IMRWyJJAk'},
#   'href': 'https://api.spotify.com/v1/tracks/77CnXU4HGxTP2IMRWyJJAk',
#   'id': '77CnXU4HGxTP2IMRWyJJAk',
#   'name': 'November Rain',
#   'popularity': 45,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2e721357b5cbe1ccc15b7f7e727c1b84a2687c27?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:77CnXU4HGxTP2IMRWyJJAk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wMmGaXRfdHPhqSEAVQIr6'},
#      'href': 'https://api.spotify.com/v1/artists/0wMmGaXRfdHPhqSEAVQIr6',
#      'id': '0wMmGaXRfdHPhqSEAVQIr6',
#      'name': 'Instrumental',
#      'type': 'artist',
#      'uri': 'spotify:artist:0wMmGaXRfdHPhqSEAVQIr6'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1pxMDMjn9XXi4SyUo2wyVb'},
#    'href': 'https://api.spotify.com/v1/albums/1pxMDMjn9XXi4SyUo2wyVb',
#    'id': '1pxMDMjn9XXi4SyUo2wyVb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/9c96f4689ee789cdf560cb182ccf46e737de1f6c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/5ea0862c55f2f23a2d50dab3acaa37ba39f977b2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/195e84002aee8193f2f8d6c68b115467b6c9f74b',
#      'width': 64}],
#    'name': '50 Classical Study Songs',
#    'release_date': '2016-12-14',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:1pxMDMjn9XXi4SyUo2wyVb'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wMmGaXRfdHPhqSEAVQIr6'},
#     'href': 'https://api.spotify.com/v1/artists/0wMmGaXRfdHPhqSEAVQIr6',
#     'id': '0wMmGaXRfdHPhqSEAVQIr6',
#     'name': 'Instrumental',
#     'type': 'artist',
#     'uri': 'spotify:artist:0wMmGaXRfdHPhqSEAVQIr6'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 253164,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBPS81601442'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3x4u7JB8TO4Y44KTe0N2Uo'},
#   'href': 'https://api.spotify.com/v1/tracks/3x4u7JB8TO4Y44KTe0N2Uo',
#   'id': '3x4u7JB8TO4Y44KTe0N2Uo',
#   'name': 'November Rain',
#   'popularity': 26,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0bd5593838d5c37611dca0632bc306bc14fb55bd?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 32,
#   'type': 'track',
#   'uri': 'spotify:track:3x4u7JB8TO4Y44KTe0N2Uo'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#      'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#      'id': '4BoBwZFmzlSepZqWiok2Z9',
#      'name': 'Anakelly',
#      'type': 'artist',
#      'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6CkestcVpVUxGKkVbK4SG4'},
#    'href': 'https://api.spotify.com/v1/albums/6CkestcVpVUxGKkVbK4SG4',
#    'id': '6CkestcVpVUxGKkVbK4SG4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/80df3433d79081074d07b4cb5e6917e77b74f448',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/aac721a141453e9d8ebb12a68f59f0f9ce599c48',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/72c2d14b2995cdc18bef50e274ed019e1f2117aa',
#      'width': 64}],
#    'name': 'Summer Lounge Beats',
#    'release_date': '2014-04-29',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:6CkestcVpVUxGKkVbK4SG4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#     'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#     'id': '4BoBwZFmzlSepZqWiok2Z9',
#     'name': 'Anakelly',
#     'type': 'artist',
#     'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 255320,
#   'explicit': False,
#   'external_ids': {'isrc': 'ARF410600421'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5TSqyACHswDUYtvXkEIwqR'},
#   'href': 'https://api.spotify.com/v1/tracks/5TSqyACHswDUYtvXkEIwqR',
#   'id': '5TSqyACHswDUYtvXkEIwqR',
#   'name': 'November Rain',
#   'popularity': 37,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2e721357b5cbe1ccc15b7f7e727c1b84a2687c27?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:5TSqyACHswDUYtvXkEIwqR'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#      'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#      'id': '4TMHGUX5WI7OOm53PqSDAT',
#      'name': 'Grateful Dead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/24rc4HaQfvOOSnq32PkOC1'},
#    'href': 'https://api.spotify.com/v1/albums/24rc4HaQfvOOSnq32PkOC1',
#    'id': '24rc4HaQfvOOSnq32PkOC1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/94baf5577e231cd2c451d2deb4e6a5a2eabf469d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/63ab7b9a6635e4a9658751828630e379b8fec23a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/a6cd7577f51c1c58b59d71765e000bb7b973be06',
#      'width': 64}],
#    'name': "Dick's Picks Vol. 34: 11/5/77 (Community War Memorial, Rochester, NY)",
#    'release_date': '2005',
#    'release_date_precision': 'year',
#    'type': 'album',
#    'uri': 'spotify:album:24rc4HaQfvOOSnq32PkOC1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#     'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#     'id': '4TMHGUX5WI7OOm53PqSDAT',
#     'name': 'Grateful Dead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 505693,
#   'explicit': False,
#   'external_ids': {'isrc': 'USRH10901610'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7q2HjPftSMAwrZZyys5Zfz'},
#   'href': 'https://api.spotify.com/v1/tracks/7q2HjPftSMAwrZZyys5Zfz',
#   'id': '7q2HjPftSMAwrZZyys5Zfz',
#   'name': 'Looks Like Rain [Live At Community War Memorial, Rochester, NY, November 5, 1977]',
#   'popularity': 24,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cbfb972cac401b11e6a2b629f811cf3fb52c6bdd?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:7q2HjPftSMAwrZZyys5Zfz'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nSGBmlgUdqWNExnOX8VtV'},
#      'href': 'https://api.spotify.com/v1/artists/5nSGBmlgUdqWNExnOX8VtV',
#      'id': '5nSGBmlgUdqWNExnOX8VtV',
#      'name': 'Rain Sounds',
#      'type': 'artist',
#      'uri': 'spotify:artist:5nSGBmlgUdqWNExnOX8VtV'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NqS7DbPFYwZmniGHCPMpm'},
#      'href': 'https://api.spotify.com/v1/artists/4NqS7DbPFYwZmniGHCPMpm',
#      'id': '4NqS7DbPFYwZmniGHCPMpm',
#      'name': 'Nature Sounds',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NqS7DbPFYwZmniGHCPMpm'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2w5q7SKsUmpdUuyf5HOA2c'},
#      'href': 'https://api.spotify.com/v1/artists/2w5q7SKsUmpdUuyf5HOA2c',
#      'id': '2w5q7SKsUmpdUuyf5HOA2c',
#      'name': 'Nature Sounds Nature Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:2w5q7SKsUmpdUuyf5HOA2c'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5tefhBt5YTFTWR60lQaY20'},
#    'href': 'https://api.spotify.com/v1/albums/5tefhBt5YTFTWR60lQaY20',
#    'id': '5tefhBt5YTFTWR60lQaY20',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/4309d6876ae25fd8df86cde5248b267135973c5c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/fe7ca3c751f417c5dcf9e1cfaef792bef591c4bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/477bba82b66134550296268cb46f41940a32f629',
#      'width': 64}],
#    'name': 'Rain Sounds for Sleep',
#    'release_date': '2016-11-02',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5tefhBt5YTFTWR60lQaY20'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nSGBmlgUdqWNExnOX8VtV'},
#     'href': 'https://api.spotify.com/v1/artists/5nSGBmlgUdqWNExnOX8VtV',
#     'id': '5nSGBmlgUdqWNExnOX8VtV',
#     'name': 'Rain Sounds',
#     'type': 'artist',
#     'uri': 'spotify:artist:5nSGBmlgUdqWNExnOX8VtV'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 127066,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMJG1613627'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5zffvp3o6umOuOgEuFIg8T'},
#   'href': 'https://api.spotify.com/v1/tracks/5zffvp3o6umOuOgEuFIg8T',
#   'id': '5zffvp3o6umOuOgEuFIg8T',
#   'name': 'November Rain',
#   'popularity': 13,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c3e3195853e6533eb098d424ac4d91fe9609104f?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:5zffvp3o6umOuOgEuFIg8T'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xnfpcM4DC9zeHVuDhYICB'},
#      'href': 'https://api.spotify.com/v1/artists/3xnfpcM4DC9zeHVuDhYICB',
#      'id': '3xnfpcM4DC9zeHVuDhYICB',
#      'name': 'Sandi Thom',
#      'type': 'artist',
#      'uri': 'spotify:artist:3xnfpcM4DC9zeHVuDhYICB'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0ugWbv9RDXOu6iKoeKKvFf'},
#    'href': 'https://api.spotify.com/v1/albums/0ugWbv9RDXOu6iKoeKKvFf',
#    'id': '0ugWbv9RDXOu6iKoeKKvFf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/20d95c516e12cf300bb146ec2df76d374dba0f5c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/aacfdedc2c9840435e52a0df7f9469ae391de132',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/b60decfc5ee3fa16f8f8682f1fd0e3106292e3a3',
#      'width': 64}],
#    'name': 'The Covers Collection',
#    'release_date': '2013-11-11',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:0ugWbv9RDXOu6iKoeKKvFf'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xnfpcM4DC9zeHVuDhYICB'},
#     'href': 'https://api.spotify.com/v1/artists/3xnfpcM4DC9zeHVuDhYICB',
#     'id': '3xnfpcM4DC9zeHVuDhYICB',
#     'name': 'Sandi Thom',
#     'type': 'artist',
#     'uri': 'spotify:artist:3xnfpcM4DC9zeHVuDhYICB'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 300975,
#   'explicit': False,
#   'external_ids': {'isrc': 'QMDA61321417'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1Md5mt7k3ZwSHbVapqJ6K3'},
#   'href': 'https://api.spotify.com/v1/tracks/1Md5mt7k3ZwSHbVapqJ6K3',
#   'id': '1Md5mt7k3ZwSHbVapqJ6K3',
#   'name': 'November Rain',
#   'popularity': 32,
#   'preview_url': 'https://p.scdn.co/mp3-preview/de592fa84663b454c29eae600d6788b3a0072ed3?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:1Md5mt7k3ZwSHbVapqJ6K3'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4Ib1mzr9xEDpZcwQmdTlAD'},
#    'href': 'https://api.spotify.com/v1/albums/4Ib1mzr9xEDpZcwQmdTlAD',
#    'id': '4Ib1mzr9xEDpZcwQmdTlAD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/281df942e99bc64826e7040c02c6cf1be0ff8964',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/6424388debc29c057d5319c463f9bea7fcadb115',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/83ec4179d19f3c3cfc951651f33b85bec7d46daf',
#      'width': 64}],
#    'name': "Bossa N' Essentials",
#    'release_date': '2011-05-24',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:4Ib1mzr9xEDpZcwQmdTlAD'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BoBwZFmzlSepZqWiok2Z9'},
#     'href': 'https://api.spotify.com/v1/artists/4BoBwZFmzlSepZqWiok2Z9',
#     'id': '4BoBwZFmzlSepZqWiok2Z9',
#     'name': 'Anakelly',
#     'type': 'artist',
#     'uri': 'spotify:artist:4BoBwZFmzlSepZqWiok2Z9'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 2,
#   'duration_ms': 258613,
#   'explicit': False,
#   'external_ids': {'isrc': 'ARF410600421'},
# ...
#      'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#      'id': '4TMHGUX5WI7OOm53PqSDAT',
#      'name': 'Grateful Dead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4QLlTAC9pOzbZo7qQ63dXm'},
#    'href': 'https://api.spotify.com/v1/albums/4QLlTAC9pOzbZo7qQ63dXm',
#    'id': '4QLlTAC9pOzbZo7qQ63dXm',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/10923ad1731fe10d3fd4dc60208769bfe38f8486',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/95006f6fb083338a144d3feab214e7b4ef6ce8f9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/90fd5f55e48135cf865beeb139a9664cb5431ef8',
#      'width': 64}],
#    'name': "Dick's Picks Vol. 21: 11/1/85 (Richmond Coliseum, Richmond, VA)",
#    'release_date': '2001',
#    'release_date_precision': 'year',
#    'type': 'album',
#    'uri': 'spotify:album:4QLlTAC9pOzbZo7qQ63dXm'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TMHGUX5WI7OOm53PqSDAT'},
#     'href': 'https://api.spotify.com/v1/artists/4TMHGUX5WI7OOm53PqSDAT',
#     'id': '4TMHGUX5WI7OOm53PqSDAT',
#     'name': 'Grateful Dead',
#     'type': 'artist',
#     'uri': 'spotify:artist:4TMHGUX5WI7OOm53PqSDAT'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 452506,
#   'explicit': False,
#   'external_ids': {'isrc': 'USRH10900706'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1T6dQI8z0iHcbn1LwmppIE'},
#   'href': 'https://api.spotify.com/v1/tracks/1T6dQI8z0iHcbn1LwmppIE',
#   'id': '1T6dQI8z0iHcbn1LwmppIE',
#   'name': 'Cold Rain & Snow [Live at Richmond Coliseum, Richmond, VA, November 1, 1985]',
#   'popularity': 16,
#   'preview_url': 'https://p.scdn.co/mp3-preview/352b5c6751b11df428d1db9d285eaba93ac73250?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1T6dQI8z0iHcbn1LwmppIE'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oyZF2G7rCd7ZPxXsnXwBR'},
#      'href': 'https://api.spotify.com/v1/artists/2oyZF2G7rCd7ZPxXsnXwBR',
#      'id': '2oyZF2G7rCd7ZPxXsnXwBR',
#      'name': 'Rain relax',
#      'type': 'artist',
#      'uri': 'spotify:artist:2oyZF2G7rCd7ZPxXsnXwBR'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/61xIwfrVYpdQk9rmWptAN8'},
#    'href': 'https://api.spotify.com/v1/albums/61xIwfrVYpdQk9rmWptAN8',
#    'id': '61xIwfrVYpdQk9rmWptAN8',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/a4e2813bcb11479a322c2363ab6d63fc6f392d01',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ad3b0b36cfe638459492f756582654e5e9c755e1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/7c22ec735b6b98060e45e057e7b601d3d471f6fc',
#      'width': 64}],
#    'name': '100 Nature Rain Sounds and Ambient Sounds for Relaxation',
#    'release_date': '2015-05-11',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:61xIwfrVYpdQk9rmWptAN8'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2oyZF2G7rCd7ZPxXsnXwBR'},
#     'href': 'https://api.spotify.com/v1/artists/2oyZF2G7rCd7ZPxXsnXwBR',
#     'id': '2oyZF2G7rCd7ZPxXsnXwBR',
#     'name': 'Rain relax',
#     'type': 'artist',
#     'uri': 'spotify:artist:2oyZF2G7rCd7ZPxXsnXwBR'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 227395,
#   'explicit': False,
#   'external_ids': {'isrc': 'GB-SMU-20-98894'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0ersyoaH6HDtJ77Cow60VS'},
#   'href': 'https://api.spotify.com/v1/tracks/0ersyoaH6HDtJ77Cow60VS',
#   'id': '0ersyoaH6HDtJ77Cow60VS',
#   'name': 'November rain',
#   'popularity': 0,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3b6e1937364149fe58f29d924c4ccee1d2dc55da?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:0ersyoaH6HDtJ77Cow60VS'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mDSQ2wWtSRVgalV0BJX2d'},
#      'href': 'https://api.spotify.com/v1/artists/1mDSQ2wWtSRVgalV0BJX2d',
#      'id': '1mDSQ2wWtSRVgalV0BJX2d',
#      'name': 'Sixx Digit',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mDSQ2wWtSRVgalV0BJX2d'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5MTdosz9Th00BxmDHAReF2'},
#    'href': 'https://api.spotify.com/v1/albums/5MTdosz9Th00BxmDHAReF2',
#    'id': '5MTdosz9Th00BxmDHAReF2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1ce89e8d3c8ce5320ccbe0e2dbc2b458973ecfaf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/6676c40f97cd6883d2cdcdcfe80c9c5682f0b694',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/0b12e25007bbc67bec3af19deb04dbe4c5fd2a3e',
#      'width': 64}],
#    'name': 'Cold November Rain',
#    'release_date': '2009-07-13',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5MTdosz9Th00BxmDHAReF2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mDSQ2wWtSRVgalV0BJX2d'},
#     'href': 'https://api.spotify.com/v1/artists/1mDSQ2wWtSRVgalV0BJX2d',
#     'id': '1mDSQ2wWtSRVgalV0BJX2d',
#     'name': 'Sixx Digit',
#     'type': 'artist',
#     'uri': 'spotify:artist:1mDSQ2wWtSRVgalV0BJX2d'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 2,
#   'duration_ms': 295546,
#   'explicit': True,
#   'external_ids': {'isrc': 'ushm80944600'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4oGxGCkpSGGr8kS8x5wUar'},
#   'href': 'https://api.spotify.com/v1/tracks/4oGxGCkpSGGr8kS8x5wUar',
#   'id': '4oGxGCkpSGGr8kS8x5wUar',
#   'name': 'Cold November Rain',
#   'popularity': 0,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7c0b7f07e46ec3fb21631029753f6e78834ddba2?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:4oGxGCkpSGGr8kS8x5wUar'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3A12QFuD1pphKdNKs2B2mg'},
#      'href': 'https://api.spotify.com/v1/artists/3A12QFuD1pphKdNKs2B2mg',
#      'id': '3A12QFuD1pphKdNKs2B2mg',
#      'name': 'Dirge for November',
#      'type': 'artist',
#      'uri': 'spotify:artist:3A12QFuD1pphKdNKs2B2mg'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5jpEWBMsUhRS2rkBS6YAsK'},
#    'href': 'https://api.spotify.com/v1/albums/5jpEWBMsUhRS2rkBS6YAsK',
#    'id': '5jpEWBMsUhRS2rkBS6YAsK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/834d7b3f503ea8eec5cca0afa497e4713cfdc582',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/0499442c9900a3f48d0da7cb77c021fb4da8fa67',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/91d7a07325e823c1df9b06ca5ad2e9c89d7d02d0',
#      'width': 64}],
#    'name': 'November',
#    'release_date': '2017-04-01',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5jpEWBMsUhRS2rkBS6YAsK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3A12QFuD1pphKdNKs2B2mg'},
#     'href': 'https://api.spotify.com/v1/artists/3A12QFuD1pphKdNKs2B2mg',
#     'id': '3A12QFuD1pphKdNKs2B2mg',
#     'name': 'Dirge for November',
#     'type': 'artist',
#     'uri': 'spotify:artist:3A12QFuD1pphKdNKs2B2mg'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 165866,
#   'explicit': False,
#   'external_ids': {'isrc': 'QM4DW1794461'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/15TJnX8wI4dWmC5fm8ZJ5N'},
#   'href': 'https://api.spotify.com/v1/tracks/15TJnX8wI4dWmC5fm8ZJ5N',
#   'id': '15TJnX8wI4dWmC5fm8ZJ5N',
#   'name': 'Rain',
#   'popularity': 0,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c683998b4c4e037800b433232abbdb89b8f01bd3?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:15TJnX8wI4dWmC5fm8ZJ5N'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oXAHFsKzKMklJtiBw8peV'},
#      'href': 'https://api.spotify.com/v1/artists/1oXAHFsKzKMklJtiBw8peV',
#      'id': '1oXAHFsKzKMklJtiBw8peV',
#      'name': 'DJ Darq',
#      'type': 'artist',
#      'uri': 'spotify:artist:1oXAHFsKzKMklJtiBw8peV'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5qyTqcVVwA9efacmZEbKbU'},
#    'href': 'https://api.spotify.com/v1/albums/5qyTqcVVwA9efacmZEbKbU',
#    'id': '5qyTqcVVwA9efacmZEbKbU',
#    'images': [{'height': 600,
#      'url': 'https://i.scdn.co/image/e6bcf19a7cf3398740c438d8d9a57a5bf3e90910',
#      'width': 600},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/e47556f98ae495350c8baa01edf8e4a31518925f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/bd7e646d36b1dfbe90d5a5202126493725989ee3',
#      'width': 64}],
#    'name': 'November Rain',
#    'release_date': '2010-03-05',
#    'release_date_precision': 'day',
#    'type': 'album',
#    'uri': 'spotify:album:5qyTqcVVwA9efacmZEbKbU'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oXAHFsKzKMklJtiBw8peV'},
#     'href': 'https://api.spotify.com/v1/artists/1oXAHFsKzKMklJtiBw8peV',
#     'id': '1oXAHFsKzKMklJtiBw8peV',
#     'name': 'DJ Darq',
#     'type': 'artist',
#     'uri': 'spotify:artist:1oXAHFsKzKMklJtiBw8peV'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
#    'TH',
#    'TR',
#    'TW',
#    'US',
#    'UY'],
#   'disc_number': 1,
#   'duration_ms': 488805,
#   'explicit': False,
#   'external_ids': {'isrc': 'DEAR41036113'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4I0riUaf4ADqQyRNh0mWy2'},
#   'href': 'https://api.spotify.com/v1/tracks/4I0riUaf4ADqQyRNh0mWy2',
#   'id': '4I0riUaf4ADqQyRNh0mWy2',
#   'name': 'November Rain - Original Mix',
#   'popularity': 1,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3b4846a747b7ab27439739901725dd44ee7f6ed6?cid=f50bb3a5dd0946fdb02c6c6459d69aea',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4I0riUaf4ADqQyRNh0mWy2'}]

# %%
# Let's take a look at the first returned result
first_returned_track = response['tracks']['items'][0]

# %%
first_returned_track.keys()
# Out:
# dict_keys(['external_urls', 'available_markets', 'disc_number', 'id', 'external_ids', 'explicit', 'preview_url', 'artists', 'popularity', 'duration_ms', 'album', 'uri', 'name', 'track_number', 'href', 'type'])

# %%
first_returned_track['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#   'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#   'id': '3qm84nBOXUEQ2vnTfUTTFC',
#   'name': "Guns N' Roses",
#   'type': 'artist',
#   'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}]

# %%
first_returned_track['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qm84nBOXUEQ2vnTfUTTFC'},
#    'href': 'https://api.spotify.com/v1/artists/3qm84nBOXUEQ2vnTfUTTFC',
#    'id': '3qm84nBOXUEQ2vnTfUTTFC',
#    'name': "Guns N' Roses",
#    'type': 'artist',
#    'uri': 'spotify:artist:3qm84nBOXUEQ2vnTfUTTFC'}],
#  'available_markets': ['CA', 'MX', 'US'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0CxPbTRARqKUYighiEY9Sz'},
#  'href': 'https://api.spotify.com/v1/albums/0CxPbTRARqKUYighiEY9Sz',
#  'id': '0CxPbTRARqKUYighiEY9Sz',
#  'images': [{'height': 637,
#    'url': 'https://i.scdn.co/image/fa10c6d51c37a2306b3a610241d32d46101fc9c6',
#    'width': 640},
#   {'height': 299,
#    'url': 'https://i.scdn.co/image/7843f5e2910381a94e5d796d6e11ce800fd13fee',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/c1e722ccf8858db0930bf3606979e444cf414856',
#    'width': 64}],
#  'name': 'Use Your Illusion I',
#  'release_date': '1991-01-01',
#  'release_date_precision': 'day',
#  'type': 'album',
#  'uri': 'spotify:album:0CxPbTRARqKUYighiEY9Sz'}

# %%
first_returned_track['popularity']
# Out:
# 70

# %%
# Now, let's create a dataframe to see all the returned data
import pandas as pd

df = pd.DataFrame(response['tracks']['items'])
df

# %%
# And we will use json_normalize to flatten the elements that are dictionaries
# We will still have elements that contain lists
from pandas.io.json import json_normalize

df_normalized = json_normalize(response['tracks']['items'])
df_normalized.dtypes
# Out:
# album.album_type                object
# album.artists                   object
# album.available_markets         object
# album.external_urls.spotify     object
# album.href                      object
# album.id                        object
# album.images                    object
# album.name                      object
# album.release_date              object
# album.release_date_precision    object
# album.type                      object
# album.uri                       object
# artists                         object
# available_markets               object
# disc_number                      int64
# duration_ms                      int64
# explicit                          bool
# external_ids.isrc               object
# external_urls.spotify           object
# href                            object
# id                              object
# name                            object
# popularity                       int64
# preview_url                     object
# track_number                     int64
# type                            object
# uri                             object
# dtype: object

# %%
df_normalized
# Out:
#    album.album_type                                      album.artists  \
# 0             album  [{'external_urls': {'spotify': 'https://open.s...
# 1       compilation  [{'external_urls': {'spotify': 'https://open.s...
# 2             album  [{'external_urls': {'spotify': 'https://open.s...
# 3       compilation  [{'external_urls': {'spotify': 'https://open.s...
# 4             album  [{'external_urls': {'spotify': 'https://open.s...
# 5            single  [{'external_urls': {'spotify': 'https://open.s...
# 6             album  [{'external_urls': {'spotify': 'https://open.s...
# 7             album  [{'external_urls': {'spotify': 'https://open.s...
# 8             album  [{'external_urls': {'spotify': 'https://open.s...
# 9            single  [{'external_urls': {'spotify': 'https://open.s...
# 10            album  [{'external_urls': {'spotify': 'https://open.s...
# 11            album  [{'external_urls': {'spotify': 'https://open.s...
# 12            album  [{'external_urls': {'spotify': 'https://open.s...
# 13            album  [{'external_urls': {'spotify': 'https://open.s...
# 14            album  [{'external_urls': {'spotify': 'https://open.s...
# 15            album  [{'external_urls': {'spotify': 'https://open.s...
# 16      compilation  [{'external_urls': {'spotify': 'https://open.s...
# 17            album  [{'external_urls': {'spotify': 'https://open.s...
# 18            album  [{'external_urls': {'spotify': 'https://open.s...
# 19            album  [{'external_urls': {'spotify': 'https://open.s...
# 20      compilation  [{'external_urls': {'spotify': 'https://open.s...
# 21            album  [{'external_urls': {'spotify': 'https://open.s...
# 22           single  [{'external_urls': {'spotify': 'https://open.s...
# 23            album  [{'external_urls': {'spotify': 'https://open.s...
# 24            album  [{'external_urls': {'spotify': 'https://open.s...
# 25            album  [{'external_urls': {'spotify': 'https://open.s...
# 26           single  [{'external_urls': {'spotify': 'https://open.s...
# 27           single  [{'external_urls': {'spotify': 'https://open.s...
# 28           single  [{'external_urls': {'spotify': 'https://open.s...
# 29           single  [{'external_urls': {'spotify': 'https://open.s...
# 30           single  [{'external_urls': {'spotify': 'https://open.s...
# 31            album  [{'external_urls': {'spotify': 'https://open.s...
# 32            album  [{'external_urls': {'spotify': 'https://open.s...
# 33            album  [{'external_urls': {'spotify': 'https://open.s...
# 34            album  [{'external_urls': {'spotify': 'https://open.s...
# 35            album  [{'external_urls': {'spotify': 'https://open.s...
# 36            album  [{'external_urls': {'spotify': 'https://open.s...
# 37            album  [{'external_urls': {'spotify': 'https://open.s...
# 38            album  [{'external_urls': {'spotify': 'https://open.s...
# 39            album  [{'external_urls': {'spotify': 'https://open.s...
# 40           single  [{'external_urls': {'spotify': 'https://open.s...
# 41           single  [{'external_urls': {'spotify': 'https://open.s...
# 42            album  [{'external_urls': {'spotify': 'https://open.s...
# 43            album  [{'external_urls': {'spotify': 'https://open.s...
# 44           single  [{'external_urls': {'spotify': 'https://open.s...
# 45            album  [{'external_urls': {'spotify': 'https://open.s...
# 46            album  [{'external_urls': {'spotify': 'https://open.s...
# 47            album  [{'external_urls': {'spotify': 'https://open.s...
# 48            album  [{'external_urls': {'spotify': 'https://open.s...
# 49           single  [{'external_urls': {'spotify': 'https://open.s...
#
#                               album.available_markets  \
# 0                                        [CA, MX, US]
# 1                                        [CA, MX, US]
# 2   [AD, AR, AT, AU, BO, BR, CA, CH, CL, CO, CR, D...
# 3                                        [CA, MX, US]
# 4                                            [CA, US]
# 5   [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 6   [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 7   [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 8                                        [CA, MX, US]
# 9   [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 10  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 11  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 12  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 13  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 14  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 15  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 16  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 17  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 18  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 19  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 20                                           [CA, US]
# 21  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 22                                       [CA, MX, US]
# 23  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 24  [AD, AR, BE, BG, BO, BR, CA, CL, CO, CR, CY, C...
# 25  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 26  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 27  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 28  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 29  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 30  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 31  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 32  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 33  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 34  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 35  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 36  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 37  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 38  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 39  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 40  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 41  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 42  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 43  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 44  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 45  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 46  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 47  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 48  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 49  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
#
#                           album.external_urls.spotify  \
# 0   https://open.spotify.com/album/0CxPbTRARqKUYig...
# 1   https://open.spotify.com/album/4a92B7gXZWKJopx...
# 2   https://open.spotify.com/album/7kyjDxYcff3MeWK...
# 3   https://open.spotify.com/album/3ZwjaVcnVo2TwhK...
# 4   https://open.spotify.com/album/3PNKgHOAHp8oWnA...
# 5   https://open.spotify.com/album/3wErgKbRnazBrl2...
# 6   https://open.spotify.com/album/2tQASTYJPc7QQ9G...
# 7   https://open.spotify.com/album/5dEdYpJR27Ggmc0...
# 8   https://open.spotify.com/album/5P48aG3Qgn5oe6X...
# 9   https://open.spotify.com/album/5eOg5JJewzpCZjO...
# 10  https://open.spotify.com/album/5dPAnuLyn7AHGV6...
# 11  https://open.spotify.com/album/1pxMDMjn9XXi4Sy...
# 12  https://open.spotify.com/album/6CkestcVpVUxGKk...
# 13  https://open.spotify.com/album/24rc4HaQfvOOSnq...
# 14  https://open.spotify.com/album/5tefhBt5YTFTWR6...
# 15  https://open.spotify.com/album/0ugWbv9RDXOu6iK...
# 16  https://open.spotify.com/album/4Ib1mzr9xEDpZcw...
# 17  https://open.spotify.com/album/066yxVSrSYP2FrJ...
# 18  https://open.spotify.com/album/7MRfkn07lyFAGxe...
# 19  https://open.spotify.com/album/4YORZvEB4bvEH8N...
# 20  https://open.spotify.com/album/3nzKw4CYT0mAxI7...
# 21  https://open.spotify.com/album/2rf1fhQvEoYeGmM...
# 22  https://open.spotify.com/album/2SZsQ0uHkDdic6o...
# 23  https://open.spotify.com/album/2ktcpqlZaewceed...
# 24  https://open.spotify.com/album/3KQHyHrOgZCu1Bg...
# 25  https://open.spotify.com/album/40kPGMCLmyiEIw2...
# 26  https://open.spotify.com/album/4gKna8hiz9Odmdl...
# 27  https://open.spotify.com/album/2XtJnQk6Hnri8jR...
# 28  https://open.spotify.com/album/7JKhan1vHmlk4V7...
# 29  https://open.spotify.com/album/1jtKaoEotAce0XH...
# 30  https://open.spotify.com/album/6nPxLKwrmdLEShW...
# 31  https://open.spotify.com/album/2wVaftrYZ7Nchs9...
# 32  https://open.spotify.com/album/5SZHw2OM41jZHgc...
# 33  https://open.spotify.com/album/2awvcv0eodk2OWr...
# 34  https://open.spotify.com/album/1UkUMNfioPivYwu...
# 35  https://open.spotify.com/album/6dbdzVa3Wv37LvW...
# 36  https://open.spotify.com/album/3nKAams72FsqWTa...
# 37  https://open.spotify.com/album/6OutzhkHvwM4edY...
# 38  https://open.spotify.com/album/2KkRoRZitNLlKex...
# 39  https://open.spotify.com/album/6gnTVAqg5hYgFgT...
# 40  https://open.spotify.com/album/5rkSmRLN0QVIFYm...
# 41  https://open.spotify.com/album/5rkSmRLN0QVIFYm...
# 42  https://open.spotify.com/album/1TfHCSeeNQxVJCJ...
# 43  https://open.spotify.com/album/1I5sN2Qn9KkhkUR...
# 44  https://open.spotify.com/album/4RENzAwjf6PcQ4z...
# 45  https://open.spotify.com/album/4QLlTAC9pOzbZo7...
# 46  https://open.spotify.com/album/61xIwfrVYpdQk9r...
# 47  https://open.spotify.com/album/5MTdosz9Th00Bxm...
# 48  https://open.spotify.com/album/5jpEWBMsUhRS2rk...
# 49  https://open.spotify.com/album/5qyTqcVVwA9efac...
#
#                                            album.href                album.id  \
# 0   https://api.spotify.com/v1/albums/0CxPbTRARqKU...  0CxPbTRARqKUYighiEY9Sz
# 1   https://api.spotify.com/v1/albums/4a92B7gXZWKJ...  4a92B7gXZWKJopxs6gWgqb
# 2   https://api.spotify.com/v1/albums/7kyjDxYcff3M...  7kyjDxYcff3MeWKtw0fnLW
# 3   https://api.spotify.com/v1/albums/3ZwjaVcnVo2T...  3ZwjaVcnVo2TwhK8N8WWVs
# 4   https://api.spotify.com/v1/albums/3PNKgHOAHp8o...  3PNKgHOAHp8oWnAEB7gCXx
# 5   https://api.spotify.com/v1/albums/3wErgKbRnazB...  3wErgKbRnazBrl24VaPIRT
# 6   https://api.spotify.com/v1/albums/2tQASTYJPc7Q...  2tQASTYJPc7QQ9GCVbtXfo
# 7   https://api.spotify.com/v1/albums/5dEdYpJR27Gg...  5dEdYpJR27Ggmc0jp0Oflg
# 8   https://api.spotify.com/v1/albums/5P48aG3Qgn5o...  5P48aG3Qgn5oe6Xy9jkXdn
# 9   https://api.spotify.com/v1/albums/5eOg5JJewzpC...  5eOg5JJewzpCZjO4u3wm9O
# 10  https://api.spotify.com/v1/albums/5dPAnuLyn7AH...  5dPAnuLyn7AHGV6XIIcY64
# 11  https://api.spotify.com/v1/albums/1pxMDMjn9XXi...  1pxMDMjn9XXi4SyUo2wyVb
# 12  https://api.spotify.com/v1/albums/6CkestcVpVUx...  6CkestcVpVUxGKkVbK4SG4
# 13  https://api.spotify.com/v1/albums/24rc4HaQfvOO...  24rc4HaQfvOOSnq32PkOC1
# 14  https://api.spotify.com/v1/albums/5tefhBt5YTFT...  5tefhBt5YTFTWR60lQaY20
# 15  https://api.spotify.com/v1/albums/0ugWbv9RDXOu...  0ugWbv9RDXOu6iKoeKKvFf
# 16  https://api.spotify.com/v1/albums/4Ib1mzr9xEDp...  4Ib1mzr9xEDpZcwQmdTlAD
# 17  https://api.spotify.com/v1/albums/066yxVSrSYP2...  066yxVSrSYP2FrJ2yxK8QP
# 18  https://api.spotify.com/v1/albums/7MRfkn07lyFA...  7MRfkn07lyFAGxeXO37OFH
# 19  https://api.spotify.com/v1/albums/4YORZvEB4bvE...  4YORZvEB4bvEH8NalfUW48
# 20  https://api.spotify.com/v1/albums/3nzKw4CYT0mA...  3nzKw4CYT0mAxI7xM41NyF
# 21  https://api.spotify.com/v1/albums/2rf1fhQvEoYe...  2rf1fhQvEoYeGmM9SZPfcA
# 22  https://api.spotify.com/v1/albums/2SZsQ0uHkDdi...  2SZsQ0uHkDdic6oa81RLxc
# 23  https://api.spotify.com/v1/albums/2ktcpqlZaewc...  2ktcpqlZaewceed8UFa8WI
# 24  https://api.spotify.com/v1/albums/3KQHyHrOgZCu...  3KQHyHrOgZCu1BgBuIeQY1
# 25  https://api.spotify.com/v1/albums/40kPGMCLmyiE...  40kPGMCLmyiEIw2d2b3yAM
# 26  https://api.spotify.com/v1/albums/4gKna8hiz9Od...  4gKna8hiz9OdmdlsWvVUfR
# 27  https://api.spotify.com/v1/albums/2XtJnQk6Hnri...  2XtJnQk6Hnri8jRnQ6SzT4
# 28  https://api.spotify.com/v1/albums/7JKhan1vHmlk...  7JKhan1vHmlk4V7vTCXBtr
# 29  https://api.spotify.com/v1/albums/1jtKaoEotAce...  1jtKaoEotAce0XHmq6Fsln
# 30  https://api.spotify.com/v1/albums/6nPxLKwrmdLE...  6nPxLKwrmdLEShWt6kbJVz
# 31  https://api.spotify.com/v1/albums/2wVaftrYZ7Nc...  2wVaftrYZ7Nchs90gURRRn
# 32  https://api.spotify.com/v1/albums/5SZHw2OM41jZ...  5SZHw2OM41jZHgcd2tFsUT
# 33  https://api.spotify.com/v1/albums/2awvcv0eodk2...  2awvcv0eodk2OWrJ9cNTaQ
# 34  https://api.spotify.com/v1/albums/1UkUMNfioPiv...  1UkUMNfioPivYwunXAOevu
# 35  https://api.spotify.com/v1/albums/6dbdzVa3Wv37...  6dbdzVa3Wv37LvWLmrvxRP
# 36  https://api.spotify.com/v1/albums/3nKAams72Fsq...  3nKAams72FsqWTa0nC0hcn
# 37  https://api.spotify.com/v1/albums/6OutzhkHvwM4...  6OutzhkHvwM4edYMJeIe6x
# 38  https://api.spotify.com/v1/albums/2KkRoRZitNLl...  2KkRoRZitNLlKexQ2wZb1N
# 39  https://api.spotify.com/v1/albums/6gnTVAqg5hYg...  6gnTVAqg5hYgFgT4HVPJvf
# 40  https://api.spotify.com/v1/albums/5rkSmRLN0QVI...  5rkSmRLN0QVIFYmQsQCVhS
# 41  https://api.spotify.com/v1/albums/5rkSmRLN0QVI...  5rkSmRLN0QVIFYmQsQCVhS
# 42  https://api.spotify.com/v1/albums/1TfHCSeeNQxV...  1TfHCSeeNQxVJCJS2lORkz
# 43  https://api.spotify.com/v1/albums/1I5sN2Qn9Kkh...  1I5sN2Qn9KkhkURASpdMpz
# 44  https://api.spotify.com/v1/albums/4RENzAwjf6Pc...  4RENzAwjf6PcQ4z8SYsxQx
# 45  https://api.spotify.com/v1/albums/4QLlTAC9pOzb...  4QLlTAC9pOzbZo7qQ63dXm
# 46  https://api.spotify.com/v1/albums/61xIwfrVYpdQ...  61xIwfrVYpdQk9rmWptAN8
# 47  https://api.spotify.com/v1/albums/5MTdosz9Th00...  5MTdosz9Th00BxmDHAReF2
# 48  https://api.spotify.com/v1/albums/5jpEWBMsUhRS...  5jpEWBMsUhRS2rkBS6YAsK
# 49  https://api.spotify.com/v1/albums/5qyTqcVVwA9e...  5qyTqcVVwA9efacmZEbKbU
#
#                                          album.images  \
# 0   [{'url': 'https://i.scdn.co/image/fa10c6d51c37...
# 1   [{'url': 'https://i.scdn.co/image/4ac28b48e308...
# 2   [{'url': 'https://i.scdn.co/image/abce476a1a21...
# 3   [{'url': 'https://i.scdn.co/image/ee52ae3d67fe...
# 4   [{'url': 'https://i.scdn.co/image/e41c535d9dda...
# 5   [{'url': 'https://i.scdn.co/image/1041425390d2...
# 6   [{'url': 'https://i.scdn.co/image/34066a747764...
# 7   [{'url': 'https://i.scdn.co/image/d05eb58b15de...
# 8   [{'url': 'https://i.scdn.co/image/f911a77aaa28...
# 9   [{'url': 'https://i.scdn.co/image/1041425390d2...
# 10  [{'url': 'https://i.scdn.co/image/9aef9f1188bd...
# 11  [{'url': 'https://i.scdn.co/image/9c96f4689ee7...
# 12  [{'url': 'https://i.scdn.co/image/80df3433d790...
# 13  [{'url': 'https://i.scdn.co/image/94baf5577e23...
# 14  [{'url': 'https://i.scdn.co/image/4309d6876ae2...
# 15  [{'url': 'https://i.scdn.co/image/20d95c516e12...
# 16  [{'url': 'https://i.scdn.co/image/281df942e99b...
# 17  [{'url': 'https://i.scdn.co/image/3f30d7ca1c82...
# 18  [{'url': 'https://i.scdn.co/image/b4d128dbd318...
# 19  [{'url': 'https://i.scdn.co/image/f408d554dbc1...
# 20  [{'url': 'https://i.scdn.co/image/9599852ba9c7...
# 21  [{'url': 'https://i.scdn.co/image/9e37ca4f4eda...
# 22  [{'url': 'https://i.scdn.co/image/e2370c2ad8e9...
# 23  [{'url': 'https://i.scdn.co/image/55ef896d0bce...
# 24  [{'url': 'https://i.scdn.co/image/b897b457ee75...
# 25  [{'url': 'https://i.scdn.co/image/530b21342fe2...
# 26  [{'url': 'https://i.scdn.co/image/a37c4740e17a...
# 27  [{'url': 'https://i.scdn.co/image/2b243610421b...
# 28  [{'url': 'https://i.scdn.co/image/178b87d8d13f...
# 29  [{'url': 'https://i.scdn.co/image/d779a57d2150...
# 30  [{'url': 'https://i.scdn.co/image/285a12ccd719...
# 31  [{'url': 'https://i.scdn.co/image/a81ff48f3fa5...
# 32  [{'url': 'https://i.scdn.co/image/c1c4494d9e40...
# 33  [{'url': 'https://i.scdn.co/image/e6b706677fc7...
# 34  [{'url': 'https://i.scdn.co/image/559e1abd6d2d...
# 35  [{'url': 'https://i.scdn.co/image/f8ab4a26b485...
# 36  [{'url': 'https://i.scdn.co/image/7cd283a5a28c...
# 37  [{'url': 'https://i.scdn.co/image/37085b9537df...
# 38  [{'url': 'https://i.scdn.co/image/744e2f71e3aa...
# 39  [{'url': 'https://i.scdn.co/image/4d09cef664cd...
# 40  [{'url': 'https://i.scdn.co/image/5e77a88fd813...
# 41  [{'url': 'https://i.scdn.co/image/5e77a88fd813...
# 42  [{'url': 'https://i.scdn.co/image/e921455af3e1...
# 43  [{'url': 'https://i.scdn.co/image/ab59e82bcaa2...
# 44  [{'url': 'https://i.scdn.co/image/b3e7435cc81a...
# 45  [{'url': 'https://i.scdn.co/image/10923ad1731f...
# 46  [{'url': 'https://i.scdn.co/image/a4e2813bcb11...
# 47  [{'url': 'https://i.scdn.co/image/1ce89e8d3c8c...
# 48  [{'url': 'https://i.scdn.co/image/834d7b3f503e...
# 49  [{'url': 'https://i.scdn.co/image/e6bcf19a7cf3...
#
#                                            album.name album.release_date  \
# 0                                 Use Your Illusion I         1991-01-01
# 1                                       Greatest Hits         2004-01-01
# 2                                        English Rain         2013-05-13
# 3                                    Live Era '87-'93         1999-01-01
# 4                                     Rock Symphonies         2010-01-01
# 5                                       November Rain         2015-11-23
# 6                                      Bossa N' Roses         2006-11-14
# 7                 Lullaby Renditions of Guns n' Roses         2009-11-10
# 8                                   Brothers In Farms         2016-09-09
# 9                                    The Wind Rose EP         2016-02-05
# 10                Vintage Café - Lounge & Jazz Blends         2007-09-01
# 11                           50 Classical Study Songs         2016-12-14
# 12                                Summer Lounge Beats         2014-04-29
# 13  Dick's Picks Vol. 34: 11/5/77 (Community War M...               2005
# 14                              Rain Sounds for Sleep         2016-11-02
# 15                              The Covers Collection         2013-11-11
# 16                                Bossa N' Essentials         2011-05-24
# 17  GarciaLive Volume Seven: November 8th, 1976 So...         2016-08-19
# 18                                       Jazz and 90s         2006-09-05
# 19                      The Arrogant Sons Of Bitches!               2003
# 20                                   Live Era '87-'93         1999-01-01
# 21                                           Doom-Wop         2017-09-22
# 22                             November Rain - Single         2014-12-09
# 23                                     A Year of Rain         2017-07-07
# 24                                               Home         2014-10-12
# 25                                       New Hometown         2015-04-30
# 26                                      November Rain         2015-01-12
# 27                                      November Rain         2015-11-08
# 28                                      November Rain         2011-04-28
# 29                                      November Rain         2017-11-10
# 30                                      November Rain         2014-12-05
# 31                                     Afternoon Rain         2017-03-18
# 32                                      Relaxing Rain         2016-09-02
# 33                                        Rain Sounds         2016-09-16
# 34                                        Autumn Rain         2016-09-30
# 35                                       Vk Goes Wild         2010-11-02
# 36                          42 Classical Study Pieces         2018-01-21
# 37                        2018 Sleeping Baby Symphony         2018-02-19
# 38  Vintage Café: Lounge & Jazz Blends (Special Se...         2012-04-03
# 39                  Beautiful Classical Instrumentals         2016-11-30
# 40                                      November Rain         2012-01-23
# 41                                      November Rain         2012-01-23
# 42                                      Drops of Rain         2017-05-25
# 43                               Relaxing Rain Sounds         2016-04-21
# 44                        November Rain (Nervo Remix)         2017-10-18
# 45  Dick's Picks Vol. 21: 11/1/85 (Richmond Colise...               2001
# 46  100 Nature Rain Sounds and Ambient Sounds for ...         2015-05-11
# 47                                 Cold November Rain         2009-07-13
# 48                                           November         2017-04-01
# 49                                      November Rain         2010-03-05
#
#    album.release_date_precision                  ...                   \
# 0                           day                  ...
# 1                           day                  ...
# 2                           day                  ...
# 3                           day                  ...
# 4                           day                  ...
# 5                           day                  ...
# 6                           day                  ...
# 7                           day                  ...
# 8                           day                  ...
# 9                           day                  ...
# 10                          day                  ...
# 11                          day                  ...
# 12                          day                  ...
# 13                         year                  ...
# 14                          day                  ...
# 15                          day                  ...
# 16                          day                  ...
# 17                          day                  ...
# 18                          day                  ...
# 19                         year                  ...
# 20                          day                  ...
# 21                          day                  ...
# 22                          day                  ...
# 23                          day                  ...
# 24                          day                  ...
# 25                          day                  ...
# 26                          day                  ...
# 27                          day                  ...
# 28                          day                  ...
# 29                          day                  ...
# 30                          day                  ...
# 31                          day                  ...
# 32                          day                  ...
# 33                          day                  ...
# 34                          day                  ...
# 35                          day                  ...
# 36                          day                  ...
# 37                          day                  ...
# 38                          day                  ...
# 39                          day                  ...
# 40                          day                  ...
# 41                          day                  ...
# 42                          day                  ...
# 43                          day                  ...
# 44                          day                  ...
# 45                         year                  ...
# 46                          day                  ...
# 47                          day                  ...
# 48                          day                  ...
# 49                          day                  ...
#
#    external_ids.isrc                              external_urls.spotify  \
# 0       USGF19141510  https://open.spotify.com/track/3YRCqOhFifThpSR...
# 1       USGF19141510  https://open.spotify.com/track/11C3oTzP4WJ2UlU...
# 2       GBAYE1202442  https://open.spotify.com/track/1dMOkSlIgQEgIKF...
# 3       USIR19915125  https://open.spotify.com/track/4EQDIFyn4VPMl4O...
# 4       GBBBA1042840  https://open.spotify.com/track/1XfYyru6HemV6ae...
# 5       UK4GH1500015  https://open.spotify.com/track/1BZGq1lAq98mTVd...
# 6       ARF410600521  https://open.spotify.com/track/2sO2B8YGt8Bi9p3...
# 7       USEWC0982552  https://open.spotify.com/track/7l7hhlpkcxs4zA5...
# 8       FIUM71600358  https://open.spotify.com/track/6QF3vavxEItY8ru...
# 9       UK4GH1500015  https://open.spotify.com/track/71EeFAAKi6iekOR...
# 10      ARF410600421  https://open.spotify.com/track/77CnXU4HGxTP2IM...
# 11      GBPS81601442  https://open.spotify.com/track/3x4u7JB8TO4Y44K...
# 12      ARF410600421  https://open.spotify.com/track/5TSqyACHswDUYtv...
# 13      USRH10901610  https://open.spotify.com/track/7q2HjPftSMAwrZZ...
# 14      GBMJG1613627  https://open.spotify.com/track/5zffvp3o6umOuOg...
# 15      QMDA61321417  https://open.spotify.com/track/1Md5mt7k3ZwSHbV...
# 16      ARF410600421  https://open.spotify.com/track/7GN7JgAlC8NECrb...
# 17      USATO1600268  https://open.spotify.com/track/5xFFmNaor9iCcdB...
# 18      ARF410600421  https://open.spotify.com/track/4eCUjQ7RoqNEU2X...
# 19      USEH90610018  https://open.spotify.com/track/2cygI2GQQjeHwNs...
# 20      USIR19915125  https://open.spotify.com/track/6K0vRXdYwQLjbb4...
# 21      ushm81762587  https://open.spotify.com/track/2UjL09kQDWQIkIK...
# 22      USA2B1402880  https://open.spotify.com/track/5hcds4o1DYwyQwd...
# 23      USQY51761127  https://open.spotify.com/track/6jv09GtWHhKeeXF...
# 24      GBF7R1400013  https://open.spotify.com/track/1mRBDyN8jADp7nN...
# 25      USFQ81200020  https://open.spotify.com/track/4ynmjXnNmrehtGR...
# 26      USE830957586  https://open.spotify.com/track/2ndkqNCFTZFzfl2...
# 27      PLA291500070  https://open.spotify.com/track/3AcM7iNwXarmY3R...
# 28      uscgj1152299  https://open.spotify.com/track/0VlJO8gyBkdUgJt...
# 29      TCADI1727242  https://open.spotify.com/track/7h49Y3JnGBYrTyD...
# 30      USE830951385  https://open.spotify.com/track/1Q9qRtIARlPToDm...
# 31      GBMJG1703941  https://open.spotify.com/track/0SbQlwTgMwbIHdC...
# 32      GBMJG1610716  https://open.spotify.com/track/2y1F5uCZgjdrLoV...
# 33      GBMJG1610716  https://open.spotify.com/track/6n4OqbBehwd2Tb1...
# 34      GBMJG1612062  https://open.spotify.com/track/1MG0A59vAw6f35L...
# 35      USI4R1043728  https://open.spotify.com/track/5ZhalZfmmVfSgka...
# 36      GBPS81528347  https://open.spotify.com/track/2GMMAX4OnvrEo0o...
# 37      GBPS83639491  https://open.spotify.com/track/6mv3k5izVFN5BkU...
# 38      ARF410600421  https://open.spotify.com/track/5Z2NZCCGgF1M8ak...
# 39      GBPS81528347  https://open.spotify.com/track/2qqLyaaMlEGSDW0...
# 40      DEAR41181339  https://open.spotify.com/track/4Q26zrbO5lwT2nL...
# 41      DEAR41181340  https://open.spotify.com/track/3AuniygIEhhP9Fl...
# 42      GBMJG1708289  https://open.spotify.com/track/4tfoTilN3IQtyUf...
# 43      GBMJG1604790  https://open.spotify.com/track/0b3ZqUMUnFgeEuy...
# 44      QMEZE1743710  https://open.spotify.com/track/3o5DICOE1pUme56...
# 45      USRH10900706  https://open.spotify.com/track/1T6dQI8z0iHcbn1...
# 46   GB-SMU-20-98894  https://open.spotify.com/track/0ersyoaH6HDtJ77...
# 47      ushm80944600  https://open.spotify.com/track/4oGxGCkpSGGr8kS...
# 48      QM4DW1794461  https://open.spotify.com/track/15TJnX8wI4dWmC5...
# 49      DEAR41036113  https://open.spotify.com/track/4I0riUaf4ADqQyR...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/3YRCqOhFifTh...  3YRCqOhFifThpSRFJ1VWFM
# 1   https://api.spotify.com/v1/tracks/11C3oTzP4WJ2...  11C3oTzP4WJ2UlU3TzHtCK
# 2   https://api.spotify.com/v1/tracks/1dMOkSlIgQEg...  1dMOkSlIgQEgIKFTz4LqL6
# 3   https://api.spotify.com/v1/tracks/4EQDIFyn4VPM...  4EQDIFyn4VPMl4OWBc0EV2
# 4   https://api.spotify.com/v1/tracks/1XfYyru6HemV...  1XfYyru6HemV6aexQPdF8n
# 5   https://api.spotify.com/v1/tracks/1BZGq1lAq98m...  1BZGq1lAq98mTVdO8HLZaX
# 6   https://api.spotify.com/v1/tracks/2sO2B8YGt8Bi...  2sO2B8YGt8Bi9p3tgmSdlC
# 7   https://api.spotify.com/v1/tracks/7l7hhlpkcxs4...  7l7hhlpkcxs4zA5cOBC1jI
# 8   https://api.spotify.com/v1/tracks/6QF3vavxEItY...  6QF3vavxEItY8ru6DcL9N2
# 9   https://api.spotify.com/v1/tracks/71EeFAAKi6ie...  71EeFAAKi6iekORgxgz2d5
# 10  https://api.spotify.com/v1/tracks/77CnXU4HGxTP...  77CnXU4HGxTP2IMRWyJJAk
# 11  https://api.spotify.com/v1/tracks/3x4u7JB8TO4Y...  3x4u7JB8TO4Y44KTe0N2Uo
# 12  https://api.spotify.com/v1/tracks/5TSqyACHswDU...  5TSqyACHswDUYtvXkEIwqR
# 13  https://api.spotify.com/v1/tracks/7q2HjPftSMAw...  7q2HjPftSMAwrZZyys5Zfz
# 14  https://api.spotify.com/v1/tracks/5zffvp3o6umO...  5zffvp3o6umOuOgEuFIg8T
# 15  https://api.spotify.com/v1/tracks/1Md5mt7k3ZwS...  1Md5mt7k3ZwSHbVapqJ6K3
# 16  https://api.spotify.com/v1/tracks/7GN7JgAlC8NE...  7GN7JgAlC8NECrbFa3c7Iy
# 17  https://api.spotify.com/v1/tracks/5xFFmNaor9iC...  5xFFmNaor9iCcdBUlD0nsZ
# 18  https://api.spotify.com/v1/tracks/4eCUjQ7RoqNE...  4eCUjQ7RoqNEU2X1supEgk
# 19  https://api.spotify.com/v1/tracks/2cygI2GQQjeH...  2cygI2GQQjeHwNsZv6A3WP
# 20  https://api.spotify.com/v1/tracks/6K0vRXdYwQLj...  6K0vRXdYwQLjbb4zecNjLm
# 21  https://api.spotify.com/v1/tracks/2UjL09kQDWQI...  2UjL09kQDWQIkIK55sECnf
# 22  https://api.spotify.com/v1/tracks/5hcds4o1DYwy...  5hcds4o1DYwyQwd9ieLmbG
# 23  https://api.spotify.com/v1/tracks/6jv09GtWHhKe...  6jv09GtWHhKeeXF06702dX
# 24  https://api.spotify.com/v1/tracks/1mRBDyN8jADp...  1mRBDyN8jADp7nNmiWp7o7
# 25  https://api.spotify.com/v1/tracks/4ynmjXnNmreh...  4ynmjXnNmrehtGRYtNxd1H
# 26  https://api.spotify.com/v1/tracks/2ndkqNCFTZFz...  2ndkqNCFTZFzfl2Wqa3THM
# 27  https://api.spotify.com/v1/tracks/3AcM7iNwXarm...  3AcM7iNwXarmY3RbPZ98sw
# 28  https://api.spotify.com/v1/tracks/0VlJO8gyBkdU...  0VlJO8gyBkdUgJtutxJDAA
# 29  https://api.spotify.com/v1/tracks/7h49Y3JnGBYr...  7h49Y3JnGBYrTyDvqkx0ky
# 30  https://api.spotify.com/v1/tracks/1Q9qRtIARlPT...  1Q9qRtIARlPToDmMjkjDZf
# 31  https://api.spotify.com/v1/tracks/0SbQlwTgMwbI...  0SbQlwTgMwbIHdCxm5miuk
# 32  https://api.spotify.com/v1/tracks/2y1F5uCZgjdr...  2y1F5uCZgjdrLoV6hNFNpO
# 33  https://api.spotify.com/v1/tracks/6n4OqbBehwd2...  6n4OqbBehwd2Tb1hdzf9PI
# 34  https://api.spotify.com/v1/tracks/1MG0A59vAw6f...  1MG0A59vAw6f35L16BKoUJ
# 35  https://api.spotify.com/v1/tracks/5ZhalZfmmVfS...  5ZhalZfmmVfSgkafQmPo1p
# 36  https://api.spotify.com/v1/tracks/2GMMAX4OnvrE...  2GMMAX4OnvrEo0otlSR5k0
# 37  https://api.spotify.com/v1/tracks/6mv3k5izVFN5...  6mv3k5izVFN5BkU02NBnHj
# 38  https://api.spotify.com/v1/tracks/5Z2NZCCGgF1M...  5Z2NZCCGgF1M8akCcWeCKl
# 39  https://api.spotify.com/v1/tracks/2qqLyaaMlEGS...  2qqLyaaMlEGSDW0lyrZFu4
# 40  https://api.spotify.com/v1/tracks/4Q26zrbO5lwT...  4Q26zrbO5lwT2nLauTJzOa
# 41  https://api.spotify.com/v1/tracks/3AuniygIEhhP...  3AuniygIEhhP9Flah0LAqQ
# 42  https://api.spotify.com/v1/tracks/4tfoTilN3IQt...  4tfoTilN3IQtyUfwZimnps
# 43  https://api.spotify.com/v1/tracks/0b3ZqUMUnFge...  0b3ZqUMUnFgeEuyb2JXlXy
# 44  https://api.spotify.com/v1/tracks/3o5DICOE1pUm...  3o5DICOE1pUme56ey44oc8
# 45  https://api.spotify.com/v1/tracks/1T6dQI8z0iHc...  1T6dQI8z0iHcbn1LwmppIE
# 46  https://api.spotify.com/v1/tracks/0ersyoaH6HDt...  0ersyoaH6HDtJ77Cow60VS
# 47  https://api.spotify.com/v1/tracks/4oGxGCkpSGGr...  4oGxGCkpSGGr8kS8x5wUar
# 48  https://api.spotify.com/v1/tracks/15TJnX8wI4dW...  15TJnX8wI4dWmC5fm8ZJ5N
# 49  https://api.spotify.com/v1/tracks/4I0riUaf4ADq...  4I0riUaf4ADqQyRNh0mWy2
#
#                                                  name  popularity  \
# 0                                       November Rain          70
# 1                                       November Rain          51
# 2                                            November          40
# 3                November Rain - Live In Japan / 1992          42
# 4                                       November Rain          33
# 5                                       November Rain          35
# 6                         November Rain - B&H Version          49
# 7                                       November Rain          30
# 8                                       November Rain          29
# 9                                       November Rain          33
# 10                                      November Rain          45
# 11                                      November Rain          26
# 12                                      November Rain          37
# 13  Looks Like Rain [Live At Community War Memoria...          24
# 14                                      November Rain          13
# 15                                      November Rain          32
# 16                                      November Rain          35
# 17                         Mission in the Rain - Live          23
# 18                                      November Rain          38
# 19                                      November Rain          14
# 20               November Rain - Live In Japan / 1992          17
# 21                                      November Rain          12
# 22                                      November Rain           7
# 23                                      November Rain          10
# 24                                      November Rain          21
# 25                                      November Rain          11
# 26                                      November Rain           0
# 27                                      November Rain           0
# 28                                      November Rain           0
# 29                                      November Rain           0
# 30                                      November Rain           0
# 31                                      November Rain           4
# 32                                      November Rain           3
# 33                                      November Rain           0
# 34                                      November Rain           2
# 35                                      November Rain          19
# 36                                      November Rain           8
# 37                                      November Rain           9
# 38                                      November Rain          30
# 39                                      November Rain          11
# 40                         November Rain - Radio Rain           0
# 41                      November Rain - Extended Rain           0
# 42                                      November Rain           2
# 43                                      November Rain           2
# 44                   November Rain - Nervo Radio Edit          12
# 45  Cold Rain & Snow [Live at Richmond Coliseum, R...          16
# 46                                      November rain           0
# 47                                 Cold November Rain           0
# 48                                               Rain           0
# 49                       November Rain - Original Mix           1
#
#                                           preview_url track_number   type  \
# 0                                                None           10  track
# 1                                                None            9  track
# 2   https://p.scdn.co/mp3-preview/c1a62f079732f476...           11  track
# 3                                                None           11  track
# 4                                                None            2  track
# 5   https://p.scdn.co/mp3-preview/3349059141465b89...            1  track
# 6   https://p.scdn.co/mp3-preview/eeafe7a4a2d88f3d...            5  track
# 7   https://p.scdn.co/mp3-preview/bf7ad325883d9dfb...            5  track
# 8                                                None            6  track
# 9   https://p.scdn.co/mp3-preview/3349059141465b89...            1  track
# 10  https://p.scdn.co/mp3-preview/2e721357b5cbe1cc...           13  track
# 11  https://p.scdn.co/mp3-preview/0bd5593838d5c376...           32  track
# 12  https://p.scdn.co/mp3-preview/2e721357b5cbe1cc...            3  track
# 13  https://p.scdn.co/mp3-preview/cbfb972cac401b11...            3  track
# 14  https://p.scdn.co/mp3-preview/c3e3195853e6533e...            7  track
# 15  https://p.scdn.co/mp3-preview/de592fa84663b454...            3  track
# 16  https://p.scdn.co/mp3-preview/4daa628f2723b16d...            3  track
# 17  https://p.scdn.co/mp3-preview/7fbddbf1697a0bfe...            5  track
# 18  https://p.scdn.co/mp3-preview/4daa628f2723b16d...            9  track
# 19  https://p.scdn.co/mp3-preview/1c37652807c94928...           18  track
# 20                                               None           11  track
# 21  https://p.scdn.co/mp3-preview/965c62f4933ee3fe...           10  track
# 22  https://p.scdn.co/mp3-preview/1b41ff2479fabcbe...            1  track
# 23  https://p.scdn.co/mp3-preview/67420067d2950518...           11  track
# 24  https://p.scdn.co/mp3-preview/6f5280d345aa44fd...           13  track
# 25  https://p.scdn.co/mp3-preview/ac198960e9deb74f...            9  track
# 26  https://p.scdn.co/mp3-preview/13ca44be37ee337a...            1  track
# 27  https://p.scdn.co/mp3-preview/3782877636f6ffa4...            1  track
# 28  https://p.scdn.co/mp3-preview/e1541bc16f8b1d3c...            1  track
# 29  https://p.scdn.co/mp3-preview/c89d5bb3121e9c7c...            1  track
# 30  https://p.scdn.co/mp3-preview/bac84baa97dbfebb...            1  track
# 31  https://p.scdn.co/mp3-preview/5ef22939cfb7d59d...           11  track
# 32  https://p.scdn.co/mp3-preview/c3e3195853e6533e...           12  track
# 33  https://p.scdn.co/mp3-preview/c3e3195853e6533e...           10  track
# 34  https://p.scdn.co/mp3-preview/c3e3195853e6533e...           12  track
# 35  https://p.scdn.co/mp3-preview/5c1cc17d91dc44b6...            5  track
# 36  https://p.scdn.co/mp3-preview/0bd5593838d5c376...            7  track
# 37  https://p.scdn.co/mp3-preview/0bd5593838d5c376...            3  track
# 38  https://p.scdn.co/mp3-preview/2e721357b5cbe1cc...           12  track
# 39  https://p.scdn.co/mp3-preview/0bd5593838d5c376...            6  track
# 40  https://p.scdn.co/mp3-preview/882025c3949528b4...            1  track
# 41  https://p.scdn.co/mp3-preview/3290450d3d549fb4...            2  track
# 42  https://p.scdn.co/mp3-preview/c3e3195853e6533e...           12  track
# 43  https://p.scdn.co/mp3-preview/c3e3195853e6533e...            1  track
# 44  https://p.scdn.co/mp3-preview/dafbf81357fab4c1...            3  track
# 45  https://p.scdn.co/mp3-preview/352b5c6751b11df4...            2  track
# 46  https://p.scdn.co/mp3-preview/3b6e1937364149fe...           15  track
# 47  https://p.scdn.co/mp3-preview/7c0b7f07e46ec3fb...            4  track
# 48  https://p.scdn.co/mp3-preview/c683998b4c4e0378...            3  track
# 49  https://p.scdn.co/mp3-preview/3b4846a747b7ab27...            1  track
#
#                                      uri
# 0   spotify:track:3YRCqOhFifThpSRFJ1VWFM
# 1   spotify:track:11C3oTzP4WJ2UlU3TzHtCK
# 2   spotify:track:1dMOkSlIgQEgIKFTz4LqL6
# 3   spotify:track:4EQDIFyn4VPMl4OWBc0EV2
# 4   spotify:track:1XfYyru6HemV6aexQPdF8n
# 5   spotify:track:1BZGq1lAq98mTVdO8HLZaX
# 6   spotify:track:2sO2B8YGt8Bi9p3tgmSdlC
# 7   spotify:track:7l7hhlpkcxs4zA5cOBC1jI
# 8   spotify:track:6QF3vavxEItY8ru6DcL9N2
# 9   spotify:track:71EeFAAKi6iekORgxgz2d5
# 10  spotify:track:77CnXU4HGxTP2IMRWyJJAk
# 11  spotify:track:3x4u7JB8TO4Y44KTe0N2Uo
# 12  spotify:track:5TSqyACHswDUYtvXkEIwqR
# 13  spotify:track:7q2HjPftSMAwrZZyys5Zfz
# 14  spotify:track:5zffvp3o6umOuOgEuFIg8T
# 15  spotify:track:1Md5mt7k3ZwSHbVapqJ6K3
# 16  spotify:track:7GN7JgAlC8NECrbFa3c7Iy
# 17  spotify:track:5xFFmNaor9iCcdBUlD0nsZ
# 18  spotify:track:4eCUjQ7RoqNEU2X1supEgk
# 19  spotify:track:2cygI2GQQjeHwNsZv6A3WP
# 20  spotify:track:6K0vRXdYwQLjbb4zecNjLm
# 21  spotify:track:2UjL09kQDWQIkIK55sECnf
# 22  spotify:track:5hcds4o1DYwyQwd9ieLmbG
# 23  spotify:track:6jv09GtWHhKeeXF06702dX
# 24  spotify:track:1mRBDyN8jADp7nNmiWp7o7
# 25  spotify:track:4ynmjXnNmrehtGRYtNxd1H
# 26  spotify:track:2ndkqNCFTZFzfl2Wqa3THM
# 27  spotify:track:3AcM7iNwXarmY3RbPZ98sw
# 28  spotify:track:0VlJO8gyBkdUgJtutxJDAA
# 29  spotify:track:7h49Y3JnGBYrTyDvqkx0ky
# 30  spotify:track:1Q9qRtIARlPToDmMjkjDZf
# 31  spotify:track:0SbQlwTgMwbIHdCxm5miuk
# 32  spotify:track:2y1F5uCZgjdrLoV6hNFNpO
# 33  spotify:track:6n4OqbBehwd2Tb1hdzf9PI
# 34  spotify:track:1MG0A59vAw6f35L16BKoUJ
# 35  spotify:track:5ZhalZfmmVfSgkafQmPo1p
# 36  spotify:track:2GMMAX4OnvrEo0otlSR5k0
# 37  spotify:track:6mv3k5izVFN5BkU02NBnHj
# 38  spotify:track:5Z2NZCCGgF1M8akCcWeCKl
# 39  spotify:track:2qqLyaaMlEGSDW0lyrZFu4
# 40  spotify:track:4Q26zrbO5lwT2nLauTJzOa
# 41  spotify:track:3AuniygIEhhP9Flah0LAqQ
# 42  spotify:track:4tfoTilN3IQtyUfwZimnps
# 43  spotify:track:0b3ZqUMUnFgeEuyb2JXlXy
# 44  spotify:track:3o5DICOE1pUme56ey44oc8
# 45  spotify:track:1T6dQI8z0iHcbn1LwmppIE
# 46  spotify:track:0ersyoaH6HDtJ77Cow60VS
# 47  spotify:track:4oGxGCkpSGGr8kS8x5wUar
# 48  spotify:track:15TJnX8wI4dWmC5fm8ZJ5N
# 49  spotify:track:4I0riUaf4ADqQyRNh0mWy2
#
# [50 rows x 27 columns]
