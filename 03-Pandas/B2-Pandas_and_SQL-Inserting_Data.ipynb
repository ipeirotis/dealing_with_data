# %% [markdown]
# ### Using Pandas together with SQL

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %% [markdown]
# ### Inserting Data in a Database using Pandas

# %%
# Read the CSV file
restaurants = pd.read_csv('data/restaurant.csv.gz', encoding="utf-8", dtype="unicode")

# %%
# Usual bookkeeping regarding datatypes
restaurants["GRADE DATE"] = pd.to_datetime(restaurants["GRADE DATE"], format="%m/%d/%Y")
restaurants["RECORD DATE"] = pd.to_datetime(restaurants["RECORD DATE"], format="%m/%d/%Y")
restaurants["INSPECTION DATE"] = pd.to_datetime(restaurants["INSPECTION DATE"], format="%m/%d/%Y")
restaurants["SCORE"] = pd.to_numeric(restaurants["SCORE"])
restaurants["BORO"] =  pd.Categorical(restaurants["BORO"], ordered=False)
restaurants["GRADE"] =  pd.Categorical(restaurants["GRADE"], categories = ['A', 'B', 'C'], ordered=True)
restaurants["VIOLATION CODE"] =  pd.Categorical(restaurants["VIOLATION CODE"], ordered=False)
restaurants["CRITICAL FLAG"] =  pd.Categorical(restaurants["CRITICAL FLAG"], ordered=False)
restaurants["ACTION"] =  pd.Categorical(restaurants["ACTION"], ordered=False)
restaurants["CUISINE DESCRIPTION"] =  pd.Categorical(restaurants["CUISINE DESCRIPTION"], ordered=False)

# %%
# Connect to the MySQL, but without selecting a database
conn_string = 'mysql://{user}:{password}@{host}:{port}/{db}?charset=utf8'.format(
    user     = 'student', 
    password = 'dwdstudent2015', 
    host     = 'db.ipeirotis.org', 
    port     = 3306, 
    encoding = 'utf-8',
    db = 'public'
)
engine = create_engine(conn_string)

# %%
# Create the database where we want to store the data
# Do not worry about the Warning if the database already exists
# engine.execute('CREATE DATABASE IF NOT EXISTS nyc_restaurant_inspections')
# engine.execute('USE nyc_restaurant_inspections')

# %%
# Optional, we can drop the table if it is already there
# engine.execute('DROP TABLE IF EXISTS inspections')

# %%
# Store the dataframe as a SQL table, using the to_sql command
restaurants.to_sql(name='inspections', # name the table "inspections"
                   con=engine, # use the connection to MySQL created earlier
                   if_exists='replace', # if the table is already there, replace it
                   index=False, # do not write the index column in the database
                   chunksize=1000 # write 1000 lines at a time
)

# %%
# And then we can just retrieve it from the database
df = pd.read_sql("SELECT * FROM inspections LIMIT 100", con=engine)
df.head(100)
# Out:
#        CAMIS                          DBA       BORO BUILDING  \
# 0   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 1   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 2   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 3   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 4   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 5   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 6   30075445        MORRIS PARK BAKE SHOP      BRONX     1007
# 7   30112340                      WENDY'S   BROOKLYN      469
# 8   30112340                      WENDY'S   BROOKLYN      469
# 9   30112340                      WENDY'S   BROOKLYN      469
# 10  30112340                      WENDY'S   BROOKLYN      469
# 11  30112340                      WENDY'S   BROOKLYN      469
# 12  30112340                      WENDY'S   BROOKLYN      469
# 13  30112340                      WENDY'S   BROOKLYN      469
# 94         SURF AVENUE   11224  7183332202                          Hotdogs
# 95         SURF AVENUE   11224  7183332202                          Hotdogs
# 96       KINGS HIGHWAY   11223  7183751500                    Jewish/Kosher
# 97       KINGS HIGHWAY   11223  7183751500                    Jewish/Kosher
# 98       KINGS HIGHWAY   11223  7183751500                    Jewish/Kosher
# 99       KINGS HIGHWAY   11223  7183751500                    Jewish/Kosher
#
#    INSPECTION DATE                                             ACTION  \
# 0       2019-05-16    Violations were cited in the following area(s).
# 1       2019-05-16    Violations were cited in the following area(s).
# 2       2019-05-16    Violations were cited in the following area(s).
# 3       2018-05-11    Violations were cited in the following area(s).
# 4       2018-05-11    Violations were cited in the following area(s).
# 5       2017-05-18    Violations were cited in the following area(s).
# 6       2017-05-18    Violations were cited in the following area(s).
# 7       2019-03-04    Violations were cited in the following area(s).
# 8       2019-03-04    Violations were cited in the following area(s).
# 9       2019-03-04    Violations were cited in the following area(s).
# 10      2018-03-13    Violations were cited in the following area(s).
# 11      2018-03-13    Violations were cited in the following area(s).
# 12      2018-03-13    Violations were cited in the following area(s).
# 13      2017-10-06    Violations were cited in the following area(s).
# 14      2017-10-06    Violations were cited in the following area(s).
# 15      2017-06-26    Violations were cited in the following area(s).
# 16      2016-10-27    Violations were cited in the following area(s).
# 17      2016-10-27    Violations were cited in the following area(s).
# 18      2016-10-03    Violations were cited in the following area(s).
# 19      2016-10-03    Violations were cited in the following area(s).
# 20      2016-10-03    Violations were cited in the following area(s).
# 21      2016-10-03    Violations were cited in the following area(s).
# 22      2016-10-03    Violations were cited in the following area(s).
# 23      2016-04-30    Violations were cited in the following area(s).
# 24      2016-04-30    Violations were cited in the following area(s).
# 25      2016-04-30    Violations were cited in the following area(s).
# 26      2016-04-30    Violations were cited in the following area(s).
# 27      2016-04-30    Violations were cited in the following area(s).
# 28      2016-04-30    Violations were cited in the following area(s).
# 29      2016-04-12  No violations were recorded at the time of thi...
# ..             ...                                                ...
# 70      2017-06-22    Violations were cited in the following area(s).
# 71      2017-06-22    Violations were cited in the following area(s).
# 72      2019-05-22    Violations were cited in the following area(s).
# 73      2019-05-22    Violations were cited in the following area(s).
# 74      2018-05-31    Violations were cited in the following area(s).
# 75      2018-05-31    Violations were cited in the following area(s).
# 76      2017-06-14    Violations were cited in the following area(s).
# 77      2018-09-28    Violations were cited in the following area(s).
# 78      2018-09-28    Violations were cited in the following area(s).
# 79      2017-09-20    Violations were cited in the following area(s).
# 80      2017-09-20    Violations were cited in the following area(s).
# 81      2017-09-20    Violations were cited in the following area(s).
# 82      2016-05-06  No violations were recorded at the time of thi...
# 83      2019-04-06    Violations were cited in the following area(s).
# 84      2019-04-06    Violations were cited in the following area(s).
# 85      2019-04-06    Violations were cited in the following area(s).
# 86      2018-03-07    Violations were cited in the following area(s).
# 87      2018-03-07    Violations were cited in the following area(s).
# 88      2017-01-23    Violations were cited in the following area(s).
# 89      2017-01-23    Violations were cited in the following area(s).
# 90      2017-01-23    Violations were cited in the following area(s).
# 91      2016-07-08    Violations were cited in the following area(s).
# 92      2016-07-08    Violations were cited in the following area(s).
# 93      2016-06-01    Violations were cited in the following area(s).
# 94      2016-06-01    Violations were cited in the following area(s).
# 95      2016-06-01    Violations were cited in the following area(s).
# 96      2018-11-27    Violations were cited in the following area(s).
# 97      2017-11-27    Violations were cited in the following area(s).
# 98      2017-11-27    Violations were cited in the following area(s).
# 99      2017-11-27    Violations were cited in the following area(s).
#
#    VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0             04L  Evidence of mice or live mice present in facil...
# 1             08A  Facility not vermin proof. Harborage or condit...
# 2             10F  Non-food contact surface improperly constructe...
# 3             08C  Pesticide use not in accordance with label or ...
# 4             10F  Non-food contact surface improperly constructe...
# 5             06D  Food contact surface not properly washed, rins...
# 6             10F  Non-food contact surface improperly constructe...
# 7             02G  Cold food item held above 41Âº F (smoked fish ...
# 8             10B  Plumbing not properly installed or maintained;...
# 9             10F  Non-food contact surface improperly constructe...
# 10            04L  Evidence of mice or live mice present in facil...
# 11            08A  Facility not vermin proof. Harborage or condit...
# 12            10B  Plumbing not properly installed or maintained;...
# 13            04H  Raw, cooked or prepared food is adulterated, c...
# 14            10F  Non-food contact surface improperly constructe...
# 15            04N  Filth flies or food/refuse/sewage-associated (...
# 16            04N  Filth flies or food/refuse/sewage-associated (...
# 17            08A  Facility not vermin proof. Harborage or condit...
# 18            04N  Filth flies or food/refuse/sewage-associated (...
# 19            06A  Personal cleanliness inadequate. Outer garment...
# 20            06C  Food not protected from potential source of co...
# 21            08A  Facility not vermin proof. Harborage or condit...
# 22            10A  Toilet facility not maintained and provided wi...
# 23            06B  Tobacco use, eating, or drinking from open con...
# 24            08C  Pesticide use not in accordance with label or ...
# 25            10B  Plumbing not properly installed or maintained;...
# 26            10E  Accurate thermometer not provided in refrigera...
# 27            15I  ''''No Smoking and/or 'Smoking Permitted sig...
# 28            15L  Smoke free workplace smoking policy inadequate...
# 29           None                                               None
# ..            ...                                                ...
# 70            04L  Evidence of mice or live mice present in facil...
# 71            08A  Facility not vermin proof. Harborage or condit...
# 72            04L  Evidence of mice or live mice present in facil...
# 73            08A  Facility not vermin proof. Harborage or condit...
# 74            10B  Plumbing not properly installed or maintained;...
# 75            10F  Non-food contact surface improperly constructe...
# 76            10F  Non-food contact surface improperly constructe...
# 77            06D  Food contact surface not properly washed, rins...
# 78            10F  Non-food contact surface improperly constructe...
# 79            02G  Cold food item held above 41Âº F (smoked fish ...
# 80            10B  Plumbing not properly installed or maintained;...
# 81            10F  Non-food contact surface improperly constructe...
# 82           None                                               None
# 83            06D  Food contact surface not properly washed, rins...
# 84            10F  Non-food contact surface improperly constructe...
# 85            10I  Single service item reused, improperly stored,...
# 86            06C  Food not protected from potential source of co...
# 87            10F  Non-food contact surface improperly constructe...
# 88            06A  Personal cleanliness inadequate. Outer garment...
# 89            06D  Food contact surface not properly washed, rins...
# 90            10F  Non-food contact surface improperly constructe...
# 91            02B        Hot food item not held at or above 140Âº F.
# 92            10A  Toilet facility not maintained and provided wi...
# 93            02B        Hot food item not held at or above 140Âº F.
# 94            06C  Food not protected from potential source of co...
# 95            06F  Wiping cloths soiled or not stored in sanitizi...
# 96            10F  Non-food contact surface improperly constructe...
# 97            04N  Filth flies or food/refuse/sewage-associated (...
# 98            08A  Facility not vermin proof. Harborage or condit...
# 99            09C      Food contact surface not properly maintained.
#
#      CRITICAL FLAG  SCORE GRADE GRADE DATE RECORD DATE  \
# 0         Critical   14.0  None        NaT  2019-06-12
# 1     Not Critical   14.0  None        NaT  2019-06-12
# 2     Not Critical   14.0  None        NaT  2019-06-12
# 3     Not Critical    5.0     A 2018-05-11  2019-06-12
# 4     Not Critical    5.0     A 2018-05-11  2019-06-12
# 5         Critical    7.0     A 2017-05-18  2019-06-12
# 6     Not Critical    7.0     A 2017-05-18  2019-06-12
# 7         Critical   13.0     A 2019-03-04  2019-06-12
# 8     Not Critical   13.0     A 2019-03-04  2019-06-12
# 9     Not Critical   13.0     A 2019-03-04  2019-06-12
# 10        Critical   12.0     A 2018-03-13  2019-06-12
# 11    Not Critical   12.0     A 2018-03-13  2019-06-12
# 12    Not Critical   12.0     A 2018-03-13  2019-06-12
# 13        Critical   10.0     A 2017-10-06  2019-06-12
# 14    Not Critical   10.0     A 2017-10-06  2019-06-12
# 15        Critical    7.0  None        NaT  2019-06-12
# 16        Critical   11.0     A 2016-10-27  2019-06-12
# 17    Not Critical   11.0     A 2016-10-27  2019-06-12
# 18        Critical   48.0  None        NaT  2019-06-12
# 19        Critical   48.0  None        NaT  2019-06-12
# 20        Critical   48.0  None        NaT  2019-06-12
# 21    Not Critical   48.0  None        NaT  2019-06-12
# 22    Not Critical   48.0  None        NaT  2019-06-12
# 23        Critical   13.0     A 2016-04-30  2019-06-12
# 24    Not Critical   13.0     A 2016-04-30  2019-06-12
# 25    Not Critical   13.0     A 2016-04-30  2019-06-12
# 26    Not Critical   13.0     A 2016-04-30  2019-06-12
# 27    Not Critical    NaN  None        NaT  2019-06-12
# 28    Not Critical    NaN  None        NaT  2019-06-12
# 29  Not Applicable    0.0  None        NaT  2019-06-12
# ..             ...    ...   ...        ...         ...
# 70        Critical   10.0     A 2017-06-22  2019-06-12
# 71    Not Critical   10.0     A 2017-06-22  2019-06-12
# 72        Critical   10.0     A 2019-05-22  2019-06-12
# 73    Not Critical   10.0     A 2019-05-22  2019-06-12
# 74    Not Critical    5.0     A 2018-05-31  2019-06-12
# 75    Not Critical    5.0     A 2018-05-31  2019-06-12
# 76    Not Critical    2.0     A 2017-06-14  2019-06-12
# 77        Critical    7.0     A 2018-09-28  2019-06-12
# 78    Not Critical    7.0     A 2018-09-28  2019-06-12
# 79        Critical   11.0     A 2017-09-20  2019-06-12
# 80    Not Critical   11.0     A 2017-09-20  2019-06-12
# 81    Not Critical   11.0     A 2017-09-20  2019-06-12
# 82  Not Applicable    0.0     A 2016-05-06  2019-06-12
# 83        Critical   12.0     A 2019-04-06  2019-06-12
# 84    Not Critical   12.0     A 2019-04-06  2019-06-12
# 85    Not Critical   12.0     A 2019-04-06  2019-06-12
# 86        Critical   10.0     A 2018-03-07  2019-06-12
# 87    Not Critical   10.0     A 2018-03-07  2019-06-12
# 88        Critical   13.0     A 2017-01-23  2019-06-12
# 89        Critical   13.0     A 2017-01-23  2019-06-12
# 90    Not Critical   13.0     A 2017-01-23  2019-06-12
# 91        Critical    9.0     A 2016-07-08  2019-06-12
# 92    Not Critical    9.0     A 2016-07-08  2019-06-12
# 93        Critical   19.0  None        NaT  2019-06-12
# 94        Critical   19.0  None        NaT  2019-06-12
# 95        Critical   19.0  None        NaT  2019-06-12
# 96    Not Critical    3.0     A 2018-11-27  2019-06-12
# 97        Critical   13.0     A 2017-11-27  2019-06-12
# 98    Not Critical   13.0     A 2017-11-27  2019-06-12
# 99    Not Critical   13.0     A 2017-11-27  2019-06-12
#
#                           INSPECTION TYPE
# 0   Cycle Inspection / Initial Inspection
# 1   Cycle Inspection / Initial Inspection
# 2   Cycle Inspection / Initial Inspection
# 3   Cycle Inspection / Initial Inspection
# 4   Cycle Inspection / Initial Inspection
# 5   Cycle Inspection / Initial Inspection
# 6   Cycle Inspection / Initial Inspection
# 7   Cycle Inspection / Initial Inspection
# 8   Cycle Inspection / Initial Inspection
# 9   Cycle Inspection / Initial Inspection
# 10  Cycle Inspection / Initial Inspection
# 11  Cycle Inspection / Initial Inspection
# 12  Cycle Inspection / Initial Inspection
# 13       Cycle Inspection / Re-inspection
# 14       Cycle Inspection / Re-inspection
# 15  Cycle Inspection / Initial Inspection
# 16       Cycle Inspection / Re-inspection
# 17       Cycle Inspection / Re-inspection
# 18  Cycle Inspection / Initial Inspection
# 19  Cycle Inspection / Initial Inspection
# 20  Cycle Inspection / Initial Inspection
# 21  Cycle Inspection / Initial Inspection
# 22  Cycle Inspection / Initial Inspection
# 23       Cycle Inspection / Re-inspection
# 24       Cycle Inspection / Re-inspection
# 25       Cycle Inspection / Re-inspection
# 26       Cycle Inspection / Re-inspection
# 27     Smoke-Free Air Act / Re-inspection
# 28     Smoke-Free Air Act / Re-inspection
# 29  Cycle Inspection / Initial Inspection
# ..                                    ...
# 70  Cycle Inspection / Initial Inspection
# 71  Cycle Inspection / Initial Inspection
# 72  Cycle Inspection / Initial Inspection
# 73  Cycle Inspection / Initial Inspection
# 74  Cycle Inspection / Initial Inspection
# 75  Cycle Inspection / Initial Inspection
# 76  Cycle Inspection / Initial Inspection
# 77  Cycle Inspection / Initial Inspection
# 78  Cycle Inspection / Initial Inspection
# 79  Cycle Inspection / Initial Inspection
# 80  Cycle Inspection / Initial Inspection
# 81  Cycle Inspection / Initial Inspection
# 82  Cycle Inspection / Initial Inspection
# 83  Cycle Inspection / Initial Inspection
# 84  Cycle Inspection / Initial Inspection
# 85  Cycle Inspection / Initial Inspection
# 86  Cycle Inspection / Initial Inspection
# 87  Cycle Inspection / Initial Inspection
# 88  Cycle Inspection / Initial Inspection
# 89  Cycle Inspection / Initial Inspection
# 90  Cycle Inspection / Initial Inspection
# 91       Cycle Inspection / Re-inspection
# 92       Cycle Inspection / Re-inspection
# 93  Cycle Inspection / Initial Inspection
# 94  Cycle Inspection / Initial Inspection
# 95  Cycle Inspection / Initial Inspection
# 96  Cycle Inspection / Initial Inspection
# 97  Cycle Inspection / Initial Inspection
# 98  Cycle Inspection / Initial Inspection
# 99  Cycle Inspection / Initial Inspection
#
# [100 rows x 18 columns]
