# %% [markdown]
# # Visualization using maps in Python

# %% [markdown]
# Another perfect tool for vizualisation data processed in Python is `folium`. It builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the Leaflet.js library. It manipulate your data in Python, then visualize it in on a Leaflet map. It enables both the binding of data to a map for choropleth visualizations as well as passing Vincent/Vega visualizations as markers on the map.

# %%
# %matplotlib inline

# %%
# !sudo -H pip3 install -U folium
# !sudo -H pip3 install -U geopandas
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/55/e2/7e523df8558b7f4b2ab4c62014fd378ccecce3fdc14c9928b272a88ae4cc/folium-0.7.0-py3-none-any.whl (85kB)
#     100% |████████████████████████████████| 92kB 30.9MB/s ta 0:00:01
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/lib/python3/dist-packages (from folium) (2.10)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.15.4)
# Requirement already satisfied, skipping upgrade: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.3.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.20.0)
# Requirement already satisfied, skipping upgrade: six in /usr/lib/python3/dist-packages (from folium) (1.11.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.1)
# Requirement already satisfied, skipping upgrade: idna<2.8,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.7)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2018.10.15)
# Installing collected packages: folium
#   Found existing installation: folium 0.6.0
#     Uninstalling folium-0.6.0:
#       Successfully uninstalled folium-0.6.0
# Successfully installed folium-0.7.0
# Requirement already up-to-date: geopandas in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.23.4)
# Requirement already satisfied, skipping upgrade: pyproj in /usr/lib/python3/dist-packages (from geopandas) (1.9.5.1)
# Requirement already satisfied, skipping upgrade: fiona in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.8.0)
# Requirement already satisfied, skipping upgrade: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.6.4.post2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (1.15.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (2018.7)
# Requirement already satisfied, skipping upgrade: munch in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (2.3.2)
# Requirement already satisfied, skipping upgrade: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied, skipping upgrade: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (18.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.7 in /usr/lib/python3/dist-packages (from fiona->geopandas) (1.11.0)
# Requirement already satisfied, skipping upgrade: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied, skipping upgrade: click-plugins>=1.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.0.4)

# %% [markdown]
# `folium` provides very detailed map and we may use it to visualize geodata localized in a small scale. Let's get the data from the [Citibike API](http://www.citibikenyc.com/stations/json):

# %%
import requests
import pandas as pd

url = 'http://www.citibikenyc.com/stations/json'
results = requests.get(url).json()
data = results["stationBeanList"]

citibike = pd.DataFrame(data)
citibike.set_index('id', inplace=True)

citibike
# Out:
#      altitude  availableBikes  availableDocks city landMark  \
# id
# 304                        13              14
# 359                        35              14
# 402                         9              23
# 3255                        2              15
# 3443                        5              31
# 72                         33               4
# 79                         29               1
# 82                         19               7
# 83                          0               0
# 119                         5              13
# 120                         2              14
# 127                        28               1
# 128                        27               3
# 143                        19               5
# 144                        17               0
# 146                        32               4
# 150                         4              24
# 151                        27               2
# 157                        11              12
# 161                        32               0
# 164                        13              30
# 167                        38               7
# 168                        35               8
# 173                        29              20
# 174                         1              26
# 195                        38               3
# 212                        25               2
# 216                         1              20
# 217                        26              12
# 223                        27               4
# ...       ...             ...             ...  ...      ...
# 3674                       10              15
# 3675                        3              28
# 3676                       16               6
# 3677                        2              15
# 3678                        2              16
# 3679                        1              12
# 3680                       43              12
# 3681                        0               0
# 3684                       37               3
# 3686                       28               6
# 3687                       43              14
# 3689                        0               0
# 3690                       29               3
# 3691                        0              17
# 3692                       14               0
# 3693                       20               7
# 3694                        4              14
# 3697                        7              35
# 3699                        1              28
# 3701                       34               1
# 3704                       14               4
# 3707                       48               3
# 3708                       25               4
# 3709                       46               3
# 3711                       13              34
# 3712                       31               9
# 3714                        7              51
# 3715                       27               2
# 3716                        2              19
# 3718                        1              42
#
#        lastCommunicationTime   latitude location  longitude postalCode  \
# id
# 304   2018-12-05 04:10:49 PM  40.704633          -74.013617
# 359   2018-12-05 04:23:08 PM  40.755103          -73.974987
# 402   2018-12-05 04:23:23 PM  40.740343          -73.989551
# 3255  2018-12-05 04:23:35 PM  40.750585          -73.994685
# 3443  2018-12-05 04:22:39 PM  40.761330          -73.979820
# 72    2018-12-05 04:22:02 PM  40.767272          -73.993929
# 79    2018-12-05 04:22:39 PM  40.719116          -74.006667
# 82    2018-12-05 04:20:08 PM  40.711174          -74.000165
# 83    2018-10-09 09:05:09 AM  40.683826          -73.976323
# 119   2018-12-05 04:20:07 PM  40.696089          -73.978034
# 120   2018-12-05 04:20:30 PM  40.686768          -73.959282
# 127   2018-12-05 04:23:37 PM  40.731724          -74.006744
# 128   2018-12-05 04:21:43 PM  40.727103          -74.002971
# 143   2018-12-05 04:22:52 PM  40.692395          -73.993379
# 144   2018-12-05 04:23:18 PM  40.698399          -73.980689
# 146   2018-12-05 04:19:54 PM  40.716250          -74.009106
# 150   2018-12-05 04:23:25 PM  40.720874          -73.980858
# 151   2018-12-05 04:21:38 PM  40.722104          -73.997249
# 157   2018-12-05 04:19:59 PM  40.690893          -73.996123
# 161   2018-12-05 04:21:23 PM  40.729170          -73.998102
# 164   2018-12-05 04:21:31 PM  40.753231          -73.970325
# 167   2018-12-05 04:23:33 PM  40.748901          -73.976049
# 168   2018-12-05 04:21:06 PM  40.739713          -73.994564
# 173   2018-12-05 04:23:26 PM  40.760683          -73.984527
# 174   2018-12-05 04:20:00 PM  40.738177          -73.977387
# 195   2018-12-05 04:21:30 PM  40.709056          -74.010434
# 212   2018-12-05 04:23:38 PM  40.743349          -74.006818
# 216   2018-12-05 04:21:24 PM  40.700379          -73.995481
# 217   2018-12-05 04:23:01 PM  40.702772          -73.993836
# 223   2018-12-05 04:22:51 PM  40.737815          -73.999947
# ...                      ...        ...      ...        ...        ...
# 3674  2018-12-05 04:19:45 PM  40.701403          -73.986727
# 3675  2018-12-05 04:22:32 PM  40.784597          -73.949685
# 3676  2018-12-05 04:20:01 PM  40.675833          -74.014726
# 3677  2018-12-05 04:21:06 PM  40.727551          -74.071061
# 3678  2018-12-05 04:22:03 PM  40.725726          -74.071959
# 3679  2018-12-05 04:23:18 PM  40.722104          -74.071455
# 3680  2018-12-05 04:22:57 PM  40.754121          -73.980252
# 3681  2018-12-05 04:21:34 PM  40.715178          -74.037683
# 3684  2018-12-05 04:23:34 PM  40.737561          -74.003983
# 3686  2018-12-05 04:22:46 PM  40.739448          -74.005070
# 3687  2018-12-05 04:21:09 PM  40.743227          -73.974498
# 3689  2018-12-05 04:19:40 PM  40.799041          -73.966495
# 3690  2018-12-05 04:22:46 PM  40.713342          -74.009355
# 3691  2018-12-05 04:20:02 PM  40.764089          -73.910651
# 3692  2018-12-05 04:20:13 PM  40.699997          -73.974401
# 3693  2018-12-05 04:22:42 PM  40.722482          -73.959219
# 3694  2018-12-05 04:20:14 PM  40.711130          -74.078900
# 3697  2018-12-05 04:23:36 PM  40.775160          -73.989187
# 3699  2018-12-05 04:15:38 PM  40.763605          -73.989180
# 3701  2018-12-05 04:23:08 PM  40.708318          -74.005041
# 3704  2018-12-05 04:21:39 PM  40.743752          -73.941765
# 3707  2018-12-05 04:21:12 PM  40.741459          -73.983293
# 3708  2018-12-05 04:21:51 PM  40.735445          -73.994310
# 3709  2018-12-05 04:22:54 PM  40.738046          -73.996430
# 3711  2018-12-05 04:23:15 PM  40.729667          -73.980680
# 3712  2018-12-05 04:22:47 PM  40.754692          -73.997402
# 3714  2018-12-05 04:20:54 PM  40.706842          -73.954435
# 3715  2018-12-05 04:23:02 PM  40.718170          -73.955201
# 3716  2018-12-05 04:21:13 PM  40.753599          -73.937956
# 3718  2018-12-05 04:22:13 PM  40.727464          -73.979504
#
#                             stAddress1 stAddress2  \
# id
# 304              Broadway & Battery Pl
# 359                 E 47 St & Park Ave
# 402                 Broadway & E 22 St
# 3255                   8 Ave & W 31 St
# 3443                   W 52 St & 6 Ave
# 72                    W 52 St & 11 Ave
# 79            Franklin St & W Broadway
# 82              St James Pl & Pearl St
# 83       Atlantic Ave & Fort Greene Pl
# 119           Park Ave & St Edwards St
# 120        Lexington Ave & Classon Ave
# 127              Barrow St & Hudson St
# 128           MacDougal St & Prince St
# 143          Clinton St & Joralemon St
# 144                Nassau St & Navy St
# 146               Hudson St & Reade St
# 150                  E 2 St & Avenue C
# 151           Cleveland Pl & Spring St
# 157            Henry St & Atlantic Ave
# 161              LaGuardia Pl & W 3 St
# 164                    E 47 St & 2 Ave
# 167                    E 39 St & 3 Ave
# 168                    W 18 St & 6 Ave
# 173                 Broadway & W 49 St
# 174                    E 25 St & 1 Ave
# 195              Liberty St & Broadway
# 212            W 16 St & The High Line
# 216    Columbia Heights & Cranberry St
# 217                      Old Fulton St
# 223                    W 13 St & 7 Ave
# ...                                ...        ...
# 3674                  Jay St & York St
# 3675                   3 Ave & E 95 St
# 3676        Van Brunt St & Van Dyke St
# 3677                      Glenwood Ave
# 3678                     Fairmount Ave
# 3679                        Bergen Ave
# 3680                   E 43 St & 5 Ave
# 3681                          Grand St
# 3684                  W 12 St & W 4 St
# 3686         Gansevoort St & Hudson St
# 3687                   E 33 St & 1 Ave
# 3689          W 104 St & Amsterdam Ave
# 3690               Park Pl & Church St
# 3691                    28 Ave & 44 St
# 3692                  5 St & Market St
# 3693                N 11 St & Kent Ave
# 3694                    Jackson Square
# 3697  W 64 St & Thelonious Monk Circle
# 3699                   W 50 St & 9 Ave
# 3701              Cliff St & Fulton St
# 3704             47 Ave & Skillman Ave
# 3707           Lexington Ave & E 26 St
# 3708                   W 13 St & 5 Ave
# 3709                   W 15 St & 6 Ave
# 3711                E 13 St & Avenue A
# 3712                W 35 St & Dyer Ave
# 3714           Division Av & Hooper St
# 3715               Driggs Ave & N 9 St
# 3716              40 Ave & Crescent St
# 3718                E 11 St & Avenue B
#
#                            stationName  statusKey     statusValue  \
# id
# 304              Broadway & Battery Pl          1      In Service
# 359                 E 47 St & Park Ave          1      In Service
# 402                 Broadway & E 22 St          1      In Service
# 3255                   8 Ave & W 31 St          1      In Service
# 3443                   W 52 St & 6 Ave          1      In Service
# 72                    W 52 St & 11 Ave          1      In Service
# 79            Franklin St & W Broadway          1      In Service
# 82              St James Pl & Pearl St          1      In Service
# 83       Atlantic Ave & Fort Greene Pl          3  Not In Service
# 119           Park Ave & St Edwards St          1      In Service
# 120        Lexington Ave & Classon Ave          1      In Service
# 127              Barrow St & Hudson St          1      In Service
# 128           MacDougal St & Prince St          1      In Service
# 143          Clinton St & Joralemon St          1      In Service
# 144                Nassau St & Navy St          1      In Service
# 146               Hudson St & Reade St          1      In Service
# 150                  E 2 St & Avenue C          1      In Service
# 151           Cleveland Pl & Spring St          1      In Service
# 157            Henry St & Atlantic Ave          1      In Service
# 161              LaGuardia Pl & W 3 St          1      In Service
# 164                    E 47 St & 2 Ave          1      In Service
# 167                    E 39 St & 3 Ave          1      In Service
# 168                    W 18 St & 6 Ave          1      In Service
# 173                 Broadway & W 49 St          1      In Service
# 174                    E 25 St & 1 Ave          1      In Service
# 195              Liberty St & Broadway          1      In Service
# 212            W 16 St & The High Line          1      In Service
# 216    Columbia Heights & Cranberry St          1      In Service
# 217                      Old Fulton St          1      In Service
# 223                    W 13 St & 7 Ave          1      In Service
# ...                                ...        ...             ...
# 3674                  Jay St & York St          1      In Service
# 3675                   3 Ave & E 95 St          1      In Service
# 3676        Van Brunt St & Van Dyke St          1      In Service
# 3677                      Glenwood Ave          1      In Service
# 3678                     Fairmount Ave          1      In Service
# 3679                        Bergen Ave          1      In Service
# 3680                   E 43 St & 5 Ave          1      In Service
# 3681                          Grand St          3  Not In Service
# 3684                  W 12 St & W 4 St          1      In Service
# 3686         Gansevoort St & Hudson St          1      In Service
# 3687                   E 33 St & 1 Ave          1      In Service
# 3689          W 104 St & Amsterdam Ave          3  Not In Service
# 3690               Park Pl & Church St          1      In Service
# 3691                    28 Ave & 44 St          1      In Service
# 3692                  5 St & Market St          1      In Service
# 3693                N 11 St & Kent Ave          1      In Service
# 3694                    Jackson Square          1      In Service
# 3697  W 64 St & Thelonious Monk Circle          1      In Service
# 3699                   W 50 St & 9 Ave          1      In Service
# 3701              Cliff St & Fulton St          1      In Service
# 3704             47 Ave & Skillman Ave          1      In Service
# 3707           Lexington Ave & E 26 St          1      In Service
# 3708                   W 13 St & 5 Ave          1      In Service
# 3709                   W 15 St & 6 Ave          1      In Service
# 3711                E 13 St & Avenue A          1      In Service
# 3712                W 35 St & Dyer Ave          1      In Service
# 3714           Division Av & Hooper St          1      In Service
# 3715               Driggs Ave & N 9 St          1      In Service
# 3716              40 Ave & Crescent St          1      In Service
# 3718                E 11 St & Avenue B          1      In Service
#
#       testStation  totalDocks
# id
# 304         False          33
# 359         False          53
# 402         False          39
# 3255        False          19
# 3443        False          41
# 72          False          39
# 79          False          33
# 82          False          27
# 83          False           0
# 119         False          19
# 120         False          19
# 127         False          31
# 128         False          30
# 143         False          24
# 144         False          19
# 146         False          39
# 150         False          29
# 151         False          33
# 157         False          23
# 161         False          35
# 164         False          47
# 167         False          45
# 168         False          47
# 173         False          51
# 174         False          30
# 195         False          45
# 212         False          28
# 216         False          23
# 217         False          39
# 223         False          33
# ...           ...         ...
# 3674        False          27
# 3675        False          31
# 3676        False          24
# 3677        False          18
# 3678        False          18
# 3679        False          14
# 3680        False          55
# 3681        False           0
# 3684        False          43
# 3686        False          39
# 3687        False          59
# 3689        False           0
# 3690        False          36
# 3691        False          19
# 3692        False          15
# 3693        False          27
# 3694        False          18
# 3697        False          43
# 3699        False          30
# 3701        False          37
# 3704        False          19
# 3707        False          55
# 3708        False          29
# 3709        False          51
# 3711        False          47
# 3712        False          41
# 3714        False          61
# 3715        False          31
# 3716        False          23
# 3718        False          46
#
# [813 rows x 17 columns]

# %% [markdown]
# #### Selecting tiles
#
# The first step is to create a map. At the very basic level, we select the location, zoom level, and potentially the tiles (i.e., the style of the map) for the background. The default is 'OpenStreetMap', but often for visualizations we prefer other, more visually neutral styles. (See http://folium.readthedocs.io/en/latest/quickstart.html for more tile optionS)

# %%
import folium
fmap = folium.Map(location=[40.73, -74], zoom_start=13, tiles='OpenStreetMap')
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
fmap = folium.Map(location=[40.73, -74], zoom_start=12,  tiles='cartodbpositron')
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Adding Markers
#
# For every station, we are going to add a marker in the map:
# * Using the longitude and latitude for the location
# * Modify the color of the marker to reflect the status of the station
# * Modify the opacity to be the percentage of bikes in the station.
# * Modify the size of the circle to corresponds to the size of the station.

# %%
for name, row in citibike.iterrows():
    
    # Define the opacity of the marker to be proportional to the percentage of bikes in the station
    opacity = row["availableBikes"]/row["totalDocks"] if row["statusValue"] == 'In Service' else 1.0
    # Make the color green for the working stations, red otherwise
    color = "green" if row["statusValue"] == 'In Service' else "red"
    # The size of the marker is proportional to the number of docks
    size = row["totalDocks"]/10 if row["statusValue"] == 'In Service' else 5

    # We create a marker on the map and we add it to the map
    folium.CircleMarker(location=[row["latitude"], row["longitude"]], 
                        radius = size,
                        color='black', weight=0.5, 
                        fill=True,
                        fill_opacity = opacity,
                        fill_color = color,
                       ).add_to(fmap)

# %%
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Adding popups to the markers
#
# For each marker, we can also have a popup with text, html, or even other charts/visualizations. Here is an example of adding an HTML popup to each marker.

# %%
fmap = folium.Map(location=[40.73, -74], zoom_start=13,  tiles='cartodbpositron')

for name, row in citibike.iterrows():
    
    # Define the opacity of the marker to be proportional to the percentage of bikes in the station
    opacity = row["availableBikes"]/row["totalDocks"] if row["statusValue"] == 'In Service' else 1.0
    # Make the color green for the working stations, red otherwise
    color = "green" if row["statusValue"] == 'In Service' else "red"
    # The size of the marker is proportional to the number of docks
    size = row["totalDocks"]/5 if row["statusValue"] == 'In Service' else 5
    
   
    # The code below defines a pop-up for each station with details such as 
    # the address, number of bikes, capacity, etc.
    html = "<p style='font-family:sans-serif;font-size:11px'>" + \
           "<strong>Address: </strong>" + row["stAddress1"] + \
           "<br><strong>Available Bikes: </strong>" + str(row["availableBikes"]) + \
            "<br><strong>Total Docks: </strong>" + str(row["totalDocks"])
    iframe = folium.IFrame(html=html, width=200, height=60)
    popup = folium.Popup(iframe, max_width=200)

    # We create a marker on the map and we add it to the map
    folium.CircleMarker(location=[row["latitude"], row["longitude"]], 
                        radius = size,
                        popup = popup, 
                        color='black', weight=0.5, 
                        fill=True,
                        fill_opacity = opacity,
                        fill_color = color,
                       ).add_to(fmap)

# %%
    
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# This code below is for generating an image screenshot from a Folium map
# It is kind of convoluted, as it involves saving an HTML file
# and then launching a Selenium-driven browser and saving a screenshot
# NOTE: This requires having a properly working installation
# of Selenium


import os
import time

from pyvirtualdisplay import Display

display = Display(visible=0, size=(1600, 1600))
display.start()

delay=5
fn='citibike.html'
tmpurl='file://{path}/{mapfile}'.format(path=os.getcwd(),mapfile=fn)
fmap.save(fn)

# %%
# !sudo pip3 install pyvirtualdisplay

# %%
from selenium import webdriver
browser = webdriver.Firefox()
browser.get(tmpurl)
#Give the map tiles some time to load
time.sleep(delay)
browser.save_screenshot('citibike.png')
browser.quit()

# %% [markdown]
# #### Using shapefiles

# %%
# Dataset from NYC Open Data: https://data.cityofnewyork.us/City-Government/Neighborhood-Tabulation-Areas/cpf4-rkhq
# !curl 'https://data.cityofnewyork.us/api/geospatial/cpf4-rkhq?method=export&format=GeoJSON' -o data/nyc-neighborhoods.geojson

# %%
# NYC Zipcodes
# !curl 'https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip' -o 'data/ZIP_CODE_040114.zip'

# %%
import geopandas as gpd

nyc_neighborhoods = gpd.GeoDataFrame.from_file('data/nyc-neighborhoods.geojson')
nyc_neighborhoods = nyc_neighborhoods[['ntacode', 'ntaname', 'geometry']]
nyc_neighborhoods.head(10)

# %%
nyc_neighborhoods.plot(
    figsize=(20,20), 
    color = 'white', 
    edgecolor = 'black'
)

# %%
import folium
fmap = folium.Map(location=[40.73, -74], zoom_start=12, tiles='cartodbpositron')

folium.GeoJson(nyc_neighborhoods,
               name='NYC Neighborhoods',
               style_function=lambda feature: {
                    'fillColor': '#c0fefe',
                    'color': 'black',
                    'weight': 1,
                    'fillOpacity': 0.25
                }
              ).add_to(fmap)

fmap

# %% [markdown]
# We first transform the Citibike Dataframe into a GeoPandas datagframe, by creating
# a column that contains Points, naming the column "geometry" and then
# setting the CRS (coordinate system) to be the same as the one for NYC neighborhoods

# %%
from shapely.geometry import Point

citibike['geometry'] = citibike.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1 )
citibike_gs = gpd.GeoDataFrame.from_records(citibike)

# %% [markdown]
# #### Spatial Join using GeoPandas
#
# Now we join the `nyc_neighborhoods` dataframe that describes the NYC neighborhoods with the `citibike_gs` that has the locations of the Citibike stations.

# %%
citibike_gs.crs = nyc_neighborhoods.crs
stations_to_neighborhoods = gpd.sjoin(nyc_neighborhoods, citibike_gs, how="inner", op='intersects')

# %%
totaldocks = pd.pivot_table(
    data = stations_to_neighborhoods, 
    index = 'ntacode',
    values = 'totalDocks', 
    aggfunc = 'sum'
).drop(['MN99', 'BK99']) # drop the 'misc' areas

totaldocks.head(5)

# %%
# GeoPandas choropleths / not very appealing visually
# 
# nyc.set_index('ntacode').join(totaldocks, how='left').fillna(0).plot(
#     figsize=(20,20), column='totalDocks', cmap='OrRd', scheme='Quantiles', linewidth=0.1)

# %%
fmap = folium.Map(location=[40.73, -74], zoom_start=12, tiles='cartodbpositron')
# folium.LayerControl().add_to(fmap)

fmap.choropleth(geo_data='data/nyc-neighborhoods.geojson', 
                data=totaldocks.reset_index(),
                columns=['ntacode', 'totalDocks'],
                key_on='feature.properties.ntacode',
                fill_color='OrRd', 
                fill_opacity=0.5, 
                line_opacity=0.1,
                legend_name='Total Docks'
               )
#folium.LayerControl().add_to(fmap)
fmap
