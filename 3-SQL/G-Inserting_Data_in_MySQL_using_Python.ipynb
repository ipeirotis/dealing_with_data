# %% [markdown]
# ## Inserting data in MySQL using Python
#
# First let's start with a basic piece of code that fetches the data that we want to insert in the database. For our example, we will get the data about the Citibike stations, using the correspoding API call provided by the Citibike website:

# %%
import requests
import json

# %%
# Let's get the data from the Citibike API
url = 'http://www.citibikenyc.com/stations/json'
resp = requests.get(url)

# %%
# We transform the returned JSON answer from the API into a Python dictionary object
results = json.loads(resp.text)

# %%
# We only need a subset of the data in the JSON returned by the Citibike API, so we keep only we need
data = results["stationBeanList"]

# %%
len(data)
# Out:
# 507

# %% [markdown]
# Now we will connect to our MySQL server. We will use the MySQLdb library of Python.
#
# If you do not have the library, you need to install it by typing in the shell:
#
# `sudo apt-get install python-mysqldb`

# %%
import MySQLdb as mdb
import sys

con = mdb.connect(host = 'localhost', 
                  user = 'root', 
                  passwd = 'dwdstudent2015', 
                  charset='utf8', use_unicode=True);

# %% [markdown]
# Once we have connected successfully, we need to create our database:

# %%
# Query to create a database
db_name = 'citibike'
create_db_query = "CREATE DATABASE IF NOT EXISTS {0} DEFAULT CHARACTER SET 'utf8'".format(db_name)

# Create a database
cursor = con.cursor()
cursor.execute(create_db_query)
cursor.close()

# %% [markdown]
# Then we create the table where we will store our data. For our example, we will just import three fields in the database: station_id, station_name, and number_of_docks

# %%
cursor = con.cursor()
db_name = 'citibike'
table_name = 'Docks'
# Create a table
# The {0} and {1} are placeholders for the parameters in the format(....) statement
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (station_id int, 
                                station_name varchar(250), 
                                number_of_docks int,
                                available_docks int,
                                date datetime,
                                PRIMARY KEY(station_id, date)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()

# %% [markdown]
# Finally, we import the data into our table, using the INSERT command.

# %%
from datetime import date, datetime, timedelta

query_template = '''INSERT INTO 
    citibike.Docks(station_id, station_name, 
                number_of_docks, available_docks, date) 
    VALUES (%s, %s, %s, %s, %s)'''

cursor = con.cursor()

# THIS IS PROHIBITED
# query = "INSERT INTO citibike.Docks(station_id, station_name, number_of_docks) VALUES ("+entry["id"]+", "+entry["stationName"]+", "+entry["totalDocks"]+")"

for entry in data:
    dockid = entry["id"]
    addr = entry["stationName"]
    docks = entry["totalDocks"]
    available = entry["availableDocks"]
    # date =  datetime.now()
    # lastcommunicationtime is a string of 
    # the form "2016-02-09 10:16:49 AM"
    # See https://docs.python.org/2/library/datetime.html#strftime-and-strptime-behavior
    # to see the documentation on how to parse 
    date = datetime.strptime(entry["lastCommunicationTime"], 
                             '%Y-%m-%d %I:%M:%S %p')
    print "Inserting station", dockid, "at", addr
    query_parameters = (dockid, addr, docks, available, date)
    cursor.execute(query_template, query_parameters)

con.commit()
cursor.close()
# Out:
# Inserting station 72 at W 52 St & 11 Ave
# Inserting station 79 at Franklin St & W Broadway
# Inserting station 82 at St James Pl & Pearl St
# Inserting station 83 at Atlantic Ave & Fort Greene Pl
# Inserting station 116 at W 17 St & 8 Ave
# Inserting station 119 at Park Ave & St Edwards St
# Inserting station 120 at Lexington Ave & Classon Ave
# Inserting station 127 at Barrow St & Hudson St
# Inserting station 128 at MacDougal St & Prince St
# Inserting station 137 at E 56 St & Madison Ave
# Inserting station 143 at Clinton St & Joralemon St
# Inserting station 144 at Nassau St & Navy St
# Inserting station 146 at Hudson St & Reade St
# Inserting station 147 at Greenwich St & Warren St
# Inserting station 150 at E 2 St & Avenue C
# Inserting station 151 at Cleveland Pl & Spring St
# Inserting station 152 at Warren St & Church St
# Inserting station 153 at E 40 St & 5 Ave
# Inserting station 157 at Henry St & Atlantic Ave
# Inserting station 161 at LaGuardia Pl & W 3 St
# Inserting station 164 at E 47 St & 2 Ave
# Inserting station 167 at E 39 St & 3 Ave
# Inserting station 168 at W 18 St & 6 Ave
# Inserting station 173 at Broadway & W 49 St
# Inserting station 174 at E 25 St & 1 Ave
# Inserting station 195 at Liberty St & Broadway
# Inserting station 212 at W 16 St & The High Line
# Inserting station 216 at Columbia Heights & Cranberry St
# Inserting station 217 at Old Fulton St
# Inserting station 223 at W 13 St & 7 Ave
# Inserting station 224 at Spruce St & Nassau St
# Inserting station 225 at W 14 St & The High Line
# Inserting station 228 at E 48 St & 3 Ave
# Inserting station 229 at Great Jones St
# Inserting station 232 at Cadman Plaza E & Tillary St
# Inserting station 233 at Cadman Plaza W & Pierrepont St
# Inserting station 236 at St Marks Pl & 2 Ave
# Inserting station 237 at E 11 St & 2 Ave
# Inserting station 238 at Bank St & Washington St
# Inserting station 239 at Willoughby St & Fleet St
# Inserting station 241 at DeKalb Ave & S Portland Ave
# Inserting station 242 at Carlton Ave & Flushing Ave
# Inserting station 243 at Fulton St & Rockwell Pl
# Inserting station 244 at Willoughby Ave & Hall St
# Inserting station 245 at Myrtle Ave & St Edwards St
# Inserting station 247 at Perry St & Bleecker St
# Inserting station 248 at Laight St & Hudson St
# Inserting station 249 at Harrison St & Hudson St
# Inserting station 250 at Lafayette St & Jersey St
# Inserting station 251 at Mott St & Prince St
# Inserting station 252 at MacDougal St & Washington Sq
# Inserting station 253 at W 13 St & 5 Ave
# Inserting station 254 at W 11 St & 6 Ave
# Inserting station 257 at Lispenard St & Broadway
# Inserting station 258 at DeKalb Ave & Vanderbilt Ave
# Inserting station 259 at South St & Whitehall St
# Inserting station 260 at Broad St & Bridge St
# Inserting station 261 at Johnson St & Gold St
# Inserting station 262 at Washington Park
# Inserting station 263 at Elizabeth St & Hester St
# Inserting station 264 at Maiden Ln & Pearl St
# Inserting station 265 at Stanton St & Chrystie St
# Inserting station 266 at Avenue D & E 8 St
# Inserting station 267 at Broadway & W 36 St
# Inserting station 268 at Howard St & Centre St
# Inserting station 270 at Adelphi St & Myrtle Ave
# Inserting station 274 at Lafayette Ave & Fort Greene Pl
# Inserting station 275 at Washington Ave & Greene Ave
# Inserting station 276 at Duane St & Greenwich St
# Inserting station 278 at Concord St & Bridge St
# Inserting station 279 at Peck Slip & Front St
# Inserting station 280 at E 10 St & 5 Ave
# Inserting station 281 at Grand Army Plaza & Central Park S
# Inserting station 282 at Kent Ave & S 11 St
# Inserting station 284 at Greenwich Ave & 8 Ave
# Inserting station 285 at Broadway & E 14 St
# Inserting station 289 at Monroe St & Classon Ave
# Inserting station 291 at Madison St & Montgomery St
# Inserting station 293 at Lafayette St & E 8 St
# Inserting station 295 at Pike St & E Broadway
# Inserting station 296 at Division St & Bowery
# Inserting station 297 at E 15 St & 3 Ave
# Inserting station 298 at 3 Ave & Schermerhorn St
# Inserting station 300 at Shevchenko Pl & E 7 St
# Inserting station 301 at E 2 St & Avenue B
# Inserting station 302 at Avenue D & E 3 St
# Inserting station 303 at Mercer St & Spring St
# Inserting station 304 at Broadway & Battery Pl
# Inserting station 305 at E 58 St & 3 Ave
# Inserting station 306 at Cliff St & Fulton St
# Inserting station 307 at Canal St & Rutgers St
# Inserting station 308 at St James Pl & Oliver St
# Inserting station 309 at Murray St & West St
# Inserting station 310 at State St & Smith St
# Inserting station 311 at Norfolk St & Broome St
# Inserting station 312 at Allen St & Stanton St
# Inserting station 313 at Washington Ave & Park Ave
# Inserting station 315 at South St & Gouverneur Ln
# Inserting station 316 at Fulton St & William St
# Inserting station 317 at E 6 St & Avenue B
# Inserting station 319 at Fulton St & Broadway
# Inserting station 320 at Leonard St & Church St
# Inserting station 321 at Cadman Plaza E & Red Cross Pl
# Inserting station 322 at Clinton St & Tillary St
# Inserting station 323 at Lawrence St & Willoughby St
# Inserting station 324 at DeKalb Ave & Hudson Ave
# Inserting station 325 at E 19 St & 3 Ave
# Inserting station 326 at E 11 St & 1 Ave
# Inserting station 327 at Vesey Pl & River Terrace
# Inserting station 328 at Watts St & Greenwich St
# Inserting station 329 at Greenwich St & N Moore St
# Inserting station 330 at Reade St & Broadway
# Inserting station 331 at Pike St & Monroe St
# Inserting station 332 at Cherry St
# Inserting station 334 at W 20 St & 7 Ave
# Inserting station 335 at Washington Pl & Broadway
# Inserting station 336 at Sullivan St & Washington Sq
# Inserting station 337 at Old Slip & Front St
# Inserting station 339 at Avenue D & E 12 St
# Inserting station 340 at Madison St & Clinton St
# Inserting station 341 at Stanton St & Mangin St
# Inserting station 342 at Columbia St & Rivington St
# Inserting station 343 at Clinton Ave & Flushing Ave
# Inserting station 344 at Monroe St & Bedford Ave
# Inserting station 345 at W 13 St & 6 Ave
# Inserting station 346 at Bank St & Hudson St
# Inserting station 347 at Greenwich St & W Houston St
# Inserting station 348 at W Broadway & Spring St
# Inserting station 349 at Rivington St & Ridge St
# Inserting station 350 at Clinton St & Grand St
# Inserting station 351 at Front St & Maiden Ln
# Inserting station 352 at W 56 St & 6 Ave
# Inserting station 353 at S Portland Ave & Hanson Pl
# Inserting station 354 at Emerson Pl & Myrtle Ave
# Inserting station 355 at Bayard St & Baxter St
# Inserting station 356 at Bialystoker Pl & Delancey St
# Inserting station 357 at E 11 St & Broadway
# Inserting station 358 at Christopher St & Greenwich St
# Inserting station 359 at E 47 St & Park Ave
# Inserting station 360 at William St & Pine St
# Inserting station 361 at Allen St & Hester St
# Inserting station 362 at Broadway & W 37 St
# Inserting station 363 at West Thames St
# Inserting station 364 at Lafayette Ave & Classon Ave
# Inserting station 365 at Fulton St & Grand Ave
# Inserting station 366 at Clinton Ave & Myrtle Ave
# Inserting station 367 at E 53 St & Lexington Ave
# Inserting station 368 at Carmine St & 6 Ave
# Inserting station 369 at Washington Pl & 6 Ave
# Inserting station 372 at Franklin Ave & Myrtle Ave
# Inserting station 373 at Willoughby Ave & Walworth St
# Inserting station 376 at John St & William St
# Inserting station 377 at 6 Ave & Canal St
# Inserting station 379 at W 31 St & 7 Ave
# Inserting station 380 at W 4 St & 7 Ave S
# Inserting station 382 at University Pl & E 14 St
# Inserting station 383 at Greenwich Ave & Charles St
# Inserting station 384 at Fulton St & Washington Ave
# Inserting station 385 at E 55 St & 2 Ave
# Inserting station 386 at Centre St & Worth St
# Inserting station 387 at Centre St & Chambers St
# Inserting station 388 at W 26 St & 10 Ave
# Inserting station 389 at Broadway & Berry St
# Inserting station 390 at Duffield St & Willoughby St
# Inserting station 391 at Clark St & Henry St
# Inserting station 392 at Jay St & Tech Pl
# Inserting station 393 at E 5 St & Avenue C
# Inserting station 394 at E 9 St & Avenue C
# Inserting station 395 at Bond St & Schermerhorn St
# Inserting station 396 at Lefferts Pl & Franklin Ave
# Inserting station 397 at Fulton St & Clermont Ave
# Inserting station 398 at Atlantic Ave & Furman St
# Inserting station 399 at Lafayette Ave & St James Pl
# Inserting station 400 at Pitt St & Stanton St
# Inserting station 401 at Allen St & Rivington St
# Inserting station 402 at Broadway & E 22 St
# Inserting station 403 at E 2 St & 2 Ave
# Inserting station 405 at Washington St & Gansevoort St
# Inserting station 406 at Hicks St & Montague St
# Inserting station 407 at Henry St & Poplar St
# Inserting station 408 at Market St & Cherry St
# Inserting station 409 at DeKalb Ave & Skillman St
# Inserting station 410 at Suffolk St & Stanton St
# Inserting station 411 at E 6 St & Avenue D
# Inserting station 412 at Forsyth St & Canal St
# Inserting station 414 at Pearl St & Anchorage Pl
# Inserting station 415 at Pearl St & Hanover Square
# Inserting station 416 at Cumberland St & Lafayette Ave
# Inserting station 417 at Barclay St & Church St
# Inserting station 418 at Front St & Gold St
# Inserting station 419 at Carlton Ave & Park Ave
# Inserting station 420 at Clermont Ave & Lafayette Ave
# Inserting station 421 at Clermont Ave & Park Ave
# Inserting station 422 at W 59 St & 10 Ave
# Inserting station 423 at W 54 St & 9 Ave
# Inserting station 426 at West St & Chambers St
# Inserting station 427 at Bus Slip & State St
# Inserting station 428 at E 3 St & 1 Ave
# Inserting station 430 at York St & Jay St
# Inserting station 432 at E 7 St & Avenue A
# Inserting station 433 at E 13 St & Avenue A
# Inserting station 434 at 9 Ave & W 18 St
# Inserting station 435 at W 21 St & 6 Ave
# Inserting station 436 at Hancock St & Bedford Ave
# Inserting station 437 at Macon St & Nostrand Ave
# Inserting station 438 at St Marks Pl & 1 Ave
# Inserting station 439 at E 4 St & 2 Ave
# Inserting station 440 at E 45 St & 3 Ave
# Inserting station 441 at E 52 St & 2 Ave
# Inserting station 442 at W 27 St & 7 Ave
# Inserting station 443 at Bedford Ave & S 9 St
# Inserting station 444 at Broadway & W 24 St
# Inserting station 445 at E 10 St & Avenue A
# Inserting station 446 at W 24 St & 7 Ave
# Inserting station 447 at 8 Ave & W 52 St
# Inserting station 448 at W 37 St & 10 Ave
# Inserting station 449 at W 52 St & 9 Ave
# Inserting station 450 at W 49 St & 8 Ave
# Inserting station 453 at W 22 St & 8 Ave
# Inserting station 454 at E 51 St & 1 Ave
# Inserting station 455 at 1 Ave & E 44 St
# Inserting station 456 at E 53 St & Madison Ave
# Inserting station 457 at Broadway & W 58 St
# Inserting station 458 at 11 Ave & W 27 St
# Inserting station 459 at W 20 St & 11 Ave
# Inserting station 460 at S 4 St & Wythe Ave
# Inserting station 461 at E 20 St & 2 Ave
# Inserting station 462 at W 22 St & 10 Ave
# Inserting station 463 at 9 Ave & W 16 St
# Inserting station 465 at Broadway & W 41 St
# Inserting station 466 at W 25 St & 6 Ave
# Inserting station 467 at Dean St & 4 Ave
# Inserting station 468 at Broadway & W 55 St
# Inserting station 469 at Broadway & W 53 St
# Inserting station 470 at W 20 St & 8 Ave
# Inserting station 471 at Grand St & Havemeyer St
# Inserting station 472 at E 32 St & Park Ave
# Inserting station 473 at Rivington St & Chrystie St
# Inserting station 474 at 5 Ave & E 29 St
# Inserting station 475 at E 16 St & Irving Pl
# Inserting station 476 at E 31 St & 3 Ave
# Inserting station 477 at W 41 St & 8 Ave
# Inserting station 478 at 11 Ave & W 41 St
# Inserting station 479 at 9 Ave & W 45 St
# Inserting station 480 at W 53 St & 10 Ave
# Inserting station 481 at S 3 St & Bedford Ave
# Inserting station 482 at W 15 St & 7 Ave
# Inserting station 483 at E 12 St & 3 Ave
# Inserting station 484 at W 44 St & 5 Ave
# Inserting station 485 at W 37 St & 5 Ave
# Inserting station 486 at Broadway & W 29 St
# Inserting station 487 at E 20 St & FDR Drive
# Inserting station 488 at W 39 St & 9 Ave
# Inserting station 490 at 8 Ave & W 33 St
# Inserting station 491 at E 24 St & Park Ave S
# Inserting station 492 at W 33 St & 7 Ave
# Inserting station 493 at W 45 St & 6 Ave
# Inserting station 494 at W 26 St & 8 Ave
# Inserting station 495 at W 47 St & 10 Ave
# Inserting station 496 at E 16 St & 5 Ave
# Inserting station 497 at E 17 St & Broadway
# Inserting station 498 at Broadway & W 32 St
# Inserting station 499 at Broadway & W 60 St
# Inserting station 500 at Broadway & W 51 St
# Inserting station 501 at FDR Drive & E 35 St
# Inserting station 502 at Henry St & Grand St
# Inserting station 503 at E 20 St & Park Ave
# Inserting station 504 at 1 Ave & E 15 St
# Inserting station 505 at 6 Ave & W 33 St
# Inserting station 507 at E 25 St & 2 Ave
# Inserting station 508 at W 46 St & 11 Ave
# Inserting station 509 at 9 Ave & W 22 St
# Inserting station 510 at W 51 St & 6 Ave
# Inserting station 511 at E 14 St & Avenue B
# Inserting station 513 at W 56 St & 10 Ave
# Inserting station 514 at 12 Ave & W 40 St
# Inserting station 515 at W 43 St & 10 Ave
# Inserting station 516 at E 47 St & 1 Ave
# Inserting station 517 at Pershing Square South
# Inserting station 518 at E 39 St & 2 Ave
# Inserting station 519 at Pershing Square North
# Inserting station 520 at W 52 St & 5 Ave
# Inserting station 522 at E 51 St & Lexington Ave
# Inserting station 523 at W 38 St & 8 Ave
# Inserting station 524 at W 43 St & 6 Ave
# Inserting station 525 at W 34 St & 11 Ave
# Inserting station 526 at E 33 St & 5 Ave
# Inserting station 527 at E 33 St & 2 Ave
# Inserting station 528 at 2 Ave & E 31 St
# Inserting station 529 at W 42 St & 8 Ave
# Inserting station 530 at 11 Ave & W 59 St
# Inserting station 531 at Forsyth St & Broome St
# Inserting station 532 at S 5 Pl & S 4 St
# Inserting station 533 at Broadway & W 39 St
# Inserting station 534 at Water - Whitehall Plaza
# Inserting station 536 at 1 Ave & E 30 St
# Inserting station 537 at Lexington Ave & E 24 St
# Inserting station 539 at Metropolitan Ave & Bedford Ave
# Inserting station 540 at Lexington Ave & E 29 St
# Inserting station 545 at E 23 St & 1 Ave
# Inserting station 546 at E 30 St & Park Ave S
# Inserting station 2000 at Front St & Washington St
# Inserting station 2001 at Sands St & Navy St
# Inserting station 2002 at Wythe Ave & Metropolitan Ave
# Inserting station 2003 at 1 Ave & E 18 St
# Inserting station 2004 at 6 Ave & Broome St
# Inserting station 2005 at Railroad Ave & Kay Ave
# Inserting station 2006 at Central Park S & 6 Ave
# Inserting station 2008 at Little West St & 1 Pl
# Inserting station 2009 at Catherine St & Monroe St
# Inserting station 2010 at Grand St & Greene St
# Inserting station 2012 at E 27 St & 1 Ave
# Inserting station 2017 at E 43 St & 2 Ave
# Inserting station 2021 at W 45 St & 8 Ave
# Inserting station 2022 at E 60 St & York Ave
# Inserting station 2023 at E 55 St & Lexington Ave
# Inserting station 3002 at South End Ave & Liberty St
# Inserting station 3016 at Kent Ave & N 7 St
# Inserting station 3041 at Kingston Ave & Herkimer St
# Inserting station 3042 at Fulton St & Utica Ave
# Inserting station 3043 at Lewis Ave & Decatur St
# Inserting station 3044 at Albany Ave & Fulton St
# Inserting station 3046 at Marcus Garvey Blvd & Macon St
# Inserting station 3047 at Halsey St & Tompkins Ave
# Inserting station 3048 at Putnam Ave & Nostrand Ave
# Inserting station 3049 at Cambridge Pl & Gates Ave
# Inserting station 3050 at Putnam Ave & Throop Ave
# Inserting station 3052 at Lewis Ave & Madison St
# Inserting station 3053 at Marcy Ave & Lafayette Ave
# Inserting station 3054 at Greene Ave & Throop Ave
# Inserting station 3055 at Greene Ave & Nostrand Ave
# Inserting station 3056 at Kosciuszko St & Nostrand Ave
# Inserting station 3057 at Kosciuszko St & Tompkins Ave
# Inserting station 3058 at Lewis Ave & Kosciuszko St
# Inserting station 3059 at Pulaski St & Marcus Garvey Blvd
# Inserting station 3060 at Willoughby Ave & Tompkins Ave
# Inserting station 3061 at Throop Ave & Myrtle Ave
# Inserting station 3062 at Myrtle Ave & Marcy Ave
# Inserting station 3063 at Nostrand Ave & Myrtle Ave
# Inserting station 3064 at Myrtle Ave & Lewis Ave
# Inserting station 3065 at Union Ave & Wallabout St
# Inserting station 3066 at Tompkins Ave & Hopkins St
# Inserting station 3067 at Broadway & Whipple St
# Inserting station 3068 at Humboldt St & Varet St
# Inserting station 3069 at Lorimer St & Broadway
# Inserting station 3070 at McKibbin St & Manhattan Ave
# Inserting station 3071 at Boerum St & Broadway
# Inserting station 3072 at Leonard St & Boerum St
# Inserting station 3073 at Division Ave & Hooper St
# Inserting station 3074 at Montrose Ave & Bushwick Ave
# Inserting station 3075 at Division Ave & Marcy Ave
# Inserting station 3076 at Scholes St & Manhattan Ave
# Inserting station 3077 at Stagg St & Union Ave
# Inserting station 3078 at Broadway & Roebling St
# Inserting station 3079 at Leonard St & Grand St
# Inserting station 3080 at S 4 St & Rodney St
# Inserting station 3081 at Graham Ave & Grand St
# Inserting station 3082 at Hope St & Union Ave
# Inserting station 3083 at Bushwick Ave & Powers St
# Inserting station 3084 at Devoe St & Leonard St
# Inserting station 3085 at Roebling St & N 4 St
# Inserting station 3086 at Graham Ave & Conselyea St
# Inserting station 3087 at Metropolitan Ave & Meeker Ave
# Inserting station 3088 at Union Ave & Jackson St
# Inserting station 3089 at Leonard St & Meeker Ave
# Inserting station 3090 at N 8 St & Driggs Ave
# Inserting station 3091 at Frost St & Meeker St
# Inserting station 3092 at Berry St & N 8 St
# Inserting station 3093 at N 6 St & Bedford Ave
# Inserting station 3094 at Graham Ave & Withers St
# Inserting station 3095 at Graham Ave & Herbert St
# Inserting station 3096 at Union Ave & N 12 St
# Inserting station 3098 at Leonard St & Bayard St
# Inserting station 3099 at Leonard St & Manhattan Ave
# Inserting station 3100 at Nassau Ave & Newell St
# Inserting station 3101 at N 12 St & Bedford Ave
# Inserting station 3102 at Driggs Ave & Lorimer St
# Inserting station 3103 at N 11 St & Wythe Ave
# Inserting station 3105 at N 15 St & Wythe Ave
# Inserting station 3106 at Driggs Ave & N Henry St
# Inserting station 3107 at Bedford Ave & Nassau Ave
# Inserting station 3108 at Nassau Ave & Russell St
# Inserting station 3109 at Banker St & Meserole Ave
# Inserting station 3110 at Meserole Ave & Manhattan Ave
# Inserting station 3111 at Norman Ave & Leonard St
# Inserting station 3112 at Milton St & Franklin St
# Inserting station 3113 at Greenpoint Ave & Manhattan Ave
# Inserting station 3114 at India St & East River
# Inserting station 3115 at India St & Manhattan Ave
# Inserting station 3116 at Huron St & Franklin St
# Inserting station 3117 at Franklin St & Dupont St
# Inserting station 3118 at McGuinness Blvd & Eagle St
# Inserting station 3119 at Vernon Blvd & 50 Ave
# Inserting station 3120 at Center Blvd & Borden Ave
# Inserting station 3121 at Jackson Ave & 46 Rd
# Inserting station 3122 at 48 Ave & 5 St
# Inserting station 3123 at 31 St & Thomson Ave
# Inserting station 3124 at 46 Ave & 5 St
# Inserting station 3125 at 45 Rd & 11 St
# Inserting station 3126 at 44 Dr & Jackson Ave
# Inserting station 3127 at 9 St & 44 Rd
# Inserting station 3128 at 21 St & 43 Ave
# Inserting station 3129 at Queens Plaza North & Crescent St
# Inserting station 3131 at E 68 St & 3 Ave
# Inserting station 3132 at E 59 St & Madison Ave
# Inserting station 3134 at 3 Ave & E 62 St
# Inserting station 3135 at E 75 St & 3 Ave
# Inserting station 3136 at 5 Ave & E 63 St
# Inserting station 3137 at 5 Ave & E 73 St
# Inserting station 3138 at E 77 St & Park Ave
# Inserting station 3139 at E 72 St & Park Ave
# Inserting station 3140 at 1 Ave & E 78 St
# Inserting station 3141 at 1 Ave & E 68 St
# Inserting station 3142 at 1 Ave & E 62 St
# Inserting station 3143 at 5 Ave & E 78 St
# Inserting station 3144 at E 81 St & Park Ave
# Inserting station 3145 at E 84 St & Park Ave
# Inserting station 3146 at E 81 St & 3 Ave
# Inserting station 3147 at E 85 St & 3 Ave
# Inserting station 3148 at E 84 St & 1 Ave
# Inserting station 3150 at E 85 St & York Ave
# Inserting station 3151 at E 81 St & York Ave
# Inserting station 3153 at E 71 St & 2 Ave
# Inserting station 3154 at E 77 St & 3 Ave
# Inserting station 3155 at Lexington Ave & E 63 St
# Inserting station 3156 at E 72 St & York Ave
# Inserting station 3157 at East End Ave & E 86 St
# Inserting station 3158 at W 63 St & Broadway
# Inserting station 3159 at W 67 St & Broadway
# Inserting station 3160 at Central Park West & W 76 St
# Inserting station 3161 at W 76 St & Columbus Ave
# Inserting station 3162 at W 78 St & Broadway
# Inserting station 3163 at Central Park West & W 68 St
# Inserting station 3164 at Columbus Ave & W 72 St
# Inserting station 3165 at Central Park West & W 72 St
# Inserting station 3166 at Riverside Dr & W 72 St
# Inserting station 3167 at Amsterdam Ave & W 73 St
# Inserting station 3168 at Central Park West & W 85 St
# Inserting station 3169 at Riverside Dr & W 82 St
# Inserting station 3170 at W 84 St & Columbus Ave
# Inserting station 3171 at Amsterdam Ave & W 82 St
# Inserting station 3172 at W 74 St & Columbus Ave
# Inserting station 3173 at Riverside Blvd & W 67 St
# Inserting station 3175 at W 70 St & Amsterdam Ave
# Inserting station 3176 at W 64 St & West End Ave
# Inserting station 3177 at W 84 St & Broadway
# Inserting station 3178 at Riverside Dr & W 78 St
# Inserting station 3179 at Park Ave & Marcus Garvey Blvd
# Inserting station 3180 at Brooklyn Bridge Park - Pier 2
# Inserting station 3182 at Yankee Ferry Terminal
# Inserting station 3183 at Exchange Place
# Inserting station 3184 at Paulus Hook
# Inserting station 3185 at City Hall
# Inserting station 3186 at Grove St PATH
# Inserting station 3187 at Warren St
# Inserting station 3188 at NJCU
# Inserting station 3189 at West Side Light Rail
# Inserting station 3190 at Garfield Ave Light Rail
# Inserting station 3191 at Union St
# Inserting station 3192 at Liberty Light Rail
# Inserting station 3193 at Lincoln Park
# Inserting station 3194 at McGinley Square
# Inserting station 3195 at Sip Ave
# Inserting station 3196 at Riverview Park
# Inserting station 3197 at North St
# Inserting station 3198 at Heights Elevator
# Inserting station 3199 at Newport Pkwy
# Inserting station 3200 at MLK Light Rail
# Inserting station 3201 at Dey St
# Inserting station 3202 at Newport PATH
# Inserting station 3203 at Hamilton Park
# Inserting station 3205 at JC Medical Center
# Inserting station 3206 at Hilltop
# Inserting station 3207 at Oakland Ave
# Inserting station 3209 at Brunswick St
# Inserting station 3210 at Pershing Field
# Inserting station 3211 at Newark Ave
# Inserting station 3212 at Christ Hospital
# Inserting station 3213 at Van Vorst Park
# Inserting station 3214 at Essex Light Rail
# Inserting station 3215 at Central Ave
# Inserting station 3216 at Columbia Park
# Inserting station 3217 at Bayside Park
# Inserting station 3220 at 5 Corners Library
# Inserting station 3221 at 47 Ave & 31 St
# Inserting station 3222 at Hanson Pl & St Felix St
# Inserting station 3223 at E 55 St & 3 Ave
# Inserting station 3224 at W 13 St & Hudson St
# Inserting station 3225 at Baldwin at Montgomery
# Inserting station 3226 at W 82 St & Central Park West
# Inserting station 3230 at Penn Station Valet
# Inserting station 3231 at E 67 St & Park Ave
# Inserting station 3232 at Bond St & Fulton St
# Inserting station 3233 at E 48 St & 5 Ave
# Inserting station 3235 at E 41 St & Madison Ave
# Inserting station 3236 at W 42 St & Dyer Ave
# Inserting station 3237 at 21 St & 41 Ave
# Inserting station 3238 at E 80 St & 2 Ave
# Inserting station 3241 at Monroe St & Tompkins Ave
# Inserting station 3242 at Schermerhorn St & Court St
# Inserting station 3243 at E 58 St & 1 Ave
# Inserting station 3244 at University Pl & E 8 St
# Inserting station 3246 at Montague St & Clinton St
# Inserting station 3248 at LPI Facility
# Inserting station 3249 at Verona Pl & Fulton St
# Inserting station 3254 at Soissons Landing
# Inserting station 3255 at 8 Ave & W 31 St

# %%
cur = con.cursor(mdb.cursors.DictCursor)
cur.execute("SELECT * FROM citibike.Docks")
rows = cur.fetchall()

for row in rows:
    print "Station ID:", row["station_id"]
    print "Station Name:", row["station_name"]
    print "Number of Docks:", row["number_of_docks"]
    print "Available Docks:", row["available_docks"]
    print "Last Communication:", row["date"]
    print "============================================="
    
cur.close()
# Out:
# Station ID: 72
# Station Name: W 52 St & 11 Ave
# Number of Docks: 39
# Available Docks: 36
# Last Communication: 2016-05-25 16:15:54
# =============================================
# Station ID: 79
# Station Name: Franklin St & W Broadway
# Number of Docks: 33
# Available Docks: 8
# Last Communication: 2016-05-25 16:18:45
# =============================================
# Station ID: 82
# Station Name: St James Pl & Pearl St
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:16:57
# =============================================
# Station ID: 83
# Station Name: Atlantic Ave & Fort Greene Pl
# Number of Docks: 62
# Available Docks: 32
# Last Communication: 2016-05-25 16:18:53
# =============================================
# Station ID: 116
# Station Name: W 17 St & 8 Ave
# Number of Docks: 39
# Available Docks: 35
# Last Communication: 2016-05-25 16:18:45
# =============================================
# Station ID: 119
# Station Name: Park Ave & St Edwards St
# Number of Docks: 19
# Available Docks: 12
# Last Communication: 2016-05-25 16:17:33
# =============================================
# Station ID: 120
# Station Name: Lexington Ave & Classon Ave
# Number of Docks: 19
# Available Docks: 12
# Last Communication: 2016-05-25 16:15:57
# =============================================
# Station ID: 127
# Station Name: Barrow St & Hudson St
# Number of Docks: 31
# Available Docks: 27
# Last Communication: 2016-05-25 16:19:11
# =============================================
# Station ID: 128
# Station Name: MacDougal St & Prince St
# Number of Docks: 30
# Available Docks: 4
# Last Communication: 2016-05-25 16:17:53
# =============================================
# Station ID: 137
# Station Name: E 56 St & Madison Ave
# Number of Docks: 46
# Available Docks: 11
# Last Communication: 2016-05-25 16:17:26
# =============================================
# Station ID: 143
# Station Name: Clinton St & Joralemon St
# Number of Docks: 24
# Available Docks: 24
# Last Communication: 2016-05-25 16:16:44
# =============================================
# Station ID: 144
# Station Name: Nassau St & Navy St
# Number of Docks: 19
# Available Docks: 16
# Last Communication: 2016-05-25 16:15:29
# =============================================
# Station ID: 146
# Station Name: Hudson St & Reade St
# Number of Docks: 39
# Available Docks: 26
# Last Communication: 2016-05-25 16:15:43
# =============================================
# Station ID: 147
# Station Name: Greenwich St & Warren St
# Number of Docks: 33
# Available Docks: 2
# Last Communication: 2016-05-25 16:19:12
# =============================================
# Station ID: 150
# Station Name: E 2 St & Avenue C
# Number of Docks: 31
# Available Docks: 19
# Last Communication: 2016-05-25 16:18:51
# =============================================
# Station ID: 151
# Station Name: Cleveland Pl & Spring St
# Number of Docks: 33
# Available Docks: 32
# Last Communication: 2016-05-25 16:17:48
# =============================================
# Station ID: 152
# Station Name: Warren St & Church St
# Number of Docks: 29
# Available Docks: 12
# Last Communication: 2016-05-25 16:18:57
# =============================================
# Station ID: 153
# Station Name: E 40 St & 5 Ave
# Number of Docks: 55
# Available Docks: 24
# Last Communication: 2016-05-25 16:15:45
# =============================================
# Station ID: 157
# Station Name: Henry St & Atlantic Ave
# Number of Docks: 23
# Available Docks: 16
# Last Communication: 2016-05-25 16:19:06
# =============================================
# Station ID: 161
# Station Name: LaGuardia Pl & W 3 St
# Number of Docks: 35
# Available Docks: 28
# Last Communication: 2016-05-25 16:18:12
# =============================================
# Station ID: 164
# Station Name: E 47 St & 2 Ave
# Number of Docks: 47
# Available Docks: 27
# Last Communication: 2016-05-25 16:18:39
# =============================================
# Station ID: 167
# Station Name: E 39 St & 3 Ave
# Number of Docks: 45
# Available Docks: 41
# Last Communication: 2016-05-25 16:18:08
# =============================================
# Station ID: 168
# Station Name: W 18 St & 6 Ave
# Number of Docks: 47
# Available Docks: 30
# Last Communication: 2016-05-25 16:19:08
# =============================================
# Station ID: 173
# Station Name: Broadway & W 49 St
# Number of Docks: 51
# Available Docks: 29
# Last Communication: 2016-05-25 16:18:50
# =============================================
# Station ID: 174
# Station Name: E 25 St & 1 Ave
# Number of Docks: 30
# Available Docks: 28
# Last Communication: 2016-05-25 16:19:10
# =============================================
# Station ID: 195
# Station Name: Liberty St & Broadway
# Number of Docks: 45
# Available Docks: 30
# Last Communication: 2016-05-25 16:17:44
# =============================================
# Station ID: 212
# Station Name: W 16 St & The High Line
# Number of Docks: 28
# Available Docks: 4
# Last Communication: 2016-05-25 16:18:46
# =============================================
# Station ID: 216
# Station Name: Columbia Heights & Cranberry St
# Number of Docks: 23
# Available Docks: 23
# Last Communication: 2016-05-25 16:19:11
# =============================================
# Station ID: 217
# Station Name: Old Fulton St
# =============================================
# Station ID: 306
# Station Name: Cliff St & Fulton St
# Number of Docks: 25
# Available Docks: 16
# Last Communication: 2016-05-25 16:18:44
# =============================================
# Station ID: 307
# Station Name: Canal St & Rutgers St
# Number of Docks: 29
# Available Docks: 27
# Last Communication: 2016-05-25 16:18:41
# =============================================
# Station ID: 308
# Station Name: St James Pl & Oliver St
# Number of Docks: 27
# Available Docks: 21
# Last Communication: 2016-05-25 16:18:07
# =============================================
# Station ID: 309
# Station Name: Murray St & West St
# Number of Docks: 41
# Available Docks: 4
# Last Communication: 2016-05-25 16:16:52
# =============================================
# Station ID: 310
# Station Name: State St & Smith St
# Number of Docks: 36
# Available Docks: 19
# Last Communication: 2016-05-25 16:17:48
# =============================================
# Station ID: 311
# Station Name: Norfolk St & Broome St
# Number of Docks: 31
# Available Docks: 29
# Last Communication: 2016-05-25 16:17:59
# =============================================
# Station ID: 312
# Station Name: Allen St & Stanton St
# Number of Docks: 0
# Available Docks: 0
# Last Communication: 2016-04-19 13:37:40
# =============================================
# Station ID: 313
# Station Name: Washington Ave & Park Ave
# Number of Docks: 23
# Available Docks: 14
# Last Communication: 2016-05-25 16:17:40
# =============================================
# Station ID: 315
# Station Name: South St & Gouverneur Ln
# Number of Docks: 29
# Available Docks: 4
# Last Communication: 2016-05-25 16:15:41
# =============================================
# Station ID: 316
# Station Name: Fulton St & William St
# Number of Docks: 43
# Available Docks: 20
# Last Communication: 2016-05-25 16:17:55
# =============================================
# Station ID: 317
# Station Name: E 6 St & Avenue B
# Number of Docks: 27
# Available Docks: 19
# Last Communication: 2016-05-25 16:18:32
# =============================================
# Station ID: 319
# Station Name: Fulton St & Broadway
# Number of Docks: 33
# Available Docks: 9
# Last Communication: 2016-05-25 16:17:37
# =============================================
# Station ID: 320
# Station Name: Leonard St & Church St
# Number of Docks: 39
# Available Docks: 21
# Last Communication: 2016-05-25 16:16:51
# =============================================
# Station ID: 321
# Station Name: Cadman Plaza E & Red Cross Pl
# Number of Docks: 27
# Available Docks: 9
# Last Communication: 2016-05-25 16:19:18
# =============================================
# Station ID: 322
# Station Name: Clinton St & Tillary St
# Number of Docks: 31
# Available Docks: 18
# Last Communication: 2016-05-25 16:15:21
# =============================================
# Station ID: 323
# Station Name: Lawrence St & Willoughby St
# Number of Docks: 39
# Available Docks: 6
# Last Communication: 2016-05-25 16:19:08
# =============================================
# Station ID: 324
# Station Name: DeKalb Ave & Hudson Ave
# Number of Docks: 51
# Available Docks: 10
# Last Communication: 2016-05-25 16:15:48
# =============================================
# Station ID: 325
# Station Name: E 19 St & 3 Ave
# Number of Docks: 35
# Available Docks: 33
# Last Communication: 2016-05-25 16:19:12
# =============================================
# Station ID: 326
# Station Name: E 11 St & 1 Ave
# Number of Docks: 27
# Available Docks: 20
# Last Communication: 2016-05-25 16:16:52
# =============================================
# Station ID: 327
# Station Name: Vesey Pl & River Terrace
# Number of Docks: 39
# Available Docks: 14
# Last Communication: 2016-05-25 16:17:54
# =============================================
# Station ID: 328
# Station Name: Watts St & Greenwich St
# =============================================
# Station ID: 351
# Station Name: Front St & Maiden Ln
# Number of Docks: 39
# Available Docks: 0
# Last Communication: 2016-05-25 16:19:10
# =============================================
# Station ID: 352
# Station Name: W 56 St & 6 Ave
# Number of Docks: 36
# Available Docks: 34
# Last Communication: 2016-05-25 16:17:30
# =============================================
# Station ID: 353
# Station Name: S Portland Ave & Hanson Pl
# Number of Docks: 27
# Available Docks: 13
# Last Communication: 2016-05-25 16:17:42
# =============================================
# Station ID: 354
# Station Name: Emerson Pl & Myrtle Ave
# Number of Docks: 23
# Available Docks: 14
# Last Communication: 2016-05-25 16:17:58
# =============================================
# Station ID: 355
# Station Name: Bayard St & Baxter St
# Number of Docks: 43
# Available Docks: 41
# Last Communication: 2016-05-25 16:18:48
# =============================================
# Station ID: 356
# Station Name: Bialystoker Pl & Delancey St
# Number of Docks: 23
# Available Docks: 14
# Last Communication: 2016-05-25 16:17:19
# =============================================
# Station ID: 357
# Station Name: E 11 St & Broadway
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:19:12
# =============================================
# Station ID: 358
# Station Name: Christopher St & Greenwich St
# Number of Docks: 36
# Available Docks: 21
# Last Communication: 2016-05-25 16:18:47
# =============================================
# Station ID: 359
# Station Name: E 47 St & Park Ave
# Number of Docks: 55
# Available Docks: 34
# Last Communication: 2016-05-25 16:19:15
# =============================================
# Station ID: 360
# Station Name: William St & Pine St
# Number of Docks: 39
# Available Docks: 16
# Last Communication: 2016-05-25 16:18:50
# =============================================
# Station ID: 361
# Station Name: Allen St & Hester St
# Number of Docks: 43
# Available Docks: 41
# Last Communication: 2016-05-25 16:18:11
# =============================================
# Station ID: 362
# Station Name: Broadway & W 37 St
# Number of Docks: 57
# Available Docks: 57
# Last Communication: 2016-05-25 16:17:44
# =============================================
# Station ID: 363
# Station Name: West Thames St
# Number of Docks: 49
# Available Docks: 39
# Last Communication: 2016-05-25 16:18:14
# =============================================
# Station ID: 364
# Station Name: Lafayette Ave & Classon Ave
# Number of Docks: 27
# Available Docks: 25
# Last Communication: 2016-05-25 16:16:34
# =============================================
# Station ID: 365
# Station Name: Fulton St & Grand Ave
# Number of Docks: 31
# Available Docks: 27
# Last Communication: 2016-05-25 16:17:48
# =============================================
# Station ID: 366
# Station Name: Clinton Ave & Myrtle Ave
# Number of Docks: 33
# Available Docks: 24
# Last Communication: 2016-05-25 16:16:10
# =============================================
# Station ID: 367
# Station Name: E 53 St & Lexington Ave
# Number of Docks: 34
# Available Docks: 24
# Last Communication: 2016-05-25 16:18:46
# =============================================
# Station ID: 368
# Station Name: Carmine St & 6 Ave
# Number of Docks: 39
# Available Docks: 27
# Last Communication: 2016-05-25 16:16:55
# =============================================
# Station ID: 369
# Station Name: Washington Pl & 6 Ave
# Number of Docks: 35
# Available Docks: 28
# Last Communication: 2016-05-25 16:18:00
# =============================================
# Station ID: 372
# Station Name: Franklin Ave & Myrtle Ave
# Number of Docks: 27
# Available Docks: 18
# Last Communication: 2016-05-25 16:15:50
# =============================================
# Station ID: 373
# Station Name: Willoughby Ave & Walworth St
# Number of Docks: 19
# Available Docks: 11
# Last Communication: 2016-05-25 16:15:52
# =============================================
# Station ID: 376
# Station Name: John St & William St
# Number of Docks: 43
# Available Docks: 15
# Last Communication: 2016-05-25 16:16:26
# =============================================
# Station ID: 377
# Station Name: 6 Ave & Canal St
# Number of Docks: 47
# Available Docks: 5
# Last Communication: 2016-05-25 16:17:19
# =============================================
# Station ID: 379
# Station Name: W 31 St & 7 Ave
# Number of Docks: 42
# Available Docks: 11
# Last Communication: 2016-05-25 16:18:27
# =============================================
# Station ID: 380
# Station Name: W 4 St & 7 Ave S
# Number of Docks: 39
# Available Docks: 29
# Last Communication: 2016-05-25 16:18:48
# =============================================
# Station ID: 382
# Station Name: University Pl & E 14 St
# Number of Docks: 36
# Available Docks: 5
# Last Communication: 2016-05-25 16:19:12
# =============================================
# Station ID: 383
# Station Name: Greenwich Ave & Charles St
# Number of Docks: 39
# Available Docks: 29
# Last Communication: 2016-05-25 16:18:08
# =============================================
# Station ID: 384
# Station Name: Fulton St & Washington Ave
# Number of Docks: 31
# Available Docks: 26
# Last Communication: 2016-05-25 16:17:58
# =============================================
# Station ID: 385
# Station Name: E 55 St & 2 Ave
# Number of Docks: 29
# Available Docks: 24
# Last Communication: 2016-05-25 16:16:03
# =============================================
# Station ID: 386
# Station Name: Centre St & Worth St
# Number of Docks: 43
# Available Docks: 2
# Last Communication: 2016-05-25 16:18:52
# =============================================
# Station ID: 387
# Station Name: Centre St & Chambers St
# Number of Docks: 39
# Available Docks: 30
# Last Communication: 2016-05-25 16:17:18
# =============================================
# Station ID: 388
# Station Name: W 26 St & 10 Ave
# Number of Docks: 35
# Available Docks: 20
# Last Communication: 2016-05-25 16:19:13
# =============================================
# Station ID: 389
# Station Name: Broadway & Berry St
# Number of Docks: 27
# Available Docks: 10
# Last Communication: 2016-05-25 16:18:05
# =============================================
# Station ID: 390
# Station Name: Duffield St & Willoughby St
# Number of Docks: 31
# Available Docks: 10
# Last Communication: 2016-05-25 16:17:44
# =============================================
# Station ID: 391
# Station Name: Clark St & Henry St
# Number of Docks: 31
# Available Docks: 31
# Last Communication: 2016-05-25 16:18:27
# =============================================
# Station ID: 392
# Station Name: Jay St & Tech Pl
# Number of Docks: 32
# Available Docks: 1
# Last Communication: 2016-05-25 16:19:09
# =============================================
# Station ID: 393
# Station Name: E 5 St & Avenue C
# Number of Docks: 31
# Available Docks: 27
# Last Communication: 2016-05-25 16:16:30
# =============================================
# Station ID: 394
# Station Name: E 9 St & Avenue C
# Number of Docks: 32
# Available Docks: 30
# Last Communication: 2016-05-25 16:18:56
# =============================================
# Station ID: 395
# Station Name: Bond St & Schermerhorn St
# Number of Docks: 30
# Available Docks: 26
# Last Communication: 2016-05-25 16:15:32
# =============================================
# Station ID: 396
# Station Name: Lefferts Pl & Franklin Ave
# Number of Docks: 25
# Available Docks: 18
# Last Communication: 2016-05-25 16:16:31
# =============================================
# Station ID: 397
# Station Name: Fulton St & Clermont Ave
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:18:57
# =============================================
# Station ID: 398
# Station Name: Atlantic Ave & Furman St
# Number of Docks: 31
# Available Docks: 20
# Last Communication: 2016-05-25 16:18:44
# =============================================
# Station ID: 399
# Station Name: Lafayette Ave & St James Pl
# Number of Docks: 27
# Available Docks: 16
# Last Communication: 2016-05-25 16:16:51
# =============================================
# Station ID: 400
# Station Name: Pitt St & Stanton St
# Number of Docks: 15
# Available Docks: 14
# Last Communication: 2016-05-25 16:19:10
# =============================================
# Station ID: 401
# Station Name: Allen St & Rivington St
# Number of Docks: 0
# Available Docks: 0
# Last Communication: 2016-04-20 08:01:54
# =============================================
# Station ID: 402
# Station Name: Broadway & E 22 St
# Number of Docks: 42
# Available Docks: 29
# Last Communication: 2016-05-25 16:18:38
# =============================================
# Station ID: 403
# Station Name: E 2 St & 2 Ave
# Number of Docks: 15
# Available Docks: 15
# Last Communication: 2016-02-24 11:41:40
# =============================================
# Station ID: 405
# Station Name: Washington St & Gansevoort St
# Number of Docks: 40
# Available Docks: 18
# Last Communication: 2016-05-25 16:17:54
# =============================================
# Station ID: 406
# Station Name: Hicks St & Montague St
# Number of Docks: 34
# Available Docks: 27
# Last Communication: 2016-05-25 16:17:33
# =============================================
# Station ID: 407
# Station Name: Henry St & Poplar St
# Number of Docks: 37
# Available Docks: 26
# Last Communication: 2016-05-25 16:15:43
# =============================================
# Station ID: 408
# Station Name: Market St & Cherry St
# Number of Docks: 23
# Available Docks: 16
# Last Communication: 2016-05-25 16:18:02
# =============================================
# Station ID: 409
# Station Name: DeKalb Ave & Skillman St
# Number of Docks: 19
# Available Docks: 15
# Last Communication: 2016-05-25 16:17:16
# =============================================
# Station ID: 410
# Station Name: Suffolk St & Stanton St
# Number of Docks: 35
# Available Docks: 24
# Last Communication: 2016-05-25 16:19:18
# =============================================
# Station ID: 411
# Station Name: E 6 St & Avenue D
# Number of Docks: 23
# Available Docks: 20
# Last Communication: 2016-05-25 16:16:52
# =============================================
# Station ID: 412
# Station Name: Forsyth St & Canal St
# Number of Docks: 29
# Available Docks: 16
# Last Communication: 2016-05-25 16:17:48
# =============================================
# Station ID: 414
# Station Name: Pearl St & Anchorage Pl
# Number of Docks: 24
# Available Docks: 2
# Last Communication: 2016-05-25 16:17:49
# =============================================
# Station ID: 415
# Station Name: Pearl St & Hanover Square
# Number of Docks: 42
# Available Docks: 21
# Last Communication: 2016-05-25 16:17:25
# =============================================
# Station ID: 416
# Station Name: Cumberland St & Lafayette Ave
# Number of Docks: 31
# Available Docks: 24
# Last Communication: 2016-05-25 16:18:37
# =============================================
# Station ID: 417
# Station Name: Barclay St & Church St
# Number of Docks: 23
# Available Docks: 2
# Last Communication: 2016-05-25 16:19:16
# =============================================
# Station ID: 418
# Station Name: Front St & Gold St
# Number of Docks: 23
# Available Docks: 13
# Last Communication: 2016-05-25 16:15:35
# =============================================
# Station ID: 419
# Station Name: Carlton Ave & Park Ave
# Number of Docks: 23
# Available Docks: 14
# Last Communication: 2016-05-25 16:18:46
# =============================================
# Station ID: 420
# Station Name: Clermont Ave & Lafayette Ave
# Number of Docks: 23
# Available Docks: 19
# Last Communication: 2016-05-25 16:17:15
# =============================================
# Station ID: 421
# Station Name: Clermont Ave & Park Ave
# Number of Docks: 19
# Available Docks: 15
# Last Communication: 2016-05-25 16:16:03
# =============================================
# Station ID: 422
# Station Name: W 59 St & 10 Ave
# Number of Docks: 55
# Available Docks: 54
# Last Communication: 2016-05-25 16:16:59
# =============================================
# Station ID: 423
# Station Name: W 54 St & 9 Ave
# Number of Docks: 39
# Available Docks: 38
# Last Communication: 2016-05-25 16:18:05
# =============================================
# Station ID: 426
# Station Name: West St & Chambers St
# Number of Docks: 31
# Available Docks: 6
# Last Communication: 2016-05-25 16:19:14
# =============================================
# Station ID: 427
# Station Name: Bus Slip & State St
# Number of Docks: 47
# Available Docks: 27
# Last Communication: 2016-05-25 16:17:08
# =============================================
# Station ID: 428
# Station Name: E 3 St & 1 Ave
# Number of Docks: 31
# Available Docks: 30
# Last Communication: 2016-05-25 16:19:04
# =============================================
# Station ID: 430
# Station Name: York St & Jay St
# Number of Docks: 27
# Available Docks: 9
# Last Communication: 2016-05-25 16:18:06
# =============================================
# Station ID: 432
# Station Name: E 7 St & Avenue A
# Number of Docks: 31
# Available Docks: 21
# Last Communication: 2016-05-25 16:17:15
# =============================================
# Station ID: 433
# Station Name: E 13 St & Avenue A
# Number of Docks: 39
# Available Docks: 34
# Last Communication: 2016-05-25 16:17:30
# =============================================
# Station ID: 434
# Station Name: 9 Ave & W 18 St
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:18:38
# =============================================
# Station ID: 435
# Station Name: W 21 St & 6 Ave
# Number of Docks: 47
# Available Docks: 25
# Last Communication: 2016-05-25 16:18:06
# =============================================
# Station ID: 436
# Station Name: Hancock St & Bedford Ave
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:15:58
# =============================================
# Station ID: 437
# Station Name: Macon St & Nostrand Ave
# Number of Docks: 24
# Available Docks: 15
# Last Communication: 2016-05-25 16:18:45
# =============================================
# Station ID: 438
# Station Name: St Marks Pl & 1 Ave
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:16:12
# =============================================
# Station ID: 439
# Station Name: E 4 St & 2 Ave
# Number of Docks: 39
# Available Docks: 29
# Last Communication: 2016-05-25 16:16:56
# =============================================
# Station ID: 440
# Station Name: E 45 St & 3 Ave
# Number of Docks: 32
# Available Docks: 30
# Last Communication: 2016-05-25 16:18:27
# =============================================
# Station ID: 441
# Station Name: E 52 St & 2 Ave
# Number of Docks: 35
# Available Docks: 28
# Last Communication: 2016-05-25 16:18:20
# =============================================
# Station ID: 442
# Station Name: W 27 St & 7 Ave
# Number of Docks: 0
# Available Docks: 0
# Last Communication: 2016-04-28 11:37:37
# =============================================
# Station ID: 443
# Station Name: Bedford Ave & S 9 St
# Number of Docks: 23
# Available Docks: 12
# Last Communication: 2016-05-25 16:15:58
# Number of Docks: 36
# Available Docks: 30
# Last Communication: 2016-05-25 16:18:10
# =============================================
# Station ID: 488
# Station Name: W 39 St & 9 Ave
# Number of Docks: 40
# Available Docks: 23
# Last Communication: 2016-05-25 16:17:19
# =============================================
# Station ID: 490
# Station Name: 8 Ave & W 33 St
# Number of Docks: 59
# Available Docks: 43
# Last Communication: 2016-05-25 16:19:07
# =============================================
# Station ID: 491
# Station Name: E 24 St & Park Ave S
# Number of Docks: 53
# Available Docks: 19
# Last Communication: 2016-05-25 16:19:12
# =============================================
# Station ID: 492
# Station Name: W 33 St & 7 Ave
# Number of Docks: 49
# Available Docks: 1
# Last Communication: 2016-05-25 16:19:15
# =============================================
# Station ID: 493
# Station Name: W 45 St & 6 Ave
# Number of Docks: 34
# Available Docks: 16
# Last Communication: 2016-05-25 16:19:14
# =============================================
# Station ID: 494
# Station Name: W 26 St & 8 Ave
# Number of Docks: 35
# Available Docks: 18
# Last Communication: 2016-05-25 16:19:02
# =============================================
# Station ID: 495
# Station Name: W 47 St & 10 Ave
# Number of Docks: 25
# Available Docks: 23
# Last Communication: 2016-05-25 16:18:00
# =============================================
# Station ID: 496
# Station Name: E 16 St & 5 Ave
# Number of Docks: 47
# Available Docks: 3
# Last Communication: 2016-05-25 16:16:07
# =============================================
# Station ID: 497
# Station Name: E 17 St & Broadway
# Number of Docks: 59
# Available Docks: 5
# Last Communication: 2016-05-25 16:18:33
# =============================================
# Station ID: 498
# Station Name: Broadway & W 32 St
# Number of Docks: 30
# Available Docks: 26
# Last Communication: 2016-05-25 16:18:48
# =============================================
# Station ID: 499
# Station Name: Broadway & W 60 St
# Number of Docks: 36
# Available Docks: 35
# Last Communication: 2016-05-25 16:19:20
# =============================================
# Station ID: 500
# Station Name: Broadway & W 51 St
# Number of Docks: 40
# Available Docks: 25
# Last Communication: 2016-05-25 16:18:49
# =============================================
# Station ID: 501
# Station Name: FDR Drive & E 35 St
# Number of Docks: 43
# Available Docks: 30
# Last Communication: 2016-05-25 16:18:45
# =============================================
# Station ID: 502
# Station Name: Henry St & Grand St
# Number of Docks: 30
# Available Docks: 27
# Last Communication: 2016-05-25 16:17:23
# =============================================
# Station ID: 503
# Station Name: E 20 St & Park Ave
# Number of Docks: 29
# Available Docks: 11
# Last Communication: 2016-05-25 16:17:57
# =============================================
# Station ID: 504
# Station Name: 1 Ave & E 15 St
# Number of Docks: 45
# Available Docks: 43
# Last Communication: 2016-05-25 16:19:00
# =============================================
# Station ID: 505
# Station Name: 6 Ave & W 33 St
# Number of Docks: 36
# Available Docks: 11
# Last Communication: 2016-05-25 16:16:07
# =============================================
# Station ID: 507
# Station Name: E 25 St & 2 Ave
# Number of Docks: 47
# Available Docks: 46
# Last Communication: 2016-05-25 16:16:55
# =============================================
# Station ID: 508
# Station Name: W 46 St & 11 Ave
# Number of Docks: 24
# Available Docks: 20
# Last Communication: 2016-05-25 16:16:55
# =============================================
# Station ID: 509
# Station Name: 9 Ave & W 22 St
# Number of Docks: 36
# ...
# =============================================
# Station Name: Amsterdam Ave & W 73 St
# Number of Docks: 55
# Available Docks: 42
# Last Communication: 2016-05-25 16:16:58
# =============================================
# Station ID: 3168
# Station Name: Central Park West & W 85 St
# Number of Docks: 31
# Available Docks: 22
# Last Communication: 2016-05-25 16:16:56
# =============================================
# Station ID: 3169
# Station Name: Riverside Dr & W 82 St
# Number of Docks: 59
# Available Docks: 51
# Last Communication: 2016-05-25 16:18:25
# =============================================
# Station ID: 3170
# Station Name: W 84 St & Columbus Ave
# Number of Docks: 35
# Available Docks: 35
# Last Communication: 2016-05-25 16:15:52
# =============================================
# Station ID: 3171
# Station Name: Amsterdam Ave & W 82 St
# Number of Docks: 39
# Available Docks: 36
# Last Communication: 2016-05-25 16:15:30
# =============================================
# Station ID: 3172
# Station Name: W 74 St & Columbus Ave
# Number of Docks: 27
# Available Docks: 24
# Last Communication: 2016-05-25 16:19:19
# =============================================
# Station ID: 3173
# Station Name: Riverside Blvd & W 67 St
# Number of Docks: 63
# Available Docks: 38
# Last Communication: 2016-05-25 16:17:50
# =============================================
# Station ID: 3175
# Station Name: W 70 St & Amsterdam Ave
# Number of Docks: 31
# Available Docks: 28
# Last Communication: 2016-05-25 16:17:32
# =============================================
# Station ID: 3176
# Station Name: W 64 St & West End Ave
# Number of Docks: 43
# Available Docks: 43
# Last Communication: 2016-05-25 16:15:54
# =============================================
# Station ID: 3177
# Station Name: W 84 St & Broadway
# Number of Docks: 63
# Available Docks: 55
# Last Communication: 2016-05-25 16:16:58
# =============================================
# Station ID: 3178
# Station Name: Riverside Dr & W 78 St
# Number of Docks: 59
# Available Docks: 57
# Last Communication: 2016-05-25 16:17:18
# =============================================
# Station ID: 3179
# Station Name: Park Ave & Marcus Garvey Blvd
# Number of Docks: 23
# Available Docks: 23
# Last Communication: 2016-05-25 16:16:39
# =============================================
# Station ID: 3180
# Station Name: Brooklyn Bridge Park - Pier 2
# Number of Docks: 31
# Available Docks: 28
# Last Communication: 2016-05-25 16:18:55
# =============================================
# Station ID: 3182
# Station Name: Yankee Ferry Terminal
# Number of Docks: 42
# Available Docks: 42
# Last Communication: 2016-05-25 16:15:59
# =============================================
# Station ID: 3183
# Station Name: Exchange Place
# Number of Docks: 30
# Available Docks: 6
# Last Communication: 2016-05-25 16:18:51
# =============================================
# Station ID: 3184
# Station Name: Paulus Hook
# Number of Docks: 14
# Available Docks: 8
# Last Communication: 2016-05-25 16:17:00
# =============================================
# Station ID: 3185
# Station Name: City Hall
# Number of Docks: 22
# Available Docks: 11
# Last Communication: 2016-05-25 16:17:19
# =============================================
# Station ID: 3186
# Station Name: Grove St PATH
# Number of Docks: 22
# Available Docks: 4
# Last Communication: 2016-05-25 13:40:05
# =============================================
# Station ID: 3187
# Station Name: Warren St
# Number of Docks: 22
# Available Docks: 5
# Last Communication: 2016-05-25 16:18:44
# =============================================
# Station ID: 3188
# Station Name: NJCU
# Number of Docks: 18
# Available Docks: 10
# Last Communication: 2016-05-25 16:17:04
# =============================================
# Station ID: 3189
# Last Communication: 2016-05-25 16:18:02
# =============================================
# Station ID: 3213
# Station Name: Van Vorst Park
# Number of Docks: 22
# Available Docks: 15
# Last Communication: 2016-05-25 16:16:19
# =============================================
# Station ID: 3214
# Station Name: Essex Light Rail
# Number of Docks: 22
# Available Docks: 12
# Last Communication: 2016-05-25 16:19:15
# =============================================
# Station ID: 3215
# Station Name: Central Ave
# Number of Docks: 18
# Available Docks: 15
# Last Communication: 2016-05-25 16:17:57
# =============================================
# Station ID: 3216
# Station Name: Columbia Park
# Number of Docks: 18
# Available Docks: 11
# Last Communication: 2016-05-25 16:18:16
# =============================================
# Station ID: 3217
# Station Name: Bayside Park
# Number of Docks: 18
# Available Docks: 13
# Last Communication: 2016-05-25 16:19:00
# =============================================
# Station ID: 3220
# Station Name: 5 Corners Library
# Number of Docks: 18
# Available Docks: 17
# Last Communication: 2016-05-25 16:15:50
# =============================================
# Station ID: 3221
# Station Name: 47 Ave & 31 St
# Number of Docks: 27
# Available Docks: 6
# Last Communication: 2016-05-25 16:17:58
# =============================================
# Station ID: 3222
# Station Name: Hanson Pl & St Felix St
# Number of Docks: 39
# Available Docks: 15
# Last Communication: 2016-05-25 16:17:26
# =============================================
# Station ID: 3223
# Station Name: E 55 St & 3 Ave
# Number of Docks: 55
# Available Docks: 19
# Last Communication: 2016-05-25 16:18:35
# =============================================
# Station ID: 3224
# Station Name: W 13 St & Hudson St
# Number of Docks: 39
# Available Docks: 12
# Last Communication: 2016-05-25 16:18:42
# =============================================
# Station ID: 3225
# Station Name: Baldwin at Montgomery
# Number of Docks: 14
# Available Docks: 10
# Last Communication: 2016-05-25 16:17:13
# =============================================
# Station ID: 3226
# Station Name: W 82 St & Central Park West
# Number of Docks: 45
# Available Docks: 36
# Last Communication: 2016-05-25 16:18:49
# =============================================
# Station ID: 3230
# Station Name: Penn Station Valet
# Number of Docks: 7
# Available Docks: 6
# Last Communication: 2016-05-25 16:19:15
# =============================================
# Station ID: 3231
# Station Name: E 67 St & Park Ave
# Number of Docks: 59
# Available Docks: 54
# Last Communication: 2016-05-25 16:15:22
# =============================================
# Station ID: 3232
# Station Name: Bond St & Fulton St
# Number of Docks: 31
# Available Docks: 5
# Last Communication: 2016-05-25 16:16:31
# =============================================
# Station ID: 3233
# Station Name: E 48 St & 5 Ave
# Number of Docks: 39
# Available Docks: 23
# Last Communication: 2016-05-25 16:16:57
# =============================================
# Station ID: 3235
# Station Name: E 41 St & Madison Ave
# Number of Docks: 31
# Available Docks: 14
# Last Communication: 2016-05-25 16:17:10
# =============================================
# Station ID: 3236
# Station Name: W 42 St & Dyer Ave
# Number of Docks: 33
# Available Docks: 32
# Last Communication: 2016-05-25 16:19:02
# =============================================
# Station ID: 3237
# Station Name: 21 St & 41 Ave
# Number of Docks: 25
# Available Docks: 8
# Last Communication: 2016-05-25 16:17:37
# =============================================
# Station ID: 3238
# Station Name: E 80 St & 2 Ave
# Number of Docks: 37
# Available Docks: 35
# Last Communication: 2016-05-25 16:18:16
# =============================================
# Station ID: 3241
# Station Name: Monroe St & Tompkins Ave
# Number of Docks: 19
# Available Docks: 10
# Last Communication: 2016-05-25 16:17:32
# =============================================
# Station ID: 3242
# Station Name: Schermerhorn St & Court St
# Number of Docks: 39
# Available Docks: 29
# Last Communication: 2016-05-25 16:17:10
# =============================================
# Station ID: 3243
# Station Name: E 58 St & 1 Ave
# Number of Docks: 29
# Available Docks: 24
# Last Communication: 2016-05-25 16:16:18
# =============================================
# Station ID: 3244
# Station Name: University Pl & E 8 St
# Number of Docks: 31
# Available Docks: 22
# Last Communication: 2016-05-25 16:17:51
# =============================================
# Station ID: 3246
# Station Name: Montague St & Clinton St
# Number of Docks: 39
# Available Docks: 32
# Last Communication: 2016-05-25 16:17:45
# =============================================
# Station ID: 3248
# Station Name: LPI Facility
# Number of Docks: 0
# Available Docks: 0
# Last Communication: 2016-04-12 08:02:03
# =============================================
# Station ID: 3249
# Station Name: Verona Pl & Fulton St
# Number of Docks: 15
# Available Docks: 13
# Last Communication: 2016-05-25 16:17:35
# =============================================
# Station ID: 3254
# Station Name: Soissons Landing
# Number of Docks: 29
# Available Docks: 29
# Last Communication: 2016-05-25 16:17:37
# =============================================
# Station ID: 3255
# Station Name: 8 Ave & W 31 St
# Number of Docks: 43
# Available Docks: 11
# Last Communication: 2016-05-25 16:18:02
# =============================================

# %% [markdown]
# We can, of course, transform the results back into a DataFrame (see below) or we can use the data directly from the rows object (which is a tuple, containing one dictionary object for each line of the results).

# %%
import pandas as pd

cur = con.cursor(mdb.cursors.DictCursor)
cur.execute("SELECT * FROM citibike.Docks")
rows = cur.fetchall()
df_from_sql = pd.DataFrame(list(rows))
df_from_sql
# Out:
#      available_docks                date  number_of_docks  station_id  \
# 0                 36 2016-05-25 16:15:54               39          72
# 1                  8 2016-05-25 16:18:45               33          79
# 2                 24 2016-05-25 16:16:57               27          82
# 3                 32 2016-05-25 16:18:53               62          83
# 4                 35 2016-05-25 16:18:45               39         116
# 5                 12 2016-05-25 16:17:33               19         119
# 6                 12 2016-05-25 16:15:57               19         120
# 7                 27 2016-05-25 16:19:11               31         127
# 8                  4 2016-05-25 16:17:53               30         128
# 9                 11 2016-05-25 16:17:26               46         137
# 10                24 2016-05-25 16:16:44               24         143
# 11                16 2016-05-25 16:15:29               19         144
# 12                26 2016-05-25 16:15:43               39         146
# 13                 2 2016-05-25 16:19:12               33         147
# 14                19 2016-05-25 16:18:51               31         150
# 15                32 2016-05-25 16:17:48               33         151
# 16                12 2016-05-25 16:18:57               29         152
# 17                24 2016-05-25 16:15:45               55         153
# 18                16 2016-05-25 16:19:06               23         157
# 19                28 2016-05-25 16:18:12               35         161
# 20                27 2016-05-25 16:18:39               47         164
# 21                41 2016-05-25 16:18:08               45         167
# 22                30 2016-05-25 16:19:08               47         168
# 23                29 2016-05-25 16:18:50               51         173
# 24                28 2016-05-25 16:19:10               30         174
# 25                30 2016-05-25 16:17:44               45         195
# 26                 4 2016-05-25 16:18:46               28         212
# 27                23 2016-05-25 16:19:11               23         216
# 494               14 2016-05-25 16:17:10               31        3235
# 495               32 2016-05-25 16:19:02               33        3236
# 496                8 2016-05-25 16:17:37               25        3237
# 497               35 2016-05-25 16:18:16               37        3238
# 498               10 2016-05-25 16:17:32               19        3241
# 499               29 2016-05-25 16:17:10               39        3242
# 500               24 2016-05-25 16:16:18               29        3243
# 501               22 2016-05-25 16:17:51               31        3244
# 502               32 2016-05-25 16:17:45               39        3246
# 503                0 2016-04-12 08:02:03                0        3248
# 504               13 2016-05-25 16:17:35               15        3249
# 505               29 2016-05-25 16:17:37               29        3254
# 506               11 2016-05-25 16:18:02               43        3255
#
#                         station_name  bikes_taken
# 0                   W 52 St & 11 Ave            3
# 1           Franklin St & W Broadway           25
# 2             St James Pl & Pearl St            3
# 3      Atlantic Ave & Fort Greene Pl           30
# 4                    W 17 St & 8 Ave            4
# 5           Park Ave & St Edwards St            7
# 6        Lexington Ave & Classon Ave            7
# 7              Barrow St & Hudson St            4
# 8           MacDougal St & Prince St           26
# 9              E 56 St & Madison Ave           35
# 10         Clinton St & Joralemon St            0
# 11               Nassau St & Navy St            3
# 12              Hudson St & Reade St           13
# 13          Greenwich St & Warren St           31
# 14                 E 2 St & Avenue C           12
# 15          Cleveland Pl & Spring St            1
# 16             Warren St & Church St           17
# 17                   E 40 St & 5 Ave           31
# 18           Henry St & Atlantic Ave            7
# 19             LaGuardia Pl & W 3 St            7
# 20                   E 47 St & 2 Ave           20
# 21                   E 39 St & 3 Ave            4
# 22                   W 18 St & 6 Ave           17
# 23                Broadway & W 49 St           22
# 24                   E 25 St & 1 Ave            2
# 25             Liberty St & Broadway           15
# 26           W 16 St & The High Line           24
# 27   Columbia Heights & Cranberry St            0
# 28                     Old Fulton St           14
# 29                   W 13 St & 7 Ave            5
# ..                               ...          ...
# 477                  Christ Hospital            5
# 478                   Van Vorst Park            7
# 479                 Essex Light Rail           10
# 480                      Central Ave            3
# 481                    Columbia Park            7
# 482                     Bayside Park            5
# 483                5 Corners Library            1
# 484                   47 Ave & 31 St           21
# 485          Hanson Pl & St Felix St           24
# 486                  E 55 St & 3 Ave           36
# 487              W 13 St & Hudson St           27
# 488            Baldwin at Montgomery            4
# 489      W 82 St & Central Park West            9
# 490               Penn Station Valet            1
# 491               E 67 St & Park Ave            5
# 492              Bond St & Fulton St           26
# 493                  E 48 St & 5 Ave           16
# 494            E 41 St & Madison Ave           17
# 495               W 42 St & Dyer Ave            1
# 496                   21 St & 41 Ave           17
# 497                  E 80 St & 2 Ave            2
# 498         Monroe St & Tompkins Ave            9
# 499       Schermerhorn St & Court St           10
# 500                  E 58 St & 1 Ave            5
# 501           University Pl & E 8 St            9
# 502         Montague St & Clinton St            7
# 503                     LPI Facility            0
# 504            Verona Pl & Fulton St            2
# 505                 Soissons Landing            0
# 506                  8 Ave & W 31 St           32
#
# [507 rows x 6 columns]

# %% [markdown]
# Finally, let's close our database connection.

# %%
con.close()

# %%
df_from_sql.to_excel("citibike.xls")
df_from_sql.to_csv("citibike.csv")
