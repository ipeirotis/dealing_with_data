# %% [markdown]
# ## SQL Queries

# %%
# %reload_ext sql

# %% [markdown]
# To connect to our database, we issue the following command:
#
# `%sql mysql://username:password@hostname:port/database_name`
#
# For example, to connect to your IMDB database:

# %%
# %sql mysql://root:dwdstudent2015@localhost:3306/imdb?charset=utf8
# Out:
# 'Connected: root@imdb'

# %% [markdown]
# To enter a multiline SQL statement using the iPython extension, we use the `%%sql` command at the beginning of the cell.

# %% [markdown]
# ### SELECT Queries (IMDB database)

# %% [markdown]
# Let's connect to the IMDB database first.

# %%
# %sql mysql://root:dwdstudent2015@localhost:3306/imdb?charset=utf8
# Out:
# 'Connected: root@imdb'

# %%
# %sql USE imdb;
# Out:
# 0 rows affected.
# []

# %% [markdown]
# #### Find all movie titles with id less than 100.

# %%
# %%sql
# SELECT *
# FROM movies
# WHERE id<100
# Out:
# 96 rows affected.
# [(0, '#28', 2002, None),
#  (1, '#7 Train: An Immigrant Journey, The', 2000, None),
#  (2, '$', 1971, 6.4),
#  (3, '$1,000 Reward', 1913, None),
#  (4, '$1,000 Reward', 1915, None),
#  (5, '$1,000 Reward', 1923, None),
#  (6, '$1,000,000 Duck', 1971, 5.0),
#  (7, '$1,000,000 Reward, The', 1920, None),
#  (8, '$10,000 Under a Pillow', 1921, None),
#  (9, '$100,000', 1915, None),
#  (10, '$100,000 Pyramid, The', 2001, None),
#  (11, '$1000 a Touchdown', 1939, 6.7),
#  (12, '$20,000 Carat, The', 1913, None),
#  (13, '$21 a Day Once a Month', 1941, None),
#  (14, '$2500 Bride, The', 1912, None),
#  (15, '$30', 1999, 7.5),
#  (16, '$30,000', 1920, None),
#  (17, '$300 y tickets', 2002, None),
#  (18, '$40,000', 1996, 9.6),
#  (19, '$5,000 Reward', 1918, None),
#  (20, '$5,000,000 Counterfeiting Plot, The', 1914, None),
#  (21, '$5.15/Hr.', 2004, None),
#  (22, '$5.20 an Hour Dream, The', 1980, None),
#  (23, '$50,000 Challenge, The', 1989, None),
#  (24, '$50,000 Climax Show, The', 1975, 2.6),
#  (25, '$50,000 Jewel Theft, The', 1915, None),
#  (26, '$50,000 Reward', 1924, None),
#  (28, '$500 Reward, The', 1911, None),
#  (29, '$500,000 Reward', 1911, None),
#  (31, '$pent', 2000, 4.3),
#  (32, '$ucces Part One', 1986, None),
#  (33, '$windle', 2002, 5.4),
#  (34, '& frres', 2000, None),
#  (35, "''Bear'' Facts, The", 1914, None),
#  (36, "'15'", 2002, 6.8),
#  (37, "'24-25' ne vozvrashchayetsya", 1968, None),
#  (38, "'38", 1987, 6.7),
#  (39, "'42", 1951, None),
#  (40, "'49, un souffle de colre", 1996, None),
#  (41, "'49-'17", 1917, 5.8),
#  (42, "'60s Pop Rock Reunion", 2004, None),
#  (43, "'60s, The", 1999, None),
#  (44, "'68", 1988, 5.5),
#  (45, "'70s Celebration: The Beat Is Back, A", 1993, None),
#  (46, "'70s: The Decade That Changed Television, The", 2000, None),
#  (47, "'88 Dodge Aries", 2002, None),
#  (48, "'93 jie tou ba wang", 1993, None),
#  (49, "'94 du bi dao zhi qing", 1994, 5.7),
#  (50, "'?' Motorist, The", 1906, 6.8),
#  (51, "'A'", 1965, 7.1),
#  (52, "'A' gai waak", 1983, 7.2),
#  (53, "'A' gai waak juk jaap", 1987, 7.2),
#  (54, "'Abbot' and 'Cresceus' Race, The", 1901, None),
#  (55, "'Akasaka no shimai' yori: yoru no wada", 1960, None),
#  (56, "'Amphitrite', The", 1897, None),
#  (57, "'Ang Galing galing mo, Babes'", 2002, None),
#  (58, "'Arriet's Baby", 1913, None),
#  (59, "'Arry and 'Arriet's Evening Out", 1909, None),
#  (60, "'Arry on the Steamboat", 1901, None),
#  (61, "'As se hizo' - Torremolinos 73", 2003, None),
#  (62, "'Babicky dobjejte presne!'", 1983, 5.6),
#  (63, "'Bad Buck' of Santa Ynez", 1915, None),
#  (64, "'Bats' Abound", 1999, None),
#  (65, "'Belle de Varsovie, La'", 1993, None),
#  (66, "'Betty Bee' (sopravvivere d'arte)", 1999, None),
#  (67, "'Billy Elliot' Boy, The", 2001, None),
#  (68, "'Borovo' Institut", 1984, None),
#  (69, "'Breaker' Morant", 1980, 7.9),
#  (70, "'Brennus', Le", 1897, None),
#  (71, "'Broadway Melody of 1940'", 1940, 7.1),
#  (72, "'Bullitt': Steve McQueen's Commitment to Reality", 1968, 6.6),
#  (73, "'burbs, The", 1989, 5.9),
#  (74, "'C' Word, The", 1993, None),
#  (76, "'Cat and Mouse' at the Home", 1983, None),
#  (77, "'Catch Me If You Can': Behind the Camera", 2003, None),
#  (78, "'Columbia'", 1899, None),
#  (79, "'Columbia' and 'Defender' Rounding Stake-Boat", 1899, None),
#  (80, "'Columbia' and 'Shamrock II' Finishing Second Race", 1901, None),
#  (81, "'Columbia' and 'Shamrock II': Jockeying and Starting", 1901, None),
#  (82, "'Columbia' and 'Shamrock II': Start of Second Race", 1901, None),
#  (83, "'Columbia' and 'Shamrock II': Starting in the Third Race", 1901, None),
#  (84, "'Columbia' and 'Shamrock II': Turning the Outer Stake Boat", 1901, None),
#  (85, "'Columbia' Close to the Wind", 1899, None),
#  (86, "'Columbia' vs. 'Defender'", 1899, None),
#  (87, "'Columbia' Winning the Cup", 1899, 3.6),
#  (88, "'Columbia' Winning the Cup (1901/I)", 1901, None),
#  (89, "'Columbia' Winning the Cup (1901/II)", 1901, None),
#  (90, "'Corsair', The", 1899, None),
#  (91, "'Courageous', O", 1932, None),
#  (93, "'Courier'", 1900, None),
#  (94, "'Crocodile' Dundee II", 1988, 4.9),
#  (95, "'Cross the Mexican Line", 1914, None),
#  (96, "'Den vide verden's billedbog nr. 1", 1938, None),
#  (97, "'Deutschland' Leaving New York at Full Speed (with Prince Henry of Prussia)", 1902, None),
#  (98, "'Diamond S' Ranch, The", 1912, None),
#  (99, "'Dikke Bertha' op doortocht in Brussel", 1919, None)]

# %% [markdown]
# #### Find all information about movies that were released before 1895 (excl)

# %%
# %%sql
# SELECT *
# FROM movies
# WHERE year<1895

# %% [markdown]
# #### Find all information about movies that were released before 1895 and after 2006 (inclusive)

# %%
# %%sql
# SELECT *
# FROM movies
# WHERE year<=1895 OR year>=2006

# %% [markdown]
# #### Find all information about movies released between 1895 and 1898 (excl)

# %%
# %%sql
# SELECT *
# FROM movies
# WHERE year>1895 AND year<1898

# %% [markdown]
# #### Find all information about *actresses* who are have first name Skyler

# %%
# %%sql
# SELECT *
# FROM actors
# WHERE first_name = 'Skyler' AND gender = 'F';

# %% [markdown]
# #### Find the director ID of Steven Spielberg

# %%
# %%sql
# SELECT id
# FROM directors
# WHERE first_name = 'Steven' AND last_name = 'Spielberg';

# %% [markdown]
# #### Find the director IDs and the first and last names of directors with the last name Spielberg and Hitchcock

# %%
# %%sql
# SELECT id, first_name, last_name
# FROM directors
# WHERE last_name = 'Spielberg' OR last_name = 'Hitchcock';

# %% [markdown]
# #### Find all genres of films and the corresponding probabilities for the director ID that corresponds to Steven Spielberg. Sort the results by probability.

# %%
# %%sql
# SELECT genre, prob
# FROM directors_genres
# WHERE director_id = '75380' # the id of Spielberg FROM above
# ORDER BY prob DESC

# %% [markdown]
# #### Find the id of the movie Schindler's List.

# %%
# %%sql
# SELECT *
# FROM movies
# WHERE name = "Schindler's List"

# %% [markdown]
# #### List all the roles for the movie with id 290070. Sort them alphabetically

# %%
# %%sql
# SELECT *
# FROM roles
# WHERE movie_id = '290070'

# %% [markdown]
# ### SELECT Queries (Facebook database)

# %%
# %sql mysql://root:dwdstudent2015@localhost:3306/facebook?charset=utf8
 
# %sql use facebook;

# %% [markdown]
# #### Find all names of students FROM the Profiles table

# %%
# %%sql
# SELECT name
# FROM Profiles

# %% [markdown]
# #### Get the names and sex of all liberal students (Need to use “backticks” (\`) for attribute names with space in them.)

# %%
# %%sql
# SELECT name, sex
# FROM Profiles
# WHERE `Political Views`='Liberal'

# %% [markdown]
# #### Get the High Schools of the students in the database

# %%
# %%sql
# SELECT `High School`
# FROM Profiles

# %% [markdown]
# #### Find all the possible political views, eliminating duplicate entries

# %%
# %%sql
# SELECT DISTINCT `Political Views`
# FROM Profiles

# %% [markdown]
# #### Find all possible relationship statuses

# %%
# %%sql
# SELECT DISTINCT RelationshipStatus
# FROM RelationshipStatus

# %% [markdown]
# #### Find all possible values for the “status” attribute in Profiles

# %%
# %%sql
# SELECT DISTINCT Status
# FROM Profiles

# %% [markdown]
# #### Find all possible values for the “Residence” attribute in Profiles, eliminating duplicates

# %%
# %%sql
# SELECT DISTINCT Residence
# FROM Profiles

# %% [markdown]
# #### Find all students living in Palladium

# %%
# %%sql
# SELECT *
# FROM Profiles
# WHERE Residence LIKE 'Palladium%'

# %% [markdown]
# #### Find all students who attended Stuyvesant

# %%
# %%sql
# SELECT *
# FROM Profiles
# WHERE `High School` LIKE 'Stuyvesant%'

# %% [markdown]
# #### Find all names that contain a digit

# %%
# %%sql
# SELECT *
# FROM Profiles
# WHERE name REGEXP '[0-9]+'

# %% [markdown]
# #### Find all students with a name that contains a non-letter character, other than \- and \.

# %%
# %%sql
# SELECT *
# FROM Profiles
# WHERE name NOT REGEXP '^[A-z \-\.]+$'

# %% [markdown]
# ### Aggregation Queries (IMDB Database)

# %% [markdown]
# #### Number of movies for each director

# %%
# %%sql
# SELECT director_id, count(*) AS NumberOfMovies
# FROM movies_directors
# GROUP BY director_id;

# %% [markdown]
# #### Rank directors by the number of movies they directed

# %%
# %%sql
# SELECT director_id, count(*) AS NumberOfMovies
# FROM movies_directors
# GROUP BY director_id
# ORDER BY count(*) desc;

# %% [markdown]
# #### Find the number of actors in each movie

# %%
# %%sql
# SELECT movie_id, count(*)
# FROMroles
# GROUP BY movie_id;

# %% [markdown]
# #### Find the movies with more than 100 actors

# %%
# %%sql
# SELECT movie_id, count(*)
# FROM roles
# GROUP BY movie_id
# HAVING count(*) > 100;

# %% [markdown]
# #### Find the most popular genres (basd on the number of movies)

# %%
# %%sql
# SELECT genre, count(*)
# FROM movies_genres
# GROUP BY genre
# ORDER BY count(*) desc

# %% [markdown]
# #### Find the average rank of the movies in the database, per year of release

# %%
# %%sql
# SELECT year, avg(rank)
# FROM movies
# GROUP BY year

# %% [markdown]
# ### Aggregation Queries (Facebook database)

# %% [markdown]
# #### List the number of males and females

# %%
# %%sql
# SELECT sex, count(*)
# FROM profiles
# GROUP BY sex

# %% [markdown]
# #### List the number of students for each political view

# %%
# %%sql
# SELECT `Political Views`, count(*)
# FROM profiles
# GROUP BY `Political Views`

# %% [markdown]
# #### List the number of males and female students for each political view

# %%
# %%sql
# SELECT sex,`Political Views`, count(*)
# FROM profiles
# WHERE sex is not null and `Political Views` is not null
# GROUP BY sex, `Political Views`

# %% [markdown]
# #### List the number of students per each birth year: Use the Year(date) function to get the year value FROM a dateime column List only years that have at least 10 students

# %%
# %%sql
# SELECT YEAR(birthday), count(*)
# FROM profiles
# WHERE birthday is not null
# GROUP BY YEAR(birthday)
# HAVING count(*) > 10

# %% [markdown]
# #### Find the most popular tv shows and books

# %%
# %%sql
# SELECT FavoriteTVShow, count(*)
# FROM FavoriteTVShows
# WHERE FavoriteTVShow is not null
# GROUP BY FavoriteTVShow
# ORDER BY count(*) desc
# #Same for books

# %% [markdown]
# #### Find the number of students in various relationship statuses

# %%
# %%sql
# SELECT RelationshipStatus,count(*)
# FROM RelationshipStatus
# GROUP BY RelationshipStatus

# %% [markdown]
# #### Find the most popular majors (concentrations)

# %%
# %%sql
# SELECT Concentration,count(*) FROM Concentration
# WHERE Concentration is not null
# GROUP BY Concentration
# ORDER BY count(*) desc;

# %% [markdown]
# ### JOINS

# %%
# %%sql
# # List all the movies from year 2000
# SELECT *
# FROM movies M
# WHERE M.year = 2000;

# %%
# %%sql
# # List all the movies from year 2000 and their genres
# SELECT *
# FROM movies M INNER JOIN movies_genres MG ON M.id=MG.movie_id
# WHERE M.year = 2000;
# LIMIT 100l
# Out:
# 12143 rows affected.
# [(1, '#7 Train: An Immigrant Journey, The', 2000, None, 1, 'Short'),
#  (1, '#7 Train: An Immigrant Journey, The', 2000, None, 1, 'Documentary'),
#  (31, '$pent', 2000, 4.3, 31, 'Drama'),
#  (34, '& frres', 2000, None, 34, 'Short'),
#  (46, "'70s: The Decade That Changed Television, The", 2000, None, 46, 'Documentary'),
#  (176, "'N Sync & Britney Spears: Your #1 Video Requests... And More!", 2000, None, 176, 'Short'),
#  (176, "'N Sync & Britney Spears: Your #1 Video Requests... And More!", 2000, None, 176, 'Music'),
#  (178, "'N Sync: 'Ntimate Holiday Special", 2000, None, 178, 'Family'),
#  (178, "'N Sync: 'Ntimate Holiday Special", 2000, None, 178, 'Music'),
#  (180, "'N Sync: Making the Tour", 2000, None, 180, 'Documentary'),
#  (180, "'N Sync: Making the Tour", 2000, None, 180, 'Music'),
#  (298, "'When It Rains'", 2000, None, 298, 'Short'),
#  (347, '...An Incredible Simulation', 2000, None, 347, 'Documentary'),
#  (357, '...At First Sight', 2000, None, 357, 'Short'),
#  (417, '...Lost', 2000, 6.0, 417, 'Short'),
#  (428, '...Or Forever Hold Your Peace', 2000, 6.9, 428, 'Comedy'),
#  (428, '...Or Forever Hold Your Peace', 2000, 6.9, 428, 'Drama'),
#  (455, '...und das ist erst der Anfang', 2000, 5.9, 455, 'Comedy'),
#  (455, '...und das ist erst der Anfang', 2000, 5.9, 455, 'Romance'),
#  (520, '0 texvertices', 2000, None, 520, 'Short'),
#  (530, '007 Racing', 2000, None, 530, 'Animation'),
#  (530, '007 Racing', 2000, None, 530, 'Action'),
#  (530, '007 Racing', 2000, None, 530, 'Adventure'),
#  (533, '008 - Agent wider Willen', 2000, None, 533, 'Comedy'),
#  (540, '01412 pasasingeum', 2000, None, 540, 'Action'),
#  (540, '01412 pasasingeum', 2000, None, 540, 'Fantasy'),
#  (541, '02:06 - Anatomija bola', 2000, None, 541, 'Documentary'),
#  (598, '1. de ei', 2000, None, 598, 'Short'),
#  (598, '1. de ei', 2000, None, 598, 'Drama'),
#  (674, "100 Cameras: Capturing Lars Von Trier's Vision", 2000, None, 674, 'Documentary'),
#  (674, "100 Cameras: Capturing Lars Von Trier's Vision", 2000, None, 674, 'Short'),
#  (682, '100 Girls', 2000, 5.8, 682, 'Comedy'),
#  (696, '100 Jahre FC Bayern', 2000, None, 696, 'Documentary'),
#  (814, '1000 Feet', 2000, None, 814, 'Short'),
#  (869, '101 Rent Boys', 2000, 6.1, 869, 'Documentary'),
#  (870, '101 Reykjavk', 2000, 6.9, 870, 'Comedy'),
#  (874, '101 Ways (The Things a Girl Will Do to Keep Her Volvo)', 2000, None, 874, 'Comedy'),
#  (880, '102 Dalmatians', 2000, 4.7, 880, 'Comedy'),
#  (880, '102 Dalmatians', 2000, 4.7, 880, 'Family'),
#  (881, '102 Dalmatians: Puppies to the Rescue', 2000, None, 881, 'Family'),
#  (881, '102 Dalmatians: Puppies to the Rescue', 2000, None, 881, 'Comedy'),
#  (881, '102 Dalmatians: Puppies to the Rescue', 2000, None, 881, 'Action'),
#  (881, '102 Dalmatians: Puppies to the Rescue', 2000, None, 881, 'Adventure'),
#  (893, '10:10', 2000, 6.1, 893, 'Short'),
#  (901, '10th Kingdom: The Making of an Epic, The', 2000, None, 901, 'Short'),
#  (901, '10th Kingdom: The Making of an Epic, The', 2000, None, 901, 'Documentary'),
#  (916, '11 ottavi', 2000, None, 916, 'Comedy'),
#  (919, '11 Uhr 59', 2000, None, 919, 'Short'),
#  (922, '11* mandamiento, El', 2000, None, 922, 'Short'),
#  (957, '11th & Congress', 2000, None, 957, 'Short'),
#  (989, '12 pasos', 2000, None, 989, 'Short'),
#  (992, '12 Rounds', 2000, None, 992, 'Drama'),
#  (992, '12 Rounds', 2000, None, 992, 'Short'),
#  (1023, '12x12', 2000, None, 1023, 'Drama'),
#  (1023, '12x12', 2000, None, 1023, 'Short'),
#  (1091, '13th Sign, The', 2000, 4.1, 1091, 'Horror'),
#  (1138, '15 das', 2000, 8.3, 1138, 'Comedy'),
#  (1138, '15 das', 2000, 8.3, 1138, 'Short'),
#  (1156, "15' zondergrond", 2000, None, 1156, 'Short'),
#  (1158, '15, rue de bains', 2000, None, 1158, 'Drama'),
#  (1160, '15-Sai: Gakko IV', 2000, 6.5, 1160, 'Drama'),
#  (1220, '18 & Confused', 2000, None, 1220, 'Adult'),
#  (1247, '18 and Nasty 13', 2000, None, 1247, 'Adult'),
#  (1250, '18 and Nasty 16', 2000, None, 1250, 'Adult'),
#  (1251, '18 and Nasty 17', 2000, None, 1251, 'Adult'),
#  (1252, '18 and Nasty 18', 2000, None, 1252, 'Adult'),
#  (1296, '18 cambios', 2000, None, 1296, 'Short'),
#  (1334, '186 Days', 2000, None, 1334, 'Drama'),
#  (1334, '186 Days', 2000, None, 1334, 'Short'),
#  (1351, '19', 2000, 6.8, 1351, 'Drama'),
#  (1367, '1900 UK', 2000, None, 1367, 'Documentary'),
#  (1368, '1900 USA', 2000, None, 1368, 'Documentary'),
#  (1416, '1974', 2000, 4.7, 1416, 'Short'),
#  (1416, '1974', 2000, 4.7, 1416, 'Animation'),
#  (1489, '1st Annual Latin Grammy Awards, The', 2000, None, 1489, 'Music'),
#  (1511, '2 1/2 Minutes of Pleasure', 2000, None, 1511, 'Drama'),
#  (1522, '2 compas, Los', 2000, None, 1522, 'Action'),
#  (1523, '2 Cueball', 2000, None, 1523, 'Family'),
#  (1535, "2 G's & a Key", 2000, 4.4, 1535, 'Action'),
#  (1567, '2 on U', 2000, None, 1567, 'Drama'),
#  (1567, '2 on U', 2000, None, 1567, 'Adventure'),
#  (1567, '2 on U', 2000, None, 1567, 'Short'),
#  (1601, '2. juledag', 2000, 5.5, 1601, 'Short'),
#  (1604, '2.06-Anatomija bola', 2000, None, 1604, 'Documentary'),
#  (1658, '20.13 - Mord im Blitzlicht', 2000, None, 1658, 'Thriller'),
#  (1669, '2000 + 1 stigmes', 2000, None, 1669, 'Drama'),
#  (1673, '2000 Billboard Music Awards, The', 2000, None, 1673, 'Family'),
#  (1673, '2000 Billboard Music Awards, The', 2000, None, 1673, 'Music'),
#  (1674, '2000 Blockbuster Entertainment Awards', 2000, None, 1674, 'Family'),
#  (1674, '2000 Blockbuster Entertainment Awards', 2000, None, 1674, 'Documentary'),
#  (1678, '2000 Latin Grammy Nominees', 2000, None, 1678, 'Music'),
#  (1681, '2000 MTV Movie Awards', 2000, None, 1681, 'Documentary'),
#  (1682, '2000 Much Music Video Music Awards', 2000, None, 1682, 'Music'),
#  (1684, '2000 Nordestes', 2000, 7.9, 1684, 'Documentary'),
#  (1685, '2000 Official World Series', 2000, None, 1685, 'Documentary'),
#  (1712, '2001: A Space Travesty', 2000, 2.5, 1712, 'Comedy'),
#  (1712, '2001: A Space Travesty', 2000, 2.5, 1712, 'Sci-Fi'),
#  (1714, '2001: The Final Breath', 2000, None, 1714, 'Documentary'),
#  (1784, '21', 2000, 6.5, 1784, 'Comedy'),
#  (1784, '21', 2000, 6.5, 1784, 'Drama'),
#  (1784, '21', 2000, 6.5, 1784, 'Romance'),
#  (1802, '21st Annual W.C. Handy Blues Awards', 2000, None, 1802, 'Music'),
#  (1807, '22', 2000, None, 1807, 'Horror'),
#  (1807, '22', 2000, None, 1807, 'Thriller'),
#  (1830, '23 Hours', 2000, None, 1830, 'Action'),
#  (1830, '23 Hours', 2000, None, 1830, 'Thriller'),
#  (1837, '237', 2000, None, 1837, 'Short'),
#  (1853, '24 chasa', 2000, 6.6, 1853, 'Crime'),
#  (1853, '24 chasa', 2000, 6.6, 1853, 'Drama'),
#  (1874, '24 Hours in London', 2000, 3.6, 1874, 'Thriller'),
#  (1925, '24fps', 2000, 4.7, 1925, 'Short'),
#  (1936, '25 de Abril - Uma Aventura Para a Democracia', 2000, None, 1936, 'Documentary'),
#  (1936, '25 de Abril - Uma Aventura Para a Democracia', 2000, None, 1936, 'Short'),
#  (1987, '27 Missing Kisses', 2000, 6.6, 1987, 'Drama'),
#  (1987, '27 Missing Kisses', 2000, 6.6, 1987, 'Comedy'),
#  (1987, '27 Missing Kisses', 2000, 6.6, 1987, 'Family'),
#  (1987, '27 Missing Kisses', 2000, 6.6, 1987, 'Romance'),
#  (1999, '28 Days', 2000, 6.0, 1999, 'Drama'),
#  (2024, '29th Annual Juno Awards, The', 2000, None, 2024, 'Music'),
#  (2034, '2gether', 2000, None, 2034, 'Drama'),
#  (2034, '2gether', 2000, None, 2034, 'Comedy'),
#  (2034, '2gether', 2000, None, 2034, 'Music'),
#  (2047, '2nd Annual TV Guide Awards', 2000, None, 2047, 'Family'),
#  (2062, '23', 2000, None, 2062, 'Short'),
#  (2085, '3 cuernos de chivo', 2000, None, 2085, 'Action'),
#  (2097, '3 Engel fr Charlie (2000/II)', 2000, None, 2097, 'Adult'),
#  (2123, '3 Minute Wonder', 2000, None, 2123, 'Short'),
#  (2150, '3 Strikes', 2000, 3.6, 2150, 'Comedy'),
#  (2153, '3 Tage 44', 2000, None, 2153, 'Short'),
#  (2160, '3 weken feest?!', 2000, None, 2160, 'Documentary'),
#  (2183, '3-D Geisterjger', 2000, None, 2183, 'Documentary'),
#  (2184, '3-D Megahaie', 2000, None, 2184, 'Documentary'),
#  (2185, '3-D Safari', 2000, None, 2185, 'Documentary'),
#  (2207, '30 Frames a Second: The WTO in Seattle', 2000, 6.2, 2207, 'Documentary'),
#  (2225, '30 Views of Mt. Mayon', 2000, None, 2225, 'Documentary'),
#  (2225, '30 Views of Mt. Mayon', 2000, None, 2225, 'Short'),
#  (2251, "3000 mtres d'altitudes", 2000, None, 2251, 'Animation'),
#  (2251, "3000 mtres d'altitudes", 2000, None, 2251, 'Short'),
#  (2280, '31st NAACP Image Awards', 2000, None, 2280, 'Family'),
#  (2300, '336 PEK', 2000, None, 2300, 'Drama'),
#  (2385, '3D', 2000, None, 2385, 'Short'),
#  (2388, '3D Halloween', 2000, None, 2388, 'Drama'),
#  (2427, '4 Finger Club 12, The', 2000, None, 2427, 'Adult'),
#  (2455, '4 P.M.', 2000, 6.0, 2455, 'Short'),
#  (2455, '4 P.M.', 2000, 6.0, 2455, 'Drama'),
#  (2465, '4 Vertigo', 2000, None, 2465, 'Short'),
#  (2467, '4 Young Barents Dox', 2000, None, 2467, 'Documentary'),
#  (2511, '405', 2000, 6.7, 2511, 'Short'),
#  (2511, '405', 2000, 6.7, 2511, 'Comedy'),
#  (2511, '405', 2000, 6.7, 2511, 'Thriller'),
#  (2511, '405', 2000, 6.7, 2511, 'Action'),
#  (2514, '40th Anniversary Celebration of Coronation Street', 2000, None, 2514, 'Documentary'),
#  (2521, '41 Shots', 2000, None, 2521, 'Short'),
#  (2537, '42K', 2000, 7.1, 2537, 'Action'),
#  (2537, '42K', 2000, 7.1, 2537, 'Adventure'),
#  (2537, '42K', 2000, 7.1, 2537, 'Comedy'),
#  (2537, '42K', 2000, 7.1, 2537, 'Horror'),
#  (2539, '42nd Annual Grammy Awards, The', 2000, None, 2539, 'Music'),
#  (2554, '44', 2000, None, 2554, 'Short'),
#  (2554, '44', 2000, None, 2554, 'Mystery'),
#  (2554, '44', 2000, None, 2554, 'Thriller'),
#  (2570, '451 Forte', 2000, None, 2570, 'Drama'),
#  (2735, '500 Anos de Escravido', 2000, None, 2735, 'Short'),
#  (2748, '50CC', 2000, 7.4, 2748, 'Family'),
#  (2748, '50CC', 2000, 7.4, 2748, 'Action'),
#  (2748, '50CC', 2000, 7.4, 2748, 'Romance'),
#  (2748, '50CC', 2000, 7.4, 2748, 'Short'),
#  (2770, '52nd Annual Primetime Emmy Awards, The', 2000, None, 2770, 'Family'),
#  (2788, '54th Annual Tony Awards, The', 2000, None, 2788, 'Music'),
#  (2788, '54th Annual Tony Awards, The', 2000, None, 2788, 'Documentary'),
#  (2843, '6 auf See', 2000, None, 2843, 'Comedy'),
#  (2855, '6,000 Miles from Hollywood', 2000, None, 2855, 'Comedy'),
#  (2855, '6,000 Miles from Hollywood', 2000, None, 2855, 'Drama'),
#  (2912, '66 AD: The Last Revolt', 2000, None, 2912, 'Documentary'),
#  (2959, '6th Annual Screen Actors Guild Awards', 2000, None, 2959, 'Family'),
#  (2964, '6th Day, The', 2000, 5.9, 2964, 'Action'),
#  (2964, '6th Day, The', 2000, 5.9, 2964, 'Sci-Fi'),
#  (2964, '6th Day, The', 2000, 5.9, 2964, 'Thriller'),
#  (2966, '7 1/2 Floor Orientation, The', 2000, None, 2966, 'Comedy'),
#  (2966, '7 1/2 Floor Orientation, The', 2000, None, 2966, 'Short'),
#  (2976, '7 ddssyndene, De', 2000, 8.3, 2976, 'Drama'),
#  (3003, '7 vies du docteur Laux, Les', 2000, None, 3003, 'Thriller'),
#  (3039, '72nd Annual Academy Awards Pre-Show', 2000, None, 3039, 'Family'),
#  (3040, '72nd Annual Academy Awards, The', 2000, None, 3040, 'Family'),
#  (3040, '72nd Annual Academy Awards, The', 2000, None, 3040, 'Documentary'),
#  (3041, '7337', 2000, 3.0, 3041, 'Short'),
#  (3041, '7337', 2000, 3.0, 3041, 'Fantasy'),
#  (3041, '7337', 2000, 3.0, 3041, 'Horror'),
#  (3041, '7337', 2000, 3.0, 3041, 'Mystery'),
#  (3048, '75 Degrees in July', 2000, 4.8, 3048, 'Drama'),
#  (3054, '76-89-03', 2000, 6.7, 3054, 'Comedy'),
#  (3058, '77 Steps', 2000, None, 3058, 'Short'),
#  (3073, '7mo ngel, El', 2000, None, 3073, 'Action'),
#  (3073, '7mo ngel, El', 2000, None, 3073, 'Horror'),
#  (3073, '7mo ngel, El', 2000, None, 3073, 'Mystery'),
#  (3087, '7Up 2000', 2000, None, 3087, 'Documentary'),
#  (3124, '80 kilos suicidas', 2000, None, 3124, 'Action'),
#  (3130, '80-rs fdselsdagen', 2000, None, 3130, 'Comedy'),
#  (3130, '80-rs fdselsdagen', 2000, None, 3130, 'Short'),
#  (3143, '82', 2000, None, 3143, 'Comedy'),
#  (3143, '82', 2000, None, 3143, 'Short'),
#  (3239, '92 and Still Banging', 2000, None, 3239, 'Adult'),
#  (3245, '92,8 MHz - drmmar i sder', 2000, None, 3245, 'Documentary'),
#  (3284, '990714.com', 2000, None, 3284, 'Mystery'),
#  (3284, '990714.com', 2000, None, 3284, 'Sci-Fi'),
#  (3284, '990714.com', 2000, None, 3284, 'Horror'),
#  (3294, '9mm of Love', 2000, 6.6, 3294, 'Short'),
#  (3294, '9mm of Love', 2000, 6.6, 3294, 'Crime'),
#  (3294, '9mm of Love', 2000, 6.6, 3294, 'Comedy'),
#  (3294, '9mm of Love', 2000, 6.6, 3294, 'Romance'),
#  (3312, '@MTV with Eve', 2000, None, 3312, 'Music'),
#  (3313, '@MTV with Hot Boys Feat, Juvenile', 2000, None, 3313, 'Music'),
#  (3314, '@MTV with Smashing Pumpkins', 2000, None, 3314, 'Music'),
#  (3316, '[Insert Title Here]', 2000, None, 3316, 'Short'),
#  (3395, 'A galope tendido', 2000, 5.6, 3395, 'Comedy'),
#  (3395, 'A galope tendido', 2000, 5.6, 3395, 'Western'),
#  (3422, 'A la carte', 2000, None, 3422, 'Short'),
#  (3502, 'A propsito de Buuel', 2000, 7.5, 3502, 'Documentary'),
#  (3516, 'A ruota libera', 2000, 3.7, 3516, 'Comedy'),
#  (3539, 'A Tale of two Cities - Eine Erzhlung von zwei Stdten', 2000, None, 3539, 'Documentary'),
#  (3589, 'A&E Biography: Admiral Richard Byrd', 2000, None, 3589, 'Documentary'),
#  (3590, "A&E Biography: Adolf Eichmann - Hitler's Master of Death", 2000, None, 3590, 'Documentary'),
#  (3595, 'A&E Biography: Allan Pinkerton - The Original Private Eye', 2000, None, 3595, 'Documentary'),
#  (3599, 'A&E Biography: Andrew Cunanan', 2000, None, 3599, 'Documentary'),
#  (3600, 'A&E Biography: Andrew Jackson - A Man for the People', 2000, None, 3600, 'Documentary'),
#  (3608, 'A&E Biography: Arnold Schwarzenegger - Flex Appeal', 2000, None, 3608, 'Documentary'),
#  (3612, 'A&E Biography: Ayatollah Khomeini - Holy Terror', 2000, None, 3612, 'Documentary'),
#  (3618, 'A&E Biography: Benedict Arnold', 2000, None, 3618, 'Documentary'),
#  (3620, 'A&E Biography: Betty Boop', 2000, None, 3620, 'Documentary'),
#  (3622, 'A&E Biography: Bill Gates - Sultan of Software', 2000, None, 3622, 'Documentary'),
#  (3625, 'A&E Biography: Bloomingdales', 2000, None, 3625, 'Documentary'),
#  (3627, 'A&E Biography: Bonnie & Clyde', 2000, None, 3627, 'Documentary'),
#  (3628, 'A&E Biography: Brigham Young - Architect of Faith', 2000, None, 3628, 'Documentary'),
#  (3633, 'A&E Biography: Caligula - Reign of Madness', 2000, None, 3633, 'Documentary'),
#  (3636, "A&E Biography: Casanova - World's Greatest Lover", 2000, None, 3636, 'Documentary'),
#  (3638, 'A&E Biography: Charles Atlas - Modern Day Hercules', 2000, None, 3638, 'Documentary'),
#  (3641, 'A&E Biography: Charles Lindbergh - Against the Wind', 2000, None, 3641, 'Documentary'),
#  (3645, 'A&E Biography: Chiang Kai-Shek', 2000, None, 3645, 'Documentary'),
#  (3646, 'A&E Biography: Christopher Columbus - Explorer of the New World', 2000, None, 3646, 'Documentary'),
#  (3653, "A&E Biography: Colonel Sanders - America's Chicken King", 2000, None, 3653, 'Documentary'),
#  (3658, 'A&E Biography: Crazy Horse', 2000, None, 3658, 'Documentary'),
#  (3663, 'A&E Biography: Dave Thomas - Made to Order', 2000, None, 3663, 'Documentary'),
#  (3668, 'A&E Biography: Donald Trump - Master of the Deal', 2000, None, 3668, 'Documentary'),
#  (3670, 'A&E Biography: Dr. Joyce Brothers', 2000, None, 3670, 'Documentary'),
#  (3671, 'A&E Biography: Dr. Laura Schlessinger - Tough Talker', 2000, None, 3671, 'Documentary'),
#  (3672, 'A&E Biography: Dr. Ruth Westheimer', 2000, None, 3672, 'Documentary'),
#  (3674, 'A&E Biography: Dutch Schultz - Menace to Society', 2000, None, 3674, 'Documentary'),
#  (3685, 'A&E Biography: Estee Lauder - The Sweet Smell of Success', 2000, None, 3685, 'Documentary'),
#  (3690, 'A&E Biography: Fatty Arbuckle - Betrayed by Hollywood', 2000, None, 3690, 'Documentary'),
#  (3691, 'A&E Biography: Flash Gordon - Journey to Greatness', 2000, None, 3691, 'Documentary'),
#  (3693, 'A&E Biography: Frank Costello - Prime Minister of the Underworld', 2000, None, 3693, 'Documentary'),
#  (3694, 'A&E Biography: Frank Serpico', 2000, None, 3694, 'Documentary'),
#  (3697, 'A&E Biography: Gary Gilmore - A Fight to Die', 2000, None, 3697, 'Documentary'),
#  (3699, "A&E Biography: George Armstrong Custer - America's Golden Cavalier", 2000, None, 3699, 'Documentary'),
#  (3701, 'A&E Biography: George W. Bush - Son Also Rises', 2000, None, 3701, 'Documentary'),
#  (3703, 'A&E Biography: Geronimo', 2000, None, 3703, 'Documentary'),
#  (3712, 'A&E Biography: Henry VIII', 2000, None, 3712, 'Documentary'),
#  (3713, 'A&E Biography: Hercules - Power of the Gods', 2000, None, 3713, 'Documentary'),
#  (3715, 'A&E Biography: Hirohito', 2000, None, 3715, 'Documentary'),
#  (3719, 'A&E Biography: Huey Long - The King Fish', 2000, None, 3719, 'Documentary'),
#  (3722, 'A&E Biography: Ivan the Terrible', 2000, None, 3722, 'Documentary'),
#  (3723, 'A&E Biography: J. Pierpont Morgan', 2000, None, 3723, 'Documentary'),
#  (3724, 'A&E Biography: J. Robert Oppenheimer - Father of the Atomic Bomb', 2000, None, 3724, 'Documentary'),
#  (3725, 'A&E Biography: J.C. Penney - Main Street Millionaire', 2000, None, 3725, 'Documentary'),
#  (3726, 'A&E Biography: J.W. Marriott - Host to the World', 2000, None, 3726, 'Documentary'),
#  (3730, 'A&E Biography: James Bond - The Secret Life of 007', 2000, None, 3730, 'Documentary'),
#  (3752, 'A&E Biography: John Wilkes Booth', 2000, None, 3752, 'Documentary'),
#  (3756, 'A&E Biography: Joseph Kennedy Sr. - Father of an American Dynasty', 2000, None, 3756, 'Documentary'),
#  (3764, 'A&E Biography: King George III - Mad or Maligned?', 2000, None, 3764, 'Documentary'),
#  (3765, "A&E Biography: Lana Turner - Hollywood's Screen Siren", 2000, None, 3765, 'Documentary'),
#  (3768, 'A&E Biography: Lee Harvey Oswald', 2000, None, 3768, 'Documentary'),
#  (3769, 'A&E Biography: Leif Ericsson - Voyages of a Viking', 2000, None, 3769, 'Documentary'),
#  (3772, 'A&E Biography: Lewis & Clark - Explorers of the New Frontier', 2000, None, 3772, 'Documentary'),
#  (3775, 'A&E Biography: Louis Lepke', 2000, None, 3775, 'Documentary'),
#  (3778, 'A&E Biography: Lucrezia Borgia - Pretty Poison', 2000, None, 3778, 'Documentary'),
#  (3779, 'A&E Biography: Lyndon Johnson - Triumph and Tragedy', 2000, None, 3779, 'Documentary'),
#  (3781, 'A&E Biography: Malcolm Forbes - High Flying Millionaire', 2000, None, 3781, 'Documentary'),
#  (3785, 'A&E Biography: Marconi - Whisper in the Air', 2000, None, 3785, 'Documentary'),
#  (3786, 'A&E Biography: Marie Antoinette - Tragic Queen', 2000, None, 3786, 'Documentary'),
#  (3788, 'A&E Biography: Marlene - Inventing Dietrich', 2000, None, 3788, 'Documentary'),
#  (3792, 'A&E Biography: Mary Magdalene - The Hidden Apostle', 2000, None, 3792, 'Documentary'),
#  (3794, 'A&E Biography: Masters & Johnson - The Science of Sex', 2000, None, 3794, 'Documentary'),
#  (3796, 'A&E Biography: Mayflower Madam - The Sidney Biddle Barrows Story', 2000, None, 3796, 'Documentary'),
#  (3797, 'A&E Biography: Melvin Purvis - The Man Who Got Dillinger', 2000, None, 3797, 'Documentary'),
#  (3798, 'A&E Biography: Men in Space - From Goddard to Armstrong', 2000, None, 3798, 'Documentary'),
#  (3799, 'A&E Biography: Meyer Lansky', 2000, None, 3799, 'Documentary'),
#  (3808, 'A&E Biography: Napoleon Bonaparte - The Glory of France', 2000, None, 3808, 'Documentary'),
#  (3809, 'A&E Biography: Neiman Marcus - The Last of the Merchant Kings', 2000, None, 3809, 'Documentary'),
#  (3822, 'A&E Biography: Peter Graves - Mission Accomplished', 2000, None, 3822, 'Documentary'),
#  (3823, 'A&E Biography: Peter the Great - The Tyrant Reformer', 2000, None, 3823, 'Documentary'),
#  (3826, 'A&E Biography: Pol Pot - Secret Killer', 2000, None, 3826, 'Documentary'),
#  (3827, 'A&E Biography: Ponce de Leon - The First Conquistador', 2000, None, 3827, 'Documentary'),
#  (3832, 'A&E Biography: R.H. Macy', 2000, None, 3832, 'Documentary'),
#  (3833, 'A&E Biography: Rasputin - The Mad Monk', 2000, None, 3833, 'Documentary'),
#  (3834, 'A&E Biography: Ray Kroc - Fast Food McMillionaire', 2000, None, 3834, 'Documentary'),
#  (3835, 'A&E Biography: Red Baron - Master of the Air', 2000, None, 3835, 'Documentary'),
#  (3836, 'A&E Biography: Redd Foxx - Say It Like It Is', 2000, None, 3836, 'Documentary'),
#  (3837, 'A&E Biography: Richard Branson - The Top of the World', 2000, None, 3837, 'Documentary'),
#  (3840, 'A&E Biography: Richard the Lionheart', 2000, None, 3840, 'Documentary'),
#  (3841, 'A&E Biography: Robert E. Lee', 2000, None, 3841, 'Documentary'),
#  (3845, 'A&E Biography: Roman Polanski - Reflections of Darkness', 2000, None, 3845, 'Documentary'),
#  (3848, 'A&E Biography: Sally Hemings - Redefining History', 2000, None, 3848, 'Documentary'),
#  (3862, 'A&E Biography: Sitting Bull - Chief of the Lakota Nation', 2000, None, 3862, 'Documentary'),
#  (3868, 'A&E Biography: Stephen King - Fear, Fame and Fortune', 2000, None, 3868, 'Documentary'),
#  (3870, 'A&E Biography: Stonewall Jackson', 2000, None, 3870, 'Documentary'),
#  (3874, 'A&E Biography: The Astors - High Society', 2000, None, 3874, 'Documentary'),
#  (3877, 'A&E Biography: The Coors - A Family Brew', 2000, None, 3877, 'Documentary'),
#  (3879, 'A&E Biography: The Flying Wallendas - Legends of the High Wire', 2000, None, 3879, 'Documentary'),
#  (3880, 'A&E Biography: The Gambinos - The First Family of Crime', 2000, None, 3880, 'Documentary'),
#  (3883, 'A&E Biography: The Harlem Globetrotters', 2000, None, 3883, 'Documentary'),
#  (3885, 'A&E Biography: The James Gang - Outlaw Brothers', 2000, None, 3885, 'Documentary'),
#  (3892, 'A&E Biography: The Tiffanys - Mark of Excellence', 2000, None, 3892, 'Documentary'),
#  (3894, 'A&E Biography: The Von Trapp Family - Harmony and Discord', 2000, None, 3894, 'Documentary'),
#  (3895, 'A&E Biography: The Woolworths - Five and Dime Fortune and Failure', 2000, None, 3895, 'Documentary'),
#  (3897, 'A&E Biography: Thomas Edison', 2000, None, 3897, 'Documentary'),
#  (3900, 'A&E Biography: Timothy McVeigh - Soldier of Terror', 2000, None, 3900, 'Documentary'),
#  (3903, 'A&E Biography: Tony Robbins - The Secret of His Success', 2000, None, 3903, 'Documentary'),
#  (3906, 'A&E Biography: Vincent Price - The Versatile Villain', 2000, None, 3906, 'Documentary'),
#  (3911, 'A&E Biography: Woodrow Wilson - Reluctant Warrior', 2000, None, 3911, 'Documentary'),
#  (3981, 'A.P.E. #9', 2000, None, 3981, 'Adventure'),
#  (3981, 'A.P.E. #9', 2000, None, 3981, 'Sci-Fi'),
#  (3981, 'A.P.E. #9', 2000, None, 3981, 'Short'),
#  (3981, 'A.P.E. #9', 2000, None, 3981, 'Thriller'),
#  (4017, 'Aa! Megamisama! The Movie', 2000, 7.8, 4017, 'Animation'),
#  (4017, 'Aa! Megamisama! The Movie', 2000, 7.8, 4017, 'Comedy'),
#  (4017, 'Aa! Megamisama! The Movie', 2000, 7.8, 4017, 'Fantasy'),
#  (4017, 'Aa! Megamisama! The Movie', 2000, 7.8, 4017, 'Romance'),
#  (4110, 'Aagaayam', 2000, None, 4110, 'Musical'),
#  (4117, 'Aaghaaz', 2000, 7.1, 4117, 'Action'),
#  (4117, 'Aaghaaz', 2000, 7.1, 4117, 'Crime'),
#  (4117, 'Aaghaaz', 2000, 7.1, 4117, 'Drama'),
#  (4117, 'Aaghaaz', 2000, 7.1, 4117, 'Romance'),
#  (4299, 'Aanklacht, De', 2000, None, 4299, 'Drama'),
#  (4362, "Aaron Carter: Aaron's Party (Come Get It)", 2000, None, 4362, 'Documentary'),
#  (4365, 'Aaron Jacks Off', 2000, None, 4365, 'Adult'),
#  (4384, "Aaron's Casting Couch", 2000, None, 4384, 'Adult'),
#  (4467, 'Aau fung yee', 2000, None, 4467, 'Horror'),
#  (4491, 'Aazad', 2000, None, 4491, 'Action'),
#  (4539, 'Abandonada', 2000, None, 4539, 'Drama'),
#  (4736, "Abe's Manhood", 2000, 5.1, 4736, 'Short'),
#  (4806, 'Abenteurerin, Die', 2000, None, 4806, 'Short'),
#  (4813, 'Aber schn war es doch', 2000, None, 4813, 'Documentary'),
#  (4815, 'Aberdeen', 2000, 7.3, 4815, 'Drama'),
#  (4998, 'Aborto de la naturaleza', 2000, None, 4998, 'Documentary'),
#  (4998, 'Aborto de la naturaleza', 2000, None, 4998, 'Short'),
#  (5013, 'About Adam', 2000, 6.5, 5013, 'Comedy'),
#  (5013, 'About Adam', 2000, 6.5, 5013, 'Romance'),
#  (5045, 'About Vivien', 2000, None, 5045, 'Short'),
#  (5057, 'Above Suspicion', 2000, 5.7, 5057, 'Drama'),
#  (5126, 'Abschied - Brechts letzter Sommer', 2000, 5.6, 5126, 'Drama'),
#  (5185, 'Absolument cinma: Juliette Binoche', 2000, None, 5185, 'Documentary'),
#  (5185, 'Absolument cinma: Juliette Binoche', 2000, None, 5185, 'Short'),
#  (5296, 'Abuzer Kadayif', 2000, 6.4, 5296, 'Musical'),
#  (5296, 'Abuzer Kadayif', 2000, 6.4, 5296, 'Drama'),
#  (5296, 'Abuzer Kadayif', 2000, 6.4, 5296, 'Comedy'),
#  (5337, 'Academy of Country Music Awards', 2000, None, 5337, 'Music'),
#  (5358, 'Acapulco Black Film Festival', 2000, None, 5358, 'Documentary'),
#  (5450, 'Accidents', 2000, None, 5450, 'Short'),
#  (5512, "Accueil de jour, L'", 2000, 8.6, 5512, 'Documentary'),
#  (5512, "Accueil de jour, L'", 2000, 8.6, 5512, 'Short'),
#  (5643, "Achilles' Love", 2000, 5.3, 5643, 'Comedy'),
#  (5643, "Achilles' Love", 2000, 5.3, 5643, 'Romance'),
#  (5654, 'Achoti', 2000, None, 5654, 'Documentary'),
#  (5731, 'Acidente Geogrfico', 2000, None, 5731, 'Short'),
#  (5731, 'Acidente Geogrfico', 2000, None, 5731, 'Documentary'),
#  (5778, 'Acratas', 2000, None, 5778, 'Documentary'),
#  (5789, 'Acrobacias del corazn', 2000, 3.1, 5789, 'Drama'),
#  (5789, 'Acrobacias del corazn', 2000, 3.1, 5789, 'Romance'),
#  (5791, 'Acrobatas da Pedra Rolada, Os', 2000, None, 5791, 'Documentary'),
#  (5797, 'Acrobatic Sex Cult, The', 2000, None, 5797, 'Short'),
#  (5833, 'Across the Line', 2000, 5.3, 5833, 'Drama'),
#  (5833, 'Across the Line', 2000, 5.3, 5833, 'Thriller'),
#  (5887, 'Act Without Words I', 2000, None, 5887, 'Short'),
#  (5888, 'Act Without Words II', 2000, None, 5888, 'Short'),
#  (5900, 'Acteurs, Les', 2000, 4.8, 5900, 'Comedy'),
#  (5938, 'Action Man: Operation Extreme', 2000, None, 5938, 'Action'),
#  (6061, 'Acstico MTV: Capital Inicial', 2000, None, 6061, 'Music'),
#  (6073, 'Ad libitum 1. Angliyski duet alla turca', 2000, None, 6073, 'Short'),
#  (6074, 'Ad libitum 2. Rechitativ na zavistnika', 2000, None, 6074, 'Short'),
#  (6075, 'Ad libitum 3. Balada za dvama priyateli i gayda', 2000, None, 6075, 'Short'),
#  (6076, 'Ad libitum 4. Variatzii na graf dyo Burbulon', 2000, None, 6076, 'Short'),
#  (6104, 'Adagio', 2000, 6.1, 6104, 'Animation'),
#  (6104, 'Adagio', 2000, 6.1, 6104, 'Short'),
#  (6104, 'Adagio', 2000, 6.1, 6104, 'Musical'),
#  (6104, 'Adagio', 2000, 6.1, 6104, 'Drama'),
#  (6104, 'Adagio', 2000, 6.1, 6104, 'Mystery'),
#  (6148, 'Adam and Steve', 2000, None, 6148, 'Short'),
#  (6148, 'Adam and Steve', 2000, None, 6148, 'Drama'),
#  (6217, 'Adanggaman', 2000, 6.0, 6217, 'Drama'),
#  (6233, 'Adavi Chukka', 2000, None, 6233, 'Action'),
#  (6233, 'Adavi Chukka', 2000, None, 6233, 'Drama'),
#  (6265, 'Addicted to Murder 3: Blood Lust', 2000, 5.9, 6265, 'Horror'),
#  (6281, 'Addio Lugano bella', 2000, None, 6281, 'Documentary'),
#  (6313, 'Adela', 2000, 6.4, 6313, 'Thriller'),
#  (6468, 'Adis con el corazn', 2000, 6.6, 6468, 'Comedy'),
#  (6468, 'Adis con el corazn', 2000, 6.6, 6468, 'Drama'),
#  (6666, 'Adrian und der Wolf', 2000, 5.3, 6666, 'Short'),
#  (6677, 'Adriana Lecouvreur', 2000, None, 6677, 'Music'),
#  (6677, 'Adriana Lecouvreur', 2000, None, 6677, 'Drama'),
#  (6894, 'Adventures in Wild California', 2000, 7.2, 6894, 'Documentary'),
#  (6894, 'Adventures in Wild California', 2000, 7.2, 6894, 'Short'),
#  (6955, "Adventures of Cinderella's Daughter, The", 2000, None, 6955, 'Family'),
#  (7005, 'Adventures of Handyman, The', 2000, None, 7005, 'Short'),
#  (7005, 'Adventures of Handyman, The', 2000, None, 7005, 'Adventure'),
#  (7005, 'Adventures of Handyman, The', 2000, None, 7005, 'Comedy'),
#  (7075, 'Adventures of Pee Man 3', 2000, None, 7075, 'Adult'),
#  (7099, 'Adventures of Rocky & Bullwinkle, The', 2000, 4.3, 7099, 'Fantasy'),
#  (7099, 'Adventures of Rocky & Bullwinkle, The', 2000, 4.3, 7099, 'Comedy'),
#  (7099, 'Adventures of Rocky & Bullwinkle, The', 2000, 4.3, 7099, 'Adventure'),
#  (7099, 'Adventures of Rocky & Bullwinkle, The', 2000, 4.3, 7099, 'Animation'),
#  (7382, 'Afdaling, De', 2000, None, 7382, 'Drama'),
#  (7382, 'Afdaling, De', 2000, None, 7382, 'Short'),
#  (7462, "Affaire Marcorelle, L'", 2000, 6.9, 7462, 'Thriller'),
#  (7462, "Affaire Marcorelle, L'", 2000, 6.9, 7462, 'Fantasy'),
#  (7583, "AFI's 100 Years, 100 Laughs: America's Funniest Movies", 2000, None, 7583, 'Documentary'),
#  (7753, "Afro-Centrix Volume 90: Goin' Downtown", 2000, None, 7753, 'Adult'),
#  (7770, 'Afsaneh-e eshgh', 2000, None, 7770, 'Drama'),
#  (7781, 'Afsporet', 2000, 5.8, 7781, 'Short'),
#  (7781, 'Afsporet', 2000, 5.8, 7781, 'Drama'),
#  (7784, 'Afta', 2000, 7.5, 7784, 'Drama'),
#  (7784, 'Afta', 2000, 7.5, 7784, 'Short'),
#  (7827, "After Diff'rent Strokes: When the Laughter Stopped", 2000, None, 7827, 'Drama'),
#  (7830, 'After Eden', 2000, None, 7830, 'Short'),
#  (7889, 'After School Special, The', 2000, 8.6, 7889, 'Comedy'),
#  (7890, 'After Sex', 2000, 4.4, 7890, 'Comedy'),
#  (7890, 'After Sex', 2000, 4.4, 7890, 'Drama'),
#  (7890, 'After Sex', 2000, 4.4, 7890, 'Romance'),
#  (7927, 'After the Fox', 2000, None, 7927, 'Musical'),
#  (7927, 'After the Fox', 2000, None, 7927, 'Short'),
#  (7948, 'After the Rain', 2000, 3.3, 7948, 'Thriller'),
#  (8027, 'Aftertaste', 2000, None, 8027, 'Short'),
#  (8034, 'Afti i nihta meni', 2000, 7.3, 8034, 'Drama'),
#  (8034, 'Afti i nihta meni', 2000, 7.3, 8034, 'Romance'),
#  (8115, 'Agapi einai elefantas, I', 2000, 5.1, 8115, 'Comedy'),
#  (8115, 'Agapi einai elefantas, I', 2000, 5.1, 8115, 'Romance'),
#  (8116, 'Agapi einai elephandas, I', 2000, None, 8116, 'Comedy'),
#  (8189, 'Age of Slavery', 2000, None, 8189, 'Documentary'),
#  (8209, 'Agelastos petra', 2000, 7.8, 8209, 'Documentary'),
#  (8477, 'Agostinho Neto', 2000, None, 8477, 'Documentary'),
#  (8588, 'Ah Fu', 2000, 5.8, 8588, 'Drama'),
#  (8588, 'Ah Fu', 2000, 5.8, 8588, 'Romance'),
#  (8711, 'Ahot Zara', 2000, 6.6, 8711, 'Drama'),
#  (8779, 'Ai qing min gan di dai', 2000, None, 8779, 'Comedy'),
#  (8779, 'Ai qing min gan di dai', 2000, None, 8779, 'Romance'),
#  (8929, 'Aimants, Les', 2000, None, 8929, 'Short'),
#  (8929, 'Aimants, Les', 2000, None, 8929, 'Animation'),
#  (8946, 'Aime S. emprisonne en 1945', 2000, None, 8946, 'Short'),
#  (9008, 'Air Bud: World Pup', 2000, None, 9008, 'Family'),
#  (9008, 'Air Bud: World Pup', 2000, None, 9008, 'Comedy'),
#  (9008, 'Air Bud: World Pup', 2000, None, 9008, 'Drama'),
#  (9020, "Air et le feu, L'", 2000, None, 9020, 'Short'),
#  (9082, 'Air: Climate', 2000, None, 9082, 'Documentary'),
#  (9082, 'Air: Climate', 2000, None, 9082, 'Short'),
#  (9155, 'Aisha', 2000, None, 9155, 'Short'),
#  (9155, 'Aisha', 2000, None, 9155, 'Documentary'),
#  (9169, 'Aitanic', 2000, 4.2, 9169, 'Musical'),
#  (9213, 'Ajax: Daar hoorden zij engelen zingen', 2000, 6.7, 9213, 'Documentary'),
#  (9248, 'Ajuste de cuentas', 2000, None, 9248, 'Action'),
#  (9492, 'Akrobat', 2000, None, 9492, 'Short'),
#  (9492, 'Akrobat', 2000, None, 9492, 'Animation'),
#  (9526, 'Aktion C+M+B', 2000, None, 9526, 'Comedy'),
#  (9526, 'Aktion C+M+B', 2000, None, 9526, 'Family'),
#  (9687, 'Al Lewis: Forever Grandpa', 2000, None, 9687, 'Documentary'),
#  (9687, 'Al Lewis: Forever Grandpa', 2000, None, 9687, 'Short'),
#  (9690, 'Al Loves Trees', 2000, 4.0, 9690, 'Animation'),
#  (9690, 'Al Loves Trees', 2000, 4.0, 9690, 'Comedy'),
#  (9690, 'Al Loves Trees', 2000, 4.0, 9690, 'Short'),
#  (9698, 'Al momento giusto', 2000, 4.6, 9698, 'Comedy'),
#  (9783, 'ALAC Awards 2000, The', 2000, None, 9783, 'Family'),
#  (9849, 'Alai Payuthey', 2000, 6.3, 9849, 'Musical'),
#  (9849, 'Alai Payuthey', 2000, 6.3, 9849, 'Drama'),
#  (9849, 'Alai Payuthey', 2000, 6.3, 9849, 'Romance'),
#  (9986, 'alaska.de', 2000, 6.2, 9986, 'Drama'),
#  (10092, 'Alberto', 2000, None, 10092, 'Comedy'),
#  (10092, 'Alberto', 2000, None, 10092, 'Short'),
#  (10138, 'Alcatraz Avenue', 2000, 2.5, 10138, 'Thriller'),
#  (10169, 'Alcina', 2000, None, 10169, 'Drama'),
#  (10169, 'Alcina', 2000, None, 10169, 'Fantasy'),
#  (10169, 'Alcina', 2000, None, 10169, 'Romance'),
#  (10169, 'Alcina', 2000, None, 10169, 'Music'),
#  (10175, 'Alcohol Years, The', 2000, None, 10175, 'Documentary'),
#  (10195, 'Aldeia', 2000, None, 10195, 'Short'),
#  (10308, 'Alex 2000', 2000, None, 10308, 'Short'),
#  (10322, "Alex l'ariete", 2000, 3.1, 10322, 'Action'),
#  (10322, "Alex l'ariete", 2000, 3.1, 10322, 'Crime'),
#  (10360, 'Alexandra - prinsesse i tiden', 2000, None, 10360, 'Documentary'),
#  (10377, "Alexandrophagie, L'", 2000, 7.2, 10377, 'Comedy'),
#  (10377, "Alexandrophagie, L'", 2000, 7.2, 10377, 'Short'),
#  (10426, 'Alfred 007', 2000, None, 10426, 'Comedy'),
#  (10426, 'Alfred 007', 2000, None, 10426, 'Short'),
#  (10494, 'Algrie, entre douleur et libert', 2000, None, 10494, 'Documentary'),
#  (10534, 'Ali Farka Tour: a coule de source', 2000, None, 10534, 'Documentary'),
#  (10536, 'Ali G, Aiii', 2000, None, 10536, 'Comedy'),
#  (10548, 'Ali Zaoua, prince de la rue', 2000, 7.3, 10548, 'Drama'),
#  (10554, 'Ali-Frazier I: One Nation... Divisible', 2000, None, 10554, 'Documentary'),
#  (10673, 'Alice (2000/I)', 2000, None, 10673, 'Short'),
#  (10674, 'Alice (2000/II)', 2000, None, 10674, 'Action'),
#  (10674, 'Alice (2000/II)', 2000, None, 10674, 'Fantasy'),
#  (10674, 'Alice (2000/II)', 2000, None, 10674, 'Horror'),
#  (10871, 'Alien Fury: Countdown to Invasion', 2000, None, 10871, 'Drama'),
#  (10871, 'Alien Fury: Countdown to Invasion', 2000, None, 10871, 'Thriller'),
#  (10917, 'Alien: Resurrection', 2000, None, 10917, 'Animation'),
#  (10917, 'Alien: Resurrection', 2000, None, 10917, 'Sci-Fi'),
#  (10917, 'Alien: Resurrection', 2000, None, 10917, 'Action'),
#  (10917, 'Alien: Resurrection', 2000, None, 10917, 'Horror'),
#  (10996, 'Alipin ng tukso', 2000, None, 10996, 'Drama'),
#  (11068, 'Alkhimiki', 2000, None, 11068, 'Comedy'),
#  (11084, "All About 'The Birds'", 2000, None, 11084, 'Documentary'),
#  (11109, 'All About George', 2000, None, 11109, 'Short'),
#  (11130, "All Access: The Making of 'Almost Famous'", 2000, None, 11130, 'Documentary'),
#  (11251, 'All Forgotten', 2000, 4.6, 11251, 'Romance'),
#  (11251, 'All Forgotten', 2000, 4.6, 11251, 'Drama'),
#  (11299, 'All in the Family: The E! True Hollywood Story', 2000, None, 11299, 'Documentary'),
#  (11314, 'All Jokes Aside', 2000, 3.7, 11314, 'Documentary'),
#  (11314, 'All Jokes Aside', 2000, 3.7, 11314, 'Comedy'),
#  (11346, 'All My Ties', 2000, None, 11346, 'Short'),
#  (11346, 'All My Ties', 2000, None, 11346, 'Animation'),
#  (11346, 'All My Ties', 2000, None, 11346, 'Comedy'),
#  (11353, 'All New Adventures of Chastity Blade, The', 2000, None, 11353, 'Action'),
#  (11353, 'All New Adventures of Chastity Blade, The', 2000, None, 11353, 'Adventure'),
#  (11353, 'All New Adventures of Chastity Blade, The', 2000, None, 11353, 'Short'),
#  (11358, 'All Night Diner', 2000, None, 11358, 'Adult'),
#  (11388, 'All of the Dead', 2000, 6.6, 11388, 'Animation'),
#  (11388, 'All of the Dead', 2000, 6.6, 11388, 'Short'),
#  (11457, 'All Star', 2000, None, 11457, 'Adult'),
#  (11529, 'All the Pretty Horses', 2000, 5.7, 11529, 'Drama'),
#  (11529, 'All the Pretty Horses', 2000, 5.7, 11529, 'Western'),
#  (11570, 'All the Wrong Places', 2000, 6.2, 11570, 'Comedy'),
#  (11570, 'All the Wrong Places', 2000, 6.2, 11570, 'Romance'),
#  (11700, 'Alla Nazimova and Rudolph Valentino', 2000, None, 11700, 'Documentary'),
#  (11700, 'Alla Nazimova and Rudolph Valentino', 2000, None, 11700, 'Short'),
#  (11774, 'Alle Kinder brauchen Liebe', 2000, None, 11774, 'Family'),
#  (11845, 'Alles', 2000, None, 11845, 'Documentary'),
#  (11883, 'Alles ist ein Wunder. Ein Artistenleben', 2000, None, 11883, 'Documentary'),
#  (11888, 'Alles mit Besteck', 2000, None, 11888, 'Short'),
#  (11915, 'Alley Cats Strike', 2000, None, 11915, 'Drama'),
#  (11943, 'Alligator Alley', 2000, 6.4, 11943, 'Comedy'),
#  (11943, 'Alligator Alley', 2000, 6.4, 11943, 'Family'),
#  (11954, 'Allison', 2000, None, 11954, 'Thriller'),
#  (12131, 'Almas em Chamas', 2000, None, 12131, 'Short'),
#  (12131, 'Almas em Chamas', 2000, None, 12131, 'Animation'),
#  (12131, 'Almas em Chamas', 2000, None, 12131, 'Comedy'),
#  (12146, 'Almejas y mejillones', 2000, 6.1, 12146, 'Comedy'),
#  (12148, 'Almendros - Plaza nueva -, Los', 2000, 9.0, 12148, 'Musical'),
#  (12148, 'Almendros - Plaza nueva -, Los', 2000, 9.0, 12148, 'Short'),
#  (12156, 'Almirante Reis', 2000, None, 12156, 'Short'),
#  (12157, 'Almodou', 2000, None, 12157, 'Drama'),
#  (12161, 'Almoloya: cadena perpetua', 2000, None, 12161, 'Action'),
#  (12210, 'Almost Blue', 2000, 5.2, 12210, 'Thriller'),
#  (12217, 'Almost Famous', 2000, 8.0, 12217, 'Drama'),
#  (12217, 'Almost Famous', 2000, 8.0, 12217, 'Comedy'),
#  (12217, 'Almost Famous', 2000, 8.0, 12217, 'Music'),
#  (12327, 'Alone with a Stranger', 2000, 5.6, 12327, 'Drama'),
#  (12327, 'Alone with a Stranger', 2000, 5.6, 12327, 'Thriller'),
#  (12476, 'ALS Video #19: Zoe Photo Shoot 1 Part 1', 2000, None, 12476, 'Adult'),
#  (12633, 'Althorp: A Private Garden', 2000, None, 12633, 'Short'),
#  (12656, 'Altman on His Own Terms', 2000, None, 12656, 'Documentary'),
#  (12704, 'Altweibersommer', 2000, None, 12704, 'Comedy'),
#  (12736, 'Alvin and the Chipmunks Meet the Wolfman', 2000, None, 12736, 'Animation'),
#  (12736, 'Alvin and the Chipmunks Meet the Wolfman', 2000, None, 12736, 'Horror'),
#  (12736, 'Alvin and the Chipmunks Meet the Wolfman', 2000, None, 12736, 'Family'),
#  (12736, 'Alvin and the Chipmunks Meet the Wolfman', 2000, None, 12736, 'Musical'),
#  (12736, 'Alvin and the Chipmunks Meet the Wolfman', 2000, None, 12736, 'Comedy'),
#  (12752, 'Always a Bridesmaid', 2000, 7.0, 12752, 'Documentary'),
#  (12816, 'Alzheimer', 2000, None, 12816, 'Drama'),
#  (12816, 'Alzheimer', 2000, None, 12816, 'Short'),
#  (12825, 'Al-Bab (El tesoro)', 2000, None, 12825, 'Animation'),
#  (12852, 'Am Ende siegt die Liebe', 2000, None, 12852, 'Drama'),
#  (12974, 'Amami', 2000, None, 12974, 'Short'),
#  (12974, 'Amami', 2000, None, 12974, 'Romance'),
#  (13021, 'Amanh', 2000, None, 13021, 'Short'),
#  (13175, 'Amarantado', 2000, None, 13175, 'Drama'),
#  (13175, 'Amarantado', 2000, None, 13175, 'Short'),
#  (13188, 'Amargosa', 2000, 6.4, 13188, 'Documentary'),
#  (13320, 'Amati Girls, The', 2000, 3.6, 13320, 'Drama'),
#  (13368, 'Amazing Journeys', 2000, None, 13368, 'Short'),
#  (13368, 'Amazing Journeys', 2000, None, 13368, 'Documentary'),
#  (13440, 'Amazone', 2000, 5.2, 13440, 'Adventure'),
#  (13440, 'Amazone', 2000, 5.2, 13440, 'Comedy'),
#  (13444, 'Amazones 2000', 2000, 9.3, 13444, 'Documentary'),
#  (13598, "AMC's Film Preservation with Jodie Foster", 2000, None, 13598, 'Documentary'),
#  (13771, "American Arts & Culture Presents John Horatio Malkovich 'Dance of Despair & Disillusionment'", 2000, None, 13771, 'Comedy'),
#  (13771, "American Arts & Culture Presents John Horatio Malkovich 'Dance of Despair & Disillusionment'", 2000, None, 13771, 'Short'),
#  (13791, 'American Beauty Pie', 2000, 7.5, 13791, 'Comedy'),
#  (13791, 'American Beauty Pie', 2000, 7.5, 13791, 'Short'),
#  (13793, 'American Beauty: Look Closer...', 2000, None, 13793, 'Documentary'),
#  (13793, 'American Beauty: Look Closer...', 2000, None, 13793, 'Short'),
#  (13855, 'American Daughter, An', 2000, None, 13855, 'Drama'),
#  (13985, 'American History: Resettlement of Japanese Americans in Greater Cleveland, An', 2000, 9.0, 13985, 'Documentary'),
#  (14009, 'American Justice Set', 2000, None, 14009, 'Documentary'),
#  (14009, 'American Justice Set', 2000, None, 14009, 'Horror'),
#  (14010, "American Justice: A Mother's Story of Murder", 2000, None, 14010, 'Crime'),
#  (14011, 'American Justice: A Murder Before Homecoming', 2000, None, 14011, 'Crime'),
#  (14012, "American Justice: A Parent's Nightmare", 2000, None, 14012, 'Crime'),
#  (14013, 'American Justice: A Questionable Doctor', 2000, None, 14013, 'Crime'),
#  (14014, 'American Justice: A Woman Scorned - The Betty Broderick Story', 2000, None, 14014, 'Crime'),
#  (14015, 'American Justice: Body of Evidence - The Tom Capano Trial', 2000, None, 14015, 'Crime'),
#  (14025, 'American Justice: Deadly Magnolia - Patricia Allanson', 2000, None, 14025, 'Crime'),
#  (14030, 'American Justice: Death Row Radical - Mumia Abu-Jamal', 2000, None, 14030, 'Crime'),
#  (14037, 'American Justice: Eyewitness', 2000, None, 14037, 'Documentary'),
#  (14038, 'American Justice: Great Brinks Heist', 2000, None, 14038, 'Crime'),
#  (14039, 'American Justice: Hunt for the Unabomber', 2000, None, 14039, 'Crime'),
#  (14040, 'American Justice: Hunting Bambi', 2000, None, 14040, 'Crime'),
#  (14041, "American Justice: It's Not My Fault - Strange Defenses", 2000, None, 14041, 'Crime'),
#  (14042, 'American Justice: Kill Thy Neighbor - George Trepal', 2000, None, 14042, 'Crime'),
#  (14044, 'American Justice: Martha Moxley', 2000, None, 14044, 'Crime'),
#  (14046, 'American Justice: Matthew Shepard - Death in the High Desert', 2000, None, 14046, 'Crime'),
#  (14047, 'American Justice: Outlaws', 2000, None, 14047, 'Documentary'),
#  (14048, 'American Justice: Pizza Connection', 2000, None, 14048, 'Documentary'),
#  (14049, 'American Justice: Preppie Murder', 2000, None, 14049, 'Documentary'),
#  (14050, 'American Justice: Selena - Murder of a Star', 2000, None, 14050, 'Documentary'),
#  (14053, 'American Justice: The Heidi Fleiss Story', 2000, None, 14053, 'Crime'),
#  (14055, 'American Justice: The Jonesboro Schoolyard Ambush', 2000, None, 14055, 'Documentary'),
#  (14057, 'American Justice: The Life and Death of Teena Brandon', 2000, None, 14057, 'Crime'),
#  (14062, 'American Justice: The Sam Sheppard Story', 2000, None, 14062, 'Crime'),
#  (14064, 'American Justice: The Scarsdale Diet Doctor Murder', 2000, None, 14064, 'Documentary'),
#  (14065, 'American Justice: The Sinatra Kidnapping', 2000, None, 14065, 'Crime'),
#  (14067, 'American Justice: The Trial of Louise Woodward', 2000, None, 14067, 'Documentary'),
#  (14070, 'American Justice: The Yosemite Killer', 2000, None, 14070, 'Documentary'),
#  (14074, 'American Justice: Vegas and the Mob', 2000, None, 14074, 'Crime'),
#  (14074, 'American Justice: Vegas and the Mob', 2000, None, 14074, 'Documentary'),
#  (14105, 'American Nightmare, The', 2000, 7.1, 14105, 'Documentary'),
#  (14105, 'American Nightmare, The', 2000, 7.1, 14105, 'Horror'),
#  (14144, 'American Prophet: The Story of Joseph Smith', 2000, 4.4, 14144, 'Documentary'),
#  (14145, 'American Psycho', 2000, 6.7, 14145, 'Horror'),
#  (14145, 'American Psycho', 2000, 6.7, 14145, 'Drama'),
#  (14145, 'American Psycho', 2000, 6.7, 14145, 'Thriller'),
#  (14184, 'American Slices', 2000, None, 14184, 'Short'),
#  (14207, 'American Tail: The Treasure of Manhattan Island, An', 2000, None, 14207, 'Adventure'),
#  (14207, 'American Tail: The Treasure of Manhattan Island, An', 2000, None, 14207, 'Animation'),
#  (14207, 'American Tail: The Treasure of Manhattan Island, An', 2000, None, 14207, 'Family'),
#  (14207, 'American Tail: The Treasure of Manhattan Island, An', 2000, None, 14207, 'Musical'),
#  (14212, 'American Tragedy', 2000, None, 14212, 'Crime'),
#  (14212, 'American Tragedy', 2000, None, 14212, 'Drama'),
#  (14223, 'American Virgin', 2000, 3.8, 14223, 'Comedy'),
#  (14268, 'Americanos: Latino Life in the United States', 2000, 7.0, 14268, 'Documentary'),
#  (14277, 'Ameriga', 2000, None, 14277, 'Short'),
#  (14556, 'Amnesia', 2000, 6.6, 14556, 'Short'),
#  (14573, 'Amo-te, Teresa', 2000, None, 14573, 'Drama'),
#  (14573, 'Amo-te, Teresa', 2000, None, 14573, 'Romance'),
#  (14593, 'Amon: Devilman mokushiroku', 2000, None, 14593, 'Action'),
#  (14593, 'Amon: Devilman mokushiroku', 2000, None, 14593, 'Fantasy'),
#  (14593, 'Amon: Devilman mokushiroku', 2000, None, 14593, 'Horror'),
#  (14593, 'Amon: Devilman mokushiroku', 2000, None, 14593, 'Animation'),
#  (14600, 'Among Others', 2000, 7.0, 14600, 'Drama'),
#  (14600, 'Among Others', 2000, 7.0, 14600, 'Short'),
#  (14634, 'Amor', 2000, 9.2, 14634, 'Short'),
#  (14774, 'Amor prohibido', 2000, None, 14774, 'Short'),
#  (14800, 'Amor y el espanto, El', 2000, 8.0, 14800, 'Drama'),
#  (14812, 'Amor ndio', 2000, None, 14812, 'Short'),
#  (14812, 'Amor ndio', 2000, None, 14812, 'Animation'),
#  (14942, 'Amores perros', 2000, 8.2, 14942, 'Thriller'),
#  (14942, 'Amores perros', 2000, 8.2, 14942, 'Drama'),
#  (14945, 'Amores que matan', 2000, None, 14945, 'Short'),
#  (14945, 'Amores que matan', 2000, None, 14945, 'Documentary'),
#  (14996, 'Amour amenic', 2000, None, 14996, 'Drama'),
#  (14996, 'Amour amenic', 2000, None, 14996, 'Short'),
#  (15055, 'Amour Infinity', 2000, 6.7, 15055, 'Drama'),
#  (15095, "Amour, l'argent, l'amour, L'", 2000, 6.1, 15095, 'Drama'),
#  (15095, "Amour, l'argent, l'amour, L'", 2000, 6.1, 15095, 'Romance'),
#  (15144, 'Amphitryon', 2000, None, 15144, 'Fantasy'),
#  (15144, 'Amphitryon', 2000, None, 15144, 'Short'),
#  (15154, "Ampoule lectrique, L'", 2000, 7.0, 15154, 'Short'),
#  (15154, "Ampoule lectrique, L'", 2000, 7.0, 15154, 'Animation'),
#  (15240, 'Amlia', 2000, 8.8, 15240, 'Comedy'),
#  (15240, 'Amlia', 2000, 8.8, 15240, 'Drama'),
#  (15240, 'Amlia', 2000, 8.8, 15240, 'Short'),
#  (15257, 'Amlcar Cabral', 2000, None, 15257, 'Documentary'),
#  (15371, 'Anabel duerme', 2000, None, 15371, 'Short'),
#  (15381, 'Anacronas', 2000, None, 15381, 'Short'),
#  (15412, 'Anak', 2000, 7.3, 15412, 'Drama'),
#  (15440, 'Anaknya Sazali', 2000, None, 15440, 'Comedy'),
#  (15440, 'Anaknya Sazali', 2000, None, 15440, 'Family'),
#  (15857, 'Anarchists', 2000, 4.0, 15857, 'Action'),
#  (15857, 'Anarchists', 2000, 4.0, 15857, 'Thriller'),
#  (15860, 'Anarchy Monkey', 2000, None, 15860, 'Short'),
#  (15916, 'Anatomie', 2000, 6.1, 15916, 'Horror'),
#  (15916, 'Anatomie', 2000, 6.1, 15916, 'Thriller'),
#  (15947, 'Anatomy of Disgust', 2000, None, 15947, 'Documentary'),
#  (15956, 'Anazahevun', 2000, 6.0, 15956, 'Crime'),
#  (15956, 'Anazahevun', 2000, 6.0, 15956, 'Horror'),
#  (16019, 'Ancient Evil: Scream of the Mummy', 2000, 2.1, 16019, 'Horror'),
#  (16044, 'And Beyond', 2000, None, 16044, 'Short'),
#  (16097, "And That's My Life Story", 2000, None, 16097, 'Comedy'),
#  (16097, "And That's My Life Story", 2000, None, 16097, 'Short'),
#  (16124, 'And Then Came Summer', 2000, 4.2, 16124, 'Drama'),
#  (16250, 'Anderson', 2000, None, 16250, 'Comedy'),
#  (16314, 'Andorra', 2000, None, 16314, 'Drama'),
#  (16314, 'Andorra', 2000, None, 16314, 'War'),
#  (16344, 'Andrea Bocelli: Sacred Arias', 2000, None, 16344, 'Music'),
#  (16434, 'Andr le magnifique', 2000, 5.9, 16434, 'Comedy'),
#  (16483, 'Andy of Mayberry: The E! True Hollywood Story', 2000, None, 16483, 'Documentary'),
#  (16774, "Angel's Ladies", 2000, None, 16774, 'Documentary'),
#  (16792, 'Angela', 2000, 6.2, 16792, 'Short'),
#  (16821, 'Angelic Attire: Dressing Cameron, Drew & Lucy', 2000, None, 16821, 'Documentary'),
#  (16821, 'Angelic Attire: Dressing Cameron, Drew & Lucy', 2000, None, 16821, 'Short'),
#  (16824, 'Angelic Effects', 2000, None, 16824, 'Documentary'),
#  (16824, 'Angelic Effects', 2000, None, 16824, 'Short'),
#  (16825, 'Angelic Organ, The', 2000, None, 16825, 'Animation'),
#  (16825, 'Angelic Organ, The', 2000, None, 16825, 'Short'),
#  (16827, 'Angelica Maria - 50 aos de trayectoria artistica', 2000, None, 16827, 'Music'),
#  (16890, "Angels Don't Sleep Here", 2000, 3.7, 16890, 'Thriller'),
#  (16891, 'Angels Forever', 2000, None, 16891, 'Short'),
#  (16894, 'Angels in a Cage', 2000, None, 16894, 'Drama'),
#  (16894, 'Angels in a Cage', 2000, None, 16894, 'Thriller'),
#  (16899, 'Angels in the Infield', 2000, None, 16899, 'Family'),
#  (16899, 'Angels in the Infield', 2000, None, 16899, 'Fantasy'),
#  (16899, 'Angels in the Infield', 2000, None, 16899, 'Comedy'),
#  (16918, 'Angels!', 2000, 3.3, 16918, 'Comedy'),
#  (16971, 'Angin kemarau', 2000, None, 16971, 'Short'),
#  (17043, 'Angst', 2000, 5.7, 17043, 'Comedy'),
#  (17122, 'Anik', 2000, None, 17122, 'Documentary'),
#  (17163, 'Animal Factory', 2000, 6.5, 17163, 'Drama'),
#  (17205, 'Animali che attraversano la strada', 2000, 2.8, 17205, 'Drama'),
#  (17242, 'Animated Corpse', 2000, None, 17242, 'Short'),
#  (17242, 'Animated Corpse', 2000, None, 17242, 'Musical'),
#  (17242, 'Animated Corpse', 2000, None, 17242, 'Drama'),
#  (17242, 'Animated Corpse', 2000, None, 17242, 'Fantasy'),
#  (17245, 'Animated Epics: Don Quixote', 2000, None, 17245, 'Animation'),
#  (17291, 'Animorphs: Shattered Reality', 2000, None, 17291, 'Sci-Fi'),
#  (17294, 'Anina prica', 2000, None, 17294, 'Documentary'),
#  (17294, 'Anina prica', 2000, None, 17294, 'Short'),
#  (17298, 'Anino', 2000, 8.7, 17298, 'Short'),
#  (17298, 'Anino', 2000, 8.7, 17298, 'Drama'),
#  (17445, 'Anleitung zur sexuellen Unzufriedenheit', 2000, 8.3, 17445, 'Comedy'),
#  (17497, 'Anna (2000/II)', 2000, None, 17497, 'Comedy'),
#  (17498, 'Anna (2000/III)', 2000, 4.1, 17498, 'Drama'),
#  (17505, 'Anna and the King', 2000, None, 17505, 'Animation'),
#  (17528, 'Anna H. - Geliebte, Ehefrau und Hure', 2000, None, 17528, 'Drama'),
#  (17600, 'Anna Wunder', 2000, 5.8, 17600, 'Drama'),
#  (17673, 'Annayya', 2000, 7.2, 17673, 'Action'),
#  (17673, 'Annayya', 2000, 7.2, 17673, 'Family'),
#  (17696, 'Anne of Green Gables: The Continuing Story', 2000, None, 17696, 'Drama'),
# ...
#  (17820, "Annonce, L'", 2000, None, 17820, 'Short'),
#  (17825, 'Announcement, The', 2000, 6.0, 17825, 'Drama'),
#  (17849, "Anne des treize lunes, L'", 2000, 8.8, 17849, 'Short'),
#  (17882, 'Anoche so que habas muerto', 2000, None, 17882, 'Drama'),
#  (17882, 'Anoche so que habas muerto', 2000, None, 17882, 'Short'),
#  (17952, 'Another Day in L.A.', 2000, None, 17952, 'Short'),
#  (18032, "Another Woman's Husband", 2000, None, 18032, 'Drama'),
#  (18126, 'Antarctic Antics', 2000, None, 18126, 'Family'),
#  (18260, 'Antietam: A Documentary Drama', 2000, 5.6, 18260, 'Documentary'),
#  (18288, 'Antilles sur Seine', 2000, 4.8, 18288, 'Comedy'),
#  (18293, 'Antinome', 2000, None, 18293, 'Short'),
#  (18311, 'Antitrust: Cracking the Code', 2000, None, 18311, 'Documentary'),
#  (18311, 'Antitrust: Cracking the Code', 2000, None, 18311, 'Short'),
#  (18376, 'Antonio Pappano', 2000, None, 18376, 'Documentary'),
#  (18517, 'Anwalt Abel - Das Geheimnis der Zeugin', 2000, None, 18517, 'Crime'),
#  (18517, 'Anwalt Abel - Das Geheimnis der Zeugin', 2000, None, 18517, 'Thriller'),
#  (18520, 'Anwalt Abel - Der Voyeur und das Mdchen', 2000, None, 18520, 'Crime'),
#  (18520, 'Anwalt Abel - Der Voyeur und das Mdchen', 2000, None, 18520, 'Thriller'),
#  (18545, 'Any Given Wednesday', 2000, 6.4, 18545, 'Short'),
#  (18545, 'Any Given Wednesday', 2000, 6.4, 18545, 'Comedy'),
#  (18636, 'Anywhere Out of the World', 2000, None, 18636, 'Short'),
#  (18636, 'Anywhere Out of the World', 2000, None, 18636, 'Drama'),
#  (18636, 'Anywhere Out of the World', 2000, None, 18636, 'Action'),
#  (18636, 'Anywhere Out of the World', 2000, None, 18636, 'Mystery'),
#  (18638, 'Anyd! A sznyogok', 2000, 7.7, 18638, 'Comedy'),
#  (18645, 'Ansia - Um Vo no Tempo', 2000, None, 18645, 'Documentary'),
#  (18649, 'Annimo', 2000, None, 18649, 'Drama'),
#  (18649, 'Annimo', 2000, None, 18649, 'Short'),
#  (18663, 'Ao no to', 2000, None, 18663, 'Drama'),
#  (18795, 'Apariencias', 2000, 7.1, 18795, 'Comedy'),
#  (18795, 'Apariencias', 2000, 7.1, 18795, 'Romance'),
#  (18823, 'Apartment Hunting', 2000, 6.1, 18823, 'Comedy'),
#  (18823, 'Apartment Hunting', 2000, 6.1, 18823, 'Romance'),
#  (18830, 'Apartment, The', 2000, None, 18830, 'Short'),
#  (18832, 'Apart', 2000, None, 18832, 'Short'),
#  (18877, 'Apesanteurs', 2000, None, 18877, 'Short'),
#  (18883, 'Apfel, Der', 2000, None, 18883, 'Drama'),
#  (18883, 'Apfel, Der', 2000, None, 18883, 'Short'),
#  (18967, 'Apogee', 2000, None, 18967, 'Sci-Fi'),
#  (18967, 'Apogee', 2000, None, 18967, 'Short'),
#  (19025, 'Apostles of Civilised Vice', 2000, None, 19025, 'Documentary'),
#  (19331, 'Aprs la rconciliation', 2000, 6.3, 19331, 'Drama'),
#  (19350, 'Aprs-midi de Laura, Les', 2000, None, 19350, 'Short'),
#  (19411, 'Aqua i Kina', 2000, None, 19411, 'Documentary'),
#  (19411, 'Aqua i Kina', 2000, None, 19411, 'Short'),
#  (19411, 'Aqua i Kina', 2000, None, 19411, 'Music'),
#  (19431, 'Aquarium', 2000, None, 19431, 'Animation'),
#  (19431, 'Aquarium', 2000, None, 19431, 'Short'),
#  (19436, 'Aquarius', 2000, None, 19436, 'Action'),
#  (19436, 'Aquarius', 2000, None, 19436, 'Sci-Fi'),
#  (19561, 'Arabian Nights', 2000, None, 19561, 'Family'),
#  (19561, 'Arabian Nights', 2000, None, 19561, 'Fantasy'),
#  (19561, 'Arabian Nights', 2000, None, 19561, 'Adventure'),
#  (19593, 'Arabische Prinz, Der', 2000, None, 19593, 'Romance'),
#  (19717, 'Arayannegalude Veedu', 2000, None, 19717, 'Drama'),
#  (19718, 'Arayyy!', 2000, None, 19718, 'Comedy'),
#  (19718, 'Arayyy!', 2000, None, 19718, 'Drama'),
#  (19744, "Arbre au chien pendu, L'", 2000, 7.3, 19744, 'Short'),
#  (19744, "Arbre au chien pendu, L'", 2000, 7.3, 19744, 'Drama'),
#  (19771, 'Arc-en-CL', 2000, None, 19771, 'Short'),
#  (19826, 'Archi le petit excrment', 2000, None, 19826, 'Animation'),
#  (19826, 'Archi le petit excrment', 2000, None, 19826, 'Short'),
#  (19870, 'Archiv FAMU', 2000, None, 19870, 'Documentary'),
#  (19991, 'Are You Cinderella?', 2000, 4.2, 19991, 'Short'),
#  (19994, "Are You Hip-Hop's Biggest Fan?", 2000, None, 19994, 'Music'),
#  (20066, 'Argent content', 2000, 5.3, 20066, 'Short'),
#  (20066, 'Argent content', 2000, 5.3, 20066, 'Action'),
#  (20147, 'Ariadne auf Naxos', 2000, None, 20147, 'Music'),
#  (20147, 'Ariadne auf Naxos', 2000, None, 20147, 'Comedy'),
#  (20147, 'Ariadne auf Naxos', 2000, None, 20147, 'Drama'),
#  (20147, 'Ariadne auf Naxos', 2000, None, 20147, 'Fantasy'),
#  (20388, 'Armario, El (2000/I)', 2000, 3.6, 20388, 'Drama'),
#  (20389, 'Armario, El (2000/II)', 2000, None, 20389, 'Short'),
#  (20396, 'Armas tuss 50 aastat hiljem', 2000, None, 20396, 'Drama'),
#  (20396, 'Armas tuss 50 aastat hiljem', 2000, None, 20396, 'Short'),
#  (20399, 'Armastuse vimalikkusest', 2000, None, 20399, 'Short'),
#  (20399, 'Armastuse vimalikkusest', 2000, None, 20399, 'Animation'),
#  (20470, "Armonie dell'Estasi", 2000, None, 20470, 'Documentary'),
#  (20470, "Armonie dell'Estasi", 2000, None, 20470, 'Music'),
#  (20478, 'Armored Core 2', 2000, None, 20478, 'Action'),
#  (20478, 'Armored Core 2', 2000, None, 20478, 'Animation'),
#  (20518, 'Army Men: Air Attack 2', 2000, None, 20518, 'Action'),
#  (20518, 'Army Men: Air Attack 2', 2000, None, 20518, 'Animation'),
#  (20518, 'Army Men: Air Attack 2', 2000, None, 20518, 'Adventure'),
#  (20518, 'Army Men: Air Attack 2', 2000, None, 20518, 'War'),
#  (20520, 'Army Men: Air Tactics', 2000, None, 20520, 'Action'),
#  (20520, 'Army Men: Air Tactics', 2000, None, 20520, 'Adventure'),
#  (20520, 'Army Men: Air Tactics', 2000, None, 20520, 'Animation'),
#  (20520, 'Army Men: Air Tactics', 2000, None, 20520, 'War'),
#  (20523, "Army Men: Sarge's Heroes 2", 2000, None, 20523, 'Action'),
#  (20523, "Army Men: Sarge's Heroes 2", 2000, None, 20523, 'Animation'),
#  (20523, "Army Men: Sarge's Heroes 2", 2000, None, 20523, 'Adventure'),
#  (20523, "Army Men: Sarge's Heroes 2", 2000, None, 20523, 'War'),
#  (20524, 'Army Men: World War', 2000, None, 20524, 'Action'),
#  (20524, 'Army Men: World War', 2000, None, 20524, 'Animation'),
#  (20524, 'Army Men: World War', 2000, None, 20524, 'Adventure'),
#  (20524, 'Army Men: World War', 2000, None, 20524, 'War'),
#  (20615, 'Around the World 1995-1999', 2000, None, 20615, 'Documentary'),
#  (20615, 'Around the World 1995-1999', 2000, None, 20615, 'Music'),
#  (20618, 'Around the World in 72 Days', 2000, None, 20618, 'Documentary'),
#  (20827, "Arrive, L'", 2000, None, 20827, 'Short'),
#  (20857, 'Arruso', 2000, None, 20857, 'Documentary'),
#  (20857, 'Arruso', 2000, None, 20857, 'Short'),
#  (20968, 'Art of Amlia, The', 2000, 7.2, 20968, 'Documentary'),
#  (20989, 'Art of Exotic Dancing for Everyday Women, The', 2000, None, 20989, 'Documentary'),
#  (21017, 'Art of Seduction', 2000, None, 21017, 'Adult'),
#  (21026, 'Art of Stanley Kubrick: From Short Films to Strangelove, The', 2000, None, 21026, 'Documentary'),
#  (21026, 'Art of Stanley Kubrick: From Short Films to Strangelove, The', 2000, None, 21026, 'Short'),
#  (21037, 'Art of Violin, The', 2000, None, 21037, 'Documentary'),
#  (21037, 'Art of Violin, The', 2000, None, 21037, 'Music'),
#  (21040, 'Art of War, The (2000/I)', 2000, 5.2, 21040, 'Action'),
#  (21040, 'Art of War, The (2000/I)', 2000, 5.2, 21040, 'Thriller'),
#  (21041, 'Art of War, The (2000/II)', 2000, None, 21041, 'Documentary'),
#  (21041, 'Art of War, The (2000/II)', 2000, None, 21041, 'Short'),
#  (21052, 'Art total', 2000, None, 21052, 'Short'),
#  (21052, 'Art total', 2000, None, 21052, 'Documentary'),
#  (21075, 'Arte de morir, El', 2000, 6.0, 21075, 'Horror'),
#  (21184, "Arthur's Perfect Christmas", 2000, None, 21184, 'Animation'),
#  (21193, 'Article 15 bis', 2000, None, 21193, 'Short'),
#  (21243, "Artist's Circle, The", 2000, 7.4, 21243, 'Short'),
#  (21276, "Artista, L'", 2000, None, 21276, 'Short'),
#  (21304, 'Artists In Exile: A Story of Modern Dance In San Francisco', 2000, None, 21304, 'Documentary'),
#  (21305, "Artists of Hell's Kitchen", 2000, None, 21305, 'Documentary'),
#  (21395, 'Arzew', 2000, None, 21395, 'Documentary'),
#  (21395, 'Arzew', 2000, None, 21395, 'Short'),
#  (21454, 'As I Was Moving Ahead Occasionally I Saw Brief Glimpses of Beauty', 2000, 9.3, 21454, 'Documentary'),
#  (21539, 'As You Are Me', 2000, None, 21539, 'Animation'),
#  (21539, 'As You Are Me', 2000, None, 21539, 'Short'),
#  (21654, 'ASCII Alphabet', 2000, None, 21654, 'Short'),
#  (21737, 'Ash Wednesday', 2000, None, 21737, 'Comedy'),
#  (21737, 'Ash Wednesday', 2000, None, 21737, 'Short'),
#  (21911, 'Asian Dolls Uncut 8', 2000, None, 21911, 'Adult'),
#  (21925, 'Asian Hookers', 2000, None, 21925, 'Adult'),
#  (21928, 'Asian Kool', 2000, None, 21928, 'Documentary'),
#  (21928, 'Asian Kool', 2000, None, 21928, 'Short'),
#  (21928, 'Asian Kool', 2000, None, 21928, 'Music'),
#  (21935, 'Asian Pride Porn', 2000, 4.6, 21935, 'Short'),
#  (22116, 'Asociacin Argentina de actores', 2000, None, 22116, 'Short'),
#  (22616, 'Astitva', 2000, 6.2, 22616, 'Drama'),
#  (22629, 'Astoria', 2000, 4.8, 22629, 'Drama'),
#  (22665, 'Astronomy of Errors', 2000, None, 22665, 'Comedy'),
#  (22665, 'Astronomy of Errors', 2000, None, 22665, 'Sci-Fi'),
#  (22665, 'Astronomy of Errors', 2000, None, 22665, 'Thriller'),
#  (22735, 'Asylum, The', 2000, 5.3, 22735, 'Horror'),
#  (22735, 'Asylum, The', 2000, 5.3, 22735, 'Thriller'),
#  (22770, 'As es la vida', 2000, 6.6, 22770, 'Drama'),
#  (22802, 'At Any Cost', 2000, None, 22802, 'Drama'),
#  (22987, 'At the Second Traffic Light', 2000, None, 22987, 'Short'),
#  (23109, 'Atemknstler, Der', 2000, 7.6, 23109, 'Short'),
#  (23247, 'Atlantis - Das ewige Rtsel', 2000, None, 23247, 'Documentary'),
#  (23247, 'Atlantis - Das ewige Rtsel', 2000, None, 23247, 'Short'),
#  (23305, 'Atom Ant', 2000, None, 23305, 'Animation'),
#  (23305, 'Atom Ant', 2000, None, 23305, 'Musical'),
#  (23305, 'Atom Ant', 2000, None, 23305, 'Short'),
#  (23371, 'Atraco en la gran final', 2000, None, 23371, 'Comedy'),
#  (23371, 'Atraco en la gran final', 2000, None, 23371, 'Short'),
#  (23392, 'Atravs da Janela', 2000, 6.3, 23392, 'Drama'),
#  (23399, 'Atrocity Exhibition, The', 2000, 7.9, 23399, 'Horror'),
#  (23449, 'Attack of the Bat Monsters', 2000, 5.2, 23449, 'Comedy'),
#  (23455, 'Attack of the Giant Mousaka, The', 2000, 4.7, 23455, 'Comedy'),
#  (23455, 'Attack of the Giant Mousaka, The', 2000, 4.7, 23455, 'Sci-Fi'),
#  (23514, "Attentat, L'", 2000, None, 23514, 'Documentary'),
#  (23536, 'Attention Shoppers', 2000, 4.4, 23536, 'Comedy'),
#  (23538, 'Attention!', 2000, None, 23538, 'Short'),
#  (23595, 'Attraction', 2000, 4.8, 23595, 'Drama'),
#  (23736, "Au premier dimanche d'aot", 2000, 6.7, 23736, 'Short'),
#  (23736, "Au premier dimanche d'aot", 2000, 6.7, 23736, 'Animation'),
#  (23739, 'Au ras des pquerettes', 2000, None, 23739, 'Animation'),
#  (23739, 'Au ras des pquerettes', 2000, None, 23739, 'Short'),
#  (23855, 'Aubade', 2000, None, 23855, 'Short'),
#  (23951, 'Audition, The', 2000, 6.3, 23951, 'Short'),
#  (23973, 'Audrey Hepburn Story, The', 2000, None, 23973, 'Drama'),
#  (24026, 'Auf die Frauen, die Kunst und das, was wir lieben!', 2000, None, 24026, 'Short'),
#  (24047, 'Auf schmalem Grat', 2000, None, 24047, 'Drama'),
#  (24090, 'Aufschneider, Die', 2000, 5.9, 24090, 'Short'),
#  (24137, 'Auggie Rose', 2000, 6.2, 24137, 'Drama'),
#  (24137, 'Auggie Rose', 2000, 6.2, 24137, 'Mystery'),
#  (24177, 'Auguy', 2000, None, 24177, 'Short'),
#  (24206, 'Aunque t no lo sepas', 2000, 8.9, 24206, 'Drama'),
#  (24206, 'Aunque t no lo sepas', 2000, 8.9, 24206, 'Romance'),
#  (24235, 'Aunt Tiger', 2000, None, 24235, 'Animation'),
#  (24235, 'Aunt Tiger', 2000, None, 24235, 'Family'),
#  (24235, 'Aunt Tiger', 2000, None, 24235, 'Short'),
#  (24244, "Auntie's Golden Bloomers", 2000, None, 24244, 'Comedy'),
#  (24244, "Auntie's Golden Bloomers", 2000, None, 24244, 'Short'),
#  (24248, "Auntie's Shocking Soccer Bloomers", 2000, None, 24248, 'Short'),
#  (24365, 'Ausbruch, Der', 2000, None, 24365, 'Short'),
#  (24365, 'Ausbruch, Der', 2000, None, 24365, 'Drama'),
#  (24366, 'Auschwitz: The Final Witnesses', 2000, None, 24366, 'Documentary'),
#  (24419, 'Austausch, Der', 2000, None, 24419, 'Documentary'),
#  (24460, 'Austria 3', 2000, None, 24460, 'Documentary'),
#  (24460, 'Austria 3', 2000, None, 24460, 'Music'),
#  (24470, 'Auszeit', 2000, None, 24470, 'Short'),
#  (24480, 'Authentiques', 2000, None, 24480, 'Documentary'),
#  (24480, 'Authentiques', 2000, None, 24480, 'Musical'),
#  (24496, 'Auto da Compadecida, O', 2000, 8.4, 24496, 'Adventure'),
#  (24496, 'Auto da Compadecida, O', 2000, 8.4, 24496, 'Comedy'),
#  (24496, 'Auto da Compadecida, O', 2000, 8.4, 24496, 'Drama'),
#  (24496, 'Auto da Compadecida, O', 2000, 8.4, 24496, 'Romance'),
#  (24506, 'Auto Motives', 2000, None, 24506, 'Comedy'),
#  (24506, 'Auto Motives', 2000, None, 24506, 'Short'),
#  (24565, 'Automat Kalaschnikow', 2000, 6.8, 24565, 'Documentary'),
#  (24617, 'Autoportree emaga', 2000, None, 24617, 'Documentary'),
#  (24657, 'Autour de Pinget', 2000, None, 24657, 'Documentary'),
#  (24677, "Autre temps, L'", 2000, None, 24677, 'Short'),
#  (24677, "Autre temps, L'", 2000, None, 24677, 'Animation'),
#  (24683, 'Autres filles, Les', 2000, 6.2, 24683, 'Drama'),
#  (24689, 'Autsch, du Frhliche', 2000, None, 24689, 'Comedy'),
#  (24699, 'Autumn Has Come', 2000, None, 24699, 'Animation'),
#  (24703, 'Autumn in New York', 2000, 4.7, 24703, 'Romance'),
#  (24703, 'Autumn in New York', 2000, 4.7, 24703, 'Drama'),
#  (24720, 'Auwe', 2000, None, 24720, 'Short'),
#  (24887, 'Ave Brank', 2000, None, 24887, 'Documentary'),
#  (24916, 'Avec Marinette', 2000, None, 24916, 'Short'),
#  (24977, 'Avenging the Avengers', 2000, None, 24977, 'Documentary'),
#  (24977, 'Avenging the Avengers', 2000, None, 24977, 'Short'),
#  (25023, 'Aventuras de Dios, Las', 2000, 7.1, 25023, 'Drama'),
#  (25195, 'Aviature', 2000, None, 25195, 'Documentary'),
#  (25206, 'Avioneta amarilla, La', 2000, None, 25206, 'Action'),
#  (25208, 'Aviotes mnimes', 2000, None, 25208, 'Documentary'),
#  (25217, 'Aviso de bomba', 2000, None, 25217, 'Short'),
#  (25245, 'Avoiding the Hollywood Hooker', 2000, None, 25245, 'Short'),
#  (25251, 'Avon Project, The', 2000, None, 25251, 'Documentary'),
#  (25458, 'Awesome Interiors', 2000, None, 25458, 'Documentary'),
#  (25590, 'Ayos na ang kasunod', 2000, None, 25590, 'Action'),
#  (25590, 'Ayos na ang kasunod', 2000, None, 25590, 'Comedy'),
#  (25645, 'Ayyappante Amma Neyyappam Chuttu', 2000, None, 25645, 'Musical'),
#  (25722, 'Aznar-Almunia: Diario de campaa', 2000, None, 25722, 'Documentary'),
#  (25738, 'Azucena', 2000, 4.7, 25738, 'Drama'),
#  (25764, 'Azzurro', 2000, 6.6, 25764, 'Drama'),
#  (25788, 'Ae', 2000, 6.1, 25788, 'Comedy'),
#  (25796, 'Ao Mariano', 2000, 4.0, 25796, 'Comedy'),
#  (25928, 'Baaghi', 2000, None, 25928, 'Action'),
#  (25928, 'Baaghi', 2000, None, 25928, 'Romance'),
#  (25928, 'Baaghi', 2000, None, 25928, 'Crime'),
#  (25994, 'Baba', 2000, 5.3, 25994, 'Comedy'),
#  (25994, 'Baba', 2000, 5.3, 25994, 'Drama'),
#  (26038, 'Babaouo', 2000, 7.8, 26038, 'Fantasy'),
#  (26161, 'Babewatch 12', 2000, None, 26161, 'Adult'),
#  (26226, 'Babs', 2000, 4.3, 26226, 'Musical'),
#  (26226, 'Babs', 2000, 4.3, 26226, 'Comedy'),
#  (26256, 'Baby', 2000, None, 26256, 'Drama'),
#  (26273, 'Baby Bedlam', 2000, 4.6, 26273, 'Family'),
#  (26273, 'Baby Bedlam', 2000, 4.6, 26273, 'Adventure'),
#  (26273, 'Baby Bedlam', 2000, 4.6, 26273, 'Comedy'),
#  (26585, 'Bach in Auschwitz', 2000, None, 26585, 'Documentary'),
#  (26724, 'Back Ground', 2000, None, 26724, 'Short'),
#  (26730, 'Back Home Years Ago: The Real Casino', 2000, None, 26730, 'Documentary'),
#  (26730, 'Back Home Years Ago: The Real Casino', 2000, None, 26730, 'Short'),
#  (26768, 'Back Spot Turn', 2000, None, 26768, 'Comedy'),
#  (26768, 'Back Spot Turn', 2000, None, 26768, 'Drama'),
#  (26774, 'Back Story', 2000, None, 26774, 'Short'),
#  (26812, 'Back to Misery', 2000, None, 26812, 'Short'),
#  (26840, 'Back to the Black Lagoon', 2000, None, 26840, 'Documentary'),
#  (26841, 'Back to the Crack', 2000, None, 26841, 'Adult'),
#  (27012, 'Backseat Driver 13', 2000, None, 27012, 'Adult'),
#  (27035, 'Backstage', 2000, 4.5, 27035, 'Documentary'),
#  (27058, 'Backstreet Boys Live', 2000, None, 27058, 'Music'),
#  (27074, 'Backward Writing', 2000, 6.5, 27074, 'Short'),
#  (27074, 'Backward Writing', 2000, 6.5, 27074, 'Animation'),
#  (27074, 'Backward Writing', 2000, 6.5, 27074, 'Comedy'),
#  ...]

# %%
# %%sql
# # List all the Drama movies from year 2000
# SELECT *
# FROM movies M INNER JOIN movies_genres MG ON M.id=MG.movie_id
# WHERE M.year = 2000 AND MG.genre = 'Drama';

# %%
# %%sql
# # List all the movies from year 2000 and their average rating
# # broken down by genre
# SELECT AVG(M.rank), MG.genre
# FROM movies M INNER JOIN movies_genres MG ON M.id=MG.movie_id
# WHERE M.year = 2000
# GROUP BY MG.genre;

# %%
# %%sql
# # List the average ratings for the movies broken down by genre
# SELECT AVG(M.rank) AS avg_rating, MG.genre
# FROM movies M INNER JOIN movies_genres MG ON M.id=MG.movie_id
# GROUP BY MG.genre
# ORDER BY avg_rating DESC

# %%
# %%sql
# SELECT distinct a.first_name, a.last_name
# FROM actors a INNER JOIN roles r ON a.id = r.actor_id
#     INNER JOIN movies_directors md ON r.movie_id = md.movie_id
#     INNER JOIN directors d ON d.id = md.director_id
# WHERE d.first_name = 'Steven' and d.last_name='Spielberg';

# %% [markdown]
# #### List all the actors that worked with Steven Spielberg

# %% [markdown]
# #### Compute the average rank for the movies direcred by steven spielberg

# %%
# %%sql
# SELECT avg(rank)
# FROM movies m
#     INNER JOIN movies_directors md ON m.id = md.movie_id
#     INNER JOIN directors d ON d.id = md.director_id
# WHERE d.first_name = 'Steven' and d.last_name='Spielberg';

# %%
# %%sql
# SELECT avg(R.ACT)
# FROM movies m
#     INNER JOIN roles md ON m.id = md.movie_id
# WHERE d.first_name = 'Steven' and d.last_name='Spielberg';

# %% [markdown]
# #### List the movies of Brad Pitt - exclude those that he plays himself

# %%
# %%sql
# SELECT m.name
# FROM movies m
#     INNER JOIN roles r on m.id = r.movie_id
#     INNER JOIN actors a on r.actor_id = a.id
# WHERE r.role not like '%Himself%' and a.first_name = 'Brad' and a.last_name = 'Pitt'

# %% [markdown]
# #### Average rank of Brad Pitt's movies

# %%
# %%sql
# SELECT avg(rank)
# FROM movies m
#     INNER JOIN roles r on m.id = r.movie_id
#     INNER JOIN actors a on r.actor_id = a.id
# WHERE r.role not like '%H%' and a.first_name = 'Brad' and a.last_name = 'Pitt'

# %% [markdown]
# #### List the genre of the movies where Sean Connery appears, and rank them in descending order by count

# %%
# %%sql
# SELECT mg.genre, count(*)
# FROM movies_genres mg
#     INNER JOIN movies m ON m.id  =mg.movies_id
#     INNER JOIN roles r ON m.id = r.movie_id
#     INNER JOIN actors a ON r.actor_id = a.id
# WHERE r.role not like '%Himself%' and a.first_name = 'Sean' and a.last_name = 'Connery'
# GROUP BY genre
# ORDER BY count(*) desc

# %% [markdown]
# #### Compute the average rank for the movies of each actor and rank the actors in descending order based on that rank

# %%
# %%sql
# SELECT r.actor_id, avg(rank)
# FROM movies m
#     INNER JOIN roles r on m.id = r.movie_id
# GROUP BY r.actor_id
# ORDER BY avg(rank) desc

# %% [markdown]
# ### Subqueries

# %% [markdown]
# #### List all the actors that have not worked with Francis Ford Coppola.

# %%
# %%sql
# SELECT id FROM actors WHERE id NOT IN (
# SELECT DISTINCT R.actor_id
# FROM roles R
#     INNER JOIN movies_directors MD ON R.movie_id=MD.movie_id
#     INNER JOIN directors D ON MD.director_id=D.id
# WHERE D.first_name = 'Francis Ford' and D.last_name = 'Coppola')

# %% [markdown]
# #### Find the average number of movies directed by each director

# %%
# %%sql
# SELECT avg(noMovies)
# FROM
#     (
#     SELECT director_id, count(*) as noMovies
#     FROM movies_directors dm
#     GROUP BY director_id
#     ) r;

# %% [markdown]
# #### Report how many directors have directed one movie, two movies, three movies, etc. (in other words, create a the distribution for the variable "number of movies directed by a given director")

# %%
# %%sql
# SELECT NumMovies, COUNT(director_id) as NumDirectors
# FROM
#     (
#     SELECT director_id, count(*) as NumMovies
#     FROM movies_directors dm
#     GROUP BY director_id
#     ) r
# GROUP BY NumMovies
# ORDER BY NumMovies;

# %% [markdown]
# #### Find the average number of movies played by each actor

# %%
# %%sql
# SELECT avg(noMovies)
# FROM
# (
# SELECT actor_id, count(distinct movie_id) as noMovies
# FROM roles
# GROUP BY actor_id
# ) r;

# %%
# %%sql
# SELECT NumMovies, COUNT(actor_id) as NumActors
# FROM
#     (
#     SELECT actor_id, count(*) as NumMovies
#     FROM roles r
#     GROUP BY actor_id
#     ) r
# GROUP BY NumMovies
# ORDER BY NumMovies;

# %%
# %%sql
# SELECT actor_id, count(*) As NumberOfMovies
# FROM roles
# GROUP BY movie_id;

# %% [markdown]
# #### Find the maximum number of genres associated with a movie

# %%
# %%sql
# SELECT max(noGenres) FROM (
# SELECT count(*) as noGenres
# FROM movies_genres
# GROUP BY movie_id) r;

# %%
# %%sql
# SELECT max(noMovies)FROM (
# SELECT count(*) as noMovies, director_id as director
# FROM movies_directors
# GROUP BY director_id
# ) ;

# %%
# %%sql
# SELECT count(*) as noMovies, director_id as director
# FROM movies_directors
# GROUP BY director_id
# ;

# %% [markdown]
# #### Compare the favorite books of liberal and conservative students

# %%
# %%sql
#
# USE facebook;
#
# DROP VIEW IF EXISTS BooksLiberals;
# CREATE VIEW BooksLiberals AS
# SELECT B.FavoriteBook, COUNT(P.ProfileID) AS NumLiberalStudents
# FROM Profiles AS P
#     INNER JOIN FavoriteBooks AS B ON P.ProfileID = B.ProfileId
# WHERE `Political Views` = 'Liberal'
# GROUP BY B.FavoriteBook
# ORDER BY COUNT(P.ProfileID) DESC;
#
# DROP VIEW IF EXISTS BooksConservatives;
# CREATE VIEW BooksConservatives AS
# SELECT B.FavoriteBook, COUNT(P.ProfileID) AS NumConservativeStudents
# FROM Profiles AS P
#     INNER JOIN FavoriteBooks AS B ON P.ProfileID = B.ProfileId
# WHERE `Political Views` = 'Conservative'
# GROUP BY B.FavoriteBook
# ORDER BY COUNT(P.ProfileID) DESC;
#
# DROP VIEW IF EXISTS Conservatives;
# CREATE VIEW Conservatives AS
# SELECT COUNT(*) AS NumCons
# FROM Profiles
# WHERE `Political Views` = 'Conservative';
#
# DROP VIEW IF EXISTS Liberals;
# CREATE VIEW Liberals AS
# SELECT COUNT(*) AS NumLib
# FROM Profiles
# WHERE `Political Views` = 'Liberal';
#
# SELECT BC.FavoriteBook,
#     BC.NumConservativeStudents AS Conservatives,
#     BL.NumLiberalStudents AS Liberals,
#     BC.NumConservativeStudents/C.NumCons AS PercentageConservatives,
#     BL.NumLiberalStudents/L.NumLib AS PercentageLiberals,
#     (BC.NumConservativeStudents/C.NumCons)/(BL.NumLiberalStudents/L.NumLib) AS OddsBeingConservative
# FROM BooksConservatives AS BC
#     INNER JOIN BooksLiberals BL ON BC.FavoriteBook = BL.FavoriteBook,
#     Conservatives C, Liberals L
# WHERE BC.NumConservativeStudents > 5 AND BL.NumLiberalStudents > 5
# ORDER BY OddsBeingConservative DESC
