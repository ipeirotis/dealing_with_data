# %% [markdown]
# ### Classifying Inaugural Speeches
#
# The NLTK toolkit contains the inaugural speeches for all presidents from 1789 till 2009.

# %%
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# [u'1789-Washington.txt',
#  u'1793-Washington.txt',
#  u'1797-Adams.txt',
#  u'1801-Jefferson.txt',
#  u'1805-Jefferson.txt',
#  u'1809-Madison.txt',
#  u'1813-Madison.txt',
#  u'1817-Monroe.txt',
#  u'1821-Monroe.txt',
#  u'1825-Adams.txt',
#  u'1829-Jackson.txt',
#  u'1833-Jackson.txt',
#  u'1837-VanBuren.txt',
#  u'1841-Harrison.txt',
#  u'1845-Polk.txt',
#  u'1849-Taylor.txt',
#  u'1853-Pierce.txt',
#  u'1857-Buchanan.txt',
#  u'1861-Lincoln.txt',
#  u'1865-Lincoln.txt',
#  u'1869-Grant.txt',
#  u'1873-Grant.txt',
#  u'1877-Hayes.txt',
#  u'1881-Garfield.txt',
#  u'1885-Cleveland.txt',
#  u'1889-Harrison.txt',
#  u'1893-Cleveland.txt',
#  u'1897-McKinley.txt',
#  u'1901-McKinley.txt',
#  u'1905-Roosevelt.txt',
#  u'1909-Taft.txt',
#  u'1913-Wilson.txt',
#  u'1917-Wilson.txt',
#  u'1921-Harding.txt',
#  u'1925-Coolidge.txt',
#  u'1929-Hoover.txt',
#  u'1933-Roosevelt.txt',
#  u'1937-Roosevelt.txt',
#  u'1941-Roosevelt.txt',
#  u'1945-Roosevelt.txt',
#  u'1949-Truman.txt',
#  u'1953-Eisenhower.txt',
#  u'1957-Eisenhower.txt',
#  u'1961-Kennedy.txt',
#  u'1965-Johnson.txt',
#  u'1969-Nixon.txt',
#  u'1973-Nixon.txt',
#  u'1977-Carter.txt',
#  u'1981-Reagan.txt',
#  u'1985-Reagan.txt',
#  u'1989-Bush.txt',
#  u'1993-Clinton.txt',
#  u'1997-Clinton.txt',
#  u'2001-Bush.txt',
#  u'2005-Bush.txt',
#  u'2009-Obama.txt']

# %% [markdown]
# If we want to see the words and/or sentences of these speeches we use the following commands:

# %%
speech = '2009-Obama.txt'

# Here is the list of sentences. Each sentence is a list of tokens
inaugural.sents(speech)
# Out:
# [[u'My', u'fellow', u'citizens', u':'], [u'I', u'stand', u'here', u'today', u'humbled', u'by', u'the', u'task', u'before', u'us', u',', u'grateful', u'for', u'the', u'trust', u'you', u'have', u'bestowed', u',', u'mindful', u'of', u'the', u'sacrifices', u'borne', u'by', u'our', u'ancestors', u'.'], ...]

# %%
# Here is the first sentence
inaugural.sents(speech)[0]
# Out:
# [u'My', u'fellow', u'citizens', u':']

# %%
# Here is the second sentence
inaugural.sents(speech)[1]
# Out:
# [u'I',
#  u'stand',
#  u'here',
#  u'today',
#  u'humbled',
#  u'by',
#  u'the',
#  u'task',
#  u'before',
#  u'us',
#  u',',
#  u'grateful',
#  u'for',
#  u'the',
#  u'trust',
#  u'you',
#  u'have',
#  u'bestowed',
#  u',',
#  u'mindful',
#  u'of',
#  u'the',
#  u'sacrifices',
#  u'borne',
#  u'by',
#  u'our',
#  u'ancestors',
#  u'.']

# %%
# And here is the list of tokens
list(inaugural.words(speech))
# Out:
# [u'My',
#  u'fellow',
#  u'citizens',
#  u':',
#  u'I',
#  u'stand',
#  u'here',
#  u'today',
#  u'humbled',
#  u'by',
#  u'the',
#  u'task',
#  u'before',
#  u'us',
#  u',',
#  u'grateful',
#  u'for',
#  u'the',
#  u'trust',
#  u'you',
#  u'have',
#  u'bestowed',
#  u',',
#  u'mindful',
#  u'of',
#  u'the',
#  u'sacrifices',
#  u'borne',
#  u'by',
#  u'our',
#  u'ancestors',
#  u'.',
#  u'I',
#  u'thank',
#  u'President',
#  u'Bush',
#  u'for',
#  u'his',
#  u'service',
#  u'to',
#  u'our',
#  u'nation',
#  u',',
#  u'as',
#  u'well',
#  u'as',
#  u'the',
#  u'generosity',
#  u'and',
#  u'cooperation',
#  u'he',
#  u'has',
#  u'shown',
#  u'throughout',
#  u'this',
#  u'transition',
#  u'.',
#  u'Forty',
#  u'-',
#  u'four',
#  u'Americans',
#  u'have',
#  u'now',
#  u'taken',
#  u'the',
#  u'presidential',
#  u'oath',
#  u'.',
#  u'The',
#  u'words',
#  u'have',
#  u'been',
#  u'spoken',
#  u'during',
#  u'rising',
#  u'tides',
#  u'of',
#  u'prosperity',
#  u'and',
#  u'the',
#  u'still',
#  u'waters',
#  u'of',
#  u'peace',
#  u'.',
#  u'Yet',
#  u',',
#  u'every',
#  u'so',
#  u'often',
#  u'the',
#  u'oath',
#  u'is',
#  u'taken',
#  u'amidst',
#  u'gathering',
#  u'clouds',
#  u'and',
#  u'raging',
#  u'storms',
#  u'.',
#  u'At',
#  u'these',
#  u'moments',
#  u',',
#  u'America',
#  u'has',
#  u'carried',
#  u'on',
#  u'not',
#  u'simply',
#  u'because',
#  u'of',
#  u'the',
#  u'skill',
#  u'or',
#  u'vision',
#  u'of',
#  u'those',
#  u'in',
#  u'high',
#  u'office',
#  u',',
#  u'but',
#  u'because',
#  u'We',
#  u'the',
#  u'People',
#  u'have',
#  u'remained',
#  u'faithful',
#  u'to',
#  u'the',
#  u'ideals',
#  u'of',
#  u'our',
#  u'forbearers',
#  u',',
#  u'and',
#  u'true',
#  u'to',
#  u'our',
#  u'founding',
#  u'documents',
#  u'.',
#  u'So',
#  u'it',
#  u'has',
#  u'been',
#  u'.',
#  u'So',
#  u'it',
#  u'must',
#  u'be',
#  u'with',
#  u'this',
#  u'generation',
#  u'of',
#  u'Americans',
#  u'.',
#  u'That',
#  u'we',
#  u'are',
#  u'in',
#  u'the',
#  u'midst',
#  u'of',
#  u'crisis',
#  u'is',
#  u'now',
#  u'well',
#  u'understood',
#  u'.',
#  u'Our',
#  u'nation',
#  u'is',
#  u'at',
#  u'war',
#  u',',
#  u'against',
#  u'a',
#  u'far',
#  u'-',
#  u'reaching',
#  u'network',
#  u'of',
#  u'violence',
#  u'and',
#  u'hatred',
#  u'.',
#  u'Our',
#  u'economy',
#  u'is',
#  u'badly',
#  u'weakened',
#  u',',
#  u'a',
#  u'consequence',
#  u'of',
#  u'greed',
#  u'and',
#  u'irresponsibility',
#  u'on',
#  u'the',
#  u'part',
#  u'of',
#  u'some',
#  u',',
#  u'but',
#  u'also',
#  u'our',
#  u'collective',
#  u'failure',
#  u'to',
#  u'make',
#  u'hard',
#  u'choices',
#  u'and',
#  u'prepare',
#  u'the',
#  u'nation',
#  u'for',
#  u'a',
#  u'new',
#  u'age',
#  u'.',
#  u'Homes',
#  u'have',
#  u'been',
#  u'lost',
#  u';',
#  u'jobs',
#  u'shed',
#  u';',
#  u'businesses',
#  u'shuttered',
#  u'.',
#  u'Our',
#  u'health',
#  u'care',
#  u'is',
#  u'too',
#  u'costly',
#  u';',
#  u'our',
#  u'schools',
#  u'fail',
#  u'too',
#  u'many',
#  u';',
#  u'and',
#  u'each',
#  u'day',
#  u'brings',
#  u'further',
#  u'evidence',
#  u'that',
#  u'the',
#  u'ways',
#  u'we',
#  u'use',
#  u'energy',
#  u'strengthen',
#  u'our',
#  u'adversaries',
#  u'and',
#  u'threaten',
#  u'our',
#  u'planet',
#  u'.',
#  u'These',
#  u'are',
#  u'the',
#  u'indicators',
#  u'of',
#  u'crisis',
#  u',',
#  u'subject',
#  u'to',
#  u'data',
#  u'and',
#  u'statistics',
#  u'.',
#  u'Less',
#  u'measurable',
#  u'but',
#  u'no',
#  u'less',
#  u'profound',
#  u'is',
#  u'a',
#  u'sapping',
#  u'of',
#  u'confidence',
#  u'across',
#  u'our',
#  u'land',
#  u'--',
#  u'a',
#  u'nagging',
#  u'fear',
#  u'that',
#  u'America',
#  u"'",
#  u's',
#  u'decline',
#  u'is',
#  u'inevitable',
#  u',',
#  u'that',
#  u'the',
#  u'next',
#  u'generation',
#  u'must',
#  u'lower',
#  u'its',
#  u'sights',
#  u'.',
#  u'Today',
#  u'I',
#  u'say',
#  u'to',
#  u'you',
#  u'that',
#  u'the',
#  u'challenges',
#  u'we',
#  u'face',
#  u'are',
#  u'real',
#  u'.',
#  u'They',
#  u'are',
#  u'serious',
#  u'and',
#  u'they',
#  u'are',
#  u'many',
#  u'.',
#  u'They',
#  u'will',
#  u'not',
#  u'be',
#  u'met',
#  u'easily',
#  u'or',
#  u'in',
#  u'a',
#  u'short',
#  u'span',
#  u'of',
#  u'time',
#  u'.',
#  u'But',
#  u'know',
#  u'this',
#  u',',
#  u'America',
#  u'--',
#  u'they',
#  u'will',
#  u'be',
#  u'met',
#  u'.',
#  u'On',
#  u'this',
#  u'day',
#  u',',
#  u'we',
#  u'gather',
#  u'because',
#  u'we',
#  u'have',
#  u'chosen',
#  u'hope',
#  u'over',
#  u'fear',
#  u',',
#  u'unity',
#  u'of',
#  u'purpose',
#  u'over',
#  u'conflict',
#  u'and',
#  u'discord',
#  u'.',
#  u'On',
#  u'this',
#  u'day',
#  u',',
#  u'we',
#  u'come',
#  u'to',
#  u'proclaim',
#  u'an',
#  u'end',
#  u'to',
#  u'the',
#  u'petty',
#  u'grievances',
#  u'and',
#  u'false',
#  u'promises',
#  u',',
#  u'the',
#  u'recriminations',
#  u'and',
#  u'worn',
#  u'-',
#  u'out',
#  u'dogmas',
#  u'that',
#  u'for',
#  u'far',
#  u'too',
#  u'long',
#  u'have',
#  u'strangled',
#  u'our',
#  u'politics',
#  u'.',
#  u'We',
#  u'remain',
#  u'a',
#  u'young',
#  u'nation',
#  u',',
#  u'but',
#  u'in',
#  u'the',
#  u'words',
#  u'of',
#  u'Scripture',
#  u',',
#  u'the',
#  u'time',
#  u'has',
#  u'come',
#  u'to',
#  u'set',
#  u'aside',
#  u'childish',
#  u'things',
#  u'.',
#  u'The',
#  u'time',
#  u'has',
#  u'come',
#  u'to',
#  u'reaffirm',
#  u'our',
#  u'enduring',
#  u'spirit',
#  u';',
#  u'to',
#  u'choose',
#  u'our',
#  u'better',
#  u'history',
#  u';',
#  u'to',
#  u'carry',
#  u'forward',
#  u'that',
#  u'precious',
#  u'gift',
#  u',',
#  u'that',
#  u'noble',
#  u'idea',
#  u',',
#  u'passed',
#  u'on',
#  u'from',
#  u'generation',
#  u'to',
#  u'generation',
#  u':',
#  u'the',
#  u'God',
#  u'-',
#  u'given',
#  u'promise',
#  u'that',
#  u'all',
#  u'are',
#  u'equal',
#  u',',
#  u'all',
#  u'are',
#  u'free',
#  u',',
#  u'and',
#  u'all',
#  u'deserve',
#  u'a',
#  u'chance',
#  u'to',
#  u'pursue',
#  u'their',
#  u'full',
#  u'measure',
#  u'of',
#  u'happiness',
#  u'.',
#  u'In',
#  u'reaffirming',
#  u'the',
#  u'greatness',
#  u'of',
#  u'our',
#  u'nation',
#  u',',
#  u'we',
#  u'understand',
#  u'that',
#  u'greatness',
#  u'is',
#  u'never',
#  u'a',
#  u'given',
#  u'.',
#  u'It',
#  u'must',
#  u'be',
#  u'earned',
#  u'.',
#  u'Our',
#  u'journey',
#  u'has',
#  u'never',
#  u'been',
#  u'one',
#  u'of',
#  u'shortcuts',
#  u'or',
#  u'settling',
#  u'for',
#  u'less',
#  u'.',
#  u'It',
#  u'has',
#  u'not',
#  u'been',
#  u'the',
#  u'path',
#  u'for',
#  u'the',
#  u'faint',
#  u'-',
#  u'hearted',
#  u'--',
#  u'for',
#  u'those',
#  u'who',
#  u'prefer',
#  u'leisure',
#  u'over',
#  u'work',
#  u',',
#  u'or',
#  u'seek',
#  u'only',
#  u'the',
#  u'pleasures',
#  u'of',
#  u'riches',
#  u'and',
#  u'fame',
#  u'.',
#  u'Rather',
#  u',',
#  u'it',
#  u'has',
#  u'been',
#  u'the',
#  u'risk',
#  u'-',
#  u'takers',
#  u',',
#  u'the',
#  u'doers',
#  u',',
#  u'the',
#  u'makers',
#  u'of',
#  u'things',
#  u"'",
#  u'some',
#  u'celebrated',
#  u'but',
#  u'more',
#  u'often',
#  u'men',
#  u'and',
#  u'women',
#  u'obscure',
#  u'in',
#  u'their',
#  u'labor',
#  u',',
#  u'who',
#  u'have',
#  u'carried',
#  u'us',
#  u'up',
#  u'the',
#  u'long',
#  u',',
#  u'rugged',
#  u'path',
#  u'towards',
#  u'prosperity',
#  u'and',
#  u'freedom',
#  u'.',
#  u'For',
#  u'us',
#  u',',
#  u'they',
#  u'packed',
#  u'up',
#  u'their',
#  u'few',
#  u'worldly',
#  u'possessions',
#  u'and',
#  u'traveled',
#  u'across',
#  u'oceans',
#  u'in',
#  u'search',
#  u'of',
#  u'a',
#  u'new',
#  u'life',
#  u'.',
#  u'For',
#  u'us',
#  u',',
#  u'they',
#  u'toiled',
#  u'in',
#  u'sweatshops',
#  u'and',
#  u'settled',
#  u'the',
#  u'West',
#  u';',
#  u'endured',
#  u'the',
#  u'lash',
#  u'of',
#  u'the',
#  u'whip',
#  u'and',
#  u'plowed',
#  u'the',
#  u'hard',
#  u'earth',
#  u'.',
#  u'For',
#  u'us',
#  u',',
#  u'they',
#  u'fought',
#  u'and',
#  u'died',
#  u',',
#  u'in',
#  u'places',
#  u'like',
#  u'Concord',
#  u'and',
#  u'Gettysburg',
#  u';',
#  u'Normandy',
#  u'and',
#  u'Khe',
#  u'Sahn',
#  u'.',
#  u'Time',
#  u'and',
#  u'again',
#  u'these',
#  u'men',
#  u'and',
#  u'women',
#  u'struggled',
#  u'and',
#  u'sacrificed',
#  u'and',
#  u'worked',
#  u'till',
#  u'their',
#  u'hands',
#  u'were',
#  u'raw',
#  u'so',
#  u'that',
#  u'we',
#  u'might',
#  u'live',
#  u'a',
#  u'better',
#  u'life',
#  u'.',
#  u'They',
#  u'saw',
#  u'America',
#  u'as',
#  u'bigger',
#  u'than',
#  u'the',
#  u'sum',
#  u'of',
#  u'our',
#  u'individual',
#  u'ambitions',
#  u';',
#  u'greater',
#  u'than',
#  u'all',
#  u'the',
#  u'differences',
#  u'of',
#  u'birth',
#  u'or',
#  u'wealth',
#  u'or',
#  u'faction',
#  u'.',
#  u'This',
#  u'is',
#  u'the',
#  u'journey',
#  u'we',
#  u'continue',
#  u'today',
#  u'.',
#  u'We',
#  u'remain',
#  u'the',
#  u'most',
#  u'prosperous',
#  u',',
#  u'powerful',
#  u'nation',
#  u'on',
#  u'Earth',
#  u'.',
#  u'Our',
#  u'workers',
#  u'are',
#  u'no',
#  u'less',
#  u'productive',
#  u'than',
#  u'when',
#  u'this',
#  u'crisis',
#  u'began',
#  u'.',
#  u'Our',
#  u'minds',
#  u'are',
#  u'no',
#  u'less',
#  u'inventive',
#  u',',
#  u'our',
#  u'goods',
#  u'and',
#  u'services',
#  u'no',
#  u'less',
#  u'needed',
#  u'than',
#  u'they',
#  u'were',
#  u'last',
#  u'week',
#  u'or',
#  u'last',
#  u'month',
#  u'or',
#  u'last',
#  u'year',
#  u'.',
#  u'Our',
#  u'capacity',
#  u'remains',
#  u'undiminished',
#  u'.',
#  u'But',
#  u'our',
#  u'time',
#  u'of',
#  u'standing',
#  u'pat',
#  u',',
#  u'of',
#  u'protecting',
#  u'narrow',
#  u'interests',
#  u'and',
#  u'putting',
#  u'off',
#  u'unpleasant',
#  u'decisions',
#  u'--',
#  u'that',
#  u'time',
#  u'has',
#  u'surely',
#  u'passed',
#  u'.',
#  u'Starting',
#  u'today',
#  u',',
#  u'we',
#  u'must',
#  u'pick',
#  u'ourselves',
#  u'up',
#  u',',
#  u'dust',
#  u'ourselves',
#  u'off',
#  u',',
#  u'and',
#  u'begin',
#  u'again',
#  u'the',
#  u'work',
#  u'of',
#  u'remaking',
#  u'America',
#  u'.',
#  u'For',
#  u'everywhere',
#  u'we',
#  u'look',
#  u',',
#  u'there',
#  u'is',
#  u'work',
#  u'to',
#  u'be',
#  u'done',
#  u'.',
#  u'The',
#  u'state',
#  u'of',
#  u'our',
#  u'economy',
#  u'calls',
#  u'for',
#  u'action',
#  u',',
#  u'bold',
#  u'and',
#  u'swift',
#  u',',
#  u'and',
#  u'we',
#  u'will',
#  u'act',
#  u'--',
#  u'not',
#  u'only',
#  u'to',
#  u'create',
#  u'new',
#  u'jobs',
#  u',',
#  u'but',
#  u'to',
#  u'lay',
#  u'a',
#  u'new',
#  u'foundation',
#  u'for',
#  u'growth',
#  u'.',
#  u'We',
#  u'will',
#  u'build',
#  u'the',
#  u'roads',
#  u'and',
#  u'bridges',
#  u',',
#  u'the',
#  u'electric',
#  u'grids',
#  u'and',
#  u'digital',
#  u'lines',
#  u'that',
#  u'feed',
#  u'our',
#  u'commerce',
#  u'and',
#  u'bind',
#  u'us',
#  u'together',
#  u'.',
#  u'We',
#  u'will',
#  u'restore',
#  u'science',
#  u'to',
#  u'its',
#  u'rightful',
#  u'place',
#  u',',
#  u'and',
#  u'wield',
#  u'technology',
#  u"'",
#  u's',
#  u'wonders',
#  u'to',
#  u'raise',
#  u'health',
#  u'care',
#  u"'",
#  u's',
#  u'quality',
#  u'and',
#  u'lower',
#  u'its',
#  u'cost',
#  u'.',
#  u'We',
#  u'will',
#  u'harness',
#  u'the',
#  u'sun',
#  u'and',
#  u'the',
#  u'winds',
#  u'and',
#  u'the',
#  u'soil',
#  u'to',
#  u'fuel',
#  u'our',
#  u'cars',
#  u'and',
#  u'run',
#  u'our',
#  u'factories',
#  u'.',
#  u'And',
#  u'we',
#  u'will',
#  u'transform',
#  u'our',
#  u'schools',
#  u'and',
#  u'colleges',
#  u'and',
#  u'universities',
#  u'to',
#  u'meet',
#  u'the',
#  u'demands',
#  u'of',
#  u'a',
#  u'new',
#  u'age',
#  u'.',
#  u'All',
#  u'this',
#  u'we',
#  u'can',
#  u'do',
#  u'.',
#  u'All',
#  u'this',
#  u'we',
#  u'will',
#  u'do',
#  u'.',
#  u'Now',
#  u',',
#  u'there',
#  u'are',
#  u'some',
#  u'who',
#  u'question',
#  u'the',
#  u'scale',
#  u'of',
#  u'our',
#  u'ambitions',
#  u'--',
#  u'who',
#  ...]

# %%
import nltk

# And here is the raw text
raw_text = inaugural.raw(speech)

# And as a reminder, here are the NTLK commands for 
# splitting the text into sentences, or tokenizing it
# (See part A for more details)
sentences = nltk.sent_tokenize(raw_text)
tokens = nltk.word_tokenize(raw_text)
nltk_text = nltk.Text(tokens)

# %%
# Here is the list of (non-tokenized) sentences
sentences
# Out:
# [u'My fellow citizens:\n\nI stand here today humbled by the task before us, grateful for the trust you have bestowed, mindful of the sacrifices borne by our ancestors.',
#  u'I thank President Bush for his service to our nation, as well as the generosity and cooperation he has shown throughout this transition.',
#  u'Forty-four Americans have now taken the presidential oath.',
#  u'The words have been spoken during rising tides of prosperity and the still waters of peace.',
#  u'Yet, every so often the oath is taken amidst gathering clouds and raging storms.',
#  u'At these moments, America has carried on not simply because of the skill or vision of those in high office, but because We the People have remained faithful to the ideals of our forbearers, and true to our founding documents.',
#  u'So it has been.',
#  u'So it must be with this generation of Americans.',
#  u'That we are in the midst of crisis is now well understood.',
#  u'Our nation is at war, against a far-reaching network of violence and hatred.',
#  u'Our economy is badly weakened, a consequence of greed and irresponsibility on the part of some, but also our collective failure to make hard choices and prepare the nation for a new age.',
#  u'Homes have been lost; jobs shed; businesses shuttered.',
#  u'Our health care is too costly; our schools fail too many; and each day brings further evidence that the ways we use energy strengthen our adversaries and threaten our planet.',
#  u'These are the indicators of crisis, subject to data and statistics.',
#  u"Less measurable but no less profound is a sapping of confidence across our land -- a nagging fear that America's decline is inevitable, that the next generation must lower its sights.",
#  u'Today I say to you that the challenges we face are real.',
#  u'They are serious and they are many.',
#  u'They will not be met easily or in a short span of time.',
#  u'But know this, America -- they will be met.',
#  u'On this day, we gather because we have chosen hope over fear, unity of purpose over conflict and discord.',
#  u'On this day, we come to proclaim an end to the petty grievances and false promises, the recriminations and worn-out dogmas that for far too long have strangled our politics.',
#  u'We remain a young nation, but in the words of Scripture, the time has come to set aside childish things.',
#  u'The time has come to reaffirm our enduring spirit; to choose our better history; to carry forward that precious gift, that noble idea, passed on from generation to generation: the God-given promise that all are equal, all are free, and all deserve a chance to pursue their full measure of happiness.',
#  u'In reaffirming the greatness of our nation, we understand that greatness is never a given.',
#  u'It must be earned.',
#  u'Our journey has never been one of shortcuts or settling for less.',
#  u'It has not been the path for the faint-hearted -- for those who prefer leisure over work, or seek only the pleasures of riches and fame.',
#  u"Rather, it has been the risk-takers, the doers, the makers of things'some celebrated but more often men and women obscure in their labor, who have carried us up the long, rugged path towards prosperity and freedom.",
#  u'For us, they packed up their few worldly possessions and traveled across oceans in search of a new life.',
#  u'For us, they toiled in sweatshops and settled the West; endured the lash of the whip and plowed the hard earth.',
#  u'For us, they fought and died, in places like Concord and Gettysburg; Normandy and Khe Sahn.',
#  u'Time and again these men and women struggled and sacrificed and worked till their hands were raw so that we might live a better life.',
#  u'They saw America as bigger than the sum of our individual ambitions; greater than all the differences of birth or wealth or faction.',
#  u'This is the journey we continue today.',
#  u'We remain the most prosperous, powerful nation on Earth.',
#  u'Our workers are no less productive than when this crisis began.',
#  u'Our minds are no less inventive, our goods and services no less needed than they were last week or last month or last year.',
#  u'Our capacity remains undiminished.',
#  u'But our time of standing pat, of protecting narrow interests and putting off unpleasant decisions -- that time has surely passed.',
#  u'Starting today, we must pick ourselves up, dust ourselves off, and begin again the work of remaking America.',
#  u'For everywhere we look, there is work to be done.',
#  u'The state of our economy calls for action, bold and swift, and we will act -- not only to create new jobs, but to lay a new foundation for growth.',
#  u'We will build the roads and bridges, the electric grids and digital lines that feed our commerce and bind us together.',
#  u"We will restore science to its rightful place, and wield technology's wonders to raise health care's quality and lower its cost.",
#  u'We will harness the sun and the winds and the soil to fuel our cars and run our factories.',
#  u'And we will transform our schools and colleges and universities to meet the demands of a new age.',
#  u'All this we can do.',
#  u'All this we will do.',
#  u'Now, there are some who question the scale of our ambitions -- who suggest that our system cannot tolerate too many big plans.',
#  u'Their memories are short.',
#  u'For they have forgotten what this country has already done; what free men and women can achieve when imagination is joined to common purpose, and necessity to courage.',
#  u'What the cynics fail to understand is that the ground has shifted beneath them -- that the stale political arguments that have consumed us for so long no longer apply.',
#  u'The question we ask today is not whether our government is too big or too small, but whether it works -- whether it helps families find jobs at a decent wage, care they can afford, a retirement that is dignified.',
#  u'Where the answer is yes, we intend to move forward.',
#  u'Where the answer is no, programs will end.',
#  u"And those of us who manage the public's dollars will be held to account -- to spend wisely, reform bad habits, and do our business in the light of day -- because only then can we restore the vital trust between a people and their government.",
#  u'Nor is the question before us whether the market is a force for good or ill. Its power to generate wealth and expand freedom is unmatched, but this crisis has reminded us that without a watchful eye, the market can spin out of control -- the nation cannot prosper long when it favors only the prosperous.',
#  u'The success of our economy has always depended not just on the size of our Gross Domestic Product, but on the reach of our prosperity; on the ability to extend opportunity to every willing heart -- not out of charity, but because it is the surest route to our common good.',
#  u'As for our common defense, we reject as false the choice between our safety and our ideals.',
#  u'Our Founding Fathers, faced with perils that we can scarcely imagine, drafted a charter to assure the rule of law and the rights of man, a charter expanded by the blood of generations.',
#  u"Those ideals still light the world, and we will not give them up for expedience's sake.",
#  u'And so to all the other peoples and governments who are watching today, from the grandest capitals to the small village where my father was born: know that America is a friend of each nation and every man, woman, and child who seeks a future of peace and dignity, and we are ready to lead once more.',
#  u'Recall that earlier generations faced down fascism and communism not just with missiles and tanks, but with the sturdy alliances and enduring convictions.',
#  u'They understood that our power alone cannot protect us, nor does it entitle us to do as we please.',
#  u'Instead, they knew that our power grows through its prudent use; our security emanates from the justness of our cause, the force of our example, the tempering qualities of humility and restraint.',
#  u'We are the keepers of this legacy.',
#  u'Guided by these principles once more, we can meet those new threats that demand even greater effort -- even greater cooperation and understanding between nations.',
#  u'We will begin to responsibly leave Iraq to its people, and forge a hard-earned peace in Afghanistan.',
#  u'With old friends and former foes, we will work tirelessly to lessen the nuclear threat, and roll back the specter of a warming planet.',
#  u'We will not apologize for our way of life, nor will we waver in its defense, and for those who seek to advance their aims by inducing terror and slaughtering innocents, we say to you now that our spirit is stronger and cannot be broken; you cannot outlast us, and we will defeat you.',
#  u'For we know that our patchwork heritage is a strength, not a weakness.',
#  u'We are a nation of Christians and Muslims, Jews and Hindus -- and non-believers.',
#  u'We are shaped by every language and culture, drawn from every end of this Earth; and because we have tasted the bitter swill of civil war and segregation, and emerged from that dark chapter stronger and more united, we cannot help but believe that the old hatreds shall someday pass; that the lines of tribe shall soon dissolve; that as the world grows smaller, our common humanity shall reveal itself; and that America must play its role in ushering in a new era of peace.',
#  u'To the Muslim world, we seek a new way forward, based on mutual interest and mutual respect.',
#  u"To those leaders around the globe who seek to sow conflict, or blame their society's ills on the West -- know that your people will judge you on what you can build, not what you destroy.",
#  u'To those who cling to power through corruption and deceit and the silencing of dissent, know that you are on the wrong side of history; but that we will extend a hand if you are willing to unclench your fist.',
#  u'To the people of poor nations, we pledge to work alongside you to make your farms flourish and let clean waters flow; to nourish starved bodies and feed hungry minds.',
#  u"And to those nations like ours that enjoy relative plenty, we say we can no longer afford indifference to the suffering outside our borders; nor can we consume the world's resources without regard to effect.",
#  u'For the world has changed, and we must change with it.',
#  u'As we consider the road that unfolds before us, we remember with humble gratitude those brave Americans who, at this very hour, patrol far-off deserts and distant mountains.',
#  u'They have something to tell us, just as the fallen heroes who lie in Arlington whisper through the ages.',
#  u'We honor them not only because they are the guardians of our liberty, but because they embody the spirit of service; a willingness to find meaning in something greater than themselves.',
#  u'And yet, at this moment -- a moment that will define a generation -- it is precisely this spirit that must inhabit us all.',
#  u'For as much as government can do and must do, it is ultimately the faith and determination of the American people upon which this nation relies.',
#  u'It is the kindness to take in a stranger when the levees break, the selflessness of workers who would rather cut their hours than see a friend lose their job which sees us through our darkest hours.',
#  u"It is the firefighter's courage to storm a stairway filled with smoke, but also a parent's willingness to nurture a child, that finally decides our fate.",
#  u'Our challenges may be new.',
#  u'The instruments with which we meet them may be new.',
#  u'But those values upon which our success depends -- honesty and hard work, courage and fair play, tolerance and curiosity, loyalty and patriotism -- these things are old.',
#  u'These things are true.',
#  u'They have been the quiet force of progress throughout our history.',
#  u'What is demanded then is a return to these truths.',
#  u'What is required of us now is a new era of responsibility -- a recognition, on the part of every American, that we have duties to ourselves, our nation, and the world, duties that we do not grudgingly accept but rather seize gladly, firm in the knowledge that there is nothing so satisfying to the spirit, so defining of our character, than giving our all to a difficult task.',
#  u'This is the price and the promise of citizenship.',
#  u'This is the source of our confidence -- the knowledge that God calls on us to shape an uncertain destiny.',
#  u'This is the meaning of our liberty and our creed -- why men and women and children of every race and every faith can join in celebration across this magnificent mall, and why a man whose father less than sixty years ago might not have been served at a local restaurant can now stand before you to take a most sacred oath.',
#  u'So let us mark this day with remembrance, of who we are and how far we have traveled.',
#  u"In the year of America's birth, in the coldest of months, a small band of patriots huddled by dying campfires on the shores of an icy river.",
#  u'The capital was abandoned.',
#  u'The enemy was advancing.',
#  u'The snow was stained with blood.',
#  u'At a moment when the outcome of our revolution was most in doubt, the father of our nation ordered these words be read to the people:\n\n"Let it be told to the future world ... that in the depth of winter, when nothing but hope and virtue could survive ... that the city and the country, alarmed at one common danger, came forth to meet ...',
#  u'it."',
#  u'America!',
#  u'In the face of our common dangers, in this winter of our hardship, let us remember these timeless words.',
#  u'With hope and virtue, let us brave once more the icy currents, and endure what storms may come.',
#  u"Let it be said by our children's children that when we were tested we refused to let this journey end, that we did not turn back nor did we falter; and with eyes fixed on the horizon and God's grace upon us, we carried forth that great gift of freedom and delivered it safely to future generations.",
#  u'Thank you.',
#  u'God bless you.',
#  u'And God bless the United States of America.  \n']

# %%
# And here is an example of doing POS tagging on the second sentence
sent_tokens = nltk.word_tokenize(sentences[1])
nltk.pos_tag(sent_tokens)
# Out:
# [(u'I', 'PRP'),
#  (u'thank', 'VBP'),
#  (u'President', 'NNP'),
#  (u'Bush', 'NNP'),
#  (u'for', 'IN'),
#  (u'his', 'PRP$'),
#  (u'service', 'NN'),
#  (u'to', 'TO'),
#  (u'our', 'PRP$'),
#  (u'nation', 'NN'),
#  (u',', ','),
#  (u'as', 'RB'),
#  (u'well', 'RB'),
#  (u'as', 'IN'),
#  (u'the', 'DT'),
#  (u'generosity', 'NN'),
#  (u'and', 'CC'),
#  (u'cooperation', 'NN'),
#  (u'he', 'PRP'),
#  (u'has', 'VBZ'),
#  (u'shown', 'VBN'),
#  (u'throughout', 'IN'),
#  (u'this', 'DT'),
#  (u'transition', 'NN'),
#  (u'.', '.')]

# %% [markdown]
# ### Exercise
#
# You are asked to identify the words that are most indicative of an Presidential inaugural speech for a given year.
#
# For this task, you will have to do the following:
# * Select the target speeches
# * Treat each sentence in the target speech as a document; if the sentence is part of the target speeches, mark it as positive, otherwise mark it as negative
# * Create a dataset that contains the words that appear in each "positive" and in each "negative" sentence; filter the words so that we only see words that appear in a sufficiently large number of sentences.
# * Train a classifier
# * See the most informative words

# %%
# Here we define our "target" class. We will define our target class, as all the speeches
# in the 18th and 19th century
target_speeches = [u'1789-Washington.txt',  u'1793-Washington.txt',
 u'1797-Adams.txt',  u'1801-Jefferson.txt', u'1805-Jefferson.txt', u'1809-Madison.txt',
 u'1813-Madison.txt', u'1817-Monroe.txt', u'1821-Monroe.txt', u'1825-Adams.txt',
 u'1829-Jackson.txt', u'1833-Jackson.txt', u'1837-VanBuren.txt', u'1841-Harrison.txt',
 u'1845-Polk.txt', u'1849-Taylor.txt', u'1853-Pierce.txt', u'1857-Buchanan.txt',
 u'1861-Lincoln.txt', u'1865-Lincoln.txt', u'1869-Grant.txt', u'1873-Grant.txt',
 u'1877-Hayes.txt', u'1881-Garfield.txt', u'1885-Cleveland.txt', u'1889-Harrison.txt',
 u'1893-Cleveland.txt', u'1897-McKinley.txt', u'1901-McKinley.txt']

non_target_speeches = [s for s in inaugural.fileids() if s not in target_speeches]
non_target_speeches
# Out:
# [u'1905-Roosevelt.txt',
#  u'1909-Taft.txt',
#  u'1913-Wilson.txt',
#  u'1917-Wilson.txt',
#  u'1921-Harding.txt',
#  u'1925-Coolidge.txt',
#  u'1929-Hoover.txt',
#  u'1933-Roosevelt.txt',
#  u'1937-Roosevelt.txt',
#  u'1941-Roosevelt.txt',
#  u'1945-Roosevelt.txt',
#  u'1949-Truman.txt',
#  u'1953-Eisenhower.txt',
#  u'1957-Eisenhower.txt',
#  u'1961-Kennedy.txt',
#  u'1965-Johnson.txt',
#  u'1969-Nixon.txt',
#  u'1973-Nixon.txt',
#  u'1977-Carter.txt',
#  u'1981-Reagan.txt',
#  u'1985-Reagan.txt',
#  u'1989-Bush.txt',
#  u'1993-Clinton.txt',
#  u'1997-Clinton.txt',
#  u'2001-Bush.txt',
#  u'2005-Bush.txt',
#  u'2009-Obama.txt']

# %%
# We go over all speeches, and extract the sentences (each sentence is a list, containing the words/tokens)
# If the speech is a target speech, add the sentence

# The data will contain a tuple ("pos", sentence) and ("neg", sentence)
data = []

for speech in target_speeches:
    # If we want to operate with the raw text
    raw_text = inaugural.raw(speech)
    sentences = nltk.sent_tokenize(raw_text)
    # Or, alternatively, to add the alterady tokenized sentences
    # sentences = list(inaugural.sents(speech))
    for sent in sentences:
        data.append( ("pos", sent))
    
for speech in non_target_speeches:
    # If we want to operate with the raw text
    raw_text = inaugural.raw(speech)
    sentences = nltk.sent_tokenize(raw_text)
    # Or, alternatively, to add the alterady tokenized sentences
    # sentences = list(inaugural.sents(speech))
    for sent in sentences:
        data.append( ("neg", sent))

# %%
len(data)
# Out:
# 4839

# %%
# This is the number of positive sentences
len([tag for (tag, s) in data if tag=='pos'])
# Out:
# 2159

# %%
# This is the number of negative sentences
len([tag for (tag, s) in data if tag=='neg'])
# Out:
# 2680
