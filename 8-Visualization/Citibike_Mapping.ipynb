# %%
import requests
import json

# Let's get the data from the Citibike API
url = 'http://www.citibikenyc.com/stations/json'
resp = requests.get(url)

# We transform the returned JSON answer from the API into a Python dictionary object
results = json.loads(resp.text)

# We only need a subset of the data in the JSON returned by the Citibike API, so we keep only we need
data = results["stationBeanList"]

# The code below is just to be able to look at the results in an easy-to-read DataFrame format.
# Our subsequent code that interacts with MySQL will operate using the dictionary object named "data".
import pandas

df = pandas.DataFrame(data)
df
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 0                          9              29         72
# 1                          4              29         79
# 2                         16              11         82
# 3                         20              42         83
# 4                         26              12        116
# 5                         11               8        119
# 6                          8              11        120
# 7                         16              13        127
# 8                         22               7        128
# 9                          1              44        137
# 10                        12              12        143
# 11                        10               7        144
# 12                        16              22        146
# 13                        21              11        147
# 14                        16              15        150
# 15                         1              30        151
# 16                        13              16        152
# 17                         6              49        153
# 18                        11              12        157
# 19                         0              26        160
# 20                        29               5        161
# 21                         0              47        164
# 22                         7              38        167
# 23                        27              19        168
# 24                         0              51        173
# 25                         1              28        174
# 26                         1              44        195
# 27                         1              24        212
# 28                        11              12        216
# 29                        20              19        217
# ..       ...             ...             ...  ...   ...      ...
# 477                        5               7       3207
# 478                       10               8       3209
# 479                        8               9       3210
# 480                        6              15       3211
# 481                       10              12       3212
# 482                       10              11       3213
# 483                       12              10       3214
# 484                        8               9       3215
# 485                        5              13       3216
# 486                        4              12       3217
# 487                        6               9       3220
# 488                       22               5       3221
# 489                       17              21       3222
# 490                        2              53       3223
# 491                       32               5       3224
# 492                        0              13       3225
# 493                        6              39       3226
# 494                        0              19       3229
# 495                        0               7       3230
# 496                        3              54       3231
# 497                       15              16       3232
# 498                        0              38       3233
# 499                        0              31       3235
# 500                        0               7       3236
# 501                        7              18       3237
# 502                        4              33       3238
# 503                        0              19       3241
# 504                       36               3       3242
# 505                        2              27       3243
# 506                       10              20       3244
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 0    2016-02-06 11:33:01 PM  40.767272          -73.993929
# 1    2016-02-06 11:35:14 PM  40.719116          -74.006667
# 2    2016-02-06 11:34:27 PM  40.711174          -74.000165
# 3    2016-02-06 11:36:40 PM  40.683826          -73.976323
# 4    2016-02-06 11:35:50 PM  40.741776          -74.001497
# 5    2016-02-06 11:34:26 PM  40.696089          -73.978034
# 6    2016-02-06 11:33:32 PM  40.686768          -73.959282
# 7    2016-02-06 11:35:37 PM  40.731724          -74.006744
# 8    2016-02-06 11:34:26 PM  40.727103          -74.002971
# 9    2016-02-06 11:33:06 PM  40.761628          -73.972924
# 10   2016-02-06 11:34:41 PM  40.692395          -73.993379
# 11   2016-02-06 11:33:55 PM  40.698399          -73.980689
# 12   2016-02-06 11:35:22 PM  40.716250          -74.009106
# 13   2016-02-06 11:33:34 PM  40.715422          -74.011220
# 14   2016-02-06 11:34:20 PM  40.720874          -73.980858
# 15   2016-02-06 11:36:38 PM  40.722104          -73.997249
# 16   2016-02-06 11:35:02 PM  40.714740          -74.009106
# 17   2016-02-06 11:35:22 PM  40.752062          -73.981632
# 18   2016-02-06 11:36:01 PM  40.690893          -73.996123
# 19   2016-02-06 11:36:56 PM  40.748238          -73.978311
# 20   2016-02-06 11:36:45 PM  40.729170          -73.998102
# 23                   W 18 St & 6 Ave
# 24                Broadway & W 49 St
# 25                   E 25 St & 1 Ave
# 26             Liberty St & Broadway
# 27           W 16 St & The High Line
# 28   Columbia Heights & Cranberry St
# 29                     Old Fulton St
# ..                               ...        ...
# 477                      Oakland Ave
# 478                     Brunswick St
# 479                   Pershing Field
# 480                       Newark Ave
# 481                  Christ Hospital
# 482                   Van Vorst Park
# 483                 Essex Light Rail
# 484                      Central Ave
# 485                    Columbia Park
# 486                     Bayside Park
# 487                5 Corners Library
# 488                   47 Ave & 31 St
# 489          Hanson Pl & St Felix St
# 490                  E 55 St & 3 Ave
# 491              W 13 St & Hudson St
# 492            Baldwin at Montgomery
# 493      W 82 St & Central Park West
# 494        Marcy Ave & MacDonough St
# 495               Penn Station Valet
# 496               E 67 St & Park Ave
# 497              Bond St & Fulton St
# 498                  E 48 St & 5 Ave
# 499            E 41 St & Madison Ave
# 500                       PABT Valet
# 501                   21 St & 41 Ave
# 502                  E 80 St & 2 Ave
# 503         Monroe St & Tompkins Ave
# 504       Schermerhorn St & Court St
# 505                  E 58 St & 1 Ave
# 506           University Pl & E 8 St
#
#                          stationName  statusKey     statusValue testStation  \
# 0                   W 52 St & 11 Ave          1      In Service       False
# 1           Franklin St & W Broadway          1      In Service       False
# 2             St James Pl & Pearl St          1      In Service       False
# 3      Atlantic Ave & Fort Greene Pl          1      In Service       False
# 4                    W 17 St & 8 Ave          1      In Service       False
# 5           Park Ave & St Edwards St          1      In Service       False
# 6        Lexington Ave & Classon Ave          1      In Service       False
# 7              Barrow St & Hudson St          1      In Service       False
# 8           MacDougal St & Prince St          1      In Service       False
# 9              E 56 St & Madison Ave          1      In Service       False
# 10         Clinton St & Joralemon St          1      In Service       False
# 11               Nassau St & Navy St          1      In Service       False
# 12              Hudson St & Reade St          1      In Service       False
# 13          Greenwich St & Warren St          1      In Service       False
# 14                 E 2 St & Avenue C          1      In Service       False
# 15          Cleveland Pl & Spring St          1      In Service       False
# 16             Warren St & Church St          1      In Service       False
# 17                   E 40 St & 5 Ave          1      In Service       False
# 18           Henry St & Atlantic Ave          1      In Service       False
# 19           E 37 St & Lexington Ave          1      In Service       False
# 20             LaGuardia Pl & W 3 St          1      In Service       False
# 21                   E 47 St & 2 Ave          1      In Service       False
# 22                   E 39 St & 3 Ave          1      In Service       False
# 23                   W 18 St & 6 Ave          1      In Service       False
# 24                Broadway & W 49 St          1      In Service       False
# 25                   E 25 St & 1 Ave          1      In Service       False
# 26             Liberty St & Broadway          1      In Service       False
# 27           W 16 St & The High Line          1      In Service       False
# 28   Columbia Heights & Cranberry St          1      In Service       False
# 29                     Old Fulton St          1      In Service       False
# ..                               ...        ...             ...         ...
# 477                      Oakland Ave          1      In Service       False
# 478                     Brunswick St          1      In Service       False
# 479                   Pershing Field          1      In Service       False
# 480                       Newark Ave          1      In Service       False
# 481                  Christ Hospital          1      In Service       False
# 482                   Van Vorst Park          1      In Service       False
# 483                 Essex Light Rail          1      In Service       False
# 484                      Central Ave          1      In Service       False
# 485                    Columbia Park          1      In Service       False
# 486                     Bayside Park          1      In Service       False
# 487                5 Corners Library          1      In Service       False
# 488                   47 Ave & 31 St          1      In Service       False
# 489          Hanson Pl & St Felix St          1      In Service       False
# 490                  E 55 St & 3 Ave          1      In Service       False
# 491              W 13 St & Hudson St          1      In Service       False
# 492            Baldwin at Montgomery          1      In Service       False
# 493      W 82 St & Central Park West          1      In Service       False
# 494        Marcy Ave & MacDonough St          1      In Service       False
# 495               Penn Station Valet          3  Not In Service       False
# 496               E 67 St & Park Ave          1      In Service       False
# 497              Bond St & Fulton St          1      In Service       False
# 498                  E 48 St & 5 Ave          1      In Service       False
# 499            E 41 St & Madison Ave          1      In Service       False
# 500                       PABT Valet          3  Not In Service       False
# 501                   21 St & 41 Ave          1      In Service       False
# 502                  E 80 St & 2 Ave          1      In Service       False
# 503         Monroe St & Tompkins Ave          1      In Service       False
# 504       Schermerhorn St & Court St          1      In Service       False
# 505                  E 58 St & 1 Ave          1      In Service       False
# 506           University Pl & E 8 St          1      In Service       False
#
#      totalDocks
# 0            38
# 1            33
# 2            27
# 3            62
# 4            38
# 5            19
# 6            19
# 7            29
# 8            29
# 9            45
# 10           24
# 11           17
# 12           38
# 13           32
# 14           31
# 15           31
# 16           29
# 17           55
# 18           23
# 19           26
# 20           34
# 21           47
# 22           45
# 23           46
# 24           51
# 25           29
# 26           45
# 27           25
# 28           23
# 29           39
# ..          ...
# 477          12
# 478          18
# 479          17
# 480          21
# 481          22
# 482          21
# 483          22
# 484          17
# 485          18
# 486          16
# 487          15
# 488          27
# 489          38
# 490          55
# 491          37
# 492          13
# 493          45
# 494          19
# 495           7
# 496          57
# 497          31
# 498          38
# 499          31
# 500           9
# 501          25
# 502          37
# 503          19
# 504          39
# 505          29
# 506          30
#
# [507 rows x 18 columns]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib as plt

# This defines the size of the image below
plt.rcParams['figure.figsize'] = (12, 12)

# Let's do a first plot. Put the stations on a scatterplot based on
# their longitude and latitude
df.plot(kind='scatter', x='longitude', y='latitude')

# %%
# Lets plot the stations that are out of service in red
inservice = (df["statusValue"] == 'In Service')
outofservice = (df["statusValue"] == 'Not In Service')

df[inservice].plot(kind='scatter', 
                   x='longitude', 
                   y='latitude', 
                   color='DarkBlue', 
                   label='In Service')
df[outofservice].plot(kind='scatter', 
                      x='longitude', 
                      y='latitude', 
                      color='Red', 
                      label = 'Out of Service')

# %%
# I do not like having to separate plots for that. There should be a way to merge the two plots
# After checking the online documentation, it seem that we will use the "ax" convention
inservice = (df["statusValue"] == 'In Service')
outofservice = (df["statusValue"] == 'Not In Service')

firstplot = df[inservice].plot(kind='scatter', 
                               x='longitude', 
                               y='latitude', 
                               color='DarkBlue', 
                               label='In Service')
secondplot = df[outofservice].plot(kind='scatter', 
                      x='longitude', 
                      y='latitude', 
                      color='Red', 
                      label = 'Out of Service', 
                      ax = firstplot)

# %%
# And now make the size of each point proportional to the size of available bikes
# using the s option in the plot
inservice = (df["statusValue"] == 'In Service')
outofservice = (df["statusValue"] == 'Not In Service')

# We also add the "alpha=0.5" to add transparency
firstplot = df[inservice].plot(kind='scatter', 
                               x='longitude', 
                               y='latitude', 
                               color='DarkBlue', 
                               alpha=0.5, 
                               label='In Service', 
                               s=3*(df['availableBikes']))
secondplot = df[outofservice].plot(kind='scatter', 
                                   x='longitude', 
                                   y='latitude', 
                                   color='Red', 
                                   ax = firstplot, 
                                   label = 'Out of Service')
