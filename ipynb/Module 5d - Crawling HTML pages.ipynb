# %% [markdown]
# ## Crawling and Extracting Data from Websites

# %% [markdown]
# This module uses a set of non-standard libraries, which need to be installed on your machine. By default, your instance should have these installed, but if this is not the case, type these in the Unix shell prompt
#
# `sudo apt-get install libxml2-dev libxslt-dev python-dev`
#
# and then
#
# `sudo pip install lxml`
#
# `sudo pip install pandas`
#
# It will take a few minutes to get everything installed.

# %% [markdown]
# ### Fetching the headlines from ESPN.com
#
# Let's start by trying to fetch the headlines from the site ESPN.com.

# %%
import requests # This command allows us to fetch URLs
from lxml import html # This module will allow us to parse the returned HTML/XML
import pandas # To create a dataframe

# Let's start by fetching the page, and parsing it
url = "http://www.espn.com/"
response = requests.get(url) # get the html of that url
doc = html.fromstring(response.text) # parse it and create a document

# %%
import pandas # To create a dataframe

# Let's start by fetching the page, and parsing it
url = "http://www.espn.com/"
response = requests.get(url) # get the html of that url
doc = html.fromstring(response.text) # parse it and create a document

# We search for the text of the headlines in the source
# and we see that they are all under a <ul class="headlines"> tag
# which is also the only such tag in the html source
# So, we can use the "find" command (instead of the "findall", 
# which would return a list, with just a single entry in this case)
headlineNode = doc.find('.//ul[@class="headlines"]') 
print headlineNode
# Out:
# <Element ul at 0x7fa4ea83b208>

# %% [markdown]
# The `doc` variable is an `HtmlElement` object, and we can now use **XPath** queries to locate the elements that we need. (Depending on time, we may do in class a tutorial on XPath. For now, you can look at the [W3Schools tutorial](http://www.w3schools.com/xpath/xpath_nodes.asp))

# %% [markdown]
# For example, to find all the `<a ...> ... </a>` tags in the returned html, which store the links in the page, we issue the command:

# %%
links = doc.findall(".//a")
len(links)
# Out:
# 228

# %%
print links

# %%
lnk = links[45]
type(lnk)
print lnk
# Out:
# <Element a at 0x7f03a29ca730>

# %% [markdown]
# The `lnk` variable is again an HtmlElement. To get parts of the html element that we need, we can use the `get` method (e.g., to get the `href` attribute) and the `text_content` method (to get the text within the `<a>...</a>` tag.

# %%
print lnk.get("href")
print lnk.text_content()
# Out:
# http://espn.go.com/college-football/
# NCAAF

# %% [markdown]
# Now, let's revisit the _list comprehension_ approach that we discussed in the Python Primer session, for quickly constructing lists:

# %%
urls = [lnk.get("href") for lnk in doc.findall('.//a')]
urls
# Out:
# ['http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=1280x946,200x800,1x1;',
#  'http://espn.go.com/',
#  'http://www.espn.com?country-view=us&lang-view=es',
#  'http://www.espn.com?country-view=ar&lang-view=es',
#  'http://www.espn.com.au',
#  'http://www.espn.com.br',
#  'http://www.espn.com?country-view=co&lang-view=es',
#  'http://www.espn.com?country-view=mx&lang-view=es',
#  'http://www.espn.co.uk/',
#  'http://www.espn.com?country-view=ve&lang-view=es',
#  'http://espn.go.com/boston/',
#  'http://espn.go.com/chicago/',
#  'http://espn.go.com/dallas/',
#  'http://espn.go.com/los-angeles/',
#  'http://espn.go.com/new-york/',
#  'http://m.espn.go.com/wireless/index?i=COMT',
#  'http://www.dickssportinggoods.com/category/index.jsp?categoryId=11400507&camp=Part:ESPNpart::hpshopbutton:HP',
#  '#ncb-scores',
#  '#nba-scores',
#  '#tennis-1-scores',
#  '#tennis-2-scores',
#  '#ncw-scores',
#  '#soccer40-scores',
#  '#nhl-scores',
#  '#nfl-event',
#  '#pga-scores',
#  '#',
#  '/sports/scores',
#  'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=728x90,970x66,924x50,1x1;',
#  '#',
#  '#',
#  '#',
#  '#',
#  'http://espn.go.com/espn/feature/story/_/id/12161880/duke-blue-devils-coach-mike-krzyzewski-think-is',
#  'http://insider.espn.go.com/mens-college-basketball/story/_/id/12162855/has-duke-coach-mike-krzyzewski-changed-college-basketball',
#  '/?topId=12225836',
#  '/?topId=12225681',
#  '/?topId=12225559',
#  '/?topId=12221470',
#  '/?topId=12226149',
#  None,
#  'http://espn.go.com/nfl/',
#  'http://espn.go.com/mlb/',
#  'http://espn.go.com/nba/',
#  'http://espn.go.com/nhl/',
#  'http://espn.go.com/college-football/',
#  'http://espn.go.com/mens-college-basketball/',
#  'http://espn.go.com/racing/nascar/',
#  'http://espnfc.us/',
#  'http://espn.go.com/golf/',
#  'http://espn.go.com/tennis/',
#  'http://espn.go.com/boxing/',
#  'http://espn.go.com/mma/',
#  'http://espn.go.com/sports/',
#  'http://insider.espn.go.com/insider/index',
#  'http://espn.go.com/sportsnation/',
#  'http://espn.go.com/espnradio/',
#  'http://espn.go.com/espnw/',
#  'http://games.espn.go.com/frontpage',
#  'http://espn.go.com/video/',
#  '#',
#  'http://espn.go.com/chicago/mlb/story/_/id/12226499/ernie-banks-died-suffering-heart-attack-family-says',
#  'http://espn.go.com/nfl/playoffs/2014/story/_/id/12225549/nfl-warns-seattle-seahawks-marshawn-lynch-gesture',
#  'http://espn.go.com/nba/story/_/id/12222604/former-cavaliers-guard-dion-waiters-consider-scapegoat-cleveland-early-season-struggles',
#  'http://espn.go.com/mens-college-basketball/story/_/id/12226085/kuran-iverson-enrolled-rhode-island-rams',
#  'http://espn.go.com/olympics/skiing/story/_/id/12225414/lindsey-vonn-wins-super-g-extends-record-64th-world-cup-victory',
#  'http://espn.go.com/nba/story/_/id/12224131/brandon-jennings-detroit-pistons-leaves-game-leg-injury',
#  'http://espn.go.com/mens-college-basketball/story/_/id/12221183/duke-blue-devils-c-marshall-plumlee-join-army-graduation',
#  'http://espn.go.com/tennis/story/_/id/12224023/2015-australian-open-women-fourth-round-matches',
#  'http://espn.go.com/tennis/story/_/id/12225122/2015-australian-open-men-fourth-round-matches',
#  'http://espn.go.com/nhl/story/_/id/12221212/nhl-nhlpa-toying-ryder-cup-type-tournament',
#  'http://insider.espn.go.com/nfl/story/_/id/12221629/seattle-seahawks-multiple-defensive-weaknesses-nfl',
#  None,
#  'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=300x600,300x250,1x1;',
#  'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=924x56,1x1;',
#  'http://www.grantland.com/',
#  'http://log.go.com/log?srvc=sz&guid=20547CF2-0B36-404D-81D3-E5339A6CEFBE&drop=0&addata=3374:65:478847:65&a=1&goto=http://www.dickssportinggoods.com/category/index.jsp?categoryId=11400507&camp=ESPNpart::IndexFooter:HP',
#  'http://www.sportscenter.com',
#  'http://www.teamespn.com',
#  'http://www.espnfrontrow.com',
#  'http://sports.espn.go.com/espn/news/story?page=help/index',
#  'http://espnmediazone.com/us/',
#  'http://www.espncms.com/Advertise-on-ESPN.aspx',
#  'http://www.espncms.com',
#  'http://preferences.truste.com/2.0/?type=espn&affiliateId=148',
#  'http://espn.go.com/espn/corrections',
#  'http://sports.espn.go.com/espn/news/story?page=contact/index',
#  'http://espn.go.com/espn/sitemap',
#  'http://espncareers.com',
#  'http://go.com',
#  'http://disneytermsofuse.com/',
#  'http://disneyprivacycenter.com/',
#  'https://disneyprivacycenter.com/notice-to-california-residents/',
#  'https://disneyprivacycenter.com/kids-privacy-policy/english/',
#  'http://preferences-mgr.truste.com/?type=espn&affiliateId=148']

# %% [markdown]
# #### Exercise
#
# Use a list compresension approach, to get the text_content of all the URLs in the page.

# %%
text = [lnk.text_content() for lnk in doc.findall('.//a')]
#urls = [lnk.get("href") for lnk in doc.findall('.//a')]
text
# Out:
# ['',
#  'USA',
#  'DEPORTES',
#  'Argentina',
#  'Australia',
#  'Brazil',
#  'Colombia',
#  'Mexico',
#  'United Kingdom',
#  'Venezuela',
#  'BOSTON',
#  'CHICAGO',
#  'DALLAS',
#  'LOS ANGELES',
#  'NEW YORK',
#  'Tablet Version',
#  'Shop',
#  'NCAAM',
#  'NBA',
#  'Tennis (M)',
#  'Tennis (W)',
#  'NCAAW',
#  'Soccer',
#  'NHL',
#  'NFL',
#  'Golf (M)',
#  '',
#  u'All Scores \xbb',
#  '',
#  'Kyrgios Wins Thriller',
#  'KU Wins At Texas',
#  'Belichick: Not A Scientist',
#  'Coach K, Basketball Legend',
#  u"O'Neil: You don't know Coach K \xbb",
#  "Bilas: Coach K's massive impact",
#  "\nDuke-St. John'sCoach K at 999",
#  '\nHeat At BullsLive on ESPN3',
#  '\nX Games AspenLive on ESPN',
#  '\nPete Carroll in N.E.Super Bowl XLIX',
#  '\nNHL All-Star GameWhat to watch',
#  'MyESPN',
#  'NFL',
#  'MLB',
#  'NBA',
#  'NHL',
#  'NCAAF',
#  'NCAAM',
#  'NASCAR',
#  'SOCCER',
#  'GOLF',
#  'TENNIS',
#  'BOXING',
#  'MMA',
#  'MORE SPORTS',
#  'INSIDER',
#  'SN',
#  'RADIO& MORE',
#  'espnW& X GAMES',
#  'FANTASY& GAMES',
#  'WATCH',
#  'Duke vs. SJU: Coach K seeks 1,000th win',
#  'Banks died after heart attack, family says',
#  'NFL warns Seahawks about Lynch gesture',
#  "Waiters: Not scapegoat for Cavs' early issues",
#  'Sources: Transfer Iverson enrolls at URI',
#  'Vonn extends WC record with 64th victory',
#  "SVG on Jennings injury: 'Doesn't look good'",
#  'Coach K to Uncle Sam: Plumlee to join Army',
#  'Sharapova-Bouchard match set',
#  'Nadal rolls',
#  'Sources: NHL mulls Ryder Cup-style tourney',
#  "Joyner: How Pats can exploit Seahawks' D",
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'Simmons \xbb',
#  u'Barnwell \xbb',
#  u'B.S. Report \xbb',
#  'FiveThirtyEight',
#  '',
#  '',
#  u'Paine \xbb',
#  u'Paine \xbb',
#  u'Best fits for Shields, Soriano, more \xbb',
#  u'Kubiak tops ranks ofNFL coach hires \xbb',
#  u"NBA's All-Underrated Team for 2014-15 \xbb",
#  u'All Insider content \xbb',
#  'prev',
#  'next',
#  'OTL Talkback: Underinflated Balls(6:58)',
#  'Caliendo/Gruden: Pro Bowl(1:06)',
#  'Badgers Win In Overtime(1:14)',
#  'All-Stars Form Flying V(:21)',
#  'Clay Matthews Convo(3:09)',
#  'Rumble In Sweden(:29)',
#  "Kyrgios' Thrilling Rally(1:34)",
#  'UK Improves To 19-0(:49)',
#  'Timely Slam Lifts Ohio(:30)',
#  'Chelsea Stunned(3:28)',
#  'X Games: Best of GoPro(1:46)',
#  'Special Olympics Unified Snowboarding Final(5:19)',
#  'Deflategate On Court?(:16)',
#  'Huskers Hold Off Sparty(:57)',
#  'WVU Gets Past TCU(1:11)',
#  '',
#  u'Michael Wilbon \xbb',
#  u'More MLB \xbb',
#  u'Best of enemies \xbb',
#  "Beats 'Baby Fed'",
#  u'Does it his way \xbb',
#  u'The two Madisons \xbb',
#  u'More tennis \xbb',
#  '',
#  '',
#  u'Dan Graziano \xbb',
#  u'Walker \xbb',
#  u'Harvey \xbb',
#  u'NFL Nation \xbb',
#  '',
#  '',
#  u'Graham Hays \xbb',
#  u'espnW \xbb',
#  '',
#  u'Dan Rafael \xbb',
#  u'What we learned \xbb',
#  '',
#  u'Nos. 1-10 \xbb',
#  u'11-20 \xbb',
#  u'21-30 \xbb',
#  u'31-40 \xbb',
#  u'41-50 \xbb',
#  u'51-60 \xbb',
#  u'61-70 \xbb',
#  u'71-80 \xbb',
#  u'81-90 \xbb',
#  u'91-100 \xbb',
#  u'Top 5 in each conference \xbb',
#  'Breakout players',
#  'Friday Funnies: Memorable Aussie moments',
#  "Taylor: Cowboys can't afford to let Murray go",
#  'Oreovicz: NASCAR gears up for media frenzy',
#  'Weigh-In: Bader discusses Jon Jones, more',
#  "Holmes: Magic's Vucevic recalls train accident",
#  "O'Neil: Do you know the real Mike Krzyzewski?",
#  'Stats: Big 12 or ACC better hoops conference?',
#  "Endurance: USA Triathlon's historic Cuba race",
#  'Fantasy hoops: Big men who provide 3s, steals',
#  "espnW: L'ville setter reigns as Miss Kentucky",
#  u'More Stories \xbb',
#  'ESPN Ombudsman',
#  'Comment',
#  'Corrections',
#  '',
#  '',
#  '',
#  '',
#  u'More Polls \xbb',
#  '"SportsNation" TV',
#  u'Watch \xbb',
#  u"Be part of SportsNation's live audience \xbb",
#  '',
#  u'Check this out \xbb',
#  u"Rank 'Em: World's third-best soccer player \xbb",
#  'MORE SPORTS',
#  'Racing',
#  'Golf',
#  'Tennis',
#  'Boxing',
#  'MMA',
#  'Recruiting',
#  'Olympic Sports',
#  'espnW',
#  'SCORES',
#  'NFL',
#  'MLB',
#  'NBA',
#  'NHL',
#  'College Football',
#  'College Basketball',
#  'Soccer',
#  'NASCAR',
#  'FANTASY',
#  'Football',
#  'Baseball',
#  'Streak for the Cash',
#  'SPORTSNATION',
#  'Polls',
#  'Chats',
#  'VIDEO',
#  'Most Recent',
#  'Highlights',
#  'Music',
#  'Sports Passport',
#  'Sports Calendar',
#  'Arcade',
#  'Contests',
#  'Contact Us',
#  'Member Services',
#  'myESPN',
#  'ESPN Alerts',
#  'Daily Lines',
#  'RSS',
#  'TV LISTINGS',
#  'WatchESPN',
#  'RADIO',
#  'ESPN THE MAGAZINE',
#  'SHOP',
#  'SPORTSCENTER',
#  'TEAM ESPN',
#  'ESPN FRONT ROW',
#  'Help',
#  'Press',
#  'Advertise on ESPN.com',
#  'Sales Media Kit',
#  'Interest-Based Ads',
#  'Corrections',
#  'Contact Us',
#  'Site Map',
#  'Jobs at ESPN',
#  'Go.com',
#  'Terms of Use',
#  'Privacy Policy',
#  'Your California Privacy Rights',
#  "Children's Online Privacy Policy",
#  'Interest-Based Ads']

# %% [markdown]
# And now create a list where we put together text content and the URL for each link

# %%
data = [(lnk.text_content(), lnk.get("href")) for lnk in doc.findall('.//a')]
data
# Out:
# [('',
#   'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=1280x946,200x800,1x1;'),
#  ('USA', 'http://espn.go.com/'),
#  ('DEPORTES', 'http://www.espn.com?country-view=us&lang-view=es'),
#  ('Argentina', 'http://www.espn.com?country-view=ar&lang-view=es'),
#  ('Australia', 'http://www.espn.com.au'),
#  ('Brazil', 'http://www.espn.com.br'),
#  ('Colombia', 'http://www.espn.com?country-view=co&lang-view=es'),
#  ('Mexico', 'http://www.espn.com?country-view=mx&lang-view=es'),
#  ('United Kingdom', 'http://www.espn.co.uk/'),
#  ('Venezuela', 'http://www.espn.com?country-view=ve&lang-view=es'),
#  ('BOSTON', 'http://espn.go.com/boston/'),
#  ('CHICAGO', 'http://espn.go.com/chicago/'),
#  ('DALLAS', 'http://espn.go.com/dallas/'),
#  ('LOS ANGELES', 'http://espn.go.com/los-angeles/'),
#  ('NEW YORK', 'http://espn.go.com/new-york/'),
#  ('Tablet Version', 'http://m.espn.go.com/wireless/index?i=COMT'),
#  ('Shop',
#   'http://www.dickssportinggoods.com/category/index.jsp?categoryId=11400507&camp=Part:ESPNpart::hpshopbutton:HP'),
#  ('NCAAM', '#ncb-scores'),
#  ('NBA', '#nba-scores'),
#  ('Tennis (M)', '#tennis-1-scores'),
#  ('Tennis (W)', '#tennis-2-scores'),
#  ('NCAAW', '#ncw-scores'),
#  ('Soccer', '#soccer40-scores'),
#  ('NHL', '#nhl-scores'),
#  ('NFL', '#nfl-event'),
#  ('Golf (M)', '#pga-scores'),
#  ('', '#'),
#  (u'All Scores \xbb', '/sports/scores'),
#  ('',
#   'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=728x90,970x66,924x50,1x1;'),
#  ('Kyrgios Wins Thriller', '#'),
#  ('KU Wins At Texas', '#'),
#  ('Belichick: Not A Scientist', '#'),
#   'http://espn.go.com/tennis/story/_/id/12224023/2015-australian-open-women-fourth-round-matches'),
#  ('Nadal rolls',
#   'http://espn.go.com/tennis/story/_/id/12225122/2015-australian-open-men-fourth-round-matches'),
#  ('Sources: NHL mulls Ryder Cup-style tourney',
#   'http://espn.go.com/nhl/story/_/id/12221212/nhl-nhlpa-toying-ryder-cup-type-tournament'),
#  ("Joyner: How Pats can exploit Seahawks' D",
#   'http://insider.espn.go.com/nfl/story/_/id/12221629/seattle-seahawks-multiple-defensive-weaknesses-nfl'),
#  ('', None),
#  ('',
#   'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=300x600,300x250,1x1;'),
#  ('',
#   'http://ad.Doubleclick.net/jump/espn.us.com.espn/espnfrontpage;pgtyp=espnfrontpage;sp=espn;page=front;sz=924x56,1x1;'),
#  ('', 'http://www.grantland.com/'),
#  ('', 'http://grantland.com/features/2015-nba-trade-value-part-1/'),
#  (u'Simmons \xbb',
#   'http://grantland.com/features/2015-nba-trade-value-part-1/'),
#  (u'Barnwell \xbb',
#   'http://grantland.com/the-triangle/patriots-seahawks-2012-matchup-revisited/'),
#  (u'B.S. Report \xbb',
#   'http://grantland.com/the-triangle/b-s-report-bills-dad-and-j-bug/'),
#  ('FiveThirtyEight', 'http://fivethirtyeight.com/'),
#  ('',
#   'https://fivethirtyeight.com/datalab/lebron-and-kobe-probably-got-a-lot-more-all-star-votes-than-they-deserved/'),
#  ('', 'http://fivethirtyeight.com/'),
#  (u'Paine \xbb',
#   'https://fivethirtyeight.com/datalab/lebron-and-kobe-probably-got-a-lot-more-all-star-votes-than-they-deserved/'),
#  (u'Paine \xbb',
#   'http://fivethirtyeight.com/datalab/the-rise-of-the-new-york-islanders/'),
#  (u'Best fits for Shields, Soriano, more \xbb',
#   'http://insider.espn.go.com/blog/the-gms-office/post/_/id/10759'),
#  (u'Kubiak tops ranks ofNFL coach hires \xbb',
#   'http://insider.espn.go.com/nfl/playoffs/2014/story/_/id/12216138/denver-broncos-gary-kubiak-top-new-head-coach-ranks-insider-daily'),
#  (u"NBA's All-Underrated Team for 2014-15 \xbb",
#   'http://insider.espn.go.com/nba/story/_/id/12210572/anthony-morrow-amin-elhassan-all-underrated-team-picks-nba'),
#  (u'All Insider content \xbb',
#   'http://insider.espn.go.com/insider/index?addata=2012_insider_fpimod_insiderhome_xxx'),
#  ('prev', '#'),
#  ('next', '#'),
#  ('OTL Talkback: Underinflated Balls(6:58)',
#   'http://espn.go.com/video/clip?id=12225865&categoryid=2378529'),
#  ('Caliendo/Gruden: Pro Bowl(1:06)',
#   'http://espn.go.com/video/clip?id=12225654&categoryid=2378529'),
#  ('Badgers Win In Overtime(1:14)',
#   'http://espn.go.com/video/clip?id=12223911&categoryid=2378529'),
#  ('All-Stars Form Flying V(:21)',
#   'http://espn.go.com/video/clip?id=12225636&categoryid=2378529'),
#  ('Clay Matthews Convo(3:09)',
#   'http://espn.go.com/video/clip?id=12225634&categoryid=2378529'),
#  ('Rumble In Sweden(:29)',
#   'http://espn.go.com/video/clip?id=12224195&categoryid=2378529'),
#  ('FANTASY', 'http://games.espn.go.com/frontpage'),
#  ('Football', 'http://games.espn.go.com/frontpage/football'),
#  ('Baseball', 'http://games.espn.go.com/frontpage/baseball'),
#  ('Streak for the Cash', 'http://streak.espn.go.com'),
#  ('SPORTSNATION', 'http://espn.go.com/sportsnation/'),
#  ('Polls', 'http://espn.go.com/sportsnation/polls'),
#  ('Chats', 'http://espn.go.com/sportsnation/chats'),
#  ('VIDEO', 'http://espn.go.com/video/'),
#  ('Most Recent', 'http://espn.go.com/video/category?id=2378529'),
#  ('Highlights', 'http://search.espn.go.com/highlights/video/6'),
#  ('Music', 'http://espn.go.com/blog/playbook/sounds/'),
#  ('Sports Passport', 'http://travel.espn.go.com/travel/passport/index'),
#  ('Sports Calendar', 'http://espn.go.com/travel/sports/calendar/'),
#  ('Arcade', 'http://espn.go.com/free-online-games/'),
#  ('Contests', 'http://sports.espn.go.com/espn/contests/index'),
#  ('Contact Us',
#   'http://sports.espn.go.com/espn/news/story?page=contact/index'),
#  ('Member Services', ''),
#  ('myESPN', 'http://espn.go.com/personalization/'),
#  ('ESPN Alerts', 'http://proxy.espn.go.com/mobile/alerts/alertmanager'),
#  ('Daily Lines', 'http://espn.go.com/nfl/lines'),
#  ('RSS', 'http://sports.espn.go.com/espn/news/story?page=rssinfo'),
#  ('TV LISTINGS', 'http://sports.espn.go.com/espntv/espnGuide'),
#  ('WatchESPN', 'http://www.espn3.com'),
#  ('RADIO', 'http://espnradio.espn.go.com/espnradio/index'),
#  ('ESPN THE MAGAZINE',
#   'http://insider.espn.go.com/insider/espn-the-magazine/'),
#  ('SHOP',
#   'http://log.go.com/log?srvc=sz&guid=20547CF2-0B36-404D-81D3-E5339A6CEFBE&drop=0&addata=3374:65:478847:65&a=1&goto=http://www.dickssportinggoods.com/category/index.jsp?categoryId=11400507&camp=ESPNpart::IndexFooter:HP'),
#  ('SPORTSCENTER', 'http://www.sportscenter.com'),
#  ('TEAM ESPN', 'http://www.teamespn.com'),
#  ('ESPN FRONT ROW', 'http://www.espnfrontrow.com'),
#  ('Help', 'http://sports.espn.go.com/espn/news/story?page=help/index'),
#  ('Press', 'http://espnmediazone.com/us/'),
#  ('Advertise on ESPN.com', 'http://www.espncms.com/Advertise-on-ESPN.aspx'),
#  ('Sales Media Kit', 'http://www.espncms.com'),
#  ('Interest-Based Ads',
#   'http://preferences.truste.com/2.0/?type=espn&affiliateId=148'),
#  ('Corrections', 'http://espn.go.com/espn/corrections'),
#  ('Contact Us',
#   'http://sports.espn.go.com/espn/news/story?page=contact/index'),
#  ('Site Map', 'http://espn.go.com/espn/sitemap'),
#  ('Jobs at ESPN', 'http://espncareers.com'),
#  ('Go.com', 'http://go.com'),
#  ('Terms of Use', 'http://disneytermsofuse.com/'),
#  ('Privacy Policy', 'http://disneyprivacycenter.com/'),
#  ('Your California Privacy Rights',
#   'https://disneyprivacycenter.com/notice-to-california-residents/'),
#  ("Children's Online Privacy Policy",
#   'https://disneyprivacycenter.com/kids-privacy-policy/english/'),
#  ('Interest-Based Ads',
#   'http://preferences-mgr.truste.com/?type=espn&affiliateId=148')]

# %% [markdown]
# #### Let's get the headlines...

# %% [markdown]
# Now, let's examine how we can get the data from the website. The key is to understand the structure of the HTML, where the data that we need is stored, and how to fetch the elements. Then, using a combination of `find` and `findall` commands, together with the appropriate XPath queries, we will get what we want

# %%
import requests # This command allows us to fetch URLs
from lxml import html # This module will allow us to parse the returned HTML/XML
import pandas # To create a dataframe

# Let's start by fetching the page, and parsing it
url = "http://www.espn.com/"
response = requests.get(url) # get the html of that url
doc = html.fromstring(response.text) # parse it and create a document

# We search for the text of the headlines in the source
# and we see that they are all under a <ul class="headlines"> tag
# which is also the only such tag in the html source
# So, we can use the "find" command (instead of the "findall", 
# which would return a list, with just a single entry in this case)
headlineNode = doc.find('.//ul[@class="headlines"]') 

# Each headline is under a  <li><a href="...."></a> 
# tag. We also notice that there are two <a></a> tags within
# each <li>, and we only need the first one.
# So, we get all the <li><a ...> tags within the <ul class="headlines">
# (which is stored in the "headlineNode" variable)
headlines = headlineNode.findall('./li/a')

# %%
# Now, we have the noced with the conent in the headlines variable
# We extract the text and the URL
data = [(a.text_content(), a.get("href")) for a in headlines]

data
# Out:
# [('Duke vs. SJU: Coach K seeks 1,000th win', '#'),
#  ('Banks died after heart attack, family says',
#   'http://espn.go.com/chicago/mlb/story/_/id/12226499/ernie-banks-died-suffering-heart-attack-family-says'),
#  ('NFL warns Seahawks about Lynch gesture',
#   'http://espn.go.com/nfl/playoffs/2014/story/_/id/12225549/nfl-warns-seattle-seahawks-marshawn-lynch-gesture'),
#  ('Sources: Transfer Iverson enrolls at URI',
#   'http://espn.go.com/mens-college-basketball/story/_/id/12226085/kuran-iverson-enrolled-rhode-island-rams'),
#  ('Chip Ganassi Racing wins record 6th Rolex 24',
#   'http://espn.go.com/racing/story/_/id/12226423/rolex-24-daytona-chip-ganassi-racing-wins-record-6th-title'),
#  ('Vonn extends WC record with 64th victory',
#   'http://espn.go.com/olympics/skiing/story/_/id/12225414/lindsey-vonn-wins-super-g-extends-record-64th-world-cup-victory'),
#  ("Waiters: Not scapegoat for Cavs' early issues",
#   'http://espn.go.com/nba/story/_/id/12222604/former-cavaliers-guard-dion-waiters-consider-scapegoat-cleveland-early-season-struggles'),
#  ("SVG on Jennings injury: 'Doesn't look good'",
#   'http://espn.go.com/nba/story/_/id/12224131/brandon-jennings-detroit-pistons-leaves-game-leg-injury'),
#  ('Coach K to Uncle Sam: Plumlee to join Army',
#   'http://espn.go.com/mens-college-basketball/story/_/id/12221183/duke-blue-devils-c-marshall-plumlee-join-army-graduation'),
#  ('Sources: NHL mulls Ryder Cup-style tourney',
#   'http://espn.go.com/nhl/story/_/id/12221212/nhl-nhlpa-toying-ryder-cup-type-tournament'),
#  ("Joyner: How Pats can exploit Seahawks' D",
#   'http://insider.espn.go.com/nfl/story/_/id/12221629/seattle-seahawks-multiple-defensive-weaknesses-nfl')]

# %%
# And let's create our dataframe
dataframe = pandas.DataFrame(data, columns=["Title", "URL"])

# %%
dataframe
# Out:
#                                              Title  \
# 0      Chancellor deemed 'good' after walk-through
# 1            Serena wins 19th Slam title at Aussie
# 2                                            Caple
# 3     Robinson's heroics help Pitt topple No. 8 ND
# 4     Tiger tumbles out of top 50 in world ranking
# 5   Vols defeat Auburn, spoil coach Pearl's return
# 6             Chelsea, Man City play it safe, draw
# 7                                           Brewin
# 8    Ko, 17, breaks Tiger's mark, youngest No. 1\n
# 9       Hundreds lose out on tickets to Super Bowl
# 10        Kaminsky leads No. 5 Wisconsin past Iowa
# 11  Oscar Robertson backs pot legalization in Ohio
# 12                      Law: Top 100 MLB prospects
# 13                                     Just missed
#
#                                                   URL
# 0   http://espn.go.com/nfl/playoffs/2014/story/_/i...
# 1   http://espn.go.com/tennis/aus15/story/_/id/122...
# 2   http://espn.go.com/espnw/news-commentary/artic...
# 3   http://scores.espn.go.com/ncb/recap?gameId=400...
# 4   http://espn.go.com/golf/story/_/id/12258067/ti...
# 5   http://scores.espn.go.com/ncb/recap?gameId=400...
# 6   http://www.espnfc.us/barclays-premier-league/s...
# 7   http://www.espnfc.us/blog/the-match/60/post/22...
# 8   http://espn.go.com/golf/story/_/id/12259132/ly...
# 9   http://espn.go.com/nfl/playoffs/2014/story/_/i...
# 10  http://scores.espn.go.com/ncb/recap?gameId=400...
# 11  http://espn.go.com/nba/story/_/id/12258558/osc...
# 12  http://insider.espn.go.com/mlb/story/_/id/1219...
# 13  http://insider.espn.go.com/mlb/story/_/id/1225...

# %% [markdown]
# ### Parsing Yahoo Finance
#
# Let's try to parse the page from Yahoo Finance that contains the Options prices for YHOO (or any other company, actually). Let's start with the standard process of fetching the URL, and parsing the content into a document/tree:

# %%
import requests # This command allows us to fetch URLs
from lxml import html # This module will allow us to parse the returned HTML/XML

url = "http://finance.yahoo.com/q/op?s=YHOO+Options"

# get the html of that url
response = requests.get(url)

# Parse the html into a tree
doc = html.fromstring(response.text)

# %% [markdown]
# #### Getting the data that we want
#
# Now, let's say that we want to get the prices for the different options. Scraping HTML is a little bit of an art, and sometimes involves trial and error, as the html formatting of the page can change at any point.
#
# To see where the data is stored, we need to look at the HTML, and try to understand the structure of what surrounds our data of interest. For our case, we see that the prices are stored in an HTML `<table>` element. The table also contains the attribute `class="details-table quote-table Fz-m"`. So, we fetch these two tables, and we ensure that we have two such tables (the call and put) in our results:

# %%
tables = doc.findall('.//table[@class="details-table quote-table Fz-m"]')
len(tables)
# Out:
# 2

# %%
# The first table contains the calls and the second contains the puts
calls = tables[0] 
puts = tables[1]

# %% [markdown]
# Now, we want to again parse the content of these tables. For that, we get back a list of elements that contain "table rows" which are the `<tr>...</tr>` elements. Let's get these now:

# %%
calls_rows = calls.findall('.//tr')
puts_rows = puts.findall('.//tr')

# %% [markdown]
# Now, within the `<tr>` nodes (that represent table rows) we see a set of `<td></td>` elements that contain the cells of each row. You will also notice that the first row contains `<th></th>` cells instead of `<td></td>`; the `<th></th>` cells are commonly used to mark the "headers" of the table.

# %% [markdown]
# Above, you have seen how we can use list comprehensions to get back the data that we want in a list format. Now, we will write a function that will return us directly the text content of the cells in the table

# %%
# This function takes as input a "tr" node
# and returns a list of the text content for each
# of the cells. To avoid creating two functions,
# one for header (<th>) cells and one for data (<td>) cells
# we pass a parameter isHeader that specifies that we are 
# extracting from
def extractCells(row, isHeader=False):
    if isHeader:
        cells = row.findall('.//th')
    else:
        cells = row.findall('.//td')
        
    # The ...strip().splitlines()[0] is not strictly necessary, but it helps for beautifying the headers
    return [val.text_content().strip().splitlines()[0] for val in cells]

# %% [markdown]
# For now, let's get the contents of the header row:

# %%
extractCells(calls_rows[0], isHeader=True)
# Out:
# [u'Strike',
#  'Contract Name',
#  u'Last',
#  u'Bid',
#  u'Ask',
#  u'Change',
#  u'%Change',
#  u'Volume',
#  u'Open Interest',
#  u'Implied Volatility']

# %% [markdown]
# And let's get the contents of the first row:

# %%
extractCells(calls_rows[2], isHeader=False)
# Out:
# ['40.00',
#  'YHOO150206C00040000',
#  '4.05',
#  '3.80',
#  '4.05',
#  '0.35',
#  '+9.46%',
#  '31',
#  '84',
#  '43.36%']

# %% [markdown]
# Now, out goal is to take all the above, and put them together. We will first create a function that takes the "table" object as a parameter, and creates a DataFrame object, with the headers of the table as headers for the DataFrame and the table rows become the rows of the DataFrame.

# %%
import pandas

def parse_options_data(table):
    rows = table.findall(".//tr")
    header = extractCells(rows[0], isHeader=True)
    data = [extractCells(row, isHeader=False) for row in rows[2:]]
    return pandas.DataFrame(data, columns=header)

# %% [markdown]
# Now, let's put everything together:

# %%
import requests # This command allows us to fetch URLs
from lxml import html # This module will allow us to parse the returned HTML/XML
from pandas.io.parsers import TextParser
import pandas

def extractCells(row, isHeader=False):
    if isHeader:
        cells = row.findall('.//th')
    else:
        cells = row.findall('.//td')
    return [val.text_content().strip().splitlines()[0] for val in cells]

def parse_options_data(table):
    rows = table.findall(".//tr")
    header = extractCells(rows[0], isHeader=True)
    data = [extractCells(row, isHeader=False) for row in rows[2:]]
    return pandas.DataFrame(data, columns=header)

url = "http://finance.yahoo.com/q/op?s=YHOO+Options"
response = requests.get(url) # get the html of that url
doc = html.fromstring(response.text) 

tables = doc.findall('.//table[@class="details-table quote-table Fz-m"]')
calls = tables[0] 
puts = tables[1] 

call_data = parse_options_data(calls)
put_data = parse_options_data(puts)

# %%
call_data
# Out:
#    Strike        Contract Name  Last   Bid   Ask Change  %Change Volume  \
# 0   40.00  YHOO150206C00040000  4.05  3.80  4.05   0.35   +9.46%     31
# 1   42.00  YHOO150206C00042000  2.13  2.08  2.13   0.16   +8.12%    135
# 2   43.00  YHOO150206C00043000  1.27  1.26  1.30   0.07   +5.47%    375
# 3   43.50  YHOO150206C00043500  1.00  0.93  0.97   0.04   +4.17%    656
# 4   44.00  YHOO150206C00044000  0.65  0.65  0.69  -0.06   -8.00%   4748
# 5   44.50  YHOO150206C00044500  0.45  0.44  0.47  -0.13  -21.67%   1314
# 6   45.00  YHOO150206C00045000  0.30  0.28  0.32  -0.11  -24.44%   8456
# 7   45.50  YHOO150206C00045500  0.20  0.18  0.21  -0.05  -20.00%    785
# 8   46.00  YHOO150206C00046000  0.15  0.11  0.14  -0.06  -28.57%   1742
# 9   46.50  YHOO150206C00046500  0.11  0.07  0.10  -0.06  -35.29%    659
# 10  47.00  YHOO150206C00047000  0.08  0.05  0.07  -0.03  -27.27%   1079
# 11  47.50  YHOO150206C00047500  0.07  0.03  0.06  -0.02  -22.22%     90
# 12  48.00  YHOO150206C00048000  0.06  0.02  0.05   0.01  +20.00%    832
# 13  48.50  YHOO150206C00048500  0.03  0.02  0.05   0.00    0.00%     38
# 14  49.00  YHOO150206C00049000  0.04  0.01  0.05   0.01  +33.33%     17
# 15  49.50  YHOO150206C00049500  0.02  0.00  0.04  -0.04  -66.67%     14
# 16  50.00  YHOO150206C00050000  0.03  0.00  0.04   0.00    0.00%     66
# 17  50.50  YHOO150206C00050500  0.02  0.02  0.04   0.00    0.00%    113
# 18  51.00  YHOO150206C00051000  0.03  0.01  0.03   0.01  +50.00%    332
# 19  51.50  YHOO150206C00051500  0.02  0.00  0.03  -0.05  -71.43%     12
# 20  52.00  YHOO150206C00052000  0.01  0.00  0.03  -0.01  -50.00%     50
# 21  52.50  YHOO150206C00052500  0.02  0.00  0.02  -0.01  -33.33%     50
# 22  53.00  YHOO150206C00053000  0.02  0.00  0.03   0.00    0.00%     24
# 23  53.50  YHOO150206C00053500  0.01  0.00  0.03  -0.01  -50.00%     16
# 24  54.00  YHOO150206C00054000  0.01  0.01  0.02  -0.01  -50.00%     10
# 25  54.50  YHOO150206C00054500  0.01  0.00  0.02  -0.02  -66.67%      1
# 26  55.00  YHOO150206C00055000  0.01  0.00  0.14  -0.02  -66.67%     20
# 27  55.50  YHOO150206C00055500  0.01  0.00  0.14   0.00    0.00%      8
# 28  56.00  YHOO150206C00056000  0.02  0.00  0.14   0.00    0.00%     12
# 29  56.50  YHOO150206C00056500  0.08  0.00  0.14   0.00    0.00%     15
# 30  57.00  YHOO150206C00057000  0.08  0.00  0.14   0.00    0.00%     75
# 31  58.00  YHOO150206C00058000  0.03  0.00  0.03   0.00    0.00%      5
# 32  59.00  YHOO150206C00059000  0.03  0.00  0.03   0.00    0.00%     54
# 33  60.00  YHOO150206C00060000  0.05  0.00  0.13   0.00    0.00%   1085
#
#    Open Interest Implied Volatility
# 0             84             43.36%
# 1            289             31.64%
# 2           1018             29.00%
# 3            872             28.91%
# 4          16514             28.61%
# 5           2229             28.42%
# 6           4128             29.10%
# 7            735             29.49%
# 8            822             30.37%
# 9           1003             31.84%
# 10           699             33.20%
# 11          1204             35.94%
# 12          1035             38.28%
# 13           555             41.80%
# 14          1347             45.31%
# 15           908             46.48%
# 16          3795             50.00%
# 17           680             50.39%
# 18          1979             50.00%
# 19          1076             50.78%
# 20          4793             53.91%
# 21          1464             53.13%
# 22           433             58.59%
# 23           670             60.94%
# 24          1024             64.06%
# 25          1214             62.50%
# 26          1575             86.33%
# 27            69             89.06%
# 28           189             91.80%
# 29            33             94.53%
# 30           889             97.27%
# 31           104             82.81%
# 32            63             87.50%
# 33          1151            111.33%

# %% [markdown]
# And let's plot the data:

# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
# Do not need to understand these commands
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)

X = call_data["Strike"]
Y = call_data["Last"]

plt.plot(X, Y, 'r-')
plt.title('YHOO Calls Prices')
plt.xlabel('Strike')
plt.ylabel('Last Price')

# %% [markdown]
# ### In Class Example: Crawl BuzzFeed
#
# * We will try to get the top articles that appear on Buzzfeed
# * We will grab the link for the article, the text of the title, the description, and the editor.
# * The results will be stored in a dataframe (we will see in detail what a dataframe is, in a couple of modules)

# %%
import requests # This command allows us to fetch URLs
from lxml import html # This module will allow us to parse the returned HTML/XML
import pandas

# Let's start by fetching the page, and parsing it
url = "http://www.buzzfeed.com/"
response = requests.get(url) # get the html of that url
doc = html.fromstring(response.text) # parse it and create a document

articleNodes = doc.findall('.//article') 

def parseArticleNode(article):
    headline = article.find("./header/hgroup/h2/a")
    headline_text = headline.text_content()
    headline_link = headline.get("href")
    description = article.find("./p[@class='description ']")
    description_text = description.text_content().strip()
    editor = article.find('./p[@class="small-meta small-meta--full-width"]/a[1]') 
    editor_text = editor.text_content().strip()
    result = {
        "headline": headline_text,
        "URL" : headline_link,
        "description" : description_text,
        "editor" : editor_text
    }
    return result

data = [parseArticleNode(article) for article in articleNodes]
df = pandas.DataFrame(data)
df
# Out:
#                                                   URL  \
# 0   /caitlincowie/girls-try-cosmo-flirting-tips-on...
# 1   /emmamariemusic/can-we-guess-what-you-really-w...
# 2   /christianzamora/times-disney-princes-perfectl...
# 3   /jennaguillaume/guess-im-fcking-these-dinosaur...
# 4   /aleximelvin/14-times-rachel-green-required-a-...
# 5   /samanthac4b483e219/what-disney-bound-should-y...
# 6                       /annehelenpetersen/beast-mode
# 7   /ginamaz/28-foods-to-make-sure-your-super-bowl...
# 8    /hisachie/what-beer-should-you-have-tonight-f32d
# 9   /samhaysom/photos-that-prove-britains-jurassic...
# 10  /kaitlynnknopp/if-one-tree-hill-had-used-sugge...
# 11              /mariayagoda/croatias-dalmatian-coast
# 12              /ricks14/which-guy-fieri-are-you-3i1u
# 13  /mariayagoda/16-reasons-why-sandwiches-are-bet...
# 14  /mlg263/can-you-guess-the-friends-episode-base...
# 15  /kirstenking/moments-in-history-that-were-defi...
# 16  /jimdalrympleii/gun-used-to-kill-argentinan-pr...
# 17  /kristinharris/maddie-zieglers-dance-moves-ble...
# 18  /moniquemelendez/this-is-what-happens-when-you...
# 19  /leonoraepstein/surprisingly-cool-ways-to-rock...
# 20  /chrisgeidner/ohio-will-have-no-executions-in-...
# 21  /mathewguiver/katy-perry-gifs-to-get-you-ready...
# 22  /alivelez/this-hilarious-video-perfectly-sums-...
# 23  /mjkiebus/the-universes-greatest-unsolved-myst...
# 24  /jimdalrympleii/isis-chemical-weapons-expert-k...
# 25                            /iramadison/sam-stalker
# 26               /kellyoakes/scientists-vs-the-public
# 27  /lyapalater/a-reminder-of-how-truthful-anna-ke...
# 28                  /sheridanwatson/hi-miles-whats-up
# 29              /jonmichaelpoff/going-out-with-a-bang
#
#                                           description                 editor  \
# 0                          “Big fan of the ass grab.”          Caitlin Cowie
# 1     You can have chocolate any old day of the year.              Emma Lord
# 2              You know Cinderella is a just a beard.       Christian Zamora
# 3                     Oh, there’s ghost unicorns too.        Jenna Guillaume
# 4                                      #SorryNotSorry            aleximelvin
