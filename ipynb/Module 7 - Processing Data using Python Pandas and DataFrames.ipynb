# %% [markdown]
# We start this notebook by typing a "magic" command that allows iPython notebooks to display plots directly in the browser.

# %%
# Render our plots inline
# %matplotlib inline

# %% [markdown]
# In order to read and process files, we are going to use a very powerful, and widely used Python library, called pandas. So, our next step is to import the pandas library in Python, and also import the library matplotlib for generating plots:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Pandas should already be installed on your machine, but if you get an error in the import statement above, indicating that pandas is not available, please go to the Unix shell and type:
#
# `sudo pip install -U pandas`
#
# It will take a few minutes to get everything installed.

# %% [markdown]
# And we type some code to simply change the visual style of the plots. (The code below is optional and not necessary, and for now you do not need to understand what exactly is happening.)

# %%
# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# Let's take a look at the restaurant inspections file (at /home/ubuntu/data/restaurants.csv), which we used in our earlier classes.
#
# If you do not have it, then type the following in the shell:
#
# `curl 'https://dl.dropboxusercontent.com/u/16006464/DwD_Winter2015/restaurant.zip' -o /home/ubuntu/data/restaurant.zip`
#
# `unzip /home/ubuntu/data/restaurant.zip -d /home/ubuntu/data/`

# %%
# !head -5 /home/ubuntu/data/restaurant.csv

# %% [markdown]
# We want to be able to read and process this file within Python. The pandas library has a very convenient method `read_csv` which reads the file, and returns back a variable that contains its contents.

# %%
restaurants = pd.read_csv("/home/ubuntu/data/restaurant.csv", dtype=unicode, encoding="utf-8")

# %% [markdown]
# When you read a CSV, you get back a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary. Let's take a look at how the object looks like:

# %%
restaurants.head(10)
# Out:
#       CAMIS                    DBA   BORO    BUILDING  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 1  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 2  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 3  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 4  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 5  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 6  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 7  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 8  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
# 9  30075445  MORRIS PARK BAKE SHOP  BRONX  1007
#
#                                               STREET ZIPCODE       PHONE  \
# 0  MORRIS PARK AVE                               ...   10462  7188924968
# 1  MORRIS PARK AVE                               ...   10462  7188924968
# 2  MORRIS PARK AVE                               ...   10462  7188924968
# 3  MORRIS PARK AVE                               ...   10462  7188924968
# 4  MORRIS PARK AVE                               ...   10462  7188924968
# 5  MORRIS PARK AVE                               ...   10462  7188924968
# 6  MORRIS PARK AVE                               ...   10462  7188924968
# 7  MORRIS PARK AVE                               ...   10462  7188924968
# 8  MORRIS PARK AVE                               ...   10462  7188924968
# 9  MORRIS PARK AVE                               ...   10462  7188924968
#
#   CUISINE DESCRIPTION INSPECTION DATE  \
# 0              Bakery      03/03/2014
# 1              Bakery      10/10/2013
# 2              Bakery      09/11/2013
# 3              Bakery      09/11/2013
# 4              Bakery      08/14/2013
# 5              Bakery      08/14/2013
# 6              Bakery      08/14/2013
# 7              Bakery      08/14/2013
# 8              Bakery      08/14/2013
# 9              Bakery      08/14/2013
#
#                                               ACTION VIOLATION CODE  \
# 0    Violations were cited in the following area(s).            10F
# 1  No violations were recorded at the time of thi...            NaN
# 2    Violations were cited in the following area(s).            04L
# 3    Violations were cited in the following area(s).            04N
# 4    Violations were cited in the following area(s).            04C
# 5    Violations were cited in the following area(s).            04L
# 6    Violations were cited in the following area(s).            06A
# 7    Violations were cited in the following area(s).            06C
# 8    Violations were cited in the following area(s).            08A
# 9    Violations were cited in the following area(s).            10F
#
#                                VIOLATION DESCRIPTION   CRITICAL FLAG SCORE  \
# 0  Non-food contact surface improperly constructe...    Not Critical     2
# 1                                                NaN  Not Applicable   NaN
# 2  Evidence of mice or live mice present in facil...        Critical     6
# 3  Filth flies or food/refuse/sewage-associated (...        Critical     6
# 4  Food worker does not use proper utensil to eli...        Critical    32
# 5  Evidence of mice or live mice present in facil...        Critical    32
# 6  Personal cleanliness inadequate. Outer garment...        Critical    32
# 7  Food not protected from potential source of co...        Critical    32
# 8  Facility not vermin proof. Harborage or condit...    Not Critical    32
# 9  Non-food contact surface improperly constructe...    Not Critical    32
#
#   GRADE  GRADE DATE RECORD DATE                           INSPECTION TYPE
# 0     A  03/03/2014  01/14/2015     Cycle Inspection / Initial Inspection
# 1   NaN         NaN  01/14/2015  Trans Fat / Second Compliance Inspection
# 2     A  09/11/2013  01/14/2015          Cycle Inspection / Re-inspection
# 3     A  09/11/2013  01/14/2015          Cycle Inspection / Re-inspection
# 4   NaN         NaN  01/14/2015     Cycle Inspection / Initial Inspection
# 5   NaN         NaN  01/14/2015     Cycle Inspection / Initial Inspection
# 6   NaN         NaN  01/14/2015     Cycle Inspection / Initial Inspection
# 7   NaN         NaN  01/14/2015     Cycle Inspection / Initial Inspection
# 8   NaN         NaN  01/14/2015     Cycle Inspection / Initial Inspection
# 9   NaN         NaN  01/14/2015     Cycle Inspection / Initial Inspection

# %% [markdown]
# You will notice that each line now has a number, which in a DataFrame is called the "index number" of the row (and serves as the equivalent of a primary key). If we already have a value that can serve as a primary key for a row then we can specify the "index_col" parameter.

# %%
restaurants = pd.read_csv("/home/ubuntu/data/restaurant.csv", dtype=unicode, index_col=["CAMIS"], encoding="utf-8")
restaurants
# Out:
#                                      DBA           BORO    BUILDING  \
# CAMIS
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# 30075445           MORRIS PARK BAKE SHOP          BRONX  1007
# ...                                  ...            ...         ...
# 50018804                             NaN       BROOKLYN         801
# 50018806                 OAXACA TAQUERIA      MANHATTAN         405
# 50018812                  LUKE'S LOBSTER      MANHATTAN         700
# 50018813                             NaN          BRONX        6115
# 50018816              STREETS RESTAURANT       BROOKLYN          53
# 50018819                       BRICOLAGE       BROOKLYN         162
# 50018820                             NaN          BRONX         564
# 50018822                             NaN      MANHATTAN         146
# 50018823                             NaN       BROOKLYN        1336
# 50018830                             NaN      MANHATTAN        1502
# 50018834                             NaN         QUEENS        8905
# 50018838                       ROLL N GO      MANHATTAN         386
# 50018839                     CURRY PLACE       BROOKLYN         330
# 50018845               PASTICCERIA ROCCO       BROOKLYN        9402
# 50018846                KARRIOS TEA TIME       BROOKLYN        6011
# 50018848                 OAXACA TAQUERIA      MANHATTAN         130
# 50018850                        KURO-OBI      MANHATTAN         700
# 50018853                             NaN         QUEENS        4118
# 50018854                             NaN          BRONX        3414
# 50018857                      GYRO WORLD         QUEENS        6657
# 50018858                             NaN      MANHATTAN         128
# 50018863                             NaN      MANHATTAN         127
# 50018866                             NaN         QUEENS        4017
# 50018868                             NaN          BRONX         600
# 50018870                             NaN      MANHATTAN          63
# 50018878                             NaN         QUEENS       13693
# 50018882                             NaN       BROOKLYN         723
# 50018884  DUNKIN DONUTS / BASKIN ROBBINS         QUEENS        7302
# 50018885           MANHATTANVILLE COFFEE       BROOKLYN         167
# 50018887                    JIMMY JOHN'S  STATEN ISLAND        3237
#
#                                                      STREET ZIPCODE  \
# CAMIS
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# 30075445  MORRIS PARK AVE                               ...   10462
# ...                                                     ...     ...
# 50018804                                            59TH ST   11220
# 50018806                                          W 44TH ST   10036
# 50018812                                            8TH AVE   10036
# 50018813                                           BROADWAY   10471
# 50018816                                           BROADWAY   11249
# 50018819                                            5TH AVE   11217
# 50018820                                         WALTON AVE   10451
# 50018822                                       W HOUSTON ST   10012
# 50018823                                           BROADWAY   11221
# 50018830                                      AMSTERDAM AVE   10031
# 50018834                                           37TH AVE   11372
# 50018838                                           CANAL ST   10013
# 50018839                                         MYRTLE AVE   11205
# 50018845                                            4TH AVE   11209
# 50018846                                           20TH AVE   11204
# 50018848                                           GRAND ST   10013
# 50018850                                            8TH AVE   10036
# 50018853                                            38TH ST   11101
# 50018854                                         JEROME AVE   10467
# 50018857                                      FRESH POND RD   11385
# 50018858                                            1ST AVE   10009
# 50018863                                          W 28TH ST   10001
# 50018866                                           30TH AVE   11103
# 50018868                                       VAN NEST AVE   10460
# 50018870                                           W 8TH ST   10011
# 50018878                                           37TH AVE   11354
# 50018882                                            5TH AVE   11215
# 50018884                                          AUSTIN ST   11375
# 50018885                                         ROGERS AVE   11216
# 50018887                                       RICHMOND AVE   10312
#
#                PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# CAMIS
# 30075445  7188924968              Bakery      03/03/2014
# 30075445  7188924968              Bakery      10/10/2013
# 30075445  7188924968              Bakery      09/11/2013
# 30075445  7188924968              Bakery      09/11/2013
# 30075445  7188924968              Bakery      08/14/2013
# 30075445  7188924968              Bakery      08/14/2013
# 30075445  7188924968              Bakery      08/14/2013
# 30075445  7188924968              Bakery      08/14/2013
# 30075445  7188924968              Bakery      08/14/2013
# 30075445  7188924968              Bakery      08/14/2013
# 30075445  7188924968              Bakery      06/01/2013
# 30075445  7188924968              Bakery      01/24/2013
# 30075445  7188924968              Bakery      01/24/2013
# 30075445  7188924968              Bakery      01/24/2013
# 30075445  7188924968              Bakery      12/31/2012
# 30075445  7188924968              Bakery      12/31/2012
# 30075445  7188924968              Bakery      12/31/2012
# 30075445  7188924968              Bakery      12/31/2012
# 30075445  7188924968              Bakery      12/31/2012
# 30075445  7188924968              Bakery      12/31/2012
# 30075445  7188924968              Bakery      05/03/2012
# 30075445  7188924968              Bakery      12/21/2011
# 30075445  7188924968              Bakery      11/23/2011
# 30075445  7188924968              Bakery      11/23/2011
# 30075445  7188924968              Bakery      11/23/2011
# 30075445  7188924968              Bakery      11/12/2011
# 30075445  7188924968              Bakery      11/12/2011
# 30075445  7188924968              Bakery      04/27/2011
# 30075445  7188924968              Bakery      03/10/2011
# 30075445  7188924968              Bakery      03/10/2011
# ...              ...                 ...             ...
# 50018804  6465933624               Other      01/01/1900
# 50018806  9175620005               Other      01/01/1900
# 50018812  6465594644               Other      01/01/1900
# 50018813  9145228943               Other      01/01/1900
# 50018816  2027142516               Other      01/01/1900
# 50018819  6508235565               Other      01/01/1900
# 50018820  7187429884               Other      01/01/1900
# 50018822  6466449740               Other      01/01/1900
# 50018823  7185731111               Other      01/01/1900
# 50018830  2122697722               Other      01/01/1900
# 50018834  7186519110               Other      01/01/1900
# 50018838  9172925286               Other      01/01/1900
# 50018839  7185223828               Other      01/01/1900
# 50018845  9176227242               Other      01/01/1900
# 50018846  9175888829               Other      01/01/1900
# 50018848  9175620005               Other      01/01/1900
# 50018850  9173381011               Other      01/01/1900
# 50018853  7187294000               Other      01/01/1900
# 50018854  7185475900               Other      01/01/1900
# 50018857  6467251870               Other      01/01/1900
# 50018858  3478578557               Other      01/01/1900
# 50018863  2129739000               Other      01/01/1900
# 50018866  2126736666               Other      01/01/1900
# 50018868  6463926432               Other      01/01/1900
# 50018870  7819266400               Other      01/01/1900
# 50018878  3472710588               Other      01/01/1900
# 50018882  7183442012               Other      01/01/1900
# 50018884  7185750892               Other      01/01/1900
# 50018885  7189540954               Other      01/01/1900
# 50018887  3176701112               Other      01/01/1900
#
#                                                      ACTION VIOLATION CODE  \
# CAMIS
# 30075445    Violations were cited in the following area(s).            10F
# 30075445  No violations were recorded at the time of thi...            NaN
# 30075445    Violations were cited in the following area(s).            04L
# 30075445    Violations were cited in the following area(s).            04N
# 30075445    Violations were cited in the following area(s).            04C
# 30075445    Violations were cited in the following area(s).            04L
# 30075445    Violations were cited in the following area(s).            06A
# 30075445    Violations were cited in the following area(s).            06C
# 30075445    Violations were cited in the following area(s).            08A
# 30075445    Violations were cited in the following area(s).            10F
# 30075445    Violations were cited in the following area(s).            16B
# 30075445    Violations were cited in the following area(s).            02G
# 30075445    Violations were cited in the following area(s).            10F
# 30075445  No violations were recorded at the time of thi...            NaN
# 30075445    Violations were cited in the following area(s).            02G
# 30075445    Violations were cited in the following area(s).            04L
# 30075445    Violations were cited in the following area(s).            06C
# 30075445    Violations were cited in the following area(s).            08A
# 30075445    Violations were cited in the following area(s).            10F
# 30075445    Violations were cited in the following area(s).            16B
# 30075445  No violations were recorded at the time of thi...            NaN
# 30075445    Violations were cited in the following area(s).            16B
# 30075445    Violations were cited in the following area(s).            06C
# 30075445    Violations were cited in the following area(s).            10B
# 30075445    Violations were cited in the following area(s).            10H
# 30075445    Violations were cited in the following area(s).            16A
# 30075445    Violations were cited in the following area(s).            16B
# 30075445    Violations were cited in the following area(s).            16A
# 30075445    Violations were cited in the following area(s).            04L
# 30075445    Violations were cited in the following area(s).            10F
# ...                                                     ...            ...
# 50018804                                                NaN            NaN
# 50018806                                                NaN            NaN
# 50018812                                                NaN            NaN
# 50018813                                                NaN            NaN
# 50018816                                                NaN            NaN
# 50018819                                                NaN            NaN
# 50018820                                                NaN            NaN
# 50018822                                                NaN            NaN
# 50018823                                                NaN            NaN
# 50018830                                                NaN            NaN
# 50018834                                                NaN            NaN
# 50018838                                                NaN            NaN
# 50018839                                                NaN            NaN
# 50018845                                                NaN            NaN
# 50018846                                                NaN            NaN
# 50018848                                                NaN            NaN
# 50018850                                                NaN            NaN
# 50018853                                                NaN            NaN
# 50018854                                                NaN            NaN
# 50018857                                                NaN            NaN
# 50018858                                                NaN            NaN
# 50018863                                                NaN            NaN
# 50018866                                                NaN            NaN
# 50018868                                                NaN            NaN
# 50018870                                                NaN            NaN
# 50018878                                                NaN            NaN
# 50018882                                                NaN            NaN
# 50018884                                                NaN            NaN
# 50018885                                                NaN            NaN
# 50018887                                                NaN            NaN
#
#                                       VIOLATION DESCRIPTION   CRITICAL FLAG  \
# CAMIS
# 30075445  Non-food contact surface improperly constructe...    Not Critical
# 30075445                                                NaN  Not Applicable
# 30075445  Evidence of mice or live mice present in facil...        Critical
# 30075445  Filth flies or food/refuse/sewage-associated (...        Critical
# 30075445  Food worker does not use proper utensil to eli...        Critical
# 30075445  Evidence of mice or live mice present in facil...        Critical
# 30075445  Personal cleanliness inadequate. Outer garment...        Critical
# 30075445  Food not protected from potential source of co...        Critical
# 30075445  Facility not vermin proof. Harborage or condit...    Not Critical
# 30075445  Non-food contact surface improperly constructe...    Not Critical
# 30075445  The original nutritional fact labels and/or in...    Not Critical
# 30075445  Cold food item held above 41º F (smoked fish a...        Critical
# 30075445  Non-food contact surface improperly constructe...    Not Critical
# 30075445                                                NaN  Not Applicable
# 30075445  Cold food item held above 41º F (smoked fish a...        Critical
# 30075445  Evidence of mice or live mice present in facil...        Critical
# 30075445  Food not protected from potential source of co...        Critical
# 30075445  Facility not vermin proof. Harborage or condit...    Not Critical
# 30075445  Non-food contact surface improperly constructe...    Not Critical
# 30075445  The original nutritional fact labels and/or in...    Not Critical
# 30075445                                                NaN  Not Applicable
# 30075445  The original nutritional fact labels and/or in...    Not Critical
# 30075445  Food not protected from potential source of co...        Critical
# 30075445  Plumbing not properly installed or maintained;...    Not Critical
# 30075445  Proper sanitization not provided for utensil w...    Not Critical
# 30075445  A food containing artificial trans fat, with 0...    Not Critical
# 30075445  The original nutritional fact labels and/or in...    Not Critical
# 30075445  A food containing artificial trans fat, with 0...    Not Critical
# 30075445  Evidence of mice or live mice present in facil...        Critical
# 30075445  Non-food contact surface improperly constructe...    Not Critical
# ...                                                     ...             ...
# 50018804                                                NaN  Not Applicable
# 50018806                                                NaN  Not Applicable
# 50018812                                                NaN  Not Applicable
# 50018813                                                NaN  Not Applicable
# 50018816                                                NaN  Not Applicable
# 50018819                                                NaN  Not Applicable
# 50018820                                                NaN  Not Applicable
# 50018822                                                NaN  Not Applicable
# 50018823                                                NaN  Not Applicable
# 50018830                                                NaN  Not Applicable
# 50018834                                                NaN  Not Applicable
# 50018838                                                NaN  Not Applicable
# 50018839                                                NaN  Not Applicable
# 50018845                                                NaN  Not Applicable
# 50018846                                                NaN  Not Applicable
# 50018848                                                NaN  Not Applicable
# 50018850                                                NaN  Not Applicable
# 50018853                                                NaN  Not Applicable
# 50018854                                                NaN  Not Applicable
# 50018857                                                NaN  Not Applicable
# 50018858                                                NaN  Not Applicable
# 50018863                                                NaN  Not Applicable
# 50018866                                                NaN  Not Applicable
# 50018868                                                NaN  Not Applicable
# 50018870                                                NaN  Not Applicable
# 50018878                                                NaN  Not Applicable
# 50018882                                                NaN  Not Applicable
# 50018884                                                NaN  Not Applicable
# 50018885                                                NaN  Not Applicable
# 50018887                                                NaN  Not Applicable
#
#          SCORE GRADE  GRADE DATE RECORD DATE  \
# CAMIS
# 30075445     2     A  03/03/2014  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445     6     A  09/11/2013  01/14/2015
# 30075445     6     A  09/11/2013  01/14/2015
# 30075445    32   NaN         NaN  01/14/2015
# 30075445    32   NaN         NaN  01/14/2015
# 30075445    32   NaN         NaN  01/14/2015
# 30075445    32   NaN         NaN  01/14/2015
# 30075445    32   NaN         NaN  01/14/2015
# 30075445    32   NaN         NaN  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445    10     A  01/24/2013  01/14/2015
# 30075445    10     A  01/24/2013  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445    25   NaN         NaN  01/14/2015
# 30075445    25   NaN         NaN  01/14/2015
# 30075445    25   NaN         NaN  01/14/2015
# 30075445    25   NaN         NaN  01/14/2015
# 30075445    25   NaN         NaN  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445     9     A  11/23/2011  01/14/2015
# 30075445     9     A  11/23/2011  01/14/2015
# 30075445     9     A  11/23/2011  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445   NaN   NaN         NaN  01/14/2015
# 30075445    14     B  03/10/2011  01/14/2015
# 30075445    14     B  03/10/2011  01/14/2015
# ...        ...   ...         ...         ...
# 50018804   NaN   NaN         NaN  01/14/2015
# 50018806   NaN   NaN         NaN  01/14/2015
# 50018812   NaN   NaN         NaN  01/14/2015
# 50018813   NaN   NaN         NaN  01/14/2015
# 50018816   NaN   NaN         NaN  01/14/2015
# 50018819   NaN   NaN         NaN  01/14/2015
# 50018820   NaN   NaN         NaN  01/14/2015
# 50018822   NaN   NaN         NaN  01/14/2015
# 50018823   NaN   NaN         NaN  01/14/2015
# 50018830   NaN   NaN         NaN  01/14/2015
# 50018834   NaN   NaN         NaN  01/14/2015
# 50018838   NaN   NaN         NaN  01/14/2015
# 50018839   NaN   NaN         NaN  01/14/2015
# 50018845   NaN   NaN         NaN  01/14/2015
# 50018846   NaN   NaN         NaN  01/14/2015
# 50018848   NaN   NaN         NaN  01/14/2015
# 50018850   NaN   NaN         NaN  01/14/2015
# 50018853   NaN   NaN         NaN  01/14/2015
# 50018854   NaN   NaN         NaN  01/14/2015
# 50018857   NaN   NaN         NaN  01/14/2015
# 50018858   NaN   NaN         NaN  01/14/2015
# 50018863   NaN   NaN         NaN  01/14/2015
# 50018866   NaN   NaN         NaN  01/14/2015
# 50018868   NaN   NaN         NaN  01/14/2015
# 50018870   NaN   NaN         NaN  01/14/2015
# 50018878   NaN   NaN         NaN  01/14/2015
# 50018882   NaN   NaN         NaN  01/14/2015
# 50018884   NaN   NaN         NaN  01/14/2015
# 50018885   NaN   NaN         NaN  01/14/2015
# 50018887   NaN   NaN         NaN  01/14/2015
#
#                                    INSPECTION TYPE
# CAMIS
# 30075445     Cycle Inspection / Initial Inspection
# 30075445  Trans Fat / Second Compliance Inspection
# 30075445          Cycle Inspection / Re-inspection
# 30075445          Cycle Inspection / Re-inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445         Trans Fat / Compliance Inspection
# 30075445          Cycle Inspection / Re-inspection
# 30075445          Cycle Inspection / Re-inspection
# 30075445                 Trans Fat / Re-inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445            Trans Fat / Initial Inspection
# 30075445  Trans Fat / Second Compliance Inspection
# 30075445  Trans Fat / Second Compliance Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445     Cycle Inspection / Initial Inspection
# 30075445  Trans Fat / Second Compliance Inspection
# 30075445  Trans Fat / Second Compliance Inspection
# 30075445         Trans Fat / Compliance Inspection
# 30075445          Cycle Inspection / Re-inspection
# 30075445          Cycle Inspection / Re-inspection
# ...                                            ...
# 50018804                                       NaN
# 50018806                                       NaN
# 50018812                                       NaN
# 50018813                                       NaN
# 50018816                                       NaN
# 50018819                                       NaN
# 50018820                                       NaN
# 50018822                                       NaN
# 50018823                                       NaN
# 50018830                                       NaN
# 50018834                                       NaN
# 50018838                                       NaN
# 50018839                                       NaN
# 50018845                                       NaN
# 50018846                                       NaN
# 50018848                                       NaN
# 50018850                                       NaN
# 50018853                                       NaN
# 50018854                                       NaN
# 50018857                                       NaN
# 50018858                                       NaN
# 50018863                                       NaN
# 50018866                                       NaN
# 50018868                                       NaN
# 50018870                                       NaN
# 50018878                                       NaN
# 50018882                                       NaN
# 50018884                                       NaN
# 50018885                                       NaN
# 50018887                                       NaN
#
# [515589 rows x 17 columns]

# %% [markdown]
# The read_csv method has many options, and you can read further in the [online documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.parsers.read_csv.html).

# %% [markdown]
# ### Descriptive statistics
#
# We can use the method "describe()" to get a quick overview of the data in the dataframe.

# %%
restaurants.describe()

# %% [markdown]
# ### Selecting a subset of the columns
#
# In a dataframe, we can specify the column(s) that we want to keep, and get back another dataframe with just the subset of the columns that we want to keep.

# %%
restaurants["VIOLATION CODE"]

# %%
restaurants[["GRADE DATE","VIOLATION CODE"]]

# %% [markdown]
# We can also get quick statistics about the common values that appear in each column:

# %%
violation_counts = restaurants["VIOLATION CODE"].value_counts();
violation_counts[0:10]

# %% [markdown]
# And we can use the "plot" command to plot the resulting histogram:

# %%
violation_counts[:20].plot(kind='bar')

# %% [markdown]
# #### Using the map command
#
# The map command in Python has the following syntax:
#
# `map(function, [list of values for first argument], [list of values for second argument]...)`
#
# It takes as input a function, which has a set of parameters. Then, it iterates over the lists that follow; the lists contain the arguments that are passed to the function. Map returns a list of values that are the result of applying the function to all the elements of the list(s).
#
# For example, in the following code, the `add` function is going to be applied to the two lists (`[1, 2, 3, 4]` and `[9, 10, 10, 11]`) that follow. The result of the map will be a list containing the values `[add(1,2), add(2,10), add(3,10), add(4,11)]`

# %%
def add(x,y):
    return x+y
    
example = map(add, [1, 2, 3, 4, 6], [9, 10, 10, 11, 13])
example

# %% [markdown]
# #### Using the map for dataframes
#
# Using the map command, we can:
# * Create new columns for the dataframe
# * Modify existing columns
# * Generate new lists that are the result of operations on the columns of the dataframe
#
# For example, suppose that Pandas were not able to understand that `GRADE DATE` is a datetime. We can apply the `to_datetime` function to all the elements of that column, and replace the column with datetime objects:

# %%
from pandas.tseries.tools import to_datetime

restaurants["GRADE_DATE_NEW"] = map(to_datetime, restaurants["GRADE DATE"])

# %%
restaurants[["GRADE_DATE_NEW", "GRADE DATE"]]

# %%
from pandas.tseries.tools import to_datetime
to_datetime("2/1/2015 11:44am")

# %% [markdown]
# Or that we really do not like the names of boroughs in the "BORO" attribute, so we want to replace them with their hipster versions. We can define a function that takes as input the borough code, and returns the hipster name of the borough. Then, we use the map function to apply it to the column "BORO". We can then either replace the "BORO" column with the revised version, or (more safe) create a new column with the new version:

# %%
def hipsterize(borocode):
    if borocode == "MANHATTAN":
        return "Manna-hata"
    elif borocode == "BRONX":
        return "Bronck's"
    elif borocode == "BROOKLYN":
        return "Breuckelen"
    elif borocode == "QUEENS":
        return "Queens" # Queens cannot be hipsterized, hipsters!
    elif borocode == "STATEN ISLAND":
        return "St-Generaal" 
    else:
        return "N/A"
    
restaurants['HipsterBorough'] = map(hipsterize, restaurants['BORO'])

# %%
restaurants[["DBA", "BORO", "HipsterBorough"]]
# Out:
#                                      DBA           BORO HipsterBorough
# CAMIS
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# 30075445           MORRIS PARK BAKE SHOP          BRONX       Bronck's
# ...                                  ...            ...            ...
# 50018804                             NaN       BROOKLYN     Breuckelen
# 50018806                 OAXACA TAQUERIA      MANHATTAN     Manna-hata
# 50018812                  LUKE'S LOBSTER      MANHATTAN     Manna-hata
# 50018813                             NaN          BRONX       Bronck's
# 50018816              STREETS RESTAURANT       BROOKLYN     Breuckelen
# 50018819                       BRICOLAGE       BROOKLYN     Breuckelen
# 50018820                             NaN          BRONX       Bronck's
# 50018822                             NaN      MANHATTAN     Manna-hata
# 50018823                             NaN       BROOKLYN     Breuckelen
# 50018830                             NaN      MANHATTAN     Manna-hata
# 50018834                             NaN         QUEENS         Queens
# 50018838                       ROLL N GO      MANHATTAN     Manna-hata
# 50018839                     CURRY PLACE       BROOKLYN     Breuckelen
# 50018845               PASTICCERIA ROCCO       BROOKLYN     Breuckelen
# 50018846                KARRIOS TEA TIME       BROOKLYN     Breuckelen
# 50018848                 OAXACA TAQUERIA      MANHATTAN     Manna-hata
# 50018850                        KURO-OBI      MANHATTAN     Manna-hata
# 50018853                             NaN         QUEENS         Queens
# 50018854                             NaN          BRONX       Bronck's
# 50018857                      GYRO WORLD         QUEENS         Queens
# 50018858                             NaN      MANHATTAN     Manna-hata
# 50018863                             NaN      MANHATTAN     Manna-hata
# 50018866                             NaN         QUEENS         Queens
# 50018868                             NaN          BRONX       Bronck's
# 50018870                             NaN      MANHATTAN     Manna-hata
# 50018878                             NaN         QUEENS         Queens
# 50018882                             NaN       BROOKLYN     Breuckelen
# 50018884  DUNKIN DONUTS / BASKIN ROBBINS         QUEENS         Queens
# 50018885           MANHATTANVILLE COFFEE       BROOKLYN     Breuckelen
# 50018887                    JIMMY JOHN'S  STATEN ISLAND    St-Generaal
#
# [515589 rows x 3 columns]

# %% [markdown]
# ### Selecting rows
#
# To select rows, we can use the following approach, where we generate a list of boolean values, one for each row of the dataframe, and then we use the list to select which of the rows of the dataframe we want to keep"

# %%
is_08A = (restaurants["VIOLATION CODE"] == "08A")
inspections08A = restaurants[is_08A]
inspections08A["DBA"].value_counts()[:10]

# %% [markdown]
# And we can use more complex conditions:

# %%
is_08A_manhattan = (restaurants["VIOLATION CODE"] == "08A") & (restaurants["BORO"] == "MANHATTAN")
inspections08A_in_manhattan = restaurants[is_08A_manhattan]
inspections08A_in_manhattan["DBA"].value_counts()[:10]

# %%
is_08A = (restaurants["VIOLATION CODE"] == "08A")
violations08A = restaurants[is_08A]
violations08A

# %%
violations08Acounts = violations08A['BORO'].value_counts()
violations08Acounts

# %%
boro_counts = restaurants['BORO'].value_counts()
boro_counts

# %%
violations08Acounts / boro_counts

# %%
(violations08Acounts / boro_counts).plot(kind='bar')

# %% [markdown]
# ## Reading Excel files
#
# Pandas make it trivially easy to read the contents of Excel files. For example, I stored the restaurant inspection dataset as an excel file. Let's grab it and get it stored locally:

# %%
# !curl -L -s "https://dl.dropboxusercontent.com/u/16006464/DwD_Fall2014/Restaurants.xlsx" -o Restaurants.xlsx

# %% [markdown]
# To read the Excel file, pandas uses the xlrd package. It is already installed in your machine, but if not, then type this in the shell:
#
# `sudo pip install xlrd`

# %%
restaurantsExcelFile = pd.ExcelFile("Restaurants.xlsx");

# %% [markdown]
# Read the worksheet named "WebExtract"

# %%
tableWebExtract = restaurantsExcelFile.parse(sheetname="WebExtract");

# %%
tableViolationCodes = restaurantsExcelFile.parse(sheetname='Violation');

# %%
tableWebExtract

# %%
tableViolationCodes

# %% [markdown]
# ### Comparison with SQL
#
# For a comparison with SQL, see http://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html

# %% [markdown]
# Pandas supports its own set of operators for doing SQL-like operations (in reality it runs a in-memory SQL database in the backend). It is also possible to use straightforward SQL queries to query Pandas dataframes, by using the `pandasql` package:

# %%
# !sudo -H pip install -U pandasql

# %%
from pandasql import sqldf

# %%
def pysqldf(q):
    return sqldf(q, globals())

# %%
# PandaSQL does not like column names with spaces. So we will rename (some of) them.
restaurants.rename(columns={"VIOLATION CODE": "VIOLATION"}, inplace = True)

# %%
rest = restaurants[["DBA", "BORO", "VIOLATION"]]

# %%
q  = """
SELECT BORO, VIOLATION, COUNT(*) AS CNT 
FROM
  rest
GROUP BY BORO, VIOLATION
ORDER BY CNT DESC
LIMIT 20;
"""

df = pysqldf(q)

# %%
df
