# %% [markdown]
# ## Authentication with OAuth2

# %% [markdown]
# Some of you may have already used APIs that require passing a specific key, to authorize the API calls. So the question naturally comes up: Why is that not sufficient for authentication?
#
# Here are a few reasons:
#
# * We often want our application to **act on behalf of a user** (e.g., retrieve the list of friends of a user on Facebook, and do some analysis on behalf of the user). OAuth allows for such delegation, without requiring the app to have access to the login credentials of the user.
# * Acting on behalf of a user also allows the quota to be adjusted on a per-user basis, as opposed to a per-app basis. (So that the creators of very popular apps do not have to increase the quota for their own key)
# * Users often want to give limited set of priviledges to the app (e.g., read only my profile, no posting).
# * Users want to be able to selectively remove access for specific apps, without having to change the credentials for other apps.
#
# So, how does OAuth achieves that?

# %% [markdown]
# ## OAuth2 flows

# %% [markdown]
# Fundamentally, we have the following steps:
#
# * The app sends the user to a login page. The login page asks the user whether the user really wants to grant these permissions to the app.
# * The user logs in and grants the permissions. This generates an **authorization code** that the API sends back to the app (by **calling back a _redirect URL_**)
# * The app uses the authorization code (which proves that the user has granted permissions), and calls the API, asking for an **access token**.
# * The **access token** can then be used by the app to call the API on behalf of the user.
#
# The picture below illustrates the OAuth2 flow:
#
# <img src="https://assets.digitalocean.com/articles/oauth/abstract_flow.png">
#
# Also these two tutorials explain in a simplified manner the details of the authentication process:
# * https://www.digitalocean.com/community/tutorials/an-introduction-to-oauth-2
# * http://aaronparecki.com/articles/2012/07/29/1/oauth2-simplified

# %% [markdown]
# ### Running our own Python-based web server: Flask

# %% [markdown]
# As you can see from the above "flow", in OAuth2 authentication, we will need to have our own web server, to receive the answers that come back from the API. Python can do that using Flask, a very lightweight webserver. Below you can find a small example of a webserver that will run on your machine at port 5000.
#
# _Please note that we have configured this webserver to shutdown after a responding to a single call (we added the "stop_server()" function call in call responses)._
#
# Once you run the call, visit http://yourIP:5000/ or http://yourIP:5000/testNYU to see the results. The server will stop immediately after, and the cell will stop being in "Busy" status.

# %%
# In this cell, we configure our example web server. 
# We will show in the next cell how to configure this
# web server to handle the OAuth2 calls.

# Flask is a webserver
from flask import Flask, request

# Initialize the embedded web server
webserver = Flask("MyFirstWebServer")

# Go to http://<your IP>:5000/ to see the response
@webserver.route('/')
def hello_world():
    stop_server()
    return 'Hello World!'

# Go to http://<your IP>:5000/testNYU to see the different message
@webserver.route('/testNYU')
def hello_nyu():
    stop_server()
    return 'Hello NYU!'

def start_server():
    webserver.run(host='0.0.0.0', port=5000)
    return
    
def stop_server():
    shutdown_after_request = request.environ.get('werkzeug.server.shutdown')
    shutdown_after_request()
    return

start_server()

# %% [markdown]
# ### Accessing the Jawbone API using OAuth2

# %% [markdown]
# OK, enough with the example.
#
# Next, we will create the code that can interact with the Jawbone API. The Jawbone API documentation (https://jawbone.com/up/developer/) provides a [good explanation of the authentication process](https://jawbone.com/up/developer/authentication).
#
# Below, we implement the OAuth2 flow for the API. The code below will create the webserver that will handle the "callback" calls from the API. (Steps 3 and 4 from the figure above.) Then, we will show how to implement the rest of the flow.

# %%
# This part creates a temporary web server to "receive" the requests by Jawbone

# In this cell, we just configure the server. We will start it, 
# using the command webserver.run(host='0.0.0.0') in the next cell

# Flask is a webserver
from flask import Flask, request

# We will use that part to issue a request to Jawbone
import requests
import json



# Get these after registering an app with Jawbone
# These are to communicate to Jawbone that the requests come
# from a legitimate, registered app
CLIENT_ID = 'F3rPnz_fTUY'
CLIENT_SECRET = 'efaedc99a6bc5fb40f4be3b8fb97c6b94a7eec58'

# This is the location where we will store the authentication data from Jawbone
OAUTH_FILE = '/home/ubuntu/data/jawbone_secret.json'

# Initialize the embedded web server
webserver = Flask("JawboneOAuth")

# The function below will implement the sole functionality of our server.
# The Jawbone API will first authenticate the user and then direct the browser
# to http://<your ip>:5000/receiveCode in order to send the code to the app.
# 
# This is the place where the webserver will receive the call from Jawbone
# with the authentication code (Step 3 in https://jawbone.com/up/developer/authentication)
# Notice that we will use the http://<your ip>:5000/receiveCode address below as the redirect URI 
@webserver.route("/receiveCode")
def oauth_helper():
    code = request.args.get('code')
    
    # Now that we got the code, we move to Step 4 of the instructions
    # and request the access token from Jawbone. Notice that we 
    # use the client_secret to prove that the app is the real one
    # that was registered with the Jawbone API
    url = "https://jawbone.com/auth/oauth2/token"
    params = {"grant_type": "authorization_code", 
              "client_id": CLIENT_ID, 
              "client_secret": CLIENT_SECRET, 
              "code": code }
    resp = requests.get(url, params=params)
    data = json.loads(resp.text)
    
    # We store the code in a file as the webserver does not interact with the 
    # rest of the Python code, and we also want to reuse the code in the future
    # (Typically, we would store the access_token in a database.)
    f = open(OAUTH_FILE, 'w') # Store the code as a file
    f.write(resp.text)
    f.close()
    
    # It is safe (and convenient) to shut down the web server after this request
    stop_server()
    
    # What we return here has no real impact on the functionality of the code
    return '<html><body>Code: <b>'+code+'</b><p>Response:<b>'+resp.text+'</b></body></html>'


def start_server():
    webserver.run(host='0.0.0.0', port=5000)
    return
    
def stop_server():
    shutdown_after_request = request.environ.get('werkzeug.server.shutdown')
    shutdown_after_request()
    return

# %% [markdown]
# So our server is running now, and it's ready to accept the requests from Jawbone.
#
# Let's start the OAuth2 flow now, to first interact with the user and get the user to login and grant permissions. (Steps 1 and 2 of the figure above.)

# %%
# To get the server to run in the background
import threading

# This part is required to come up with the pop-up with which Jawbone will ask for permissions
from IPython.display import display
from IPython.display import Javascript as JS


# Send an OAuth request to Jawbone, handle the redirect, and display the access
# token that's included in the redirect for the user to copy and paste
REDIRECT_URI = 'http://ipython.ipeirotis.com:5000/receiveCode'
JAWBONE_URL = 'https://jawbone.com/auth/oauth2/auth'
PERMISSIONS = 'basic_read extended_read sleep_read move_read'

url = (JAWBONE_URL + 
       '?response_type=code&client_id='+ CLIENT_ID + 
       '&scope=' + PERMISSIONS +
       '&redirect_uri=' + REDIRECT_URI )

# The code below is necessary to pop up the login window from Jawbone
# The login still start in a separate thread, in order to allow the execution
# to continue, and run the "start_server()" call below.
threading.Timer(1, lambda: display(JS("window.open('%s')" % url))).start()

# And now start the webserver so that we can receive the answer from Jawbone API
start_server()

# %%
# Read the access token from the file
f = open(OAUTH_FILE, 'r') 
content = f.read()
f.close()
auth_info = json.loads(content)

auth_info
# Out:
# {u'access_token': u'aV1SI82xvTr8kBFGA3_2VAo-F5IbiT1zPxpUR_-PPzNC7LrLTyKlES6pRlVsJUdJ8c9QkoSzRYiFw6yPEhcRiFECdgRlo_GULMgGZS0EumxrKbZFiOmnmAPChBPDZ5JP',
#  u'expires_in': 31536000,
#  u'refresh_token': u'gkGL9TjxP67eAnSXM0K37py9XOpU5P3eut8Xi9a70xzdL2WxNgQvKekaCy5aBtavNNWfJhnfRQwlAN2iCODyqw',
#  u'token_type': u'Bearer'}

# %% [markdown]
# At this point we are pretty much done. We only need to send standard API calls, as usual, with the only addition being that we include an extra _header_ in the request, with the access_token. The code below is just showing various use cases of the API.

# %%
# Testing one of the API endpoints
endpoint = "https://jawbone.com/nudge/api/v.1.1/users/@me/bandevents"

# See https://jawbone.com/up/developer/endpoints/bandevents for details
params = {}
headers = {'Authorization': 'Bearer ' + auth_info['access_token']}
resp = requests.get(endpoint, params=params, headers=headers)
bandevents_data = json.loads(resp.text)
bandevents_data
# Out:
# {u'data': {u'items': [{u'action': u'exit_sleep_mode',
#     u'date': 20150811,
#     u'time_created': 1439275648,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'enter_sleep_mode',
#     u'date': 20150811,
#     u'time_created': 1439241728,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'exit_sleep_mode',
#     u'date': 20150810,
#     u'time_created': 1439181184,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'enter_sleep_mode',
#     u'date': 20150810,
#     u'time_created': 1439180288,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'exit_sleep_mode',
#     u'date': 20150810,
#     u'time_created': 1439180288,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'enter_sleep_mode',
#     u'date': 20150810,
#     u'time_created': 1439175936,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'exit_sleep_mode',
#     u'date': 20150810,
#     u'time_created': 1439175680,
#     u'tz': u'Europe/Athens'},
#    {u'action': u'exit_sleep_mode',
#     u'date': 20150727,
#     u'time_created': 1438020608,
#     u'tz': u'America/New_York'},
#    {u'action': u'enter_sleep_mode',
#     u'date': 20150727,
#     u'time_created': 1437974528,
#     u'tz': u'America/New_York'},
#    {u'action': u'exit_sleep_mode',
#     u'date': 20150722,
#     u'time_created': 1437571840,
#     u'tz': u'America/New_York'}],
#   u'size': 10},
#  u'meta': {u'code': 200,
#   u'message': u'OK',
#   u'time': 1441030737,
#   u'user_xid': u'6CEDmZ-RtVRKxBB-NA5PoQ'}}

# %%
print bandevents_data[u'meta'][u'user_xid']
# Out:
# 6CEDmZ-RtVRKxBB-NA5PoQ

# %%
import pandas as pd
df = pd.DataFrame(bandevents_data["data"]["items"])
df
# Out:
#              action      date  time_created                tz
# 0   exit_sleep_mode  20150811    1439275648     Europe/Athens
# 1  enter_sleep_mode  20150811    1439241728     Europe/Athens
# 2   exit_sleep_mode  20150810    1439181184     Europe/Athens
# 3  enter_sleep_mode  20150810    1439180288     Europe/Athens
# 4   exit_sleep_mode  20150810    1439180288     Europe/Athens
# 5  enter_sleep_mode  20150810    1439175936     Europe/Athens
# 6   exit_sleep_mode  20150810    1439175680     Europe/Athens
# 7   exit_sleep_mode  20150727    1438020608  America/New_York
# 8  enter_sleep_mode  20150727    1437974528  America/New_York
# 9   exit_sleep_mode  20150722    1437571840  America/New_York

# %%
df["time_created"] = map(lambda x : datetime.datetime.fromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'), df["time_created"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-469818b476a3> in <module>()
# ----> 1 df["time_created"] = map(lambda x : datetime.datetime.fromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'), df["time_created"])
#
# <ipython-input-7-469818b476a3> in <lambda>(x)
# ----> 1 df["time_created"] = map(lambda x : datetime.datetime.fromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'), df["time_created"])
#
# NameError: global name 'datetime' is not defined

# %%
df

# %%
# Testing another of the API endpoints
endpoint = "https://jawbone.com/nudge/api/v.1.1/users/@me/moves"

# See https://jawbone.com/up/developer/endpoints/moves for details
params = {}
headers = {'Authorization': 'Bearer ' + auth_info['access_token']}
resp = requests.get(endpoint, params=params, headers=headers)
moves_data = json.loads(resp.text)
moves_data
# Out:
# {u'data': {u'items': [{u'date': 20150831,
#     u'details': {u'active_time': 0,
#      u'bg_calories': 4.64046832919,
#      u'bmr': 754.959650969,
#      u'bmr_day': 1754.84089644,
#      u'calories': 4.64046832919,
#      u'distance': 47.4755296707,
#      u'hourly_totals': {u'2015083107': {u'active_time': 0,
#        u'calories': 4.64046832919,
#        u'distance': 47.4755296707,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 59}},
#      u'inactive_time': 0,
#      u'km': 0.0474755296707,
#      u'longest_active': 0,
#      u'longest_idle': 0,
#      u'steps': 59,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'America/New_York',
#      u'tzs': [[1441021397, u'America/New_York']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1441021906/trVF_JXR-jtOB1ClNquC7kuWnWM8m_Ko/F3rPnz_fTUY.png',
#     u'time_completed': 1441021603,
#     u'time_created': 1441021397,
#     u'time_updated': 1441030770,
#     u'title': u'59 steps today',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jtOB1ClNquC7kuWnWM8m_Ko'},
#    {u'date': 20150830,
#     u'details': {u'active_time': 433,
#      u'bg_calories': 149.835830659,
#      u'bmr': 1746.0647954,
#      u'bmr_day': 1746.0647954,
#      u'calories': 158.630438548,
#      u'distance': 2249.05264664,
#      u'hourly_totals': {u'2015083009': {u'active_time': 0,
#        u'calories': 14.345957756,
#        u'distance': 280.025146484,
#        u'inactive_time': 3302,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3302,
#        u'steps': 348},
#       u'2015083010': {u'active_time': 0,
#        u'calories': 10.0788621902,
#        u'distance': 193.120803833,
#        u'inactive_time': 57,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 57,
#        u'steps': 240},
#       u'2015083013': {u'active_time': 300,
#        u'calories': 22.6314997673,
#        u'distance': 432.912475586,
#        u'inactive_time': 2329,
#        u'longest_active_time': 300,
#        u'longest_idle_time': 2029,
#        u'steps': 538},
#       u'2015083014': {u'active_time': 8,
#        u'calories': 19.3497282267,
#        u'distance': 66.7876081467,
#        u'inactive_time': 2679,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 1776,
#        u'steps': 83},
#       u'2015083016': {u'active_time': 2,
#        u'calories': 20.1012132466,
#        u'distance': 244.619684219,
#        u'inactive_time': 3238,
#        u'longest_active_time': 2,
#        u'longest_idle_time': 2170,
#        u'steps': 304},
#       u'2015083017': {u'active_time': 13,
#        u'calories': 15.8127269447,
#        u'distance': 234.158965111,
#        u'inactive_time': 2091,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 981,
#        u'steps': 291},
#       u'2015083018': {u'active_time': 98,
#        u'calories': 45.6147810221,
#        u'distance': 765.241163254,
#        u'inactive_time': 3264,
#        u'longest_active_time': 61,
#        u'longest_idle_time': 1109,
#        u'steps': 951},
#       u'2015083019': {u'active_time': 9,
#        u'calories': 1.43263298273,
#        u'distance': 25.7494401932,
#        u'inactive_time': 2171,
#        u'longest_active_time': 7,
#        u'longest_idle_time': 2171,
#        u'steps': 32},
#       u'2015083021': {u'active_time': 3,
#        u'calories': 0.468428522348,
#        u'distance': 6.43735980988,
#        u'inactive_time': 0,
#        u'longest_active_time': 3,
#        u'longest_idle_time': 0,
#        u'steps': 8}},
#      u'inactive_time': 38856,
#      u'km': 2.24905264664,
#      u'longest_active': 300,
#      u'longest_idle': 16429,
#      u'steps': 2795,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'America/New_York',
#      u'tzs': [[1440942902, u'America/New_York']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1441017697/trVF_JXR-jsrYaR7dadQvj716P8b7BcX/F3rPnz_fTUY.png',
#     u'time_completed': 1440983580,
#     u'time_created': 1440942902,
#     u'time_updated': 1441030770,
#     u'title': u'2,795 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jsrYaR7dadQvj716P8b7BcX'},
#    {u'date': 20150829,
#     u'details': {u'active_time': 3349,
#      u'bg_calories': 408.093996197,
#      u'bmr': 1686.85608003,
#      u'bmr_day': 1686.85608003,
#      u'calories': 476.115826302,
#      u'distance': 6621.62948704,
#      u'hourly_totals': {u'2015082909': {u'active_time': 172,
#        u'calories': 39.4748913646,
#        u'distance': 572.120378494,
#        u'inactive_time': 3393,
#        u'longest_active_time': 172,
#        u'longest_idle_time': 2372,
#        u'steps': 711},
#       u'2015082914': {u'active_time': 1348,
#        u'calories': 133.175212622,
#        u'distance': 2158.12495232,
#        u'inactive_time': 2789,
#        u'longest_active_time': 316,
#        u'longest_idle_time': 2065,
#        u'steps': 2682},
#       u'2015082915': {u'active_time': 600,
#        u'calories': 62.3250129223,
#        u'distance': 1062.96907043,
#        u'inactive_time': 132,
#        u'longest_active_time': 396,
#        u'longest_idle_time': 70,
#        u'steps': 1321},
#       u'2015082917': {u'active_time': 44,
#        u'calories': 36.4098477066,
#        u'distance': 504.528093338,
#        u'inactive_time': 3300,
#        u'longest_active_time': 38,
#        u'longest_idle_time': 2702,
#        u'steps': 627},
#       u'2015082918': {u'active_time': 869,
#        u'calories': 77.4925096035,
#        u'distance': 1290.69069481,
#        u'inactive_time': 3220,
#        u'longest_active_time': 303,
#        u'longest_idle_time': 2471,
#        u'steps': 1604},
#       u'2015082919': {u'active_time': 304,
#        u'calories': 53.2461338043,
#        u'distance': 1003.42350769,
#        u'inactive_time': 944,
#        u'longest_active_time': 304,
#        u'longest_idle_time': 604,
#        u'steps': 1247},
#       u'2015082920': {u'active_time': 7,
#        u'calories': 0.660826802254,
#        u'distance': 11.2653799057,
#        u'inactive_time': 0,
#        u'longest_active_time': 7,
#        u'longest_idle_time': 0,
#        u'steps': 14},
#       u'2015082921': {u'active_time': 5,
#        u'calories': 0.861433148384,
#        u'distance': 11.2653799057,
#        u'inactive_time': 0,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 0,
#        u'steps': 14},
#       u'2015082923': {u'active_time': 0,
#        u'calories': 4.44812822342,
#        u'distance': 7.24203014374,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 9}},
#      u'inactive_time': 37925,
#      u'km': 6.62162948704,
#      u'longest_active': 666,
#      u'longest_idle': 15724,
#      u'steps': 8229,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'America/New_York',
#      u'tzs': [[1440854447, u'America/New_York']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440938877/trVF_JXR-js3ldIqPI3HCPEOxYD14CMP/F3rPnz_fTUY.png',
#     u'time_completed': 1440906079,
#     u'time_created': 1440854447,
#     u'time_updated': 1441030770,
#     u'title': u'8,229 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-js3ldIqPI3HCPEOxYD14CMP'},
#    {u'date': 20150828,
#     u'details': {u'active_time': 5,
#      u'bg_calories': 80.6196291447,
#      u'bmr': 1754.79486048,
#      u'bmr_day': 1754.79486048,
#      u'calories': 80.7211856503,
#      u'distance': 1172.40418243,
#      u'hourly_totals': {u'2015082810': {u'active_time': 0,
#        u'calories': 6.84340143204,
#        u'distance': 127.942527771,
#        u'inactive_time': 3367,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3367,
#        u'steps': 159},
#       u'2015082811': {u'active_time': 5,
#        u'calories': 71.176150322,
#        u'distance': 993.767444611,
#        u'inactive_time': 3380,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 2921,
#        u'steps': 1235},
#       u'2015082812': {u'active_time': 0,
#        u'calories': 2.60007739067,
#        u'distance': 50.6942100525,
#        u'inactive_time': 140,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 140,
#        u'steps': 63}},
#      u'inactive_time': 10880,
#      u'km': 1.17240418243,
#      u'longest_active': 5,
#      u'longest_idle': 10121,
#      u'steps': 1457,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'America/New_York',
#      u'tzs': [[1440773767, u'America/New_York']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440808819/trVF_JXR-jvfhdX6M_m2rOSBrjebWN1h/F3rPnz_fTUY.png',
#     u'time_completed': 1440777740,
#     u'time_created': 1440773767,
#     u'time_updated': 1441030770,
#     u'title': u'1,457 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jvfhdX6M_m2rOSBrjebWN1h'},
#    {u'date': 20150827,
#     u'details': {u'active_time': 1117,
#      u'bg_calories': 291.074173104,
#      u'bmr': 1732.22696122,
#      u'bmr_day': 1732.22696122,
#      u'calories': 313.762135719,
#      u'distance': 4580.98627746,
#      u'hourly_totals': {u'2015082707': {u'active_time': 0,
#        u'calories': 17.528885603,
#        u'distance': 289.681188583,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 360},
#       u'2015082708': {u'active_time': 142,
#        u'calories': 29.8501638621,
#        u'distance': 535.910229921,
#        u'inactive_time': 0,
#        u'longest_active_time': 70,
#        u'longest_idle_time': 0,
#        u'steps': 666},
#       u'2015082709': {u'active_time': 43,
#        u'calories': 27.2847616673,
#        u'distance': 345.20343399,
#        u'inactive_time': 0,
#        u'longest_active_time': 43,
#        u'longest_idle_time': 0,
#        u'steps': 429},
#       u'2015082710': {u'active_time': 16,
#        u'calories': 1.89679467678,
#        u'distance': 32.1867990494,
#        u'inactive_time': 0,
#        u'longest_active_time': 13,
#        u'longest_idle_time': 0,
#        u'steps': 40},
#       u'2015082711': {u'active_time': 509,
#        u'calories': 51.6266701221,
#        u'distance': 922.956483841,
#        u'inactive_time': 0,
#        u'longest_active_time': 439,
#        u'longest_idle_time': 0,
#        u'steps': 1147},
#       u'2015082712': {u'active_time': 210,
#        u'calories': 70.3216218352,
#        u'distance': 1021.12622929,
#        u'inactive_time': 0,
#        u'longest_active_time': 140,
#        u'longest_idle_time': 0,
#        u'steps': 1269},
#       u'2015082713': {u'active_time': 16,
#        u'calories': 1.92002624273,
#        u'distance': 30.5774593353,
#        u'inactive_time': 0,
#        u'longest_active_time': 11,
#        u'longest_idle_time': 0,
#        u'steps': 38},
#       u'2015082714': {u'active_time': 0,
#        u'calories': 0.0431803427637,
#        u'distance': 0.804669976234,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 1},
#       u'2015082718': {u'active_time': 5,
#        u'calories': 7.93157422543,
#        u'distance': 78.0529880524,
#        u'inactive_time': 3048,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 3048,
#        u'steps': 97},
#       u'2015082719': {u'active_time': 10,
#        u'calories': 38.4097807109,
#        u'distance': 591.432430267,
#        u'inactive_time': 2553,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 1778,
#        u'steps': 735},
#       u'2015082720': {u'active_time': 0,
#        u'calories': 9.73959994316,
#        u'distance': 167.371364594,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 208},
#       u'2015082722': {u'active_time': 166,
#        u'calories': 34.5211138725,
#        u'distance': 565.683000565,
#        u'inactive_time': 0,
#        u'longest_active_time': 166,
#        u'longest_idle_time': 0,
#        u'steps': 703}},
#      u'inactive_time': 39145,
#      u'km': 4.58098627746,
#      u'longest_active': 439,
#      u'longest_idle': 22840,
#      u'steps': 5693,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'America/New_York',
#      u'tzs': [[1440650025, u'Europe/Athens'],
#       [1440663595, u'Europe/Istanbul'],
#       [1440702674, u'Atlantic/Reykjavik'],
#       [1440715574, u'America/New_York']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440726214/trVF_JXR-jszqUjVmXHIsX6kXRawCxZO/F3rPnz_fTUY.png',
#     u'time_completed': 1440721114,
#     u'time_created': 1440650025,
#     u'time_updated': 1441030770,
#     u'title': u'5,693 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jszqUjVmXHIsX6kXRawCxZO'},
#    {u'date': 20150826,
#     u'details': {u'active_time': 1143,
#      u'bg_calories': 308.140408814,
#      u'bmr': 1731.71712384,
#      u'bmr_day': 1731.71712384,
#      u'calories': 331.356715657,
#      u'distance': 4767.66974258,
#      u'hourly_totals': {u'2015082600': {u'active_time': 3,
#        u'calories': 0.58762127161,
#        u'distance': 7.24203014374,
#        u'inactive_time': 0,
#        u'longest_active_time': 3,
#        u'longest_idle_time': 0,
#        u'steps': 9},
#       u'2015082608': {u'active_time': 0,
#        u'calories': 2.2286593914,
#        u'distance': 42.6475105286,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 53},
#       u'2015082609': {u'active_time': 275,
#        u'calories': 57.8281082511,
#        u'distance': 1042.04765511,
#        u'inactive_time': 2929,
#        u'longest_active_time': 185,
#        u'longest_idle_time': 1751,
#        u'steps': 1295},
#       u'2015082610': {u'active_time': 15,
#        u'calories': 16.2101858854,
#        u'distance': 306.579265594,
#        u'inactive_time': 1455,
#        u'longest_active_time': 15,
#        u'longest_idle_time': 1127,
#        u'steps': 381},
#       u'2015082613': {u'active_time': 102,
#        u'calories': 16.4150738716,
#        u'distance': 306.579269409,
#        u'inactive_time': 3146,
#        u'longest_active_time': 74,
#        u'longest_idle_time': 1769,
#        u'steps': 381},
#       u'2015082614': {u'active_time': 395,
#        u'calories': 43.8364616632,
#        u'distance': 729.031006813,
#        u'inactive_time': 1058,
#        u'longest_active_time': 210,
#        u'longest_idle_time': 654,
#        u'steps': 906},
#       u'2015082615': {u'active_time': 9,
#        u'calories': 11.8477999568,
#        u'distance': 103.802430153,
#        u'inactive_time': 2944,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 1139,
#        u'steps': 129},
#       u'2015082616': {u'active_time': 0,
#        u'calories': 13.4057412148,
#        u'distance': 105.411770821,
#        u'inactive_time': 3507,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3507,
#        u'steps': 131},
#       u'2015082617': {u'active_time': 26,
#        u'calories': 41.6430658102,
#        u'distance': 430.498458862,
#        u'inactive_time': 2945,
#        u'longest_active_time': 21,
#        u'longest_idle_time': 2612,
#        u'steps': 535},
#       u'2015082619': {u'active_time': 0,
#        u'calories': 31.7860183716,
#        u'distance': 511.770122528,
#        u'inactive_time': 2785,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 2785,
#        u'steps': 636},
#       u'2015082620': {u'active_time': 2,
#        u'calories': 21.3671350479,
#        u'distance': 207.604858398,
#        u'inactive_time': 0,
#        u'longest_active_time': 2,
#        u'longest_idle_time': 0,
#        u'steps': 258},
#       u'2015082621': {u'active_time': 310,
#        u'calories': 50.418097198,
#        u'distance': 964.799324036,
#        u'inactive_time': 0,
#        u'longest_active_time': 310,
#        u'longest_idle_time': 0,
#        u'steps': 1199},
#       u'2015082622': {u'active_time': 6,
#        u'calories': 0.566440880299,
#        u'distance': 9.65604019165,
#        u'inactive_time': 0,
#        u'longest_active_time': 6,
#        u'longest_idle_time': 0,
#        u'steps': 12}},
#      u'inactive_time': 38420,
#      u'km': 4.76766974258,
#      u'longest_active': 310,
#      u'longest_idle': 11789,
#      u'steps': 5925,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'Europe/Athens',
#      u'tzs': [[1440536551, u'Europe/Athens']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440648914/trVF_JXR-jvpKiDses1vliaDSb4tnIzQ/F3rPnz_fTUY.png',
#     u'time_completed': 1440618302,
#     u'time_created': 1440536551,
#     u'time_updated': 1441030770,
#     u'title': u'5,925 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jvpKiDses1vliaDSb4tnIzQ'},
#    {u'date': 20150825,
#     u'details': {u'active_time': 1656,
#      u'bg_calories': 481.245538533,
#      u'bmr': 1721.31535873,
#      u'bmr_day': 1721.31535873,
#      u'calories': 514.882117336,
#      u'distance': 7930.82746983,
#      u'hourly_totals': {u'2015082500': {u'active_time': 323,
#        u'calories': 40.2175678015,
#        u'distance': 630.861284256,
#        u'inactive_time': 0,
#        u'longest_active_time': 300,
#        u'longest_idle_time': 0,
#        u'steps': 784},
#       u'2015082508': {u'active_time': 0,
#        u'calories': 5.26079320908,
#        u'distance': 47.475528717,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 59},
#       u'2015082509': {u'active_time': 164,
#        u'calories': 42.4582414627,
#        u'distance': 801.451324463,
#        u'inactive_time': 2997,
#        u'longest_active_time': 164,
#        u'longest_idle_time': 2551,
#        u'steps': 996},
#       u'2015082510': {u'active_time': 249,
#        u'calories': 42.3966843486,
#        u'distance': 734.663683891,
#        u'inactive_time': 2028,
#        u'longest_active_time': 246,
#        u'longest_idle_time': 781,
#        u'steps': 913},
#       u'2015082511': {u'active_time': 34,
#        u'calories': 36.2334724069,
#        u'distance': 597.869801521,
#        u'inactive_time': 3090,
#        u'longest_active_time': 31,
#        u'longest_idle_time': 2287,
#        u'steps': 743},
#       u'2015082512': {u'active_time': 50,
#        u'calories': 22.8541126251,
#        u'distance': 431.303110123,
#        u'inactive_time': 3265,
#        u'longest_active_time': 50,
#        u'longest_idle_time': 3265,
#        u'steps': 536},
#       u'2015082514': {u'active_time': 200,
#        u'calories': 33.9809207916,
#        u'distance': 554.417630196,
#        u'inactive_time': 2643,
#        u'longest_active_time': 200,
#        u'longest_idle_time': 2451,
#        u'steps': 689},
#       u'2015082516': {u'active_time': 0,
#        u'calories': 15.9146963358,
#        u'distance': 309.797941208,
#        u'inactive_time': 2930,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 2930,
#        u'steps': 385},
#       u'2015082518': {u'active_time': 209,
#        u'calories': 43.0971194506,
#        u'distance': 630.056602478,
#        u'inactive_time': 2462,
#        u'longest_active_time': 148,
#        u'longest_idle_time': 1474,
#        u'steps': 783},
#       u'2015082519': {u'active_time': 282,
#        u'calories': 59.8479648829,
#        u'distance': 964.79933548,
#        u'inactive_time': 3214,
#        u'longest_active_time': 202,
#        u'longest_idle_time': 2693,
#        u'steps': 1199},
#       u'2015082520': {u'active_time': 68,
#        u'calories': 44.5772963762,
#        u'distance': 729.03100872,
#        u'inactive_time': 0,
#        u'longest_active_time': 62,
#        u'longest_idle_time': 0,
#        u'steps': 906},
#       u'2015082521': {u'active_time': 0,
#        u'calories': 53.9400197268,
#        u'distance': 809.498021126,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 1006},
#       u'2015082522': {u'active_time': 77,
#        u'calories': 39.384569943,
#        u'distance': 668.680778503,
#        u'inactive_time': 0,
#        u'longest_active_time': 67,
#        u'longest_idle_time': 0,
#        u'steps': 831},
#       u'2015082523': {u'active_time': 0,
#        u'calories': 1.08207917213,
#        u'distance': 20.9214191437,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 26}},
#      u'inactive_time': 38313,
#      u'km': 7.93082746983,
#      u'longest_active': 300,
#      u'longest_idle': 13044,
#      u'steps': 9856,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'Europe/Athens',
#      u'tzs': [[1440451885, u'Europe/Athens']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440570390/trVF_JXR-jszGfiUD6EhGmCVa2FQeUzu/F3rPnz_fTUY.png',
#     u'time_completed': 1440533060,
#     u'time_created': 1440451885,
#     u'time_updated': 1441030770,
#     u'title': u'9,856 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jszGfiUD6EhGmCVa2FQeUzu'},
#    {u'date': 20150824,
#     u'details': {u'active_time': 1192,
#      u'bg_calories': 233.661958784,
#      u'bmr': 1730.75835214,
#      u'bmr_day': 1730.75835214,
#      u'calories': 257.874051026,
#      u'distance': 3978.28845215,
#      u'hourly_totals': {u'2015082400': {u'active_time': 0,
#        u'calories': 4.69570416212,
#        u'distance': 90.1230401993,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 112},
#       u'2015082409': {u'active_time': 313,
#        u'calories': 23.6958601475,
#        u'distance': 428.084453583,
#        u'inactive_time': 1547,
#        u'longest_active_time': 306,
#        u'longest_idle_time': 1301,
#        u'steps': 532},
#       u'2015082410': {u'active_time': 44,
#        u'calories': 17.3672347069,
#        u'distance': 296.118560791,
#        u'inactive_time': 2560,
#        u'longest_active_time': 44,
#        u'longest_idle_time': 2560,
#        u'steps': 368},
#       u'2015082411': {u'active_time': 82,
#        u'calories': 36.5330507755,
#        u'distance': 669.485439301,
#        u'inactive_time': 3431,
#        u'longest_active_time': 49,
#        u'longest_idle_time': 2703,
#        u'steps': 832},
#       u'2015082412': {u'active_time': 5,
#        u'calories': 18.1479149461,
#        u'distance': 347.61743927,
#        u'inactive_time': 2485,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 2485,
#        u'steps': 432},
#       u'2015082414': {u'active_time': 5,
#        u'calories': 0.861478567123,
#        u'distance': 11.2653799057,
#        u'inactive_time': 2919,
#        u'longest_active_time': 5,
#        u'longest_idle_time': 2919,
#        u'steps': 14},
#       u'2015082415': {u'active_time': 2,
#        u'calories': 1.84382990003,
#        u'distance': 29.7727899551,
#        u'inactive_time': 2683,
#        u'longest_active_time': 2,
#        u'longest_idle_time': 1430,
#        u'steps': 37},
#       u'2015082416': {u'active_time': 3,
#        u'calories': 3.99456137419,
#        u'distance': 24.9447698593,
#        u'inactive_time': 3352,
#        u'longest_active_time': 3,
#        u'longest_idle_time': 3352,
#        u'steps': 31},
#       u'2015082417': {u'active_time': 0,
#        u'calories': 9.56691551208,
#        u'distance': 64.3735990524,
#        u'inactive_time': 2791,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 2791,
#        u'steps': 80},
#       u'2015082418': {u'active_time': 16,
#        u'calories': 1.18554270267,
#        u'distance': 21.7260894775,
#        u'inactive_time': 368,
#        u'longest_active_time': 16,
#        u'longest_idle_time': 368,
#        u'steps': 27},
#       u'2015082419': {u'active_time': 301,
#        u'calories': 27.9571900368,
#        u'distance': 422.45173645,
#        u'inactive_time': 3504,
#        u'longest_active_time': 301,
#        u'longest_idle_time': 3504,
#        u'steps': 525},
#       u'2015082420': {u'active_time': 100,
#        u'calories': 15.5326077938,
#        u'distance': 294.509217262,
#        u'inactive_time': 0,
#        u'longest_active_time': 51,
#        u'longest_idle_time': 0,
#        u'steps': 366},
#       u'2015082421': {u'active_time': 321,
#        u'calories': 72.2800681591,
#        u'distance': 1277.81593704,
#        u'inactive_time': 0,
#        u'longest_active_time': 300,
#        u'longest_idle_time': 0,
#        u'steps': 1588}},
#      u'inactive_time': 38845,
#      u'km': 3.97828845215,
#      u'longest_active': 306,
#      u'longest_idle': 7574,
#      u'steps': 4944,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'Europe/Athens',
#      u'tzs': [[1440364050, u'Europe/Athens']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440445272/trVF_JXR-juPlL91wPoUehpHk1vq-ja-/F3rPnz_fTUY.png',
#     u'time_completed': 1440442731,
#     u'time_created': 1440364050,
#     u'time_updated': 1441030770,
#     u'title': u'4,944 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-juPlL91wPoUehpHk1vq-ja-'},
#    {u'date': 20150823,
#     u'details': {u'active_time': 775,
#      u'bg_calories': 430.537127674,
#      u'bmr': 1739.24686284,
#      u'bmr_day': 1739.24686284,
#      u'calories': 446.279216068,
#      u'distance': 7817.36902905,
#      u'hourly_totals': {u'2015082308': {u'active_time': 2,
#        u'calories': 25.339733541,
#        u'distance': 491.653371811,
#        u'inactive_time': 0,
#        u'longest_active_time': 2,
#        u'longest_idle_time': 0,
#        u'steps': 611},
#       u'2015082309': {u'active_time': 388,
#        u'calories': 46.1566610336,
#        u'distance': 870.652938843,
#        u'inactive_time': 3200,
#        u'longest_active_time': 270,
#        u'longest_idle_time': 2008,
#        u'steps': 1082},
#       u'2015082310': {u'active_time': 3,
#        u'calories': 29.9417244792,
#        u'distance': 568.097020149,
#        u'inactive_time': 3487,
#        u'longest_active_time': 3,
#        u'longest_idle_time': 2569,
#        u'steps': 706},
#       u'2015082311': {u'active_time': 0,
#        u'calories': 27.766254425,
#        u'distance': 481.997329712,
#        u'inactive_time': 3398,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3398,
#        u'steps': 599},
#       u'2015082312': {u'active_time': 0,
#        u'calories': 33.9855815172,
#        u'distance': 641.321983337,
#        u'inactive_time': 2819,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 2819,
#        u'steps': 797},
#       u'2015082313': {u'active_time': 0,
#        u'calories': 5.19996738434,
#        u'distance': 59.5455818176,
#        u'inactive_time': 496,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 496,
#        u'steps': 74},
#       u'2015082314': {u'active_time': 72,
#        u'calories': 16.3169341087,
#        u'distance': 316.235313416,
#        u'inactive_time': 1670,
#        u'longest_active_time': 72,
#        u'longest_idle_time': 1670,
#        u'steps': 393},
#       u'2015082316': {u'active_time': 0,
#        u'calories': 17.8165390491,
#        u'distance': 345.203422546,
#        u'inactive_time': 585,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 585,
#        u'steps': 429},
#       u'2015082317': {u'active_time': 0,
#        u'calories': 27.8515048027,
#        u'distance': 519.012138367,
#        u'inactive_time': 3142,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3142,
#        u'steps': 645},
#       u'2015082318': {u'active_time': 0,
#        u'calories': 14.732998848,
#        u'distance': 287.267181396,
#        u'inactive_time': 3539,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3539,
#        u'steps': 357},
#       u'2015082319': {u'active_time': 0,
#        u'calories': 36.4254757166,
#        u'distance': 689.602193832,
#        u'inactive_time': 3452,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3452,
#        u'steps': 857},
#       u'2015082320': {u'active_time': 0,
#        u'calories': 17.7406072617,
#        u'distance': 277.611148834,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 345},
#       u'2015082321': {u'active_time': 0,
#        u'calories': 51.8228653073,
#        u'distance': 864.215593338,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 1074},
#       u'2015082322': {u'active_time': 0,
#        u'calories': 49.4682962894,
#        u'distance': 834.4427948,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 1037},
#       u'2015082323': {u'active_time': 310,
#        u'calories': 29.9719839096,
#        u'distance': 570.511016846,
#        u'inactive_time': 0,
#        u'longest_active_time': 310,
#        u'longest_idle_time': 0,
#        u'steps': 709}},
#      u'inactive_time': 39360,
#      u'km': 7.81736902905,
#      u'longest_active': 310,
#      u'longest_idle': 19870,
#      u'steps': 9715,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'Europe/Athens',
#      u'tzs': [[1440308353, u'Europe/Athens']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440362467/trVF_JXR-jsIj_loR5R3qKYmNgHP_qcy/F3rPnz_fTUY.png',
#     u'time_completed': 1440361417,
#     u'time_created': 1440308353,
#     u'time_updated': 1441030770,
#     u'title': u'9,715 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jsIj_loR5R3qKYmNgHP_qcy'},
#    {u'date': 20150822,
#     u'details': {u'active_time': 1512,
#      u'bg_calories': 407.558610022,
#      u'bmr': 1724.29482757,
#      u'bmr_day': 1724.29482757,
#      u'calories': 438.271240538,
#      u'distance': 6171.81891406,
#      u'hourly_totals': {u'2015082208': {u'active_time': 23,
#        u'calories': 10.567726016,
#        u'distance': 77.2483196259,
#        u'inactive_time': 0,
#        u'longest_active_time': 18,
#        u'longest_idle_time': 0,
#        u'steps': 96},
#       u'2015082209': {u'active_time': 275,
#        u'calories': 28.4056520462,
#        u'distance': 430.498462677,
#        u'inactive_time': 487,
#        u'longest_active_time': 275,
#        u'longest_idle_time': 487,
#        u'steps': 535},
#       u'2015082210': {u'active_time': 466,
#        u'calories': 71.6471461058,
#        u'distance': 1182.06023788,
#        u'inactive_time': 3181,
#        u'longest_active_time': 302,
#        u'longest_idle_time': 1718,
#        u'steps': 1469},
#       u'2015082211': {u'active_time': 131,
#        u'calories': 26.851685524,
#        u'distance': 399.116321564,
#        u'inactive_time': 3352,
#        u'longest_active_time': 131,
#        u'longest_idle_time': 3352,
#        u'steps': 496},
#       u'2015082212': {u'active_time': 184,
#        u'calories': 21.177765131,
#        u'distance': 396.702308655,
#        u'inactive_time': 1536,
#        u'longest_active_time': 123,
#        u'longest_idle_time': 1413,
#        u'steps': 493},
#       u'2015082213': {u'active_time': 8,
#        u'calories': 0.685980021954,
#        u'distance': 12.0700502396,
#        u'inactive_time': 1898,
#        u'longest_active_time': 8,
#        u'longest_idle_time': 1898,
#        u'steps': 15},
#       u'2015082214': {u'active_time': 0,
#        u'calories': 5.66721153259,
#        u'distance': 14.4840602875,
#        u'inactive_time': 3573,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 3573,
#        u'steps': 18},
#       u'2015082215': {u'active_time': 0,
#        u'calories': 2.20583111048,
#        u'distance': 23.3354291916,
#        u'inactive_time': 929,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 929,
#        u'steps': 29},
#       u'2015082216': {u'active_time': 2,
#        u'calories': 27.5535896719,
#        u'distance': 276.001810074,
#        u'inactive_time': 3485,
#        u'longest_active_time': 2,
#        u'longest_idle_time': 2200,
#        u'steps': 343},
#       u'2015082217': {u'active_time': 60,
#        u'calories': 16.9221901894,
#        u'distance': 148.863947868,
#        u'inactive_time': 2650,
#        u'longest_active_time': 28,
#        u'longest_idle_time': 2307,
#        u'steps': 185},
#       u'2015082218': {u'active_time': 150,
#        u'calories': 47.1487574577,
#        u'distance': 562.464326501,
#        u'inactive_time': 3377,
#        u'longest_active_time': 140,
#        u'longest_idle_time': 2741,
#        u'steps': 699},
#       u'2015082219': {u'active_time': 0,
#        u'calories': 21.8939335346,
#        u'distance': 353.250133514,
#        u'inactive_time': 861,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 861,
#        u'steps': 439},
#       u'2015082220': {u'active_time': 210,
#        u'calories': 85.0760961771,
#        u'distance': 1531.28700829,
#        u'inactive_time': 0,
#        u'longest_active_time': 70,
#        u'longest_idle_time': 0,
#        u'steps': 1903},
#       u'2015082221': {u'active_time': 0,
#        u'calories': 17.6672050953,
#        u'distance': 342.789428711,
#        u'inactive_time': 0,
#        u'longest_active_time': 0,
#        u'longest_idle_time': 0,
#        u'steps': 426},
#       u'2015082223': {u'active_time': 3,
#        u'calories': 24.0878404081,
#        u'distance': 421.647068977,
#        u'inactive_time': 0,
#        u'longest_active_time': 3,
#        u'longest_idle_time': 0,
#        u'steps': 524}},
#      u'inactive_time': 38582,
#      u'km': 6.17181891406,
#      u'longest_active': 302,
#      u'longest_idle': 11042,
#      u'steps': 7670,
#      u'sunrise': 0,
#      u'sunset': 0,
#      u'tz': u'Europe/Athens',
#      u'tzs': [[1440220769, u'Europe/Athens']],
#      u'wo_active_time': 0,
#      u'wo_calories': 0,
#      u'wo_count': 0,
#      u'wo_longest': 0,
#      u'wo_time': 0},
#     u'snapshot_image': u'/nudge/image/e/1440314174/trVF_JXR-jt0QEinEALnoM76PiQ4atdo/F3rPnz_fTUY.png',
#     u'time_completed': 1440277024,
#     u'time_created': 1440220769,
#     u'time_updated': 1441030770,
#     u'title': u'7,670 steps',
#     u'type': u'move',
#     u'xid': u'trVF_JXR-jt0QEinEALnoM76PiQ4atdo'}],
#   u'links': {u'next': u'/nudge/api/v.1.1/users/6CEDmZ-RtVRKxBB-NA5PoQ/moves?page_token=1440277024&limit=10'},
#   u'size': 10},
#  u'meta': {u'code': 200,
#   u'message': u'OK',
#   u'time': 1441030770,
#   u'user_xid': u'6CEDmZ-RtVRKxBB-NA5PoQ'}}

# %%
import pandas as pd

df = pd.DataFrame(moves_data["data"]["items"])
df

# %%
df_details = pd.DataFrame(list(df["details"]))
df_details

# %%
# Testing another of the API endpoints
endpoint = "https://jawbone.com/nudge/api/v.1.1/users/@me/sleeps"

# See https://jawbone.com/up/developer/endpoints/sleeps
params = {}
headers = {'Authorization': 'Bearer ' + auth_info['access_token']}
resp = requests.get(endpoint, params=params, headers=headers)
sleep_data = json.loads(resp.text)
sleep_data

# %%
df = pd.DataFrame(sleep_data["data"]["items"])
df

# %%
df_details = pd.DataFrame(list(df["details"]))
df_details

# %%
df_details["asleep_time"] = map(lambda x : datetime.datetime.fromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'), df_details["asleep_time"])
df_details["awake_time"] = map(lambda x : datetime.datetime.fromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'), df_details["awake_time"])
df_details
