# %% [markdown]
# ## Example: Twitter API in Python, with OAuth1 authentication

# %% [markdown]
# <img src="images/Python_Twitter.jpg" width="300px">
#
# The guide below shows the steps of registering an application that you can integrate with **Twitter**. Registering the application is the first step in developing an application that is integrated into its users' social graph.

# %% [markdown]
# ## Register a new application
#
# All **Twitter** users are potentially **Twitter** application developers. Simply visit https://apps.twitter.com/ and sign in with your **Twitter** credentials.
#
# Click the "Create a new application" button near the top. A new page with the **_Create an application_** form requires basic information about your application.
#
# <img src="images/create_an_application_1.jpg">
#
# - In the **_Name_** field name your application in 32 characters or fewer.
# - In the **_Description_** field describe your application in 10 to 200 characters.
# - In the **_Website_** field, you can give a pointer to your website. (It does not really matter, as we will not be using that functionality yet).
# - The **_Callback URL_** leave it empty for now.
#
# The **Developer Agreement** section outlines rules you must agree to follow if you build an application that uses **Twitter’s** API. If you agree to the rules, check "Yes, I agree".
#
# <img src="images/create_an_application_2.jpg">
#
# After Captcha challenge click "Create your **Twitter** application" to complete the form and go to the application settings page.
#
# In the opened window you’ll then be presented with lots of information. The main fields to note are **_Consumer key_** and **_Consumer secret_**. These values are your application’s credentials for **Twitter**. You need them to do almost anything with **Twitter**, including going through the OAuth authorization flow and working with **Twitter’s** REST API. But we’re not quite done yet. We now need to authorise the **Twitter** app for your **Twitter** account. To do this you should select "Key and Access Tokens" menu button and create your access token. This **access token** will allow your **Twitter** application to read **Twitter** information. You’ll be able to get data of your tweets, mentions, lists and more.
#
# <img src="images/create_an_application_3.jpg">
#
# As a result you will see the window with consumer and token keys for your application
#
# <img src="images/create_an_application_4.jpg">
#
# Above the four fields are highlighted. You will need these long horrible strings of characters for your **Twitter** app. It goes without saying that you should keep these secret. If anyone was to get these keys, they could effectively access your **Twitter** account.
#
# However, if you want to do more advanced stuff like sending tweets or deleting, you’ll need to change your access type in the "Permission" menu window. Change the access type to "Read and Write" to be able to read **Twitter** data and send tweets and select "Read, Write and access direct messages" if you want to also have access to your direct messages.

# %% [markdown]
# ---
# ## Getting access to Twitter APIs using main Python tools
# ---

# %% [markdown]
# Many web services including **Twitter** require authentication, and there are many different types.
#
# Python library `requests` provides a pythonic way to make complex HTTP requests, and handles difficult tasks like authentication.
#
# A common form of authentication for several web APIs is OAuth. The `requests-oauthlib` library allows `requests`'s users to easily make OAuth authenticated requests.

# %%
import requests
from requests_oauthlib import OAuth1

import json

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
consumer_key = 'ZFSlBaBhgAnoI5Cb5YJ8Q2iSL'
consumer_secret = 'QBFuxdiXsGypn1fEL3Nu8BQtYiFXC97RIsaCf6xv7Rq7E4Dcyg'
access_token = '16976496-hhbdqyfoVqgYbFmVz076IwWxa4vM58my0v1nJNlW0'
access_secret = '3aTWUUdNMTVWDBjxCOApzRdSiiySFM4yaZcGJ1YYaub75'

# You will authenticate yourself using OAuth1 object
auth = OAuth1(consumer_key, consumer_secret, access_token, access_secret)
print(auth)
# Out:
# <requests_oauthlib.oauth1_auth.OAuth1 object at 0x7f5da80b2310>

# %%
# If the authentication was successful, you should see the name of the account print(out)
url_0 = 'https://api.twitter.com/1.1/account/verify_credentials.json'
res = requests.get(url_0, auth=auth)

print("My name is", res.json()["name"])
# Out:
# My name is Panos Ipeirotis

# %%
res.json()
# Out:
# {u'contributors_enabled': False,
#  u'created_at': u'Sun Oct 26 04:16:42 +0000 2008',
#  u'default_profile': False,
#  u'default_profile_image': False,
#  u'description': u'Professor of Data Science and Information Systems at Stern School of Business, New York University. All opinions are mine and mine alone.',
#  u'entities': {u'description': {u'urls': []},
#   u'url': {u'urls': [{u'display_url': u'ipeirotis.com',
#      u'expanded_url': u'http://www.ipeirotis.com',
#      u'indices': [0, 23],
#      u'url': u'https://t.co/HpkpSj5AGz'}]}},
#  u'favourites_count': 64,
#  u'follow_request_sent': False,
#  u'followers_count': 3745,
#  u'following': False,
#  u'friends_count': 253,
#  u'geo_enabled': True,
#  u'has_extended_profile': True,
#  u'id': 16976496,
#  u'id_str': u'16976496',
#  u'is_translation_enabled': False,
#  u'is_translator': False,
#  u'lang': u'en',
#  u'listed_count': 240,
#  u'location': u'New York, NY',
#  u'name': u'Panos Ipeirotis',
#  u'notifications': False,
#  u'profile_background_color': u'131516',
#  u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#  u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#  u'profile_background_tile': True,
#  u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/16976496/1398193510',
#  u'profile_image_url': u'http://pbs.twimg.com/profile_images/1892973512/298263_10100656005860799_818381_60300396_2035330857_n_normal.jpg',
#  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1892973512/298263_10100656005860799_818381_60300396_2035330857_n_normal.jpg',
#  u'profile_link_color': u'56068C',
#  u'profile_sidebar_border_color': u'FFFFFF',
#  u'profile_sidebar_fill_color': u'EFEFEF',
#  u'profile_text_color': u'333333',
#  u'profile_use_background_image': True,
#  u'protected': False,
#  u'screen_name': u'ipeirotis',
#  u'status': {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Jun 28 15:48:56 +0000 2016',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 16136933,
#      u'id_str': u'16136933',
#      u'indices': [0, 11],
#      u'name': u'Jeffrey P. Bigham',
#      u'screen_name': u'jeffbigham'},
#     {u'id': 197622615,
#      u'id_str': u'197622615',
#      u'indices': [12, 16],
#      u'name': u'Rev',
#      u'screen_name': u'rev'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 747819077582917632,
#   u'id_str': u'747819077582917632',
#   u'in_reply_to_screen_name': u'jeffbigham',
#   u'in_reply_to_status_id': 747818784820387841,
#   u'in_reply_to_status_id_str': u'747818784820387841',
#   u'in_reply_to_user_id': 16136933,
#   u'in_reply_to_user_id_str': u'16136933',
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'@jeffbigham @rev You can say the same for programming :-) \nUnfortunately, "plain" language is not specific enough for legal purposes.',
#   u'truncated': False},
#  u'statuses_count': 3164,
#  u'time_zone': u'Eastern Time (US & Canada)',
#  u'url': u'https://t.co/HpkpSj5AGz',
#  u'utc_offset': -14400,
#  u'verified': False}

# %% [markdown]
# ### Example 1: Read Tweets from Your Homepage
#
# The list of all available **Twitter** API you can find here https://dev.twitter.com/rest/public. Let's use `home_timeline` that returns a collection of the most recent tweets and retweets posted by the authenticating user and the users they follow.

# %%
url_1 = 'https://api.twitter.com/1.1/statuses/home_timeline.json'
res = requests.get(url_1, auth=auth, params={"count": 20})

# The res object encapsulates the "response" of the server. Notice the status code that is displayed. 
# Code 200 means that things went fine
# Code 403 means that the server understood the request, but is refusing to fulfill it
# Code 404 means that the URL was not found
# Codes 5xx mean that something went wrong

print(res, "Status code:", res.status_code)
# Let's see how looks the url
print(res.url)
print("Content type:", res.headers['content-type'], '\n')

tweets = res.json()
if res.status_code == 200:
    for tweet in tweets:
        print("* ", tweet['text'])
        print("----------------------------------")
else:   # You have no tweets
    pass
# Out:
# <Response [200]> Status code: 200
# https://api.twitter.com/1.1/statuses/home_timeline.json?count=20
# Content type: application/json;charset=utf-8
#
# *  RT @sherrirose: @mattmight and any COI statements. Both will also slow submission down even more when you have multiple coauthors.
# ----------------------------------
# *  .@AbigailKramer11 tells @jbsapien about the many efforts toward reforming NY Family Court. Can it change? https://t.co/dpxY4yzxkN
# ----------------------------------
# *  RT @analyticbridge: Top Languages for analytics, data mining, data science https://t.co/zJrJ12G06P
# ----------------------------------
# *  RT @DataScienceCtrl: Correlation Coefficient in Legal Data https://t.co/An0UBluVzn
# ----------------------------------
# *  RT @Radiolab: Physicists @neiltyson and @stevenstrogatz help us unravel everyone's favorite childhood toy: the Slinky. https://t.co/wfxxZ3V…
# ----------------------------------
# *  Top 30 #LinkedIn Groups for #Analytics, #BigData,#DataMining, and #DataScience #KDN https://t.co/Jen4OJyGlg
# ----------------------------------
# *  How Newsrooms Handle Graphic Images of Violence https://t.co/dsbESIDLYX via @NiemanReports
# ----------------------------------
# *  my course blog on public sector operations research | Punk Rock Operations Research https://t.co/WJnDpMLTq0 #orblog
# ----------------------------------
# *  New Research Discovers That Depression Is An Allergic Reaction To Inflammation https://t.co/JS3yAxpaXu https://t.co/LJPYs42Vtb
# ----------------------------------
# *  This is disappointing but fixable! https://t.co/zTfzvhhR2p
# ----------------------------------
# *  RT @SatterthwaiteML: Tyranny of the Algorithm? Predictive Analytics &amp; Human Rights | NYU School of Law -- 3/21-3/22 Register now https://t.…
# ----------------------------------
# *  RT @SF_BayArea_ACM: Super Bowl Computer Commercials
# https://t.co/Lp1dYTd6vf
# @ComputerHistory @vardi @adage
# #SB50 #STEM #SuperBowlCommercials
# ----------------------------------
# *  RT @hunterwalk: Hearing rumors that Google is changing search results from algorithmic to reverse chron
# ----------------------------------
# *  #Periscope: It's A Super Bowl Weekend Edition Of Ask Me Anything #JimmyScopes https://t.co/aVv7LrmTcx:… https://t.co/e0zA6AJS7N
# ----------------------------------
# *  RT @noamtoff: I love unpacking my toys every morning! https://t.co/Q2EO0CI6JW
# ----------------------------------
# *  RT @aboutdotme: From @twitter to @google, @jasontoff is exploring everything tech. https://t.co/NJWlpu0ADb https://t.co/CFQob9p7PN
# ----------------------------------
# *  RT @noamtoff: I love a good bath https://t.co/DQLraqCWBV
# ----------------------------------
# *  I empathize. But defensively complaining about your users' feedback isn't a great way to win their hearts and minds. https://t.co/kJWBT7ZBND
# ----------------------------------

# %% [markdown]
# ### Example 2: Search tweets by key words
#
# **Twitter** employs a special query language.  For example, the query _"vacation?"_ will return tweets that contain the word "vacation" and are phrased as a question OR the query _"summer :)"_ will return the word "summer" with a positive attitude. [Check out more examples here](https://dev.twitter.com/rest/public/search).
#
# We can mine tweets using either **_search_** or **_stream_**.
#
# >The key difference between **_stream_** and **_search_** is that **_stream_** provides new data as it comes in, while **_search_** can be used to query old data. The **_search_** API is more powerful for queries, and provides faster access to a wide-range of data.
#
# Let's search for a single tweet about "vacation", phrased as a question. Note if request phrase contains URI characters you should [encode](https://en.wikipedia.org/wiki/Percent-encoding) these queries before making the request, because these characters can play role of keys in an URL. Particularly, the question mark "?" is encoded as "%3F".

# %%
import urllib

query = "stern,nyu"
encoded_query = urllib.quote_plus(query)

url_2 = 'https://api.twitter.com/1.1/search/tweets.json?q=' + encoded_query
res = requests.get(url_2, auth=auth)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

tweets = res.json()
tweets
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=stern%2Cnyu
# {u'search_metadata': {u'completed_in': 0.051,
#   u'count': 15,
#   u'max_id': 696061569554378753,
#   u'max_id_str': u'696061569554378753',
#   u'next_results': u'?max_id=695799957400322048&q=stern%2Cnyu&include_entities=1',
#   u'query': u'stern%2Cnyu',
#   u'refresh_url': u'?since_id=696061569554378753&q=stern%2Cnyu&include_entities=1',
#   u'since_id': 0,
#   u'since_id_str': u'0'},
#  u'statuses': [{u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 20:03:05 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'pages.stern.nyu.edu/~xgabaix/paper\u2026',
#       u'expanded_url': u'http://pages.stern.nyu.edu/~xgabaix/papers/pl-ar.pdf',
#       u'indices': [64, 87],
#       u'url': u'https://t.co/PRrn5ZyVMe'}],
#     u'user_mentions': [{u'id': 211258020,
#       u'id_str': u'211258020',
#       u'indices': [0, 11],
#       u'name': u'jesus alfaro',
#       u'screen_name': u'jesusalfar'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 696061569554378753,
#    u'id_str': u'696061569554378753',
#    u'in_reply_to_screen_name': u'jesusalfar',
#    u'in_reply_to_status_id': 696043047138758656,
#    u'in_reply_to_status_id_str': u'696043047138758656',
#    u'in_reply_to_user_id': 211258020,
#    u'in_reply_to_user_id_str': u'211258020',
#    u'is_quote_status': False,
#    u'lang': u'es',
#    u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    u'text': u'@jesusalfar a m\xed me ha gustado mucho. Esta es la versi\xf3n no JEP https://t.co/PRrn5ZyVMe',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sat Sep 24 17:29:16 +0000 2011',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 4031,
#     u'follow_request_sent': False,
#     u'followers_count': 423,
#     u'following': False,
#     u'friends_count': 1912,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 379275463,
#     u'id_str': u'379275463',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'es',
#     u'listed_count': 37,
#     u'location': u'',
#     u'name': u'Israel Arroyo',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/658939191443722240/HWuwEujW_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/658939191443722240/HWuwEujW_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'iarroyo48',
#     u'statuses_count': 11713,
#     u'time_zone': None,
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 18:49:28 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'pages.stern.nyu.edu/~xgabaix/paper\u2026',
#       u'expanded_url': u'http://pages.stern.nyu.edu/~xgabaix/papers/pl-jep.pdf',
#       u'indices': [86, 109],
#       u'url': u'https://t.co/E44X0Ajbqw'}],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 696043047138758656,
#    u'id_str': u'696043047138758656',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'es',
#    u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Qu\xe9 pena! este art\xedculo no deber\xeda haberse publicado en el JEconPersp. No lo entiendo https://t.co/E44X0Ajbqw',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Nov 02 19:20:38 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Catedr\xe1tico de Derecho Mercantil.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'derechomercantilespana.blogspot.com',
#         u'expanded_url': u'http://derechomercantilespana.blogspot.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/tfcbDNkjXx'}]}},
#     u'favourites_count': 6515,
#     u'follow_request_sent': False,
#     u'followers_count': 6506,
#     u'following': False,
#     u'friends_count': 1268,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 211258020,
#     u'id_str': u'211258020',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'es',
#     u'listed_count': 250,
#     u'location': u'Espa\xf1a',
#     u'name': u'jesus alfaro',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/211258020/1428673520',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/3719358900/7a07ecf4773c275000d18882d646b4a5_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/3719358900/7a07ecf4773c275000d18882d646b4a5_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'jesusalfar',
#     u'statuses_count': 48562,
#     u'time_zone': u'Madrid',
#     u'url': u'http://t.co/tfcbDNkjXx',
#     u'utc_offset': 3600,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 17:55:33 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'tomsargent.com/source_code/mi\u2026',
#       u'expanded_url': u'http://www.tomsargent.com/source_code/mitbook.zip',
#       u'indices': [65, 88],
#       u'url': u'https://t.co/hFYvNrefby'},
#      {u'display_url': u'pages.stern.nyu.edu/~dbackus/Ident\u2026',
#       u'expanded_url': u'http://pages.stern.nyu.edu/~dbackus/Identification/LS%20RMT2ed%2004.pdf',
#       u'indices': [103, 126],
#       u'url': u'https://t.co/J9DpGdIOVM'}],
#     u'user_mentions': [{u'id': 115762625,
#       u'id_str': u'115762625',
#       u'indices': [0, 11],
#       u'name': u'Francisco Ibarra',
#       u'screen_name': u'franibar10'},
#      {u'id': 41267271,
#       u'id_str': u'41267271',
#       u'indices': [12, 24],
#       u'name': u'Carlos Antepara',
#       u'screen_name': u'fanbursatil'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 696029475448954880,
#    u'id_str': u'696029475448954880',
#    u'in_reply_to_screen_name': u'franibar10',
#    u'in_reply_to_status_id': 696026715236212737,
#    u'in_reply_to_status_id_str': u'696026715236212737',
#    u'in_reply_to_user_id': 115762625,
#    u'in_reply_to_user_id_str': u'115762625',
#    u'is_quote_status': False,
#    u'lang': u'es',
#    u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'@franibar10 @fanbursatil  En el 1\xba caso puedes ver estos c\xf3digos https://t.co/hFYvNrefby de este libro https://t.co/J9DpGdIOVM o este',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Dec 31 01:00:49 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Writing and reading stuff ...',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'lnkd.in/aNqMPW',
#         u'expanded_url': u'http://lnkd.in/aNqMPW',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/lVdmQolez7'}]}},
#     u'favourites_count': 1892,
#     u'follow_request_sent': False,
#     u'followers_count': 2150,
#     u'following': False,
#     u'friends_count': 1216,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 100640404,
#     u'id_str': u'100640404',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 129,
#     u'location': u'Madrid',
#     u'name': u'Kamal Romero',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/100640404/1444219414',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/460840518440599552/Vdfjg8tJ_normal.png',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/460840518440599552/Vdfjg8tJ_normal.png',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'kamromero',
#     u'statuses_count': 72434,
#     u'time_zone': u'Madrid',
#     u'url': u'http://t.co/lVdmQolez7',
#     u'utc_offset': 3600,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 17:02:45 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'fb.me/4lhovf4Cd',
#       u'expanded_url': u'http://fb.me/4lhovf4Cd',
#       u'indices': [104, 127],
#       u'url': u'https://t.co/jNhf6VezXa'}],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 696016188787318785,
#    u'id_str': u'696016188787318785',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    u'text': u'I posted 3 photos on Facebook in the album "[2016.02.05] Selina \u0e1a\u0e23\u0e23\u0e22\u0e32\u0e22\u0e17\u0e35\u0e48 NYU STERN SCHOOL OF BUSINESS" https://t.co/jNhf6VezXa',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Nov 05 14:28:01 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"S.H.E castle 1st THAILAND FANSITE\u2665 '\u0e40\u0e2d\u0e2a.\u0e40\u0e2d\u0e0a.\u0e2d\u0e35 \u0e44\u0e17\u0e48\u0e01\u0e31\u0e4b\u0e27' [S.H.E\u6cf0\u570b\u7b2c\u4e00\u7c89\u7d72\u7db2\u7ad9] \u2667 \u0e23\u0e27\u0e21\u0e17\u0e38\u0e01\u0e02\u0e48\u0e32\u0e27\u0e2a\u0e32\u0e23/\u0e20\u0e32\u0e1e/\u0e01\u0e34\u0e08\u0e01\u0e23\u0e23\u0e21 \u0e02\u0e2d\u0e07\u0e2a\u0e32\u0e27\u0e46 S.H.E(Selina Hebe Ella) \u0e40\u0e01\u0e34\u0e23\u0e4c\u0e25\u0e01\u0e23\u0e38\u0e4a\u0e1b No.1\u0e08\u0e32\u0e01\u0e44\u0e15\u0e49\u0e2b\u0e27\u0e31\u0e19",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'shetaiguo.com',
#         u'expanded_url': u'http://www.shetaiguo.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/UgzHKdOARD'}]}},
#     u'favourites_count': 271,
#     u'follow_request_sent': False,
#     u'followers_count': 538,
#     u'following': False,
#     u'friends_count': 91,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 87699184,
#     u'id_str': u'87699184',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 4,
#     u'location': u'Thailand \u6cf0\u570b Taiguo',
#     u'name': u'S.H.E\u6cf0\u570b-TAIGUO\u2667',
#     u'notifications': False,
#     u'profile_background_color': u'E892DB',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000115211573/90a1c6e36bc6b15f8748b6d2759c4e03.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000115211573/90a1c6e36bc6b15f8748b6d2759c4e03.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/87699184/1398325007',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/3767359557/61a1ea0872874bb7b82a815660935c5b_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/3767359557/61a1ea0872874bb7b82a815660935c5b_normal.jpeg',
#     u'profile_link_color': u'E32051',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'FFF0FF',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'SHETAIGUO',
#     u'statuses_count': 10390,
#     u'time_zone': None,
#     u'url': u'http://t.co/UgzHKdOARD',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 17:00:28 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'fb.me/4ze6GDsNF',
#       u'expanded_url': u'http://fb.me/4ze6GDsNF',
#       u'indices': [104, 127],
#       u'url': u'https://t.co/FOw17Vyg12'}],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 696015615652466688,
#    u'id_str': u'696015615652466688',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    u'text': u'I posted 4 photos on Facebook in the album "[2016.02.05] Selina \u0e1a\u0e23\u0e23\u0e22\u0e32\u0e22\u0e17\u0e35\u0e48 NYU STERN SCHOOL OF BUSINESS" https://t.co/FOw17Vyg12',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Nov 05 14:28:01 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"S.H.E castle 1st THAILAND FANSITE\u2665 '\u0e40\u0e2d\u0e2a.\u0e40\u0e2d\u0e0a.\u0e2d\u0e35 \u0e44\u0e17\u0e48\u0e01\u0e31\u0e4b\u0e27' [S.H.E\u6cf0\u570b\u7b2c\u4e00\u7c89\u7d72\u7db2\u7ad9] \u2667 \u0e23\u0e27\u0e21\u0e17\u0e38\u0e01\u0e02\u0e48\u0e32\u0e27\u0e2a\u0e32\u0e23/\u0e20\u0e32\u0e1e/\u0e01\u0e34\u0e08\u0e01\u0e23\u0e23\u0e21 \u0e02\u0e2d\u0e07\u0e2a\u0e32\u0e27\u0e46 S.H.E(Selina Hebe Ella) \u0e40\u0e01\u0e34\u0e23\u0e4c\u0e25\u0e01\u0e23\u0e38\u0e4a\u0e1b No.1\u0e08\u0e32\u0e01\u0e44\u0e15\u0e49\u0e2b\u0e27\u0e31\u0e19",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'shetaiguo.com',
#         u'expanded_url': u'http://www.shetaiguo.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/UgzHKdOARD'}]}},
#     u'favourites_count': 271,
#     u'follow_request_sent': False,
#     u'followers_count': 538,
#     u'following': False,
#     u'friends_count': 91,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 87699184,
#     u'id_str': u'87699184',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 4,
#     u'location': u'Thailand \u6cf0\u570b Taiguo',
#     u'name': u'S.H.E\u6cf0\u570b-TAIGUO\u2667',
#     u'notifications': False,
#     u'profile_background_color': u'E892DB',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000115211573/90a1c6e36bc6b15f8748b6d2759c4e03.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000115211573/90a1c6e36bc6b15f8748b6d2759c4e03.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/87699184/1398325007',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/3767359557/61a1ea0872874bb7b82a815660935c5b_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/3767359557/61a1ea0872874bb7b82a815660935c5b_normal.jpeg',
#     u'profile_link_color': u'E32051',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'FFF0FF',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'SHETAIGUO',
#     u'statuses_count': 10390,
#     u'time_zone': None,
#     u'url': u'http://t.co/UgzHKdOARD',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 12:20:58 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 188156839,
#       u'id_str': u'188156839',
#       u'indices': [3, 11],
#       u'name': u'NYAAPOR',
#       u'screen_name': u'NYAAPOR'},
#      {u'id': 13748772,
#       u'id_str': u'13748772',
#       u'indices': [61, 70],
#       u'name': u'Kristen Sosulski',
#       u'screen_name': u'sosulski'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695945277170122752,
#    u'id_str': u'695945277170122752',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 2,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Feb 06 12:07:18 +0000 2016',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 13748772,
#        u'id_str': u'13748772',
#        u'indices': [48, 57],
#        u'name': u'Kristen Sosulski',
#        u'screen_name': u'sosulski'}]},
#     u'favorite_count': 2,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 695941836586815488,
#     u'id_str': u'695941836586815488',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#     u'place': None,
#     u'retweet_count': 2,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. Details soon....',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Wed Sep 08 01:45:08 +0000 2010',
#      u'default_profile': True,
#      u'default_profile_image': False,
#      u'description': u'The New York Chapter of the American Association for Public Opinion Research',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'nyaapor.org',
#          u'expanded_url': u'http://www.nyaapor.org/',
#          u'indices': [0, 22],
#          u'url': u'http://t.co/xmaELvAzxh'}]}},
#      u'favourites_count': 84,
#      u'follow_request_sent': False,
#      u'followers_count': 173,
#      u'following': False,
#      u'friends_count': 145,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 188156839,
#      u'id_str': u'188156839',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 16,
#      u'location': u'New York',
#      u'name': u'NYAAPOR',
#      u'notifications': False,
#      u'profile_background_color': u'C0DEED',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': False,
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1119449605/NYAAPOR_apple_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1119449605/NYAAPOR_apple_normal.jpg',
#      u'profile_link_color': u'0084B4',
#      u'profile_sidebar_border_color': u'C0DEED',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'NYAAPOR',
#      u'statuses_count': 263,
#      u'time_zone': u'Pacific Time (US & Canada)',
#      u'url': u'http://t.co/xmaELvAzxh',
#      u'utc_offset': -28800,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'RT @NYAAPOR: Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. De\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Jul 15 15:48:09 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 17,
#     u'follow_request_sent': False,
#     u'followers_count': 54,
#     u'following': False,
#     u'friends_count': 242,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 167028972,
#     u'id_str': u'167028972',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 3,
#     u'location': u'',
#     u'name': u'Randy Brown',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1079240897/sydney_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1079240897/sydney_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'brown756',
#     u'statuses_count': 420,
#     u'time_zone': None,
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 12:15:41 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 188156839,
#       u'id_str': u'188156839',
#       u'indices': [3, 11],
#       u'name': u'NYAAPOR',
#       u'screen_name': u'NYAAPOR'},
#      {u'id': 13748772,
#       u'id_str': u'13748772',
#       u'indices': [61, 70],
#       u'name': u'Kristen Sosulski',
#       u'screen_name': u'sosulski'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695943946787287040,
#    u'id_str': u'695943946787287040',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 2,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Feb 06 12:07:18 +0000 2016',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 13748772,
#        u'id_str': u'13748772',
#        u'indices': [48, 57],
#        u'name': u'Kristen Sosulski',
#        u'screen_name': u'sosulski'}]},
#     u'favorite_count': 2,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 695941836586815488,
#     u'id_str': u'695941836586815488',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#     u'place': None,
#     u'retweet_count': 2,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. Details soon....',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Wed Sep 08 01:45:08 +0000 2010',
#      u'default_profile': True,
#      u'default_profile_image': False,
#      u'description': u'The New York Chapter of the American Association for Public Opinion Research',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'nyaapor.org',
#          u'expanded_url': u'http://www.nyaapor.org/',
#          u'indices': [0, 22],
#          u'url': u'http://t.co/xmaELvAzxh'}]}},
#      u'favourites_count': 84,
#      u'follow_request_sent': False,
#      u'followers_count': 173,
#      u'following': False,
#      u'friends_count': 145,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 188156839,
#      u'id_str': u'188156839',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 16,
#      u'location': u'New York',
#      u'name': u'NYAAPOR',
#      u'notifications': False,
#      u'profile_background_color': u'C0DEED',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': False,
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1119449605/NYAAPOR_apple_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1119449605/NYAAPOR_apple_normal.jpg',
#      u'profile_link_color': u'0084B4',
#      u'profile_sidebar_border_color': u'C0DEED',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'NYAAPOR',
#      u'statuses_count': 263,
#      u'time_zone': u'Pacific Time (US & Canada)',
#      u'url': u'http://t.co/xmaELvAzxh',
#      u'utc_offset': -28800,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'RT @NYAAPOR: Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. De\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri May 01 17:48:08 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Senior Education Research Scientist, Institute of Education Sciences, U.S. Department of Education -- What Works Clearinghouse',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'ies.ed.gov/ncee/wwc/',
#         u'expanded_url': u'http://ies.ed.gov/ncee/wwc/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/pkwnwtUbPG'}]}},
#     u'favourites_count': 718,
#     u'follow_request_sent': False,
#     u'followers_count': 569,
#     u'following': False,
#     u'friends_count': 761,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 36997932,
#     u'id_str': u'36997932',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 20,
#     u'location': u'NYC/DC',
#     u'name': u'Christopher Weiss',
#     u'notifications': False,
#     u'profile_background_color': u'9AE4E8',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/145887789/barfy.gif',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/145887789/barfy.gif',
#     u'profile_background_tile': True,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000801881082/63f4f3f029715cd5b502a3bfeaea2e25_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000801881082/63f4f3f029715cd5b502a3bfeaea2e25_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'BDDCAD',
#     u'profile_sidebar_fill_color': u'DDFFCC',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'chrisweiss_175',
#     u'statuses_count': 2003,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'url': u'https://t.co/pkwnwtUbPG',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 12:07:18 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 13748772,
#       u'id_str': u'13748772',
#       u'indices': [48, 57],
#       u'name': u'Kristen Sosulski',
#       u'screen_name': u'sosulski'}]},
#    u'favorite_count': 2,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695941836586815488,
#    u'id_str': u'695941836586815488',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 2,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. Details soon....',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Sep 08 01:45:08 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'The New York Chapter of the American Association for Public Opinion Research',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'nyaapor.org',
#         u'expanded_url': u'http://www.nyaapor.org/',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/xmaELvAzxh'}]}},
#     u'favourites_count': 84,
#     u'follow_request_sent': False,
#     u'followers_count': 173,
#     u'following': False,
#     u'friends_count': 145,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 188156839,
#     u'id_str': u'188156839',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 16,
#     u'location': u'New York',
#     u'name': u'NYAAPOR',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1119449605/NYAAPOR_apple_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1119449605/NYAAPOR_apple_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'NYAAPOR',
#     u'statuses_count': 263,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'url': u'http://t.co/xmaELvAzxh',
#     u'utc_offset': -28800,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 11:39:07 +0000 2016',
#    u'entities': {u'hashtags': [{u'indices': [90, 104],
#       u'text': u'eschool4girls'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'prnewswire.com/news-releases/\u2026',
#       u'expanded_url': u'http://www.prnewswire.com/news-releases/e-school-for-girls-partners-with-nyu-and-microsoft-for-entrepreneurship-event-300215639.html',
#       u'indices': [66, 89],
#       u'url': u'https://t.co/siol1JsRY4'}],
#     u'user_mentions': [{u'id': 3377476355,
#       u'id_str': u'3377476355',
#       u'indices': [3, 17],
#       u'name': u'E-School For Girls',
#       u'screen_name': u'eschool4girls'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695934742655586304,
#    u'id_str': u'695934742655586304',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 3,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Feb 06 10:51:07 +0000 2016',
#     u'entities': {u'hashtags': [{u'indices': [71, 85],
#        u'text': u'eschool4girls'}],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'prnewswire.com/news-releases/\u2026',
#        u'expanded_url': u'http://www.prnewswire.com/news-releases/e-school-for-girls-partners-with-nyu-and-microsoft-for-entrepreneurship-event-300215639.html',
#        u'indices': [47, 70],
#        u'url': u'https://t.co/siol1JsRY4'}],
#      u'user_mentions': []},
#     u'favorite_count': 7,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 695922665119416321,
#     u'id_str': u'695922665119416321',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 3,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Wed Jul 15 15:56:51 +0000 2015',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'The E-School for Girls is designed to help High School Girls become Future Entrepreneurs. Organized by #NYUCAC, #NYCPromise, #GC4W & #MIDDYFUND. #Eschool4girls',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'eschool4girls.com',
#          u'expanded_url': u'http://eschool4girls.com',
#          u'indices': [0, 23],
#          u'url': u'https://t.co/jsKixqoZJl'}]}},
#      u'favourites_count': 129,
#      u'follow_request_sent': False,
#      u'followers_count': 55,
#      u'following': False,
#      u'friends_count': 58,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 3377476355,
#      u'id_str': u'3377476355',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 2,
#      u'location': u'New York, NY',
#      u'name': u'E-School For Girls',
#      u'notifications': False,
#      u'profile_background_color': u'000000',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/3377476355/1436977048',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/621348694302920704/LSLfEnOX_normal.png',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/621348694302920704/LSLfEnOX_normal.png',
#      u'profile_link_color': u'9266CC',
#      u'profile_sidebar_border_color': u'000000',
#      u'profile_sidebar_fill_color': u'000000',
#      u'profile_text_color': u'000000',
#      u'profile_use_background_image': False,
#      u'protected': False,
#      u'screen_name': u'eschool4girls',
#      u'statuses_count': 146,
#      u'time_zone': None,
#      u'url': u'https://t.co/jsKixqoZJl',
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'RT @eschool4girls: E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Aug 17 21:32:14 +0000 2011',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Goodwill Ambassador. @Harvard Grad. @GC4Women Founder. Adjunct Professor @NYUSPS. Writer @Huffingtonpost @BlackEnterprise Power Woman. Philanthropist. Speaker.',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'linkedin.com/in/lilianajayi',
#         u'expanded_url': u'http://www.linkedin.com/in/lilianajayi',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/L3E6tPiJqE'}]}},
#     u'favourites_count': 1296,
#     u'follow_request_sent': False,
#     u'followers_count': 996,
#     u'following': False,
#     u'friends_count': 472,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 357113191,
#     u'id_str': u'357113191',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 53,
#     u'location': u'press@gc4women.org',
#     u'name': u'TheTruth',
#     u'notifications': False,
#     u'profile_background_color': u'DAEEF5',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/606587558596902912/gP13Ky30.png',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/606587558596902912/gP13Ky30.png',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/357113191/1437797635',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/687344364486561792/TIK36u7r_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/687344364486561792/TIK36u7r_normal.jpg',
#     u'profile_link_color': u'FA743E',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'99CC33',
#     u'profile_text_color': u'3E4415',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'LilianAjayi',
#     u'statuses_count': 2930,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'url': u'https://t.co/L3E6tPiJqE',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 11:37:41 +0000 2016',
#    u'entities': {u'hashtags': [{u'indices': [90, 104],
#       u'text': u'eschool4girls'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'prnewswire.com/news-releases/\u2026',
#       u'expanded_url': u'http://www.prnewswire.com/news-releases/e-school-for-girls-partners-with-nyu-and-microsoft-for-entrepreneurship-event-300215639.html',
#       u'indices': [66, 89],
#       u'url': u'https://t.co/siol1JsRY4'}],
#     u'user_mentions': [{u'id': 3377476355,
#       u'id_str': u'3377476355',
#       u'indices': [3, 17],
#       u'name': u'E-School For Girls',
#       u'screen_name': u'eschool4girls'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695934385195982850,
#    u'id_str': u'695934385195982850',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 3,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Feb 06 10:51:07 +0000 2016',
#     u'entities': {u'hashtags': [{u'indices': [71, 85],
#        u'text': u'eschool4girls'}],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'prnewswire.com/news-releases/\u2026',
#        u'expanded_url': u'http://www.prnewswire.com/news-releases/e-school-for-girls-partners-with-nyu-and-microsoft-for-entrepreneurship-event-300215639.html',
#        u'indices': [47, 70],
#        u'url': u'https://t.co/siol1JsRY4'}],
#      u'user_mentions': []},
#     u'favorite_count': 7,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 695922665119416321,
#     u'id_str': u'695922665119416321',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 3,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Wed Jul 15 15:56:51 +0000 2015',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'The E-School for Girls is designed to help High School Girls become Future Entrepreneurs. Organized by #NYUCAC, #NYCPromise, #GC4W & #MIDDYFUND. #Eschool4girls',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'eschool4girls.com',
#          u'expanded_url': u'http://eschool4girls.com',
#          u'indices': [0, 23],
#          u'url': u'https://t.co/jsKixqoZJl'}]}},
#      u'favourites_count': 129,
#      u'follow_request_sent': False,
#      u'followers_count': 55,
#      u'following': False,
#      u'friends_count': 58,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 3377476355,
#      u'id_str': u'3377476355',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 2,
#      u'location': u'New York, NY',
#      u'name': u'E-School For Girls',
#      u'notifications': False,
#      u'profile_background_color': u'000000',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/3377476355/1436977048',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/621348694302920704/LSLfEnOX_normal.png',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/621348694302920704/LSLfEnOX_normal.png',
#      u'profile_link_color': u'9266CC',
#      u'profile_sidebar_border_color': u'000000',
#      u'profile_sidebar_fill_color': u'000000',
#      u'profile_text_color': u'000000',
#      u'profile_use_background_image': False,
#      u'protected': False,
#      u'screen_name': u'eschool4girls',
#      u'statuses_count': 146,
#      u'time_zone': None,
#      u'url': u'https://t.co/jsKixqoZJl',
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'RT @eschool4girls: E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Dec 25 00:41:25 +0000 2014',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'2015 Best of Manhattan Charity Organization. Give $25 to #GC4W to bring an education to Disabled Girls https://t.co/9rbIWPwRAd. visit https://t.co/6JLgx1bk9G!',
#     u'entities': {u'description': {u'urls': [{u'display_url': u'gc4women.org/donate',
#         u'expanded_url': u'http://gc4women.org/donate',
#         u'indices': [103, 126],
#         u'url': u'https://t.co/9rbIWPwRAd'},
#        {u'display_url': u'gc4women.org/events',
#         u'expanded_url': u'http://gc4women.org/events',
#         u'indices': [134, 157],
#         u'url': u'https://t.co/6JLgx1bk9G'}]},
#      u'url': {u'urls': [{u'display_url': u'gc4women.org/events',
#         u'expanded_url': u'http://gc4women.org/events',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/6JLgx1bk9G'}]}},
#     u'favourites_count': 881,
#     u'follow_request_sent': False,
#     u'followers_count': 257,
#     u'following': False,
#     u'friends_count': 406,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 2940209050,
#     u'id_str': u'2940209050',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 19,
#     u'location': u'info@gc4women.org',
#     u'name': u'GC4Women.org Events',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2940209050/1433453287',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/687345764511670272/z-2WWS33_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/687345764511670272/z-2WWS33_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'GC4WEvents',
#     u'statuses_count': 1045,
#     u'time_zone': None,
#     u'url': u'https://t.co/6JLgx1bk9G',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 10:55:09 +0000 2016',
#    u'entities': {u'hashtags': [{u'indices': [90, 104],
#       u'text': u'eschool4girls'}],
# ...
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'RT @eschool4girls: E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Nov 03 19:41:05 +0000 2011',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'2015 Best of #Manhattan Charity. Give $50 on #Givingtuesday to bring an education to Disabled Girls. https://t.co/9rbIWPwRAd. We are @GC4WEvents @GC4WJobs',
#     u'entities': {u'description': {u'urls': [{u'display_url': u'gc4women.org/donate',
#         u'expanded_url': u'http://gc4women.org/donate',
#         u'indices': [101, 124],
#         u'url': u'https://t.co/9rbIWPwRAd'}]},
#      u'url': {u'urls': [{u'display_url': u'gc4women.org',
#         u'expanded_url': u'http://gc4women.org',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/Pk2dMsfiqv'}]}},
#     u'favourites_count': 2175,
#     u'follow_request_sent': False,
#     u'followers_count': 2392,
#     u'following': False,
#     u'friends_count': 833,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 404336863,
#     u'id_str': u'404336863',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 104,
#     u'location': u'info@gc4women.org',
#     u'name': u'GC4W Foundation',
#     u'notifications': False,
#     u'profile_background_color': u'EBEBEB',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/656215547416289280/hl46eI6F.jpg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/656215547416289280/hl46eI6F.jpg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/404336863/1452284472',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/685073308048617473/h8IQqqmE_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/685073308048617473/h8IQqqmE_normal.jpg',
#     u'profile_link_color': u'FA743E',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'F3F3F3',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'GC4Women',
#     u'statuses_count': 13854,
#     u'time_zone': u'Quito',
#     u'url': u'https://t.co/Pk2dMsfiqv',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 10:51:07 +0000 2016',
#    u'entities': {u'hashtags': [{u'indices': [71, 85],
#       u'text': u'eschool4girls'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'prnewswire.com/news-releases/\u2026',
#       u'expanded_url': u'http://www.prnewswire.com/news-releases/e-school-for-girls-partners-with-nyu-and-microsoft-for-entrepreneurship-event-300215639.html',
#       u'indices': [47, 70],
#       u'url': u'https://t.co/siol1JsRY4'}],
#     u'user_mentions': []},
#    u'favorite_count': 7,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695922665119416321,
#    u'id_str': u'695922665119416321',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 3,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Jul 15 15:56:51 +0000 2015',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'The E-School for Girls is designed to help High School Girls become Future Entrepreneurs. Organized by #NYUCAC, #NYCPromise, #GC4W & #MIDDYFUND. #Eschool4girls',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'eschool4girls.com',
#         u'expanded_url': u'http://eschool4girls.com',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/jsKixqoZJl'}]}},
#     u'favourites_count': 129,
#     u'follow_request_sent': False,
#     u'followers_count': 55,
#     u'following': False,
#     u'friends_count': 58,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 3377476355,
#     u'id_str': u'3377476355',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 2,
#     u'location': u'New York, NY',
#     u'name': u'E-School For Girls',
#     u'notifications': False,
#     u'profile_background_color': u'000000',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/3377476355/1436977048',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/621348694302920704/LSLfEnOX_normal.png',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/621348694302920704/LSLfEnOX_normal.png',
#     u'profile_link_color': u'9266CC',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'eschool4girls',
#     u'statuses_count': 146,
#     u'time_zone': None,
#     u'url': u'https://t.co/jsKixqoZJl',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 07:38:30 +0000 2016',
#    u'entities': {u'hashtags': [{u'indices': [15, 36],
#       u'text': u'GentrificationOnFire'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'fb.me/2Alo2l3xg',
#       u'expanded_url': u'http://fb.me/2Alo2l3xg',
#       u'indices': [37, 60],
#       u'url': u'https://t.co/7qogI4BWI9'}],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695874192600866820,
#    u'id_str': u'695874192600866820',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    u'text': u'Not the Onion. #GentrificationOnFire https://t.co/7qogI4BWI9',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Jun 25 01:20:10 +0000 2008',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"Maybe it's class war, I call it common sense. I have many opinions and I try to do good work. #OWS #occupywallstreet #occupy rolling with @OccupyWallStNYC",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'occupywallst.nyc',
#         u'expanded_url': u'http://www.occupywallst.nyc/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/pDbN3PYcV3'}]}},
#     u'favourites_count': 2045,
#     u'follow_request_sent': False,
#     u'followers_count': 2261,
#     u'following': False,
#     u'friends_count': 2237,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 15226117,
#     u'id_str': u'15226117',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 142,
#     u'location': u'United State of NYC',
#     u'name': u'grimwomyn',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/442835532620378113/xOS8SysU.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/442835532620378113/xOS8SysU.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/15226117/1425568596',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/573503346683744258/JFqPCdT9_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/573503346683744258/JFqPCdT9_normal.jpeg',
#     u'profile_link_color': u'FF0000',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'7AC3EE',
#     u'profile_text_color': u'3D1957',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'grimwomyn',
#     u'statuses_count': 15140,
#     u'time_zone': u'Eastern Time (US & Canada)',
#     u'url': u'https://t.co/pDbN3PYcV3',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 07:14:52 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'media': [{u'display_url': u'pic.twitter.com/QO38JQeu1B',
#       u'expanded_url': u'http://twitter.com/VegasCashFlow/status/695868243869732864/photo/1',
#       u'id': 695868231953690624,
#       u'id_str': u'695868231953690624',
#       u'indices': [47, 70],
#       u'media_url': u'http://pbs.twimg.com/media/Cag4eFgUMAAcbmb.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/Cag4eFgUMAAcbmb.jpg',
#       u'sizes': {u'large': {u'h': 1024, u'resize': u'fit', u'w': 577},
#        u'medium': {u'h': 1024, u'resize': u'fit', u'w': 577},
#        u'small': {u'h': 603, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/QO38JQeu1B'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'pages.stern.nyu.edu/~mrichar0/top6\u2026',
#       u'expanded_url': u'http://pages.stern.nyu.edu/~mrichar0/top6b.ppt',
#       u'indices': [23, 46],
#       u'url': u'https://t.co/x3JTkJP72f'}],
#     u'user_mentions': [{u'id': 21271771,
#       u'id_str': u'21271771',
#       u'indices': [0, 12],
#       u'name': u'Tren Griffin',
#       u'screen_name': u'trengriffin'},
#      {u'id': 42226885,
#       u'id_str': u'42226885',
#       u'indices': [13, 21],
#       u'name': u'Vinod Khosla',
#       u'screen_name': u'vkhosla'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695868243869732864,
#    u'id_str': u'695868243869732864',
#    u'in_reply_to_screen_name': u'trengriffin',
#    u'in_reply_to_status_id': 695860585255153664,
#    u'in_reply_to_status_id_str': u'695860585255153664',
#    u'in_reply_to_user_id': 21271771,
#    u'in_reply_to_user_id_str': u'21271771',
#    u'is_quote_status': False,
#    u'lang': u'und',
#    u'metadata': {u'iso_language_code': u'und', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'@trengriffin @vkhosla \nhttps://t.co/x3JTkJP72f https://t.co/QO38JQeu1B',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Jan 04 07:58:32 +0000 2013',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u"whether you think you CAN or think you CAN'T.... You Are Right",
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 1570,
#     u'follow_request_sent': False,
#     u'followers_count': 1977,
#     u'following': False,
#     u'friends_count': 146,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 1059842340,
#     u'id_str': u'1059842340',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 56,
#     u'location': u'lVnV',
#     u'name': u'EmergAnce',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1059842340/1454182396',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/695780884339757056/VHlJGzGE_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/695780884339757056/VHlJGzGE_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'VegasCashFlow',
#     u'statuses_count': 61883,
#     u'time_zone': None,
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Feb 06 02:43:31 +0000 2016',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'fb.me/2gvJt2Yno',
#       u'expanded_url': u'http://fb.me/2gvJt2Yno',
#       u'indices': [75, 98],
#       u'url': u'https://t.co/EEY5McLxuU'}],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 695799957400322049,
#    u'id_str': u'695799957400322049',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    u'text': u'NYU Stern | Tales in Possible | Govern Possible | EMBA Alum Richard Thomas https://t.co/EEY5McLxuU',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Apr 28 16:35:52 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 6,
#     u'follow_request_sent': False,
#     u'followers_count': 97,
#     u'following': False,
#     u'friends_count': 101,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 36111248,
#     u'id_str': u'36111248',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 2,
#     u'location': u'',
#     u'name': u'Kexi KeepItMoving',
#     u'notifications': False,
#     u'profile_background_color': u'642D8B',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     u'profile_background_tile': True,
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000599954538/bea976292df6d57368099ba79932e060_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000599954538/bea976292df6d57368099ba79932e060_normal.jpeg',
#     u'profile_link_color': u'FF0000',
#     u'profile_sidebar_border_color': u'65B0DA',
#     u'profile_sidebar_fill_color': u'7AC3EE',
#     u'profile_text_color': u'3D1957',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'KexiKeepItMovin',
#     u'statuses_count': 5227,
#     u'time_zone': u'Quito',
#     u'url': None,
#     u'utc_offset': -18000,
#     u'verified': False}}]}

# %% [markdown]
# Please pay attention on how much information each tweet contains.

# %%
# And let's see tweets text directly
for num, tweet in enumerate(tweets['statuses']):
    print('Tweet )#{0}\t{1}\t{2}\n{3}\n'.format(num+1, tweet['created_at'], 
                                               tweet['retweet_count'], 
                                               tweet['text'].encode("utf-8"))
# Out:
# Tweet #1	Sat Feb 06 20:03:05 +0000 2016	0
# @jesusalfar a mí me ha gustado mucho. Esta es la versión no JEP https://t.co/PRrn5ZyVMe
#
# Tweet #2	Sat Feb 06 18:49:28 +0000 2016	0
# Qué pena! este artículo no debería haberse publicado en el JEconPersp. No lo entiendo https://t.co/E44X0Ajbqw
#
# Tweet #3	Sat Feb 06 17:55:33 +0000 2016	0
# @franibar10 @fanbursatil  En el 1º caso puedes ver estos códigos https://t.co/hFYvNrefby de este libro https://t.co/J9DpGdIOVM o este
#
# Tweet #4	Sat Feb 06 17:02:45 +0000 2016	0
# I posted 3 photos on Facebook in the album "[2016.02.05] Selina บรรยายที่ NYU STERN SCHOOL OF BUSINESS" https://t.co/jNhf6VezXa
#
# Tweet #5	Sat Feb 06 17:00:28 +0000 2016	0
# I posted 4 photos on Facebook in the album "[2016.02.05] Selina บรรยายที่ NYU STERN SCHOOL OF BUSINESS" https://t.co/FOw17Vyg12
#
# Tweet #6	Sat Feb 06 12:20:58 +0000 2016	2
# RT @NYAAPOR: Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. De…
#
# Tweet #7	Sat Feb 06 12:15:41 +0000 2016	2
# RT @NYAAPOR: Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. De…
#
# Tweet #8	Sat Feb 06 12:07:18 +0000 2016	2
# Save the date! Data visualization workshop with @sosulski (Director of Info, Opers, &amp; Mgmt Sciences at NYU-Stern). March 3. Details soon....
#
# Tweet #9	Sat Feb 06 11:39:07 +0000 2016	3
# RT @eschool4girls: E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls
#
# Tweet #10	Sat Feb 06 11:37:41 +0000 2016	3
# RT @eschool4girls: E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls
#
# Tweet #11	Sat Feb 06 10:55:09 +0000 2016	3
# RT @eschool4girls: E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls
#
# Tweet #12	Sat Feb 06 10:51:07 +0000 2016	3
# E-School for Girls at NYU Stern on PR Newswire https://t.co/siol1JsRY4 #eschool4girls
#
# Tweet #13	Sat Feb 06 07:38:30 +0000 2016	0
# Not the Onion. #GentrificationOnFire https://t.co/7qogI4BWI9
#
# Tweet #14	Sat Feb 06 07:14:52 +0000 2016	0
# @trengriffin @vkhosla
# https://t.co/x3JTkJP72f https://t.co/QO38JQeu1B
#
# Tweet #15	Sat Feb 06 02:43:31 +0000 2016	0
# NYU Stern | Tales in Possible | Govern Possible | EMBA Alum Richard Thomas https://t.co/EEY5McLxuU

# %%
import pandas as pd
df = pd.DataFrame(tweets['statuses'])
df
# Out:
#    contributors coordinates                      created_at  \
# 0          None        None  Sat Feb 06 20:03:05 +0000 2016
# 1          None        None  Sat Feb 06 18:49:28 +0000 2016
# 2          None        None  Sat Feb 06 17:55:33 +0000 2016
# 3          None        None  Sat Feb 06 17:02:45 +0000 2016
# 4          None        None  Sat Feb 06 17:00:28 +0000 2016
# 5          None        None  Sat Feb 06 12:20:58 +0000 2016
# 6          None        None  Sat Feb 06 12:15:41 +0000 2016
# 7          None        None  Sat Feb 06 12:07:18 +0000 2016
# 8          None        None  Sat Feb 06 11:39:07 +0000 2016
# 9          None        None  Sat Feb 06 11:37:41 +0000 2016
# 10         None        None  Sat Feb 06 10:55:09 +0000 2016
# 11         None        None  Sat Feb 06 10:51:07 +0000 2016
# 12         None        None  Sat Feb 06 07:38:30 +0000 2016
# 13         None        None  Sat Feb 06 07:14:52 +0000 2016
# 14         None        None  Sat Feb 06 02:43:31 +0000 2016
#
#                                              entities  favorite_count  \
# 0   {u'symbols': [], u'user_mentions': [{u'id': 21...               0
# 1   {u'symbols': [], u'user_mentions': [], u'hasht...               0
# 2   {u'symbols': [], u'user_mentions': [{u'id': 11...               0
# 3   {u'symbols': [], u'user_mentions': [], u'hasht...               0
# 4   {u'symbols': [], u'user_mentions': [], u'hasht...               0
# 5   {u'symbols': [], u'user_mentions': [{u'id': 18...               0
# 6   {u'symbols': [], u'user_mentions': [{u'id': 18...               0
# 7   {u'symbols': [], u'user_mentions': [{u'id': 13...               2
# 8   {u'symbols': [], u'user_mentions': [{u'id': 33...               0
# 9   {u'symbols': [], u'user_mentions': [{u'id': 33...               0
# 10  {u'symbols': [], u'user_mentions': [{u'id': 33...               0
# 11  {u'symbols': [], u'user_mentions': [], u'hasht...               7
# 12  {u'symbols': [], u'user_mentions': [], u'hasht...               0
# 13  {u'symbols': [], u'user_mentions': [{u'id': 21...               0
# 14  {u'symbols': [], u'user_mentions': [], u'hasht...               0
#
#    favorited   geo                  id              id_str  \
# 0      False  None  696061569554378753  696061569554378753
# 1      False  None  696043047138758656  696043047138758656
# 2      False  None  696029475448954880  696029475448954880
# 3      False  None  696016188787318785  696016188787318785
# 4      False  None  696015615652466688  696015615652466688
# 5      False  None  695945277170122752  695945277170122752
# 6      False  None  695943946787287040  695943946787287040
# 7      False  None  695941836586815488  695941836586815488
# 8      False  None  695934742655586304  695934742655586304
# 9      False  None  695934385195982850  695934385195982850
# 10     False  None  695923679348330496  695923679348330496
# 11     False  None  695922665119416321  695922665119416321
# 12     False  None  695874192600866820  695874192600866820
# 13     False  None  695868243869732864  695868243869732864
# 14     False  None  695799957400322049  695799957400322049
#
#    in_reply_to_screen_name                        ...                          \
# 0               jesusalfar                        ...
# 1                     None                        ...
# 2               franibar10                        ...
# 3                     None                        ...
# 4                     None                        ...
# 5                     None                        ...
# 6                     None                        ...
# 7                     None                        ...
# 8                     None                        ...
# 9                     None                        ...
# 10                    None                        ...
# 11                    None                        ...
# 12                    None                        ...
# 13             trengriffin                        ...
# 14                    None                        ...
#
#                                              metadata place  \
# 0   {u'iso_language_code': u'es', u'result_type': ...  None
# 1   {u'iso_language_code': u'es', u'result_type': ...  None
# 2   {u'iso_language_code': u'es', u'result_type': ...  None
# 3   {u'iso_language_code': u'en', u'result_type': ...  None
# 4   {u'iso_language_code': u'en', u'result_type': ...  None
# 5   {u'iso_language_code': u'en', u'result_type': ...  None
# 6   {u'iso_language_code': u'en', u'result_type': ...  None
# 7   {u'iso_language_code': u'en', u'result_type': ...  None
# 8   {u'iso_language_code': u'en', u'result_type': ...  None
# 9   {u'iso_language_code': u'en', u'result_type': ...  None
# 10  {u'iso_language_code': u'en', u'result_type': ...  None
# 11  {u'iso_language_code': u'en', u'result_type': ...  None
# 12  {u'iso_language_code': u'en', u'result_type': ...  None
# 13  {u'iso_language_code': u'und', u'result_type':...  None
# 14  {u'iso_language_code': u'en', u'result_type': ...  None
#
#     possibly_sensitive retweet_count retweeted  \
# 0                False             0     False
# 1                False             0     False
# 2                False             0     False
# 3                False             0     False
# 4                False             0     False
# 5                  NaN             2     False
# 6                  NaN             2     False
# 7                  NaN             2     False
# 8                False             3     False
# 9                False             3     False
# 10               False             3     False
# 11               False             3     False
# 12               False             0     False
# 13               False             0     False
# 14               False             0     False
#
#                                      retweeted_status  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   {u'contributors': None, u'truncated': False, u...
# 6   {u'contributors': None, u'truncated': False, u...
# 7                                                 NaN
# 8   {u'contributors': None, u'truncated': False, u...
# 9   {u'contributors': None, u'truncated': False, u...
# 10  {u'contributors': None, u'truncated': False, u...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#                                                source  \
# 0   <a href="http://twitter.com/#!/download/ipad" ...
# 1   <a href="http://twitter.com" rel="nofollow">Tw...
# 2   <a href="http://twitter.com" rel="nofollow">Tw...
# 3   <a href="http://www.facebook.com/twitter" rel=...
# 4   <a href="http://www.facebook.com/twitter" rel=...
# 5   <a href="http://twitter.com/download/iphone" r...
# 6   <a href="http://twitter.com" rel="nofollow">Tw...
# 7   <a href="http://twitter.com" rel="nofollow">Tw...
# 8   <a href="http://twitter.com/download/iphone" r...
# 9   <a href="http://twitter.com/download/iphone" r...
# 10  <a href="http://twitter.com/download/iphone" r...
# 11  <a href="http://twitter.com/download/iphone" r...
# 12  <a href="http://www.facebook.com/twitter" rel=...
# 13  <a href="http://twitter.com/download/iphone" r...
# 14  <a href="http://www.facebook.com/twitter" rel=...
#
#                                                  text truncated  \
# 0   @jesusalfar a mí me ha gustado mucho. Esta es ...     False
# 1   Qué pena! este artículo no debería haberse pub...     False
# 2   @franibar10 @fanbursatil  En el 1º caso puedes...     False
# 3   I posted 3 photos on Facebook in the album "[2...     False
# 4   I posted 4 photos on Facebook in the album "[2...     False
# 5   RT @NYAAPOR: Save the date! Data visualization...     False
# 6   RT @NYAAPOR: Save the date! Data visualization...     False
# 7   Save the date! Data visualization workshop wit...     False
# 8   RT @eschool4girls: E-School for Girls at NYU S...     False
# 9   RT @eschool4girls: E-School for Girls at NYU S...     False
# 10  RT @eschool4girls: E-School for Girls at NYU S...     False
# 11  E-School for Girls at NYU Stern on PR Newswire...     False
# 12  Not the Onion. #GentrificationOnFire https://t...     False
# 13  @trengriffin @vkhosla \nhttps://t.co/x3JTkJP72...     False
# 14  NYU Stern | Tales in Possible | Govern Possibl...     False
#
#                                                  user
# 0   {u'follow_request_sent': False, u'has_extended...
# 1   {u'follow_request_sent': False, u'has_extended...
# 2   {u'follow_request_sent': False, u'has_extended...
# 3   {u'follow_request_sent': False, u'has_extended...
# 4   {u'follow_request_sent': False, u'has_extended...
# 5   {u'follow_request_sent': False, u'has_extended...
# 6   {u'follow_request_sent': False, u'has_extended...
# 7   {u'follow_request_sent': False, u'has_extended...
# 8   {u'follow_request_sent': False, u'has_extended...
# 9   {u'follow_request_sent': False, u'has_extended...
# 10  {u'follow_request_sent': False, u'has_extended...
# 11  {u'follow_request_sent': False, u'has_extended...
# 12  {u'follow_request_sent': False, u'has_extended...
# 13  {u'follow_request_sent': False, u'has_extended...
# 14  {u'follow_request_sent': False, u'has_extended...
#
# [15 rows x 26 columns]

# %%
# If we want to flatten the nested JSON entries
# we can use the json_normalize function
# http://pandas-docs.github.io/pandas-docs-travis/io.html#normalization
import pandas as pd
from pandas.io.json import json_normalize
df_flat = json_normalize(tweets['statuses'])

# %%
mylist = [
    {"FullName": {
            "Given": {
                "First": "Panos", 
                "Middle": "Gregory"
            }, 
            "Family": "Ipeirotis"
        }, 
     "Age": 40
    },
    {"FullName": {
            "Given": {
                "First": "John", 
                "Middle": "Reuben"
            }, 
            "Family": "Smith"
        }, 
     "Age": 25
    },
    {"FullName": {
            "Given": {
                "First": "Jane", 
                "Middle": "Janet"
            }, 
            "Family": "Smith"}, 
     "Age": 22
    }
]

df_test = pd.DataFrame(mylist)
df_test

# %%
from pandas.io.json import json_normalize
df_test_normalized = json_normalize(mylist)
df_test_normalized

# %% [markdown]
# You may create very specialized and more concrete queries.
#
# Let's find 5 tweets that contains the word "python" or "IPython" near New York. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language). Additional parameters allows build very complicated search requests.

# %%
url_2_2 = 'https://api.twitter.com/1.1/search/tweets.json'

params = {
    "count": 10, 
    "geocode": '40.7127,-74.0059,15mi',
    "lang": 'en',
    "q": 'python'
}

res = requests.get(url_2_2, auth=auth, params=params)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

tweets = res.json()

for num, tweet in enumerate(tweets['statuses']):
    print("-----------------------------")
    print('Tweet )#{0}\t{1}\n{2}\n'.format(num+1, tweet['created_at'], tweet['text'].encode("utf-8"))

# %% [markdown]
# ### Example 3: Get a list of all your followers
#
# **Twitter** GET request `followers/list` returns a cursored collection of user objects for users following the specified user. At this time, results are ordered with the most recent following first.

# %%
url_3 = 'https://api.twitter.com/1.1/followers/list.json'
res = requests.get(url_3, auth=auth)
print(res, res.status_code, res.headers['content-type'])
print(res.url)

followers = res.json()
followers

# %%
# And let's see only followers' name
for num, follower in enumerate(followers['users']):
    print('My follower )#{0}\t{1}'.format(num+1, follower['name'].encode("utf-8"))

# %%
# And now an example of using a "cursor" to go through pages of results
cursor = res.json().get("next_cursor_str")
res = requests.get(url_3, auth=auth, params={"cursor": cursor})
print(res, res.status_code, res.headers['content-type'])
print(res.url)

followers = res.json()
for num, follower in enumerate(followers['users']):
    print('My follower )#{0}\t{1}'.format(num+1, follower['name'].encode("utf-8"))

# %% [markdown]
# ### Example 4:  Finding what is trending
#
# According to the [tweepy API](http://tweepy.readthedocs.org/en/v3.5.0/api.html), we can return the top 50 trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, New York has a `WOEID` of 2459115. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in New York

# %%
url_4 = 'https://api.twitter.com/1.1/trends/place.json?id=2459115'
res = requests.get(url_4, auth=auth)

print(res, res.status_code, res.headers['content-type'])
print(res.url)

top50_trends = res.json()
top50_trends

# %%
# And let's see only the first 10 trends names and the respective URL
for i, trend in enumerate(top50_trends[0]['trends'][:10]):
    print('{0} - {1} - URL: {2}'.format(i+1, trend['name'], trend['url']))

# %% [markdown]
# ### Example 5: Streaming
#
# **Twitter** offers a [Streaming API](https://dev.twitter.com/streaming/overview) to make it easier to query streams of tweets.  The Stream API encapsulates some pain points of REST access to ensure that Stream calls don't exceed the rate limit. These tool allows to get tweet data when it appears in real time. There are three stream types:
#
# - `Public Streams:` Streams of public data flowthing through **Twitter**. Suitable for followign specific users, topics or for data mining.
# - `User Streams:` Single-user streams. Containing roughly all of the data corresponding with a single user's view of **Twitter**.
# - `Site Streams:` The multi-user version of user streams.
#
# >Connecting to the streaming API requires keeping a persistent HTTP connection open. In many cases this involves thinking about your application differently than if you were interacting with the REST API. An app which connects to the Streaming APIs will not be able to establish a connection in response to a user request. Instead, the code for maintaining the Streaming connection is typically run in a process separate from the process which handles HTTP requests. The streaming process gets the input tweets and performs any parsing, filtering, and/or aggregation needed before storing the result to a data store. The HTTP handling process queries the data store for results in response to user requests. While this model is more complex than the first example, the benefits from having a realtime stream of tweet data make the integration worthwhile for many types of apps.
#
# With `requests.Response.iter_lines()` you can easily iterate over streaming APIs including the **Twitter Streaming API**. Simply set `stream` parameter to `True` and iterate over the response with `iter_lines()`.
#
# Depending on the search term/terms, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#iphone_ hashtag:

# %%
import time
import urllib

query = "#iphone"
encoded_query = urllib.quote_plus(query)
url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=' + encoded_query
res = requests.get(url_5, auth=auth, stream=True)

print(res, res.status_code, res.headers['content-type'])
print(res.url, "\n")

# Let's measure the time elapsed after the start of streaming 
start = time.time()
stop_after = 10
tweets_printed = 0
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line)
        print("Elapsed:", time.time()-start, "sec",  )
                parsed_line["created_at"], "\n", 
                parsed_line['text'].encode("utf-8"), "\n"
        tweets_printed = tweets_printed + 1
        if tweets_printed>stop_after:
            break

print("Time Elapsed for getting", stop_after, " tweets about ", query, " ==>" , time.time()-start)
# Out:
# <Response [200]> 200 application/json
# https://stream.twitter.com/1.1/statuses/filter.json?track=%23iphone
#
# Elapsed: 0.842375040054 sec Sat Feb 06 20:31:59 +0000 2016
# RT @LogicaDigitaI: Ya en #LógicaDigital tenemos gran variedad de forros #UAG para tu #iPhone
#
# Elapsed: 2.57722997665 sec Sat Feb 06 20:32:01 +0000 2016
# RT @IGBundles: #RT Free Final Fantasy II for #iPhone and #android and more #gaming goodies https://t.co/zCsnjQ18Yy #finalfantasy https://t.…
#
# Elapsed: 4.56346416473 sec Sat Feb 06 20:32:03 +0000 2016
# Задание ''Прополка'' завершено! А вы сможете его выполнить? https://t.co/hR6jWPhYqx #iphone,#iphonegames,#gameinsight
#
# Elapsed: 6.47907805443 sec Sat Feb 06 20:32:05 +0000 2016
# Получил награду: Умелый ремонтник https://t.co/VcJWJtaLjD #iphone #iphonegames #gameinsight
#
# Elapsed: 7.86756205559 sec Sat Feb 06 20:32:06 +0000 2016
# I have Lumber Mill on my island! Now my island is even more awesome!  https://t.co/EbEGOXWIsM #iphone, #iphonegames, #gameinsight
#
# Elapsed: 10.6863541603 sec Sat Feb 06 20:32:09 +0000 2016
# I've harvested 1,060 of food!  https://t.co/AMYHIumnpM #iphone, #iphonegames, #gameinsight
#
# Elapsed: 13.0082659721 sec Sat Feb 06 20:32:11 +0000 2016
# @michelecwi @Connecting_SA #CSAsurpriseme #wish #win LOVE all the colours #iPhone ☑
#
# Elapsed: 13.0191111565 sec Sat Feb 06 20:32:11 +0000 2016
# https://t.co/pAwQnDeoD3 - #selfies #iphone #apple #sexy #ipad #macbookair #sex #adult #teen #wow #cleavagesnapchat https://t.co/Aheljc7Afv
#
# Elapsed: 13.8824751377 sec Sat Feb 06 20:32:12 +0000 2016
# Получил награду: Популярный остров! https://t.co/vLDWTRoe7S #iphone #iphonegames #gameinsight
#
# Elapsed: 14.0305030346 sec Sat Feb 06 20:32:12 +0000 2016
# https://t.co/pAwQnDeoD3 - #selfies #iphone #apple #sexy #ipad #macbookair #sex #adult #teen #wow #cleavagesnapchat https://t.co/euXRPNAvoL
#
# Elapsed: 18.2839570045 sec Sat Feb 06 20:32:17 +0000 2016
# #iphone IPHONE 4 LIBRE 16 Gb + Cargador. Regalo 2 Carcasas.:  59,95 EURFecha de finalización: martes feb-16-20... https://t.co/f9elRTC5iK
#
# Time Elapsed for getting 10  tweets about  #iphone  ==> 18.2842490673

# %% [markdown]
# ---
# ## Exercises
# ---

# %% [markdown]
# ## Exercise #1:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display, the list of all your friends and sort them by its followers amounts in descending order.
#
# #### HINT: `GET friends/list`  will be helpfull for you here.

# %% [markdown]
# ## Exercise #2:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library, display the list of 5 (or less if there is not so much) most recent tweets liked by you, which were also retweeted (`retweet_count` is not equal to zero). You shoud show the date of creation, author of the tweet and its text.
#
# #### HINT: `GET favorites/list` will be helpfull for you here

# %% [markdown]
# ## Exercise #3:
#
# > Using [Twitter Streaming API](https://dev.twitter.com/streaming/overview) and `requests` Python library count how many tweets with hashtags _#twitter_, _#tweet_ and _#world_ are appearing each minute over 5 minutes and display these 5 numbers. Please display also the shortest and the longest time period between to closest tweets for all 5 measures.
#
# #### HINT: `POST statuses/filter` will be helpfull for you here
