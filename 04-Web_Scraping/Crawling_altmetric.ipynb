# %% [markdown]
# <a href="https://colab.research.google.com/github/ipeirotis/dealing_with_data/blob/master/04-Web_Scraping/Crawling_altmetric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests # This command allows us to fetch URLs
from lxml import html

# %%
url = "http://www.altmetric.com/top100/2016"
response = requests.get(url) # get the html of that url
doc = html.fromstring(response.text) # parse it and create a document

articles = doc.xpath("//li[@class='article']")

def parseArticle(article):

    title = article.xpath(".//div[@class='title']/h2/a")[0].text_content()

    url = article.xpath(".//div[@class='title']/h2/a/@href")[0]

    abstract = article.xpath(".//div[@class='abstract']")[0].text_content()

    details = article.xpath(".//a[@class='more']/@href")[0]
    
    nodes = article.xpath(".//div[@class='badge']//span[contains(text(), 'news stor')]/strong")
    news = nodes[0].text_content() if len(nodes)>0 else None
    
    nodes = article.xpath(".//div[@class='badge']//span[contains(text(), 'tweet')]/strong")
    tweets = nodes[0].text_content() if len(nodes)>0 else None

    nodes = article.xpath(".//div[@class='badge']//span[contains(text(), 'blog post')]/strong")
    blogs = nodes[0].text_content() if len(nodes)>0 else None

    nodes = article.xpath(".//div[@class='badge']//span[contains(text(), 'article on F1000')]/strong")
    f1000 = nodes[0].text_content() if len(nodes)>0 else None
        
    # blogs = article.xpath(".//div[@class='mentions']//span/strong")[1].text_content()
    return {
        "title": title,
        "url": url,
        "abstract": abstract,
        "details": details,
        "news_mentions": news,
        "tweets": tweets,
        "blogs": blogs,
        "f1000": f1000
    }

# %%
import pandas as pd
data = [parseArticle(article) for article in articles]
df = pd.DataFrame(data)
df
# Out:
#                                                 title  \
# 0   United States Health Care Reform: Progress to ...
# 1   Medical errorâthe third leading cause of dea...
# 2   Observation of Gravitational Waves from a Bina...
# 3   Evidence for a Distant Giant Planet in the Sol...
# 4   Sugar Industry and Coronary Heart Disease Rese...
# ..                                                ...
# 95  Acne and telomere length. A new spectrum betwe...
# 96  Online social integration is associated with r...
# 97  Screening for Colorectal Cancer: US Preventive...
# 98  Impact of meat and Lower Palaeolithic food pro...
# 99  Loneliness and social isolation as risk factor...
#
#                                                 url  \
# 0            https://doi.org/10.1001/jama.2016.9797
# 1                 https://doi.org/10.1136/bmj.i2139
# 2    https://doi.org/10.1103/physrevlett.116.061102
# 3        https://doi.org/10.3847/0004-6256/151/2/22
# 4   https://doi.org/10.1001/jamainternmed.2016.5394
# ..                                              ...
# 95        https://doi.org/10.1016/j.jid.2016.09.014
# 96          https://doi.org/10.1073/pnas.1605554113
# 97           https://doi.org/10.1001/jama.2016.5989
# 98                              http://rdcu.be/m3aC
# 99     https://doi.org/10.1136/heartjnl-2015-309242
#
#                                              abstract  \
# 0   In the first academic paper to be published by...
# 1   Medical error is not included on death certifi...
# 2   The decades-long search for gravitational wave...
# 3   Astrophysicist Mike Brown might have been part...
# 4   Resesarchers from UCSF report that the sugar i...
# ..                                                ...
# 95  This study found a genetic link between acne a...
# 96  How many 'friends' do you have online? This st...
# 97  New recommendations state that screening for c...
# 98  The introduction of meat and new ways of prepa...
# 99  Being lonely has many implications for your me...
#
#                                        details news_mentions tweets blogs  \
# 0    https://www.altmetric.com/details/9612849           315  8,943    45
# 1    https://www.altmetric.com/details/7133536           619  2,615    42
# 2    https://www.altmetric.com/details/5333883           125  4,584    48
# 3    https://www.altmetric.com/details/5017617           536  1,134    63
# 4   https://www.altmetric.com/details/11962797           417  2,252    37
# ..                                         ...           ...    ...   ...
# 95  https://www.altmetric.com/details/12264712           221      3     2
# 96  https://www.altmetric.com/details/13203693           201    404     8
# 97   https://www.altmetric.com/details/8766061           238    522    13
# 98   https://www.altmetric.com/details/6147547           186    279    18
# 99   https://www.altmetric.com/details/6822879           201     24     6
#
#    f1000
# 0      1
# 1   None
# 2   None
# 3   None
# 4      1
# ..   ...
# 95  None
# 96  None
# 97  None
# 98  None
# 99  None
#
# [100 rows x 8 columns]
